# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "doduyquy211@gmail.com"
# !git config --global user.name "doduyquy"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
DATASET_NAME_KAGGLE = 'fer13-split'
PATH_DATASET_KAGGLE = f"/kaggle/input/datasets/doduyquynii/{DATASET_NAME_KAGGLE}"

CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
print("Dataset path:",PATH_DATASET_KAGGLE)
# Out:
# Secret ok
# --- Repo đã có, đang cập nhật bản mới nhất ---
# /kaggle/working/sgu-2026-facial-expression-recognition
# From https://github.com/doduyquy/sgu-2026-facial-expression-recognition
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition
# Dataset path: /kaggle/input/datasets/doduyquynii/fer13-split

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config simple_cnn --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: doduyquy (doduyquy-sgu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run 4w2pgees (0.2s)
# wandb: ⣾ setting up run 4w2pgees (0.2s)
# wandb: ⣷ setting up run 4w2pgees (0.2s)
# wandb: ⣯ setting up run 4w2pgees (0.2s)
# wandb: ⣟ setting up run 4w2pgees (0.2s)
# wandb: ⡿ setting up run 4w2pgees (0.7s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260331_090354-4w2pgees
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run simple_cnn_31032026_0903
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/4w2pgees
#
# --> Start training in total 101 epochs with cuda device. Start...
#
#
# 	--- Epoch 1/101
# Training: 100%|███████████████████████████████| 449/449 [00:18<00:00, 24.78it/s]
# 		 + Train loss: 1.7567 | Train acc: 0.2903
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.19it/s]
# 		 + Val loss: 1.5735 | Val acc: 0.3931
#
# 	--- Save best at 0 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 2/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.35it/s]
# 		 + Train loss: 1.6121 | Train acc: 0.3703
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.83it/s]
# 		 + Val loss: 1.4619 | Val acc: 0.4486
#
# 	--- Save best at 1 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 3/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.17it/s]
# 		 + Train loss: 1.5134 | Train acc: 0.4114
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.36it/s]
# 		 + Val loss: 1.3947 | Val acc: 0.4528
#
# 	--- Save best at 2 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 4/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.27it/s]
# 		 + Train loss: 1.4241 | Train acc: 0.4505
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.01it/s]
# 		 + Val loss: 1.3015 | Val acc: 0.4971
#
# 	--- Save best at 3 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 5/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.18it/s]
# 		 + Train loss: 1.3650 | Train acc: 0.4753
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.03it/s]
# 		 + Val loss: 1.2487 | Val acc: 0.5091
#
# 	--- Save best at 4 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 6/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.43it/s]
# 		 + Train loss: 1.3135 | Train acc: 0.4970
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.10it/s]
# 		 + Val loss: 1.1986 | Val acc: 0.5319
#
# 	--- Save best at 5 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 7/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.66it/s]
# 		 + Train loss: 1.2775 | Train acc: 0.5122
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.56it/s]
# 		 + Val loss: 1.2086 | Val acc: 0.5472
# 	-!- No improvement: 1/10
#
# 	--- Epoch 8/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.58it/s]
# 		 + Train loss: 1.2502 | Train acc: 0.5220
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.76it/s]
# 		 + Val loss: 1.1254 | Val acc: 0.5662
#
# 	--- Save best at 7 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 9/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.35it/s]
# 		 + Train loss: 1.2272 | Train acc: 0.5350
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.16it/s]
# 		 + Val loss: 1.1389 | Val acc: 0.5628
# 	-!- No improvement: 1/10
#
# 	--- Epoch 10/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.21it/s]
# 		 + Train loss: 1.2090 | Train acc: 0.5412
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.83it/s]
# 		 + Val loss: 1.0947 | Val acc: 0.5784
#
# 	--- Save best at 9 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 11/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.35it/s]
# 		 + Train loss: 1.2028 | Train acc: 0.5485
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.38it/s]
# 		 + Val loss: 1.1106 | Val acc: 0.5704
# 	-!- No improvement: 1/10
#
# 	--- Epoch 12/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.07it/s]
# 		 + Train loss: 1.1838 | Train acc: 0.5492
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.30it/s]
# 		 + Val loss: 1.0770 | Val acc: 0.5896
#
# 	--- Save best at 11 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 13/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.37it/s]
# 		 + Train loss: 1.1724 | Train acc: 0.5583
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.20it/s]
# 		 + Val loss: 1.0743 | Val acc: 0.5907
#
# 	--- Save best at 12 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 14/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.53it/s]
# 		 + Train loss: 1.1659 | Train acc: 0.5623
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.05it/s]
# 		 + Val loss: 1.1096 | Val acc: 0.5837
# 	-!- No improvement: 1/10
#
# 	--- Epoch 15/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.87it/s]
# 		 + Train loss: 1.1466 | Train acc: 0.5697
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.42it/s]
# 		 + Val loss: 1.0644 | Val acc: 0.5946
#
# 	--- Save best at 14 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 16/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.48it/s]
# 		 + Train loss: 1.1417 | Train acc: 0.5669
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 46.13it/s]
# 		 + Val loss: 1.0555 | Val acc: 0.6027
#
# 	--- Save best at 15 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 17/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.53it/s]
# 		 + Train loss: 1.1407 | Train acc: 0.5714
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.91it/s]
# 		 + Val loss: 1.0687 | Val acc: 0.5907
# 	-!- No improvement: 1/10
#
# 	--- Epoch 18/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.07it/s]
# 		 + Train loss: 1.1224 | Train acc: 0.5779
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.22it/s]
# 		 + Val loss: 1.0367 | Val acc: 0.6035
#
# 	--- Save best at 17 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 19/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.54it/s]
# 		 + Train loss: 1.1197 | Train acc: 0.5818
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.43it/s]
# 		 + Val loss: 1.0268 | Val acc: 0.6049
#
# 	--- Save best at 18 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 20/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.73it/s]
# 		 + Train loss: 1.1144 | Train acc: 0.5808
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.73it/s]
# 		 + Val loss: 1.0479 | Val acc: 0.5954
# 	-!- No improvement: 1/10
#
# 	--- Epoch 21/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.18it/s]
# 		 + Train loss: 1.1045 | Train acc: 0.5859
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.74it/s]
# 		 + Val loss: 1.0201 | Val acc: 0.6082
#
# 	--- Save best at 20 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 22/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.98it/s]
# 		 + Train loss: 1.1050 | Train acc: 0.5869
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 46.24it/s]
# 		 + Val loss: 1.0268 | Val acc: 0.6127
# 	-!- No improvement: 1/10
#
# 	--- Epoch 23/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 28.03it/s]
# 		 + Train loss: 1.0992 | Train acc: 0.5892
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.50it/s]
# 		 + Val loss: 1.0090 | Val acc: 0.6194
#
# 	--- Save best at 22 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 24/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.97it/s]
# 		 + Train loss: 1.0960 | Train acc: 0.5884
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.74it/s]
# 		 + Val loss: 1.0163 | Val acc: 0.6197
# 	-!- No improvement: 1/10
#
# 	--- Epoch 25/101
# Training: 100%|███████████████████████████████| 449/449 [00:15<00:00, 28.14it/s]
# 		 + Train loss: 1.0922 | Train acc: 0.5910
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.30it/s]
# 		 + Val loss: 1.0149 | Val acc: 0.6127
# 	-!- No improvement: 2/10
#
# 	--- Epoch 26/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 26.60it/s]
# 		 + Train loss: 1.0813 | Train acc: 0.5951
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 40.79it/s]
# 		 + Val loss: 1.0090 | Val acc: 0.6186
#
# 	--- Save best at 25 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 27/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 26.92it/s]
# 		 + Train loss: 1.0868 | Train acc: 0.5952
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.20it/s]
# 		 + Val loss: 1.0143 | Val acc: 0.6219
# 	-!- No improvement: 1/10
#
# 	--- Epoch 28/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.43it/s]
# 		 + Train loss: 1.0751 | Train acc: 0.5947
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.54it/s]
# 		 + Val loss: 1.0003 | Val acc: 0.6213
#
# 	--- Save best at 27 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 29/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.07it/s]
# 		 + Train loss: 1.0768 | Train acc: 0.5955
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.27it/s]
# 		 + Val loss: 0.9983 | Val acc: 0.6266
#
# 	--- Save best at 28 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 30/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.53it/s]
# 		 + Train loss: 1.0744 | Train acc: 0.5950
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.73it/s]
# 		 + Val loss: 1.0428 | Val acc: 0.6066
# 	-!- No improvement: 1/10
#
# 	--- Epoch 31/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.09it/s]
# 		 + Train loss: 1.0621 | Train acc: 0.6018
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.04it/s]
# 		 + Val loss: 1.0094 | Val acc: 0.6227
# 	-!- No improvement: 2/10
#
# 	--- Epoch 32/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.33it/s]
# 		 + Train loss: 1.0665 | Train acc: 0.6007
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.75it/s]
# 		 + Val loss: 0.9923 | Val acc: 0.6236
#
# 	--- Save best at 31 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 33/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.29it/s]
# 		 + Train loss: 1.0605 | Train acc: 0.5996
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.45it/s]
# 		 + Val loss: 0.9932 | Val acc: 0.6225
# 	-!- No improvement: 1/10
#
# 	--- Epoch 34/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.58it/s]
# 		 + Train loss: 1.0584 | Train acc: 0.6015
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.36it/s]
# 		 + Val loss: 1.0173 | Val acc: 0.6169
# 	-!- No improvement: 2/10
#
# 	--- Epoch 35/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.10it/s]
# 		 + Train loss: 1.0493 | Train acc: 0.6046
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.62it/s]
# 		 + Val loss: 1.0100 | Val acc: 0.6225
# 	-!- No improvement: 3/10
#
# 	--- Epoch 36/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.17it/s]
# 		 + Train loss: 1.0545 | Train acc: 0.6079
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.44it/s]
# 		 + Val loss: 1.0246 | Val acc: 0.6194
# 	-!- No improvement: 4/10
#
# 	--- Epoch 37/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.38it/s]
# 		 + Train loss: 1.0541 | Train acc: 0.6014
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.25it/s]
# 		 + Val loss: 1.0075 | Val acc: 0.6247
# 	-!- No improvement: 5/10
#
# 	--- Epoch 38/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.25it/s]
# 		 + Train loss: 1.0493 | Train acc: 0.6064
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.81it/s]
# 		 + Val loss: 0.9966 | Val acc: 0.6202
# 	-!- No improvement: 6/10
#
# 	--- Epoch 39/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.44it/s]
# 		 + Train loss: 1.0497 | Train acc: 0.6044
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.43it/s]
# 		 + Val loss: 0.9748 | Val acc: 0.6330
#
# 	--- Save best at 38 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 40/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.62it/s]
# 		 + Train loss: 1.0407 | Train acc: 0.6087
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.09it/s]
# 		 + Val loss: 0.9777 | Val acc: 0.6325
# 	-!- No improvement: 1/10
#
# 	--- Epoch 41/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.48it/s]
# 		 + Train loss: 1.0436 | Train acc: 0.6073
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 44.23it/s]
# 		 + Val loss: 0.9653 | Val acc: 0.6364
#
# 	--- Save best at 40 epoch, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
#
#
# 	--- Epoch 42/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.71it/s]
# 		 + Train loss: 1.0446 | Train acc: 0.6071
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.47it/s]
# 		 + Val loss: 0.9771 | Val acc: 0.6294
# 	-!- No improvement: 1/10
#
# 	--- Epoch 43/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.86it/s]
# 		 + Train loss: 1.0394 | Train acc: 0.6083
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 45.27it/s]
# 		 + Val loss: 0.9654 | Val acc: 0.6347
# 	-!- No improvement: 2/10
#
# 	--- Epoch 44/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.68it/s]
# 		 + Train loss: 1.0403 | Train acc: 0.6083
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.08it/s]
# 		 + Val loss: 0.9772 | Val acc: 0.6347
# 	-!- No improvement: 3/10
#
# 	--- Epoch 45/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.40it/s]
# 		 + Train loss: 1.0357 | Train acc: 0.6121
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.36it/s]
# 		 + Val loss: 0.9791 | Val acc: 0.6364
# 	-!- No improvement: 4/10
#
# 	--- Epoch 46/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.54it/s]
# 		 + Train loss: 1.0368 | Train acc: 0.6132
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.21it/s]
# 		 + Val loss: 0.9708 | Val acc: 0.6378
# 	-!- No improvement: 5/10
#
# 	--- Epoch 47/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.99it/s]
# 		 + Train loss: 1.0382 | Train acc: 0.6125
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.58it/s]
# 		 + Val loss: 0.9689 | Val acc: 0.6328
# 	-!- No improvement: 6/10
#
# 	--- Epoch 48/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.34it/s]
# 		 + Train loss: 1.0297 | Train acc: 0.6168
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.76it/s]
# 		 + Val loss: 1.0028 | Val acc: 0.6255
# 	-!- No improvement: 7/10
#
# 	--- Epoch 49/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.59it/s]
# 		 + Train loss: 1.0228 | Train acc: 0.6148
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.17it/s]
# 		 + Val loss: 1.0187 | Val acc: 0.6213
# 	-!- No improvement: 8/10
#
# 	--- Epoch 50/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.73it/s]
# 		 + Train loss: 1.0259 | Train acc: 0.6172
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 43.73it/s]
# 		 + Val loss: 0.9699 | Val acc: 0.6303
# 	-!- No improvement: 9/10
#
# 	--- Epoch 51/101
# Training: 100%|███████████████████████████████| 449/449 [00:16<00:00, 27.53it/s]
# 		 + Train loss: 1.0264 | Train acc: 0.6156
# Validating: 100%|███████████████████████████████| 57/57 [00:01<00:00, 42.46it/s]
# 		 + Val loss: 0.9890 | Val acc: 0.6291
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=50
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_0903_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 44.14it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 64.53%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.566116  0.558045  0.562051   491.000000
# disgust        0.647059  0.200000  0.305556    55.000000
# fear           0.541219  0.285985  0.374226   528.000000
# happy          0.817904  0.914676  0.863588   879.000000
# sad            0.466006  0.553872  0.506154   594.000000
# surprise       0.696017  0.798077  0.743561   416.000000
# neutral        0.645412  0.662939  0.654058   626.000000
# accuracy       0.645305  0.645305  0.645305     0.645305
# macro avg      0.625676  0.567656  0.572742  3589.000000
# weighted avg   0.637679  0.645305  0.632175  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 		DONE!
#
# wandb:
# wandb: 🚀 View run simple_cnn_31032026_0903 at: https://wandb.ai/phucga15062005/FER2013/runs/4w2pgees
# wandb: Find logs at: wandb/run-20260331_090354-4w2pgees/logs

# %% [markdown]
# # The end
# ---
