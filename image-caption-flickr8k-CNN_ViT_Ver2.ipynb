# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 8095

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "image-captioning-flickr8k-iu"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'image-captioning-flickr8k-iu'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 172 (delta 78), reused 134 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 46.96 KiB | 1.30 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# Repo ready: /kaggle/working/image-captioning-flickr8k-iu
#
# Current working dir: /kaggle/working/image-captioning-flickr8k-iu

# %%
# !python -m scripts.train --config transformer --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Image Dir: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/images
# --> Captions File: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/captions.txt
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 215MB/s]
# --> [Scheduler] StepLR (step_size=5, gamma=0.5)
#
# --> Train on 30000 samples, validate on 5000 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run k6iem9b9 (0.2s)
# wandb: ⣽ setting up run k6iem9b9 (0.2s)
# wandb: ⣾ setting up run k6iem9b9 (0.2s)
# wandb: ⣷ setting up run k6iem9b9 (0.2s)
# wandb: ⣯ setting up run k6iem9b9 (0.2s)
# wandb: ⣟ setting up run k6iem9b9 (0.7s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/image-captioning-flickr8k-iu/wandb/run-20260408_062405-k6iem9b9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_08042026_0623
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/image-captioning
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/image-captioning/runs/k6iem9b9
#
# --> Start training in total 20 epochs with cuda device. Start...
#
# Epoch 1/20 - loss: 3.7752 - val_loss: 3.2618
# 	--- Save best at ep 1, val_loss: 3.2618, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 2/20 - loss: 3.0274 - val_loss: 2.9813
# 	--- Save best at ep 2, val_loss: 2.9813, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 3/20 - loss: 2.7515 - val_loss: 2.8525
# 	--- Save best at ep 3, val_loss: 2.8525, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 4/20 - loss: 2.5739 - val_loss: 2.7845
# 	--- Save best at ep 4, val_loss: 2.7845, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 5/20 - loss: 2.4362 - val_loss: 2.7525
# 	--- Save best at ep 5, val_loss: 2.7525, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 6/20 - loss: 2.2894 - val_loss: 2.7128
# 	--- Save best at ep 6, val_loss: 2.7128, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 7/20 - loss: 2.2304 - val_loss: 2.7229
# 	-!- No improvement: 1/10
# Epoch 8/20 - loss: 2.1768 - val_loss: 2.7111
# 	--- Save best at ep 8, val_loss: 2.7111, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 9/20 - loss: 2.1275 - val_loss: 2.7079
# 	--- Save best at ep 9, val_loss: 2.7079, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0623_best.pth ---
# Epoch 10/20 - loss: 2.0823 - val_loss: 2.7163
# 	-!- No improvement: 1/10
# Epoch 11/20 - loss: 2.0182 - val_loss: 2.7130
# 	-!- No improvement: 2/10
# Epoch 12/20 - loss: 1.9921 - val_loss: 2.7174
# 	-!- No improvement: 3/10
# Epoch 13/20 - loss: 1.9697 - val_loss: 2.7228
# 	-!- No improvement: 4/10
# Epoch 14/20 - loss: 1.9485 - val_loss: 2.7295
# 	-!- No improvement: 5/10
# Epoch 15/20 - loss: 1.9278 - val_loss: 2.7308
# 	-!- No improvement: 6/10
# Epoch 16/20 - loss: 1.8947 - val_loss: 2.7337
# 	-!- No improvement: 7/10
# Epoch 17/20 - loss: 1.8830 - val_loss: 2.7399
# 	-!- No improvement: 8/10
# Epoch 18/20 - loss: 1.8715 - val_loss: 2.7390
# 	-!- No improvement: 9/10
# Epoch 19/20 - loss: 1.8614 - val_loss: 2.7456
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=19
#
# ===================================================
# Evaluate on Test set
# ===================================================
# --> [Evaluation] Đang đánh giá trên 5000 mẫu (greedy)...
# 100%|█████████████████████████████████████████| 157/157 [02:14<00:00,  1.16it/s]
#    BLEU-1: 0.3191
#    BLEU-2: 0.1561
#    BLEU-3: 0.0935
#    BLEU-4: 0.0617
#
# Ví dụ 1:
#   Gốc: a blond woman in a blue shirt appears to wait for a ride .
#   Dự đoán: a girl in a blue shirt is looking down .
# Figure(1000x800)
#
# Ví dụ 2:
#   Gốc: a small dogs ears stick up as it runs in the grass .
#   Dự đoán: a small tan dog is running on the grass .
# Figure(1000x800)
#
# Ví dụ 3:
#   Gốc: three people in the snow put their gear in <unk> .
#   Dự đoán: a group of people are sitting on a sled <unk> in the snow .
# Figure(1000x800)
#
# Ví dụ 4:
#   Gốc: three children playing in sand at beach
#   Dự đoán: a girl in a pink shirt and a girl in a pink shirt .
# Figure(1000x800)
#
# Ví dụ 5:
#   Gốc: two women and a child are sitting by a cart of <unk> in front of a booth at a medieval <unk> .
#   Dự đoán: a group of people are riding on a street .
# Figure(1000x800)
#
# Ví dụ 6:
#   Gốc: a man sleeping with a bag on his lap on public <unk>
#   Dự đoán: a man in a black shirt is looking at a <unk> .
# Figure(1000x800)
#
# Ví dụ 7:
#   Gốc: a young girl balances on wooden <unk> at the beach .
#   Dự đoán: a boy in a blue shirt is jumping off a beach .
# Figure(1000x800)
#
# Ví dụ 8:
#   Gốc: two women sitting in the grass with their bikes behind them .
#   Dự đoán: three people are riding on a dirt path .
# Figure(1000x800)
#
# Ví dụ 9:
#   Gốc: a little girl in a flowered <unk> runs through the sand at the beach
#   Dự đoán: a young boy in a bathing suit runs on the beach .
# Figure(1000x800)
#
# Ví dụ 10:
#   Gốc: person hiking up a grassy trail toward a large hill .
#   Dự đoán: a man in a blue shirt and blue jeans is standing on a grassy field .
# Figure(1000x800)
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `transformer_08042026_0623_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (0.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (0.5s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (0.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (0.5s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (0.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (1.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (1.0s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (1.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (1.0s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.0s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (1.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (1.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (1.5s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.5s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (1.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (1.5s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.5s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (1.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 1.0MB/178.2MB (0.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (2.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 1.1MB/178.2MB (1.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (2.0s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 1.1MB/178.2MB (1.0s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (2.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 1.1MB/178.2MB (1.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (2.0s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 1.1MB/178.2MB (1.0s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (2.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 1.1MB/178.2MB (1.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (2.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 1.2MB/178.2MB (1.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (2.5s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 1.2MB/178.2MB (1.5s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (2.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 1.2MB/178.2MB (1.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (2.5s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 1.2MB/178.2MB (1.5s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (2.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 1.2MB/178.2MB (1.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (3.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 1.8MB/178.2MB (2.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (3.0s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 1.8MB/178.2MB (2.0s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (3.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 1.8MB/178.2MB (2.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (3.0s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 1.8MB/178.2MB (2.0s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (3.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 1.8MB/178.2MB (2.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (3.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 3.2MB/178.2MB (2.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (3.5s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 3.2MB/178.2MB (2.5s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (3.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 3.2MB/178.2MB (2.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (3.5s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 3.2MB/178.2MB (2.5s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (3.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 3.2MB/178.2MB (2.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (4.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 10.9MB/178.2MB (3.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (4.0s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 10.9MB/178.2MB (3.0s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (4.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 10.9MB/178.2MB (3.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (4.0s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 10.9MB/178.2MB (3.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (4.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 10.9MB/178.2MB (3.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (4.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 21.7MB/178.2MB (3.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (4.5s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 21.7MB/178.2MB (3.5s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (4.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 21.7MB/178.2MB (3.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (4.5s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 21.7MB/178.2MB (3.5s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (4.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 21.7MB/178.2MB (3.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (5.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 32.4MB/178.2MB (4.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (5.0s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 32.4MB/178.2MB (4.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (5.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 32.4MB/178.2MB (4.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (5.0s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 32.4MB/178.2MB (4.0s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (5.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 32.4MB/178.2MB (4.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (5.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 42.4MB/178.2MB (4.5s)
# wandb: ⣟ uploading output.log 4.6KB/4.6KB (0.3s)
# wandb: ⣟ uploading wandb-summary.json 196B/196B (0.3s)
# wandb: ⣟ uploading config.yaml 3.6KB/3.6KB (0.3s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (5.5s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 42.4MB/178.2MB (4.5s)
# wandb: ⡿ uploading output.log 4.6KB/4.6KB (0.3s)
# wandb: ⡿ uploading wandb-summary.json 196B/196B (0.3s)
# wandb: ⡿ uploading config.yaml 3.6KB/3.6KB (0.3s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (5.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 42.4MB/178.2MB (4.5s)
# wandb: ⢿ uploading output.log 4.6KB/4.6KB (0.3s)
# wandb: ⢿ uploading wandb-summary.json 196B/196B (0.3s)
# wandb: ⢿ uploading config.yaml 3.6KB/3.6KB (0.3s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (5.5s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 42.4MB/178.2MB (4.5s)
# wandb: ⣻ uploading output.log 4.6KB/4.6KB (0.3s)
# wandb: ⣻ uploading wandb-summary.json 196B/196B (0.3s)
# wandb: ⣻ uploading config.yaml 3.6KB/3.6KB (0.3s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (5.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 42.4MB/178.2MB (4.5s)
# wandb: ⣽ uploading output.log 4.6KB/4.6KB (0.3s)
# wandb: ⣽ uploading wandb-summary.json 196B/196B (0.3s)
# wandb: ⣽ uploading config.yaml 3.6KB/3.6KB (0.3s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (6.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 52.9MB/178.2MB (5.0s)
# wandb: ⣾ uploading wandb-summary.json 196B/196B (0.8s)
# wandb: ⣾ uploading config.yaml 3.6KB/3.6KB (0.8s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (6.0s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 52.9MB/178.2MB (5.0s)
# wandb: ⣷ uploading wandb-summary.json 196B/196B (0.8s)
# wandb: ⣷ uploading config.yaml 3.6KB/3.6KB (0.8s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (6.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 52.9MB/178.2MB (5.0s)
# wandb: ⣯ uploading wandb-summary.json 196B/196B (0.8s)
# wandb: ⣯ uploading config.yaml 3.6KB/3.6KB (0.8s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (6.0s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 52.9MB/178.2MB (5.0s)
# wandb: ⣟ uploading wandb-summary.json 196B/196B (0.8s)
# wandb: ⣟ uploading config.yaml 3.6KB/3.6KB (0.8s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (6.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 52.9MB/178.2MB (5.0s)
# wandb: ⡿ uploading wandb-summary.json 196B/196B (0.8s)
# wandb: ⡿ uploading config.yaml 3.6KB/3.6KB (0.8s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (6.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 62.4MB/178.2MB (5.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (6.5s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 62.4MB/178.2MB (5.5s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (6.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 62.4MB/178.2MB (5.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (6.5s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 62.4MB/178.2MB (5.5s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (6.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 62.4MB/178.2MB (5.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (7.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 72.4MB/178.2MB (6.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (7.0s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 72.4MB/178.2MB (6.0s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (7.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 72.4MB/178.2MB (6.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (7.0s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 72.4MB/178.2MB (6.0s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (7.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 72.4MB/178.2MB (6.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (7.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 80.9MB/178.2MB (6.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (7.5s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 80.9MB/178.2MB (6.5s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (7.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 80.9MB/178.2MB (6.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (7.5s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 80.9MB/178.2MB (6.5s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (7.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 80.9MB/178.2MB (6.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (8.0s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 91.4MB/178.2MB (7.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (8.0s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 91.4MB/178.2MB (7.0s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (8.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 91.4MB/178.2MB (7.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (8.0s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 91.4MB/178.2MB (7.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (8.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 91.4MB/178.2MB (7.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (8.5s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 100.9MB/178.2MB (7.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (8.5s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 100.9MB/178.2MB (7.5s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (8.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 100.9MB/178.2MB (7.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (8.5s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 100.9MB/178.2MB (7.5s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (8.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 100.9MB/178.2MB (7.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (9.0s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 111.2MB/178.2MB (8.0s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (9.0s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 111.2MB/178.2MB (8.0s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (9.0s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 111.2MB/178.2MB (8.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (9.0s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 111.2MB/178.2MB (8.0s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (9.0s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 111.2MB/178.2MB (8.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (9.5s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 120.9MB/178.2MB (8.5s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (9.5s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 120.9MB/178.2MB (8.5s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (9.5s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 120.9MB/178.2MB (8.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (9.5s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 120.9MB/178.2MB (8.5s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (9.5s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 120.9MB/178.2MB (8.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (10s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 130.9MB/178.2MB (9.0s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (10s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 130.9MB/178.2MB (9.0s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (10s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 130.9MB/178.2MB (9.0s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (10s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 130.9MB/178.2MB (9.0s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (10s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 130.9MB/178.2MB (9.0s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 140.7MB/178.2MB (9.5s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 140.7MB/178.2MB (9.5s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 140.7MB/178.2MB (9.5s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 140.7MB/178.2MB (9.5s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 140.7MB/178.2MB (9.5s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 150.9MB/178.2MB (10s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 150.9MB/178.2MB (10s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 150.9MB/178.2MB (10s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 150.9MB/178.2MB (10s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (11s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 150.9MB/178.2MB (10s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 160.4MB/178.2MB (11s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 160.4MB/178.2MB (11s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 160.4MB/178.2MB (11s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 160.4MB/178.2MB (11s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 160.4MB/178.2MB (11s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 168.4MB/178.2MB (11s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 168.4MB/178.2MB (11s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣻ transformer_08042026_0623_best.pth 168.4MB/178.2MB (11s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣽ transformer_08042026_0623_best.pth 168.4MB/178.2MB (11s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (12s)
# wandb:   ↳ ⣾ transformer_08042026_0623_best.pth 168.4MB/178.2MB (11s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (13s)
# wandb:   ↳ ⣷ transformer_08042026_0623_best.pth 176.4MB/178.2MB (12s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (13s)
# wandb:   ↳ ⣯ transformer_08042026_0623_best.pth 176.4MB/178.2MB (12s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (13s)
# wandb:   ↳ ⣟ transformer_08042026_0623_best.pth 176.4MB/178.2MB (12s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (13s)
# wandb:   ↳ ⡿ transformer_08042026_0623_best.pth 176.4MB/178.2MB (12s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (13s)
# wandb:   ↳ ⢿ transformer_08042026_0623_best.pth 176.4MB/178.2MB (12s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (13s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (13s)
# wandb: ⣾ uploading artifact cnn_k6iem9b9 (13s)
# wandb: ⣷ uploading artifact cnn_k6iem9b9 (13s)
# wandb: ⣯ uploading artifact cnn_k6iem9b9 (13s)
# wandb: ⣟ uploading artifact cnn_k6iem9b9 (14s)
# wandb: ⡿ uploading artifact cnn_k6iem9b9 (14s)
# wandb: ⢿ uploading artifact cnn_k6iem9b9 (14s)
# wandb: ⣻ uploading artifact cnn_k6iem9b9 (14s)
# wandb: ⣽ uploading artifact cnn_k6iem9b9 (14s)
# wandb: ⣾ uploading data (0.2s)
# wandb: ⣷ uploading data (0.2s)
# wandb:
# wandb: Run history:
# wandb:         Epoch ▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██
# wandb: Learning_Rate █████▄▄▄▄▄▂▂▂▂▂▁▁▁▁
# wandb:    Train/Loss █▅▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:      Val/Loss █▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:         Epoch 19
# wandb: Learning_Rate 1e-05
# wandb:    Train/Loss 1.86138
# wandb:      Val/Loss 2.74561
# wandb:
# wandb: 🚀 View run transformer_08042026_0623 at: https://wandb.ai/phucga15062005/image-captioning/runs/k6iem9b9
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/image-captioning
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260408_062405-k6iem9b9/logs
#
# 		DONE!
#
#
# 		DONE!
