# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1007, done.
# remote: Counting objects: 100% (256/256), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 1007 (delta 192), reused 170 (delta 130), pack-reused 751 (from 2)
# Receiving objects: 100% (1007/1007), 5.91 MiB | 22.49 MiB/s, done.
# Resolving deltas: 100% (632/632), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config vgg_spatial_fusion_transformers --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 0kva6xx7 (0.3s)
# wandb: ⣷ setting up run 0kva6xx7 (0.3s)
# wandb: ⣯ setting up run 0kva6xx7 (0.3s)
# wandb: ⣟ setting up run 0kva6xx7 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_131926-0kva6xx7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_transformer_10042026_1319
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/0kva6xx7
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.1686 - accuracy: 0.1131 - val_loss: 2.1486 - val_accuracy: 0.3235
# 	--- Save best at ep 1, val_loss: 2.1486, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 2/100 - loss: 2.0128 - accuracy: 0.2298 - val_loss: 1.9023 - val_accuracy: 0.3564
# 	--- Save best at ep 2, val_loss: 1.9023, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 3/100 - loss: 1.9232 - accuracy: 0.3096 - val_loss: 1.8279 - val_accuracy: 0.3653
# 	--- Save best at ep 3, val_loss: 1.8279, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 4/100 - loss: 1.8526 - accuracy: 0.3697 - val_loss: 1.7525 - val_accuracy: 0.4489
# 	--- Save best at ep 4, val_loss: 1.7525, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 5/100 - loss: 1.8056 - accuracy: 0.4046 - val_loss: 1.7688 - val_accuracy: 0.4767
# 	-!- No improvement: 1/20
# Epoch 6/100 - loss: 1.7719 - accuracy: 0.4325 - val_loss: 1.8408 - val_accuracy: 0.3756
# 	-!- No improvement: 2/20
# Epoch 7/100 - loss: 1.7495 - accuracy: 0.4442 - val_loss: 1.7030 - val_accuracy: 0.5015
# 	--- Save best at ep 7, val_loss: 1.7030, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 8/100 - loss: 1.7239 - accuracy: 0.4678 - val_loss: 1.6977 - val_accuracy: 0.4667
# 	--- Save best at ep 8, val_loss: 1.6977, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 9/100 - loss: 1.7082 - accuracy: 0.4794 - val_loss: 1.7018 - val_accuracy: 0.4349
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 1.6872 - accuracy: 0.4909 - val_loss: 1.6769 - val_accuracy: 0.5121
# 	--- Save best at ep 10, val_loss: 1.6769, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 11/100 - loss: 1.6717 - accuracy: 0.4968 - val_loss: 1.7028 - val_accuracy: 0.4558
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 1.6568 - accuracy: 0.5102 - val_loss: 1.6237 - val_accuracy: 0.5288
# 	--- Save best at ep 12, val_loss: 1.6237, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 13/100 - loss: 1.6500 - accuracy: 0.5132 - val_loss: 1.6412 - val_accuracy: 0.5534
# 	-!- No improvement: 1/20
# Epoch 14/100 - loss: 1.6249 - accuracy: 0.5260 - val_loss: 1.6171 - val_accuracy: 0.5656
# 	--- Save best at ep 14, val_loss: 1.6171, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 15/100 - loss: 1.6177 - accuracy: 0.5313 - val_loss: 1.6260 - val_accuracy: 0.5678
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 1.6104 - accuracy: 0.5378 - val_loss: 1.5686 - val_accuracy: 0.5648
# 	--- Save best at ep 16, val_loss: 1.5686, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 17/100 - loss: 1.6038 - accuracy: 0.5424 - val_loss: 1.6523 - val_accuracy: 0.4985
# 	-!- No improvement: 1/20
# Epoch 18/100 - loss: 1.5916 - accuracy: 0.5507 - val_loss: 1.5693 - val_accuracy: 0.5709
# 	-!- No improvement: 2/20
# Epoch 19/100 - loss: 1.5752 - accuracy: 0.5549 - val_loss: 1.5631 - val_accuracy: 0.5687
# 	--- Save best at ep 19, val_loss: 1.5631, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 20/100 - loss: 1.5743 - accuracy: 0.5523 - val_loss: 1.5525 - val_accuracy: 0.5837
# 	--- Save best at ep 20, val_loss: 1.5525, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 21/100 - loss: 1.5651 - accuracy: 0.5633 - val_loss: 1.5442 - val_accuracy: 0.5756
# 	--- Save best at ep 21, val_loss: 1.5442, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 22/100 - loss: 1.5558 - accuracy: 0.5659 - val_loss: 1.6086 - val_accuracy: 0.5787
# 	-!- No improvement: 1/20
# Epoch 23/100 - loss: 1.5484 - accuracy: 0.5723 - val_loss: 1.5519 - val_accuracy: 0.5887
# 	-!- No improvement: 2/20
# Epoch 24/100 - loss: 1.5429 - accuracy: 0.5732 - val_loss: 1.5394 - val_accuracy: 0.5943
# 	--- Save best at ep 24, val_loss: 1.5394, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 25/100 - loss: 1.5369 - accuracy: 0.5763 - val_loss: 1.5287 - val_accuracy: 0.5938
# 	--- Save best at ep 25, val_loss: 1.5287, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 26/100 - loss: 1.5274 - accuracy: 0.5792 - val_loss: 1.5466 - val_accuracy: 0.5996
# 	-!- No improvement: 1/20
# Epoch 27/100 - loss: 1.5204 - accuracy: 0.5845 - val_loss: 1.5162 - val_accuracy: 0.6049
# 	--- Save best at ep 27, val_loss: 1.5162, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 28/100 - loss: 1.5161 - accuracy: 0.5876 - val_loss: 1.5064 - val_accuracy: 0.5999
# 	--- Save best at ep 28, val_loss: 1.5064, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 29/100 - loss: 1.5055 - accuracy: 0.5924 - val_loss: 1.5075 - val_accuracy: 0.6108
# 	-!- No improvement: 1/20
# Epoch 30/100 - loss: 1.5020 - accuracy: 0.5949 - val_loss: 1.5110 - val_accuracy: 0.6258
# 	-!- No improvement: 2/20
# Epoch 31/100 - loss: 1.5027 - accuracy: 0.5982 - val_loss: 1.5383 - val_accuracy: 0.5940
# 	-!- No improvement: 3/20
# Epoch 32/100 - loss: 1.4903 - accuracy: 0.6006 - val_loss: 1.5276 - val_accuracy: 0.6180
# 	-!- No improvement: 4/20
# Epoch 33/100 - loss: 1.4628 - accuracy: 0.6166 - val_loss: 1.4946 - val_accuracy: 0.6289
# 	--- Save best at ep 33, val_loss: 1.4946, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 34/100 - loss: 1.4501 - accuracy: 0.6219 - val_loss: 1.4808 - val_accuracy: 0.6311
# 	--- Save best at ep 34, val_loss: 1.4808, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 35/100 - loss: 1.4388 - accuracy: 0.6249 - val_loss: 1.4749 - val_accuracy: 0.6322
# 	--- Save best at ep 35, val_loss: 1.4749, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 36/100 - loss: 1.4350 - accuracy: 0.6291 - val_loss: 1.4841 - val_accuracy: 0.6328
# 	-!- No improvement: 1/20
# Epoch 37/100 - loss: 1.4347 - accuracy: 0.6327 - val_loss: 1.4794 - val_accuracy: 0.6356
# 	-!- No improvement: 2/20
# Epoch 38/100 - loss: 1.4279 - accuracy: 0.6346 - val_loss: 1.4741 - val_accuracy: 0.6280
# 	--- Save best at ep 38, val_loss: 1.4741, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 39/100 - loss: 1.4210 - accuracy: 0.6369 - val_loss: 1.4711 - val_accuracy: 0.6333
# 	--- Save best at ep 39, val_loss: 1.4711, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 40/100 - loss: 1.4229 - accuracy: 0.6350 - val_loss: 1.4617 - val_accuracy: 0.6361
# 	--- Save best at ep 40, val_loss: 1.4617, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 41/100 - loss: 1.4138 - accuracy: 0.6419 - val_loss: 1.4772 - val_accuracy: 0.6297
# 	-!- No improvement: 1/20
# Epoch 42/100 - loss: 1.4134 - accuracy: 0.6440 - val_loss: 1.4653 - val_accuracy: 0.6414
# 	-!- No improvement: 2/20
# Epoch 43/100 - loss: 1.4011 - accuracy: 0.6472 - val_loss: 1.4568 - val_accuracy: 0.6383
# 	--- Save best at ep 43, val_loss: 1.4568, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 44/100 - loss: 1.4074 - accuracy: 0.6447 - val_loss: 1.4508 - val_accuracy: 0.6414
# 	--- Save best at ep 44, val_loss: 1.4508, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 45/100 - loss: 1.4015 - accuracy: 0.6465 - val_loss: 1.4654 - val_accuracy: 0.6503
# 	-!- No improvement: 1/20
# Epoch 46/100 - loss: 1.3954 - accuracy: 0.6507 - val_loss: 1.4496 - val_accuracy: 0.6400
# 	--- Save best at ep 46, val_loss: 1.4496, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 47/100 - loss: 1.3922 - accuracy: 0.6530 - val_loss: 1.4327 - val_accuracy: 0.6498
# 	--- Save best at ep 47, val_loss: 1.4327, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth ---
# Epoch 48/100 - loss: 1.3910 - accuracy: 0.6545 - val_loss: 1.4468 - val_accuracy: 0.6498
# 	-!- No improvement: 1/20
# Epoch 49/100 - loss: 1.3880 - accuracy: 0.6547 - val_loss: 1.4535 - val_accuracy: 0.6434
# 	-!- No improvement: 2/20
# Epoch 50/100 - loss: 1.3846 - accuracy: 0.6568 - val_loss: 1.4554 - val_accuracy: 0.6542
# 	-!- No improvement: 3/20
# Epoch 51/100 - loss: 1.3783 - accuracy: 0.6626 - val_loss: 1.4524 - val_accuracy: 0.6500
# 	-!- No improvement: 4/20
# Epoch 52/100 - loss: 1.3550 - accuracy: 0.6722 - val_loss: 1.4399 - val_accuracy: 0.6523
# 	-!- No improvement: 5/20
# Epoch 53/100 - loss: 1.3486 - accuracy: 0.6729 - val_loss: 1.4408 - val_accuracy: 0.6528
# 	-!- No improvement: 6/20
# Epoch 54/100 - loss: 1.3488 - accuracy: 0.6714 - val_loss: 1.4472 - val_accuracy: 0.6584
# 	-!- No improvement: 7/20
# Epoch 55/100 - loss: 1.3492 - accuracy: 0.6764 - val_loss: 1.4515 - val_accuracy: 0.6578
# 	-!- No improvement: 8/20
# Epoch 56/100 - loss: 1.3333 - accuracy: 0.6839 - val_loss: 1.4507 - val_accuracy: 0.6553
# 	-!- No improvement: 9/20
# Epoch 57/100 - loss: 1.3288 - accuracy: 0.6843 - val_loss: 1.4405 - val_accuracy: 0.6643
# 	-!- No improvement: 10/20
# Epoch 58/100 - loss: 1.3218 - accuracy: 0.6868 - val_loss: 1.4388 - val_accuracy: 0.6617
# 	-!- No improvement: 11/20
# Epoch 59/100 - loss: 1.3196 - accuracy: 0.6911 - val_loss: 1.4446 - val_accuracy: 0.6598
# 	-!- No improvement: 12/20
# Epoch 60/100 - loss: 1.3181 - accuracy: 0.6904 - val_loss: 1.4372 - val_accuracy: 0.6626
# 	-!- No improvement: 13/20
# Epoch 61/100 - loss: 1.3153 - accuracy: 0.6923 - val_loss: 1.4399 - val_accuracy: 0.6631
# 	-!- No improvement: 14/20
# Epoch 62/100 - loss: 1.3101 - accuracy: 0.6941 - val_loss: 1.4416 - val_accuracy: 0.6601
# 	-!- No improvement: 15/20
# Epoch 63/100 - loss: 1.3169 - accuracy: 0.6946 - val_loss: 1.4372 - val_accuracy: 0.6662
# 	-!- No improvement: 16/20
# Epoch 64/100 - loss: 1.3060 - accuracy: 0.6958 - val_loss: 1.4362 - val_accuracy: 0.6662
# 	-!- No improvement: 17/20
# Epoch 65/100 - loss: 1.3100 - accuracy: 0.6955 - val_loss: 1.4362 - val_accuracy: 0.6626
# 	-!- No improvement: 18/20
# Epoch 66/100 - loss: 1.3027 - accuracy: 0.6982 - val_loss: 1.4385 - val_accuracy: 0.6679
# 	-!- No improvement: 19/20
# Epoch 67/100 - loss: 1.3042 - accuracy: 0.6979 - val_loss: 1.4372 - val_accuracy: 0.6648
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=67
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer/vgg_transformer_10042026_1319_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 38.44it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 65.37%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.573146  0.582485  0.577778   491.000000
# disgust        0.447917  0.781818  0.569536    55.000000
# fear           0.501211  0.392045  0.439957   528.000000
# happy          0.892473  0.849829  0.870629   879.000000
# sad            0.517471  0.523569  0.520502   594.000000
# surprise       0.747153  0.788462  0.767251   416.000000
# neutral        0.602273  0.677316  0.637594   626.000000
# accuracy       0.653664  0.653664  0.653664     0.653664
# macro avg      0.611663  0.656504  0.626178  3589.000000
# weighted avg   0.654887  0.653664  0.652015  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_transformer_10042026_1319_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_0kva6xx7 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_0kva6xx7 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_0kva6xx7 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_0kva6xx7 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_0kva6xx7 (0.5s)
# wandb:   ↳ ⣷ vgg_transformer_10042026_1319_best.pth 29.0MB/218.4MB (0.2s)
# wandb: ⣯ uploading artifact cnn_0kva6xx7 (0.5s)
# wandb:   ↳ ⣯ vgg_transformer_10042026_1319_best.pth 29.0MB/218.4MB (0.2s)
# wandb: ⣟ uploading artifact cnn_0kva6xx7 (0.5s)
# wandb:   ↳ ⣟ vgg_transformer_10042026_1319_best.pth 29.0MB/218.4MB (0.2s)
# wandb: ⡿ uploading artifact cnn_0kva6xx7 (0.5s)
# wandb:   ↳ ⡿ vgg_transformer_10042026_1319_best.pth 29.0MB/218.4MB (0.2s)
# wandb: ⢿ uploading artifact cnn_0kva6xx7 (0.5s)
# wandb:   ↳ ⢿ vgg_transformer_10042026_1319_best.pth 29.0MB/218.4MB (0.2s)
# wandb: ⣻ uploading artifact cnn_0kva6xx7 (1.0s)
# wandb:   ↳ ⣻ vgg_transformer_10042026_1319_best.pth 92.9MB/218.4MB (0.7s)
# wandb: ⣽ uploading artifact cnn_0kva6xx7 (1.0s)
# wandb:   ↳ ⣽ vgg_transformer_10042026_1319_best.pth 92.9MB/218.4MB (0.7s)
# wandb: ⣾ uploading artifact cnn_0kva6xx7 (1.0s)
# wandb:   ↳ ⣾ vgg_transformer_10042026_1319_best.pth 92.9MB/218.4MB (0.7s)
# wandb: ⣷ uploading artifact cnn_0kva6xx7 (1.0s)
# wandb:   ↳ ⣷ vgg_transformer_10042026_1319_best.pth 92.9MB/218.4MB (0.7s)
# wandb: ⣯ uploading artifact cnn_0kva6xx7 (1.0s)
# wandb:   ↳ ⣯ vgg_transformer_10042026_1319_best.pth 92.9MB/218.4MB (0.7s)
# wandb: ⣟ uploading artifact cnn_0kva6xx7 (1.5s)
# wandb:   ↳ ⣟ vgg_transformer_10042026_1319_best.pth 142.9MB/218.4MB (1.2s)
# wandb: ⡿ uploading artifact cnn_0kva6xx7 (1.5s)
# wandb:   ↳ ⡿ vgg_transformer_10042026_1319_best.pth 142.9MB/218.4MB (1.2s)
# wandb: ⢿ uploading artifact cnn_0kva6xx7 (1.5s)
# wandb:   ↳ ⢿ vgg_transformer_10042026_1319_best.pth 142.9MB/218.4MB (1.2s)
# wandb: ⣻ uploading artifact cnn_0kva6xx7 (1.5s)
# wandb:   ↳ ⣻ vgg_transformer_10042026_1319_best.pth 142.9MB/218.4MB (1.2s)
# wandb: ⣽ uploading artifact cnn_0kva6xx7 (1.5s)
# wandb:   ↳ ⣽ vgg_transformer_10042026_1319_best.pth 142.9MB/218.4MB (1.2s)
# wandb: ⣾ uploading artifact cnn_0kva6xx7 (2.0s)
# wandb:   ↳ ⣾ vgg_transformer_10042026_1319_best.pth 198.2MB/218.4MB (1.7s)
# wandb: ⣾ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣾ uploading media/images/Evaluation/Confusion_Matrix_66_d8e0225a9f1ac6...
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_67_997d1936e6055f2...
# wandb: + 3 more task(s)
# wandb: ⣷ uploading artifact cnn_0kva6xx7 (2.0s)
# wandb:   ↳ ⣷ vgg_transformer_10042026_1319_best.pth 198.2MB/218.4MB (1.7s)
# wandb: ⣷ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣷ uploading media/images/Evaluation/Confusion_Matrix_66_d8e0225a9f1ac6...
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_67_997d1936e6055f2...
# wandb: + 3 more task(s)
# wandb: ⣯ uploading artifact cnn_0kva6xx7 (2.0s)
# wandb:   ↳ ⣯ vgg_transformer_10042026_1319_best.pth 198.2MB/218.4MB (1.7s)
# wandb: ⣯ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣯ uploading media/images/Evaluation/Confusion_Matrix_66_d8e0225a9f1ac6...
# wandb: ⣯ uploading media/images/Evaluation/Correct_Samples_67_997d1936e6055f2...
# wandb: + 3 more task(s)
# wandb: ⣟ uploading artifact cnn_0kva6xx7 (2.0s)
# wandb:   ↳ ⣟ vgg_transformer_10042026_1319_best.pth 198.2MB/218.4MB (1.7s)
# wandb: ⣟ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣟ uploading media/images/Evaluation/Confusion_Matrix_66_d8e0225a9f1ac6...
# wandb: ⣟ uploading media/images/Evaluation/Correct_Samples_67_997d1936e6055f2...
# wandb: + 3 more task(s)
# wandb: ⡿ uploading artifact cnn_0kva6xx7 (2.0s)
# wandb:   ↳ ⡿ vgg_transformer_10042026_1319_best.pth 198.2MB/218.4MB (1.7s)
# wandb: ⡿ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⡿ uploading media/images/Evaluation/Confusion_Matrix_66_d8e0225a9f1ac6...
# wandb: ⡿ uploading media/images/Evaluation/Correct_Samples_67_997d1936e6055f2...
# wandb: + 3 more task(s)
# wandb: ⢿ uploading artifact cnn_0kva6xx7 (2.5s)
# wandb: ⣻ uploading artifact cnn_0kva6xx7 (2.5s)
# wandb: ⣽ uploading artifact cnn_0kva6xx7 (2.5s)
# wandb: ⣾ uploading artifact cnn_0kva6xx7 (2.5s)
# wandb: ⣷ uploading artifact cnn_0kva6xx7 (2.5s)
# wandb: ⣯ uploading history steps 65-68, summary, console lines 135-166 (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▇▇▇▇▇▇▇▇██
# wandb:  Learning_Rate █████████████████████▄▄▄▄▄▄▄▄▄▄▄▄▄▂▂▁▁▁▁
# wandb: Train/Accuracy ▁▂▃▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████████████
# wandb:     Train/Loss █▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▂▄▂▅▃▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█▇████████████
# wandb:       Val/Loss █▆▄▅▄▃▃▃▃▃▂▂▂▃▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 67
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.6979
# wandb:     Train/Loss 1.30418
# wandb:   Val/Accuracy 0.66481
# wandb:       Val/Loss 1.43721
# wandb:
# wandb: 🚀 View run vgg_transformer_10042026_1319 at: https://wandb.ai/phucga15062005/FER2013/runs/0kva6xx7
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_131926-0kva6xx7/logs
#
# 		DONE!
