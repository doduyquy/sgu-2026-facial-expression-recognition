# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 716, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 716 (delta 77), reused 80 (delta 46), pack-reused 580 (from 1)
# Receiving objects: 100% (716/716), 5.38 MiB | 23.13 MiB/s, done.
# Resolving deltas: 100% (438/438), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention AFTER Fusion in VGGFusion
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run fj6eujpq (0.2s)
# wandb: ⣾ setting up run fj6eujpq (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260405_085941-fj6eujpq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_fusion_05042026_0859
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/fj6eujpq
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.7075 - accuracy: 0.1564 - val_loss: 2.0567 - val_accuracy: 0.2898
# 	--- Save best at ep 1, val_loss: 2.0567, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 2/100 - loss: 2.5418 - accuracy: 0.2987 - val_loss: 1.8640 - val_accuracy: 0.3254
# 	--- Save best at ep 2, val_loss: 1.8640, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 3/100 - loss: 2.4188 - accuracy: 0.3760 - val_loss: 1.7918 - val_accuracy: 0.4684
# 	--- Save best at ep 3, val_loss: 1.7918, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 4/100 - loss: 2.3587 - accuracy: 0.4202 - val_loss: 1.7171 - val_accuracy: 0.5004
# 	--- Save best at ep 4, val_loss: 1.7171, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 5/100 - loss: 2.3169 - accuracy: 0.4409 - val_loss: 1.6688 - val_accuracy: 0.4993
# 	--- Save best at ep 5, val_loss: 1.6688, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 6/100 - loss: 2.2825 - accuracy: 0.4643 - val_loss: 1.6644 - val_accuracy: 0.5247
# 	--- Save best at ep 6, val_loss: 1.6644, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 7/100 - loss: 2.2550 - accuracy: 0.4798 - val_loss: 1.6638 - val_accuracy: 0.5302
# 	--- Save best at ep 7, val_loss: 1.6638, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 8/100 - loss: 2.2386 - accuracy: 0.4873 - val_loss: 1.6438 - val_accuracy: 0.5511
# 	--- Save best at ep 8, val_loss: 1.6438, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 9/100 - loss: 2.2098 - accuracy: 0.5000 - val_loss: 1.6523 - val_accuracy: 0.5213
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 2.1980 - accuracy: 0.5073 - val_loss: 1.5870 - val_accuracy: 0.5676
# 	--- Save best at ep 10, val_loss: 1.5870, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 11/100 - loss: 2.1872 - accuracy: 0.5123 - val_loss: 1.6016 - val_accuracy: 0.5539
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 2.1605 - accuracy: 0.5247 - val_loss: 1.5755 - val_accuracy: 0.5573
# 	--- Save best at ep 12, val_loss: 1.5755, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 13/100 - loss: 2.1421 - accuracy: 0.5314 - val_loss: 1.5556 - val_accuracy: 0.5631
# 	--- Save best at ep 13, val_loss: 1.5556, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 14/100 - loss: 2.1402 - accuracy: 0.5375 - val_loss: 1.5741 - val_accuracy: 0.5720
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 2.1230 - accuracy: 0.5428 - val_loss: 1.5767 - val_accuracy: 0.5695
# 	-!- No improvement: 2/20
# Epoch 16/100 - loss: 2.1128 - accuracy: 0.5499 - val_loss: 1.5922 - val_accuracy: 0.5690
# 	-!- No improvement: 3/20
# Epoch 17/100 - loss: 2.1043 - accuracy: 0.5554 - val_loss: 1.5444 - val_accuracy: 0.5915
# 	--- Save best at ep 17, val_loss: 1.5444, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 18/100 - loss: 2.0882 - accuracy: 0.5583 - val_loss: 1.5341 - val_accuracy: 0.5935
# 	--- Save best at ep 18, val_loss: 1.5341, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 19/100 - loss: 2.0795 - accuracy: 0.5681 - val_loss: 1.5641 - val_accuracy: 0.5715
# 	-!- No improvement: 1/20
# Epoch 20/100 - loss: 2.0746 - accuracy: 0.5689 - val_loss: 1.5496 - val_accuracy: 0.5926
# 	-!- No improvement: 2/20
# Epoch 21/100 - loss: 2.0634 - accuracy: 0.5779 - val_loss: 1.5469 - val_accuracy: 0.6055
# 	-!- No improvement: 3/20
# Epoch 22/100 - loss: 2.0530 - accuracy: 0.5771 - val_loss: 1.5397 - val_accuracy: 0.5918
# 	-!- No improvement: 4/20
# Epoch 23/100 - loss: 2.0065 - accuracy: 0.5960 - val_loss: 1.4696 - val_accuracy: 0.6289
# 	--- Save best at ep 23, val_loss: 1.4696, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 24/100 - loss: 1.9906 - accuracy: 0.6088 - val_loss: 1.4703 - val_accuracy: 0.6269
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 1.9787 - accuracy: 0.6111 - val_loss: 1.4723 - val_accuracy: 0.6353
# 	-!- No improvement: 2/20
# Epoch 26/100 - loss: 1.9784 - accuracy: 0.6175 - val_loss: 1.4858 - val_accuracy: 0.6308
# 	-!- No improvement: 3/20
# Epoch 27/100 - loss: 1.9612 - accuracy: 0.6202 - val_loss: 1.4629 - val_accuracy: 0.6397
# 	--- Save best at ep 27, val_loss: 1.4629, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 28/100 - loss: 1.9524 - accuracy: 0.6253 - val_loss: 1.4710 - val_accuracy: 0.6353
# 	-!- No improvement: 1/20
# Epoch 29/100 - loss: 1.9459 - accuracy: 0.6277 - val_loss: 1.4759 - val_accuracy: 0.6453
# 	-!- No improvement: 2/20
# Epoch 30/100 - loss: 1.9414 - accuracy: 0.6290 - val_loss: 1.4648 - val_accuracy: 0.6305
# 	-!- No improvement: 3/20
# Epoch 31/100 - loss: 1.9312 - accuracy: 0.6344 - val_loss: 1.4683 - val_accuracy: 0.6509
# 	-!- No improvement: 4/20
# Epoch 32/100 - loss: 1.8960 - accuracy: 0.6447 - val_loss: 1.4713 - val_accuracy: 0.6459
# 	-!- No improvement: 5/20
# Epoch 33/100 - loss: 1.8942 - accuracy: 0.6490 - val_loss: 1.4640 - val_accuracy: 0.6478
# 	-!- No improvement: 6/20
# Epoch 34/100 - loss: 1.8813 - accuracy: 0.6513 - val_loss: 1.4642 - val_accuracy: 0.6565
# 	-!- No improvement: 7/20
# Epoch 35/100 - loss: 1.8703 - accuracy: 0.6585 - val_loss: 1.4356 - val_accuracy: 0.6601
# 	--- Save best at ep 35, val_loss: 1.4356, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 36/100 - loss: 1.8634 - accuracy: 0.6584 - val_loss: 1.4406 - val_accuracy: 0.6620
# 	-!- No improvement: 1/20
# Epoch 37/100 - loss: 1.8611 - accuracy: 0.6618 - val_loss: 1.4323 - val_accuracy: 0.6701
# 	--- Save best at ep 37, val_loss: 1.4323, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 38/100 - loss: 1.8629 - accuracy: 0.6626 - val_loss: 1.4221 - val_accuracy: 0.6626
# 	--- Save best at ep 38, val_loss: 1.4221, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 39/100 - loss: 1.8462 - accuracy: 0.6682 - val_loss: 1.4308 - val_accuracy: 0.6553
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 1.8390 - accuracy: 0.6723 - val_loss: 1.4259 - val_accuracy: 0.6726
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 1.8346 - accuracy: 0.6742 - val_loss: 1.4357 - val_accuracy: 0.6748
# 	-!- No improvement: 3/20
# Epoch 42/100 - loss: 1.8258 - accuracy: 0.6766 - val_loss: 1.4248 - val_accuracy: 0.6746
# 	-!- No improvement: 4/20
# Epoch 43/100 - loss: 1.8091 - accuracy: 0.6808 - val_loss: 1.4309 - val_accuracy: 0.6740
# 	-!- No improvement: 5/20
# Epoch 44/100 - loss: 1.8012 - accuracy: 0.6858 - val_loss: 1.4343 - val_accuracy: 0.6779
# 	-!- No improvement: 6/20
# Epoch 45/100 - loss: 1.7967 - accuracy: 0.6894 - val_loss: 1.4234 - val_accuracy: 0.6790
# 	-!- No improvement: 7/20
# Epoch 46/100 - loss: 1.7939 - accuracy: 0.6913 - val_loss: 1.4265 - val_accuracy: 0.6773
# 	-!- No improvement: 8/20
# Epoch 47/100 - loss: 1.7822 - accuracy: 0.6926 - val_loss: 1.4304 - val_accuracy: 0.6801
# 	-!- No improvement: 9/20
# Epoch 48/100 - loss: 1.7754 - accuracy: 0.7003 - val_loss: 1.4279 - val_accuracy: 0.6815
# 	-!- No improvement: 10/20
# Epoch 49/100 - loss: 1.7787 - accuracy: 0.6974 - val_loss: 1.4287 - val_accuracy: 0.6821
# 	-!- No improvement: 11/20
# Epoch 50/100 - loss: 1.7651 - accuracy: 0.7010 - val_loss: 1.4300 - val_accuracy: 0.6782
# 	-!- No improvement: 12/20
# Epoch 51/100 - loss: 1.7631 - accuracy: 0.7042 - val_loss: 1.4284 - val_accuracy: 0.6807
# 	-!- No improvement: 13/20
# Epoch 52/100 - loss: 1.7565 - accuracy: 0.7030 - val_loss: 1.4232 - val_accuracy: 0.6824
# 	-!- No improvement: 14/20
# Epoch 53/100 - loss: 1.7605 - accuracy: 0.7024 - val_loss: 1.4221 - val_accuracy: 0.6815
# 	--- Save best at ep 53, val_loss: 1.4221, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 54/100 - loss: 1.7604 - accuracy: 0.7056 - val_loss: 1.4234 - val_accuracy: 0.6824
# 	-!- No improvement: 1/20
# Epoch 55/100 - loss: 1.7530 - accuracy: 0.7095 - val_loss: 1.4250 - val_accuracy: 0.6835
# 	-!- No improvement: 2/20
# Epoch 56/100 - loss: 1.7544 - accuracy: 0.7071 - val_loss: 1.4246 - val_accuracy: 0.6821
# 	-!- No improvement: 3/20
# Epoch 57/100 - loss: 1.7508 - accuracy: 0.7093 - val_loss: 1.4241 - val_accuracy: 0.6829
# 	-!- No improvement: 4/20
# Epoch 58/100 - loss: 1.7486 - accuracy: 0.7078 - val_loss: 1.4211 - val_accuracy: 0.6829
# 	--- Save best at ep 58, val_loss: 1.4211, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth ---
# Epoch 59/100 - loss: 1.7486 - accuracy: 0.7089 - val_loss: 1.4274 - val_accuracy: 0.6835
# 	-!- No improvement: 1/20
# Epoch 60/100 - loss: 1.7494 - accuracy: 0.7091 - val_loss: 1.4227 - val_accuracy: 0.6818
# 	-!- No improvement: 2/20
# Epoch 61/100 - loss: 1.7478 - accuracy: 0.7106 - val_loss: 1.4223 - val_accuracy: 0.6810
# 	-!- No improvement: 3/20
# Epoch 62/100 - loss: 1.7439 - accuracy: 0.7102 - val_loss: 1.4263 - val_accuracy: 0.6824
# 	-!- No improvement: 4/20
# Epoch 63/100 - loss: 1.7450 - accuracy: 0.7129 - val_loss: 1.4214 - val_accuracy: 0.6829
# 	-!- No improvement: 5/20
# Epoch 64/100 - loss: 1.7428 - accuracy: 0.7132 - val_loss: 1.4245 - val_accuracy: 0.6849
# 	-!- No improvement: 6/20
# Epoch 65/100 - loss: 1.7480 - accuracy: 0.7101 - val_loss: 1.4261 - val_accuracy: 0.6835
# 	-!- No improvement: 7/20
# Epoch 66/100 - loss: 1.7415 - accuracy: 0.7152 - val_loss: 1.4243 - val_accuracy: 0.6849
# 	-!- No improvement: 8/20
# Epoch 67/100 - loss: 1.7427 - accuracy: 0.7133 - val_loss: 1.4246 - val_accuracy: 0.6843
# 	-!- No improvement: 9/20
# Epoch 68/100 - loss: 1.7387 - accuracy: 0.7159 - val_loss: 1.4231 - val_accuracy: 0.6832
# 	-!- No improvement: 10/20
# Epoch 69/100 - loss: 1.7410 - accuracy: 0.7149 - val_loss: 1.4250 - val_accuracy: 0.6832
# 	-!- No improvement: 11/20
# Epoch 70/100 - loss: 1.7431 - accuracy: 0.7121 - val_loss: 1.4255 - val_accuracy: 0.6818
# 	-!- No improvement: 12/20
# Epoch 71/100 - loss: 1.7427 - accuracy: 0.7105 - val_loss: 1.4246 - val_accuracy: 0.6835
# 	-!- No improvement: 13/20
# Epoch 72/100 - loss: 1.7336 - accuracy: 0.7145 - val_loss: 1.4279 - val_accuracy: 0.6824
# 	-!- No improvement: 14/20
# Epoch 73/100 - loss: 1.7425 - accuracy: 0.7151 - val_loss: 1.4257 - val_accuracy: 0.6840
# 	-!- No improvement: 15/20
# Epoch 74/100 - loss: 1.7389 - accuracy: 0.7144 - val_loss: 1.4233 - val_accuracy: 0.6846
# 	-!- No improvement: 16/20
# Epoch 75/100 - loss: 1.7468 - accuracy: 0.7133 - val_loss: 1.4256 - val_accuracy: 0.6840
# 	-!- No improvement: 17/20
# Epoch 76/100 - loss: 1.7340 - accuracy: 0.7145 - val_loss: 1.4260 - val_accuracy: 0.6854
# 	-!- No improvement: 18/20
# Epoch 77/100 - loss: 1.7429 - accuracy: 0.7139 - val_loss: 1.4240 - val_accuracy: 0.6829
# 	-!- No improvement: 19/20
# Epoch 78/100 - loss: 1.7448 - accuracy: 0.7133 - val_loss: 1.4229 - val_accuracy: 0.6851
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=78
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_fusion/vgg_fusion_05042026_0859_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 46.10it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 69.02%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.619141  0.645621  0.632104   491.000000
# disgust        0.661290  0.745455  0.700855    55.000000
# fear           0.566745  0.458333  0.506806   528.000000
# happy          0.903800  0.865757  0.884370   879.000000
# sad            0.552588  0.557239  0.554904   594.000000
# surprise       0.744035  0.824519  0.782212   416.000000
# neutral        0.644315  0.706070  0.673780   626.000000
# accuracy       0.690164  0.690164  0.690164     0.690164
# macro avg      0.670273  0.686142  0.676433  3589.000000
# weighted avg   0.689648  0.690164  0.688399  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_fusion_05042026_0859_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_fj6eujpq (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_fj6eujpq (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_fj6eujpq (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_fj6eujpq (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_fj6eujpq (0.5s)
# wandb:   ↳ ⣷ vgg_fusion_05042026_0859_best.pth 10.6MB/101.1MB (0.1s)
# wandb: ⣯ uploading artifact cnn_fj6eujpq (0.5s)
# wandb:   ↳ ⣯ vgg_fusion_05042026_0859_best.pth 10.6MB/101.1MB (0.1s)
# wandb: ⣟ uploading artifact cnn_fj6eujpq (0.5s)
# wandb:   ↳ ⣟ vgg_fusion_05042026_0859_best.pth 10.6MB/101.1MB (0.1s)
# wandb: ⡿ uploading artifact cnn_fj6eujpq (0.5s)
# wandb:   ↳ ⡿ vgg_fusion_05042026_0859_best.pth 10.6MB/101.1MB (0.1s)
# wandb: ⢿ uploading artifact cnn_fj6eujpq (0.5s)
# wandb:   ↳ ⢿ vgg_fusion_05042026_0859_best.pth 10.6MB/101.1MB (0.1s)
# wandb: ⣻ uploading artifact cnn_fj6eujpq (1.0s)
# wandb:   ↳ ⣻ vgg_fusion_05042026_0859_best.pth 51.1MB/101.1MB (0.6s)
# wandb: ⣽ uploading artifact cnn_fj6eujpq (1.0s)
# wandb:   ↳ ⣽ vgg_fusion_05042026_0859_best.pth 51.1MB/101.1MB (0.6s)
# wandb: ⣾ uploading artifact cnn_fj6eujpq (1.0s)
# wandb:   ↳ ⣾ vgg_fusion_05042026_0859_best.pth 51.1MB/101.1MB (0.6s)
# wandb: ⣷ uploading artifact cnn_fj6eujpq (1.0s)
# wandb:   ↳ ⣷ vgg_fusion_05042026_0859_best.pth 51.1MB/101.1MB (0.6s)
# wandb: ⣯ uploading artifact cnn_fj6eujpq (1.0s)
# wandb:   ↳ ⣯ vgg_fusion_05042026_0859_best.pth 51.1MB/101.1MB (0.6s)
# wandb: ⣟ uploading artifact cnn_fj6eujpq (1.5s)
# wandb:   ↳ ⣟ vgg_fusion_05042026_0859_best.pth 89.1MB/101.1MB (1.1s)
# wandb: ⡿ uploading artifact cnn_fj6eujpq (1.5s)
# wandb:   ↳ ⡿ vgg_fusion_05042026_0859_best.pth 89.1MB/101.1MB (1.1s)
# wandb: ⢿ uploading artifact cnn_fj6eujpq (1.5s)
# wandb:   ↳ ⢿ vgg_fusion_05042026_0859_best.pth 89.1MB/101.1MB (1.1s)
# wandb: ⣻ uploading artifact cnn_fj6eujpq (1.5s)
# wandb:   ↳ ⣻ vgg_fusion_05042026_0859_best.pth 89.1MB/101.1MB (1.1s)
# wandb: ⣽ uploading artifact cnn_fj6eujpq (1.5s)
# wandb:   ↳ ⣽ vgg_fusion_05042026_0859_best.pth 89.1MB/101.1MB (1.1s)
# wandb: ⣾ uploading artifact cnn_fj6eujpq (2.0s)
# wandb: ⣷ uploading artifact cnn_fj6eujpq (2.0s)
# wandb: ⣯ uploading artifact cnn_fj6eujpq (2.0s)
# wandb: ⣟ uploading artifact cnn_fj6eujpq (2.0s)
# wandb: ⡿ uploading artifact cnn_fj6eujpq (2.0s)
# wandb: ⢿ uploading media/images/Evaluation/Correct_Samples_78_9012627468484ca...
# wandb: ⢿ uploading media/images/Evaluation/Wrong_Samples_79_6cdfc0e3977417f81...
# wandb: ⢿ uploading output.log 13.4KB/13.4KB (0.1s)
# wandb: ⢿ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⢿ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⢿ uploading media/images/Evaluation/Confusion_Matrix_77_e0e6187d31fe7c...
# wandb: ⣻ uploading media/images/Evaluation/Correct_Samples_78_9012627468484ca...
# wandb: ⣻ uploading media/images/Evaluation/Wrong_Samples_79_6cdfc0e3977417f81...
# wandb: ⣻ uploading output.log 13.4KB/13.4KB (0.1s)
# wandb: ⣻ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣻ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⣻ uploading media/images/Evaluation/Confusion_Matrix_77_e0e6187d31fe7c...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇███
# wandb:  Learning_Rate █████████████▄▄▄▄▃▃▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇██████████████████
# wandb:     Train/Loss █▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▅▆▆▆▆▆▆▇▇▇▇▇▇▇█▇███████████████████████
# wandb:       Val/Loss █▆▄▄▃▂▃▃▂▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 78
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.71326
# wandb:     Train/Loss 1.74476
# wandb:   Val/Accuracy 0.68515
# wandb:       Val/Loss 1.42291
# wandb:
# wandb: 🚀 View run vgg_fusion_05042026_0859 at: https://wandb.ai/phucga15062005/FER2013/runs/fj6eujpq
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260405_085941-fj6eujpq/logs
#
# 		DONE!
