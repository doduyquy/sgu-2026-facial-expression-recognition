# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2080, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 2080 (delta 100), reused 90 (delta 89), pack-reused 1949 (from 2)
# Receiving objects: 100% (2080/2080), 6.31 MiB | 32.33 MiB/s, done.
# Resolving deltas: 100% (1482/1482), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config cnn_dictionary --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: cnn_dict_v2_dong_17042026_0804
# --> Facial Region Dictionary: ['forehead', 'eyebrows', 'eyes', 'nose', 'mouth', 'chin']
# --> [CNNDictionary V2] Free cross-attention + soft grounding + visual shortcut
#
# ==================================================
# [Transfer Learning] Loading pretrained backbone...
# ==================================================
# [CNNDictionary] Backbone loaded: 296 weights
# [CNNDictionary] Backbone FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=7)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run fsdqclal (0.2s)
# wandb: ⣾ setting up run fsdqclal (0.2s)
# wandb: ⣷ setting up run fsdqclal (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_080440-fsdqclal
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_dict_v2_dong_17042026_0804
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/fsdqclal
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.0294 - accuracy: 0.7442 - val_loss: 1.3208 - val_accuracy: 0.6590
# 	--- Save best at ep 1, val_loss: 1.3208, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 2/100 - loss: 0.9996 - accuracy: 0.7562 - val_loss: 1.2875 - val_accuracy: 0.6665
# 	--- Save best at ep 2, val_loss: 1.2875, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 3/100 - loss: 0.9962 - accuracy: 0.7570 - val_loss: 1.2926 - val_accuracy: 0.6612
# 	-!- No improvement: 1/20
# Epoch 4/100 - loss: 1.0004 - accuracy: 0.7561 - val_loss: 1.3138 - val_accuracy: 0.6637
# 	-!- No improvement: 2/20
# Epoch 5/100 - loss: 0.9923 - accuracy: 0.7585 - val_loss: 1.2853 - val_accuracy: 0.6620
# 	--- Save best at ep 5, val_loss: 1.2853, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 6/100 - loss: 0.9917 - accuracy: 0.7568 - val_loss: 1.2737 - val_accuracy: 0.6684
# 	--- Save best at ep 6, val_loss: 1.2737, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 7/100 - loss: 0.9869 - accuracy: 0.7594 - val_loss: 1.2762 - val_accuracy: 0.6670
# 	-!- No improvement: 1/20
# Epoch 8/100 - loss: 0.9858 - accuracy: 0.7603 - val_loss: 1.3099 - val_accuracy: 0.6601
# 	-!- No improvement: 2/20
# Epoch 9/100 - loss: 0.9914 - accuracy: 0.7602 - val_loss: 1.3050 - val_accuracy: 0.6573
# 	-!- No improvement: 3/20
# Epoch 10/100 - loss: 0.9805 - accuracy: 0.7594 - val_loss: 1.3318 - val_accuracy: 0.6682
# 	-!- No improvement: 4/20
# Epoch 11/100 - loss: 0.9795 - accuracy: 0.7619 - val_loss: 1.2979 - val_accuracy: 0.6701
# 	-!- No improvement: 5/20
# Epoch 12/100 - loss: 0.9738 - accuracy: 0.7620 - val_loss: 1.2962 - val_accuracy: 0.6573
# 	-!- No improvement: 6/20
# [CNNDictionary] All parameters UNFROZEN.
# [CNNDictionary] Param groups: backbone=185 tensors (lr=5e-05), head=37 tensors (lr=0.0003)
# [Trainer] Discriminative LR: backbone=5e-05, head=0.0003
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=7)
# [Trainer] Reset patience + best_val_loss for Phase 2.
# Epoch 13/100 - loss: 0.9568 - accuracy: 0.7661 - val_loss: 1.2982 - val_accuracy: 0.6640
# 	--- Save best at ep 13, val_loss: 1.2982, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 14/100 - loss: 0.9444 - accuracy: 0.7725 - val_loss: 1.2968 - val_accuracy: 0.6617
# 	--- Save best at ep 14, val_loss: 1.2968, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 15/100 - loss: 0.9425 - accuracy: 0.7721 - val_loss: 1.2777 - val_accuracy: 0.6754
# 	--- Save best at ep 15, val_loss: 1.2777, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth ---
# Epoch 16/100 - loss: 0.9318 - accuracy: 0.7802 - val_loss: 1.3052 - val_accuracy: 0.6665
# 	-!- No improvement: 1/20
# Epoch 17/100 - loss: 0.9325 - accuracy: 0.7789 - val_loss: 1.3056 - val_accuracy: 0.6701
# 	-!- No improvement: 2/20
# Epoch 18/100 - loss: 0.9283 - accuracy: 0.7790 - val_loss: 1.2906 - val_accuracy: 0.6723
# 	-!- No improvement: 3/20
# Epoch 19/100 - loss: 0.9173 - accuracy: 0.7856 - val_loss: 1.2977 - val_accuracy: 0.6693
# 	-!- No improvement: 4/20
# Epoch 20/100 - loss: 0.9174 - accuracy: 0.7841 - val_loss: 1.2919 - val_accuracy: 0.6709
# 	-!- No improvement: 5/20
# Epoch 21/100 - loss: 0.9091 - accuracy: 0.7858 - val_loss: 1.3069 - val_accuracy: 0.6707
# 	-!- No improvement: 6/20
# Epoch 22/100 - loss: 0.9030 - accuracy: 0.7879 - val_loss: 1.2986 - val_accuracy: 0.6718
# 	-!- No improvement: 7/20
# Epoch 23/100 - loss: 0.9050 - accuracy: 0.7880 - val_loss: 1.3084 - val_accuracy: 0.6707
# 	-!- No improvement: 8/20
# Epoch 24/100 - loss: 0.8947 - accuracy: 0.7928 - val_loss: 1.3029 - val_accuracy: 0.6721
# 	-!- No improvement: 9/20
# Epoch 25/100 - loss: 0.8882 - accuracy: 0.7950 - val_loss: 1.3068 - val_accuracy: 0.6704
# 	-!- No improvement: 10/20
# Epoch 26/100 - loss: 0.8875 - accuracy: 0.7975 - val_loss: 1.3153 - val_accuracy: 0.6718
# 	-!- No improvement: 11/20
# Epoch 27/100 - loss: 0.8859 - accuracy: 0.7986 - val_loss: 1.3143 - val_accuracy: 0.6698
# 	-!- No improvement: 12/20
# Epoch 28/100 - loss: 0.8796 - accuracy: 0.7997 - val_loss: 1.3056 - val_accuracy: 0.6707
# 	-!- No improvement: 13/20
# Epoch 29/100 - loss: 0.8789 - accuracy: 0.8015 - val_loss: 1.3164 - val_accuracy: 0.6726
# 	-!- No improvement: 14/20
# Epoch 30/100 - loss: 0.8826 - accuracy: 0.7992 - val_loss: 1.3112 - val_accuracy: 0.6746
# 	-!- No improvement: 15/20
# Epoch 31/100 - loss: 0.8768 - accuracy: 0.8021 - val_loss: 1.3176 - val_accuracy: 0.6690
# 	-!- No improvement: 16/20
# Epoch 32/100 - loss: 0.8745 - accuracy: 0.8033 - val_loss: 1.3270 - val_accuracy: 0.6737
# 	-!- No improvement: 17/20
# Epoch 33/100 - loss: 0.8734 - accuracy: 0.8036 - val_loss: 1.3185 - val_accuracy: 0.6734
# 	-!- No improvement: 18/20
# Epoch 34/100 - loss: 0.8681 - accuracy: 0.8042 - val_loss: 1.3267 - val_accuracy: 0.6760
# 	-!- No improvement: 19/20
# Epoch 35/100 - loss: 0.8674 - accuracy: 0.8042 - val_loss: 1.3157 - val_accuracy: 0.6679
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=35
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_cnn_dict_v2_dong_17042026_0804.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0804_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 17.37it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 69.02%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.614141  0.619145  0.616633   491.000000
# disgust        0.755102  0.672727  0.711538    55.000000
# fear           0.532009  0.456439  0.491335   528.000000
# happy          0.905325  0.870307  0.887471   879.000000
# sad            0.547771  0.579125  0.563011   594.000000
# surprise       0.771493  0.819712  0.794872   416.000000
# neutral        0.657312  0.710863  0.683039   626.000000
# accuracy       0.690164  0.690164  0.690164     0.690164
# macro avg      0.683308  0.675474  0.678271  3589.000000
# weighted avg   0.690318  0.690164  0.689354  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
#
# --> [Attention Heatmap] Generating region attention visualization...
#
# --> Generating attention heatmap for 4 CORRECT samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_correct.png
# --> Generating attention heatmap for 4 WRONG samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_wrong.png
# --> [Attention Heatmap] Done!
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `cnn_dict_v2_dong_17042026_0804_best.pth` to cloud successfully!
# wandb: ⢿ uploading history steps 33-37, summary, console lines 76-110 (3.7s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading history steps 33-37, summary, console lines 76-110 (3.7s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading history steps 33-37, summary, console lines 76-110 (3.7s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading history steps 33-37, summary, console lines 76-110 (3.7s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading history steps 33-37, summary, console lines 76-110 (4.2s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.5s)
# wandb: ⣯ uploading history steps 33-37, summary, console lines 76-110 (4.2s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.5s)
# wandb: ⣟ uploading history steps 33-37, summary, console lines 76-110 (4.2s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.5s)
# wandb: ⡿ uploading history steps 33-37, summary, console lines 76-110 (4.2s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.5s)
# wandb: ⢿ uploading history steps 33-37, summary, console lines 76-110 (4.2s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (0.5s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.0s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.0s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.5s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0804_best.pth 1.2MB/256.4MB (0.1s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.5s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0804_best.pth 1.2MB/256.4MB (0.1s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.5s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0804_best.pth 1.2MB/256.4MB (0.1s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.5s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0804_best.pth 1.2MB/256.4MB (0.1s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (1.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0804_best.pth 1.2MB/256.4MB (0.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.0s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0804_best.pth 36.9MB/256.4MB (0.6s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.0s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0804_best.pth 36.9MB/256.4MB (0.6s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.0s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0804_best.pth 36.9MB/256.4MB (0.6s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.0s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0804_best.pth 36.9MB/256.4MB (0.6s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0804_best.pth 36.9MB/256.4MB (0.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.5s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0804_best.pth 98.5MB/256.4MB (1.1s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.5s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0804_best.pth 98.5MB/256.4MB (1.1s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0804_best.pth 98.5MB/256.4MB (1.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.5s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0804_best.pth 98.5MB/256.4MB (1.1s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (2.5s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0804_best.pth 98.5MB/256.4MB (1.1s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.0s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0804_best.pth 154.7MB/256.4MB (1.6s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.0s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0804_best.pth 154.7MB/256.4MB (1.6s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0804_best.pth 154.7MB/256.4MB (1.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.0s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0804_best.pth 154.7MB/256.4MB (1.6s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.0s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0804_best.pth 154.7MB/256.4MB (1.6s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0804_best.pth 210.8MB/256.4MB (2.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.5s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0804_best.pth 210.8MB/256.4MB (2.1s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.5s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0804_best.pth 210.8MB/256.4MB (2.1s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.5s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0804_best.pth 210.8MB/256.4MB (2.1s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (3.5s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0804_best.pth 210.8MB/256.4MB (2.1s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0804_best.pth 256.4MB/256.4MB (2.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.0s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0804_best.pth 256.4MB/256.4MB (2.6s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.0s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0804_best.pth 256.4MB/256.4MB (2.6s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.0s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0804_best.pth 256.4MB/256.4MB (2.6s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.0s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0804_best.pth 256.4MB/256.4MB (2.6s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.5s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.5s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.5s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.5s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (4.5s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (5.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (5.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (5.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (5.0s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0804_fsdqclal (5.0s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (0.2s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (0.2s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (0.2s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (0.2s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (0.2s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (0.7s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (0.7s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (0.7s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (0.7s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (0.7s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (1.2s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (1.2s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (1.2s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (1.2s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (1.2s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (1.7s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (1.7s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (1.7s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (1.7s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (1.7s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (2.2s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (2.2s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (2.2s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (2.2s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (2.2s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (2.7s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (2.7s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (2.7s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (2.7s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (2.7s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (3.2s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (3.2s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (3.2s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (3.2s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (3.2s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (3.7s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (3.7s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (3.7s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (3.7s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (3.7s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (4.2s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (4.2s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (4.2s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (4.2s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (4.2s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (4.7s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (4.7s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (4.7s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (4.7s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (4.7s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (5.3s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (5.3s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (5.3s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (5.3s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (5.3s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (5.8s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (5.8s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (5.8s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (5.8s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (5.8s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (6.3s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (6.3s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (6.3s)
# wandb: ⣯ uploading history steps 38-39, summary, console lines 111-116 (6.3s)
# wandb: ⣟ uploading history steps 38-39, summary, console lines 111-116 (6.3s)
# wandb: ⡿ uploading history steps 38-39, summary, console lines 111-116 (6.8s)
# wandb: ⢿ uploading history steps 38-39, summary, console lines 111-116 (6.8s)
# wandb: ⣻ uploading history steps 38-39, summary, console lines 111-116 (6.8s)
# wandb: ⣽ uploading history steps 38-39, summary, console lines 111-116 (6.8s)
# wandb: ⣾ uploading history steps 38-39, summary, console lines 111-116 (6.8s)
# wandb: ⣷ uploading history steps 38-39, summary, console lines 111-116 (7.3s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ████████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▂▂▃▂▃▃▃▃▃▃▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇█▇█████
# wandb:     Train/Loss █▇▇▇▆▆▆▆▆▆▆▆▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▂▁▁▁▁▁
# wandb:   Val/Accuracy ▂▄▂▃▃▅▅▂▁▅▆▁▄▃█▄▆▇▅▆▆▆▆▇▆▆▆▆▇▇▅▇▇█▅
# wandb:       Val/Loss ▇▃▃▆▂▁▁▅▅█▄▄▄▄▁▅▅▃▄▃▅▄▅▅▅▆▆▅▆▆▆▇▆▇▆
# wandb:
# wandb: Run summary:
# wandb:          Epoch 35
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.80424
# wandb:     Train/Loss 0.86743
# wandb:   Val/Accuracy 0.66787
# wandb:       Val/Loss 1.31566
# wandb:
# wandb: 🚀 View run cnn_dict_v2_dong_17042026_0804 at: https://wandb.ai/phucga15062005/FER2013/runs/fsdqclal
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 6 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_080440-fsdqclal/logs
#
# 		DONE!
