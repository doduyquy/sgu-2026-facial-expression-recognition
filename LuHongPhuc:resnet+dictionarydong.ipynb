# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2048, done.
# remote: Counting objects: 100% (416/416), done.
# remote: Compressing objects: 100% (248/248), done.
# remote: Total 2048 (delta 305), reused 230 (delta 168), pack-reused 1632 (from 1)
# Receiving objects: 100% (2048/2048), 6.30 MiB | 33.77 MiB/s, done.
# Resolving deltas: 100% (1461/1461), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config cnn_dictionary --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: cnn_dict_v2_dong_17042026_0728
# --> Facial Region Dictionary: ['forehead', 'eyebrows', 'eyes', 'nose', 'mouth', 'chin']
# --> [CNNDictionary V2] Free cross-attention + soft grounding + visual shortcut
#
# ==================================================
# [Transfer Learning] Loading pretrained backbone...
# ==================================================
# [CNNDictionary] Backbone loaded: 296 weights
# [CNNDictionary] Backbone FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=7)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 9h61z3le (0.3s)
# wandb: ⣷ setting up run 9h61z3le (0.3s)
# wandb: ⣯ setting up run 9h61z3le (0.3s)
# wandb: ⣟ setting up run 9h61z3le (0.3s)
# wandb: ⡿ setting up run 9h61z3le (0.3s)
# wandb: ⢿ setting up run 9h61z3le (0.8s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_072838-9h61z3le
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_dict_v2_dong_17042026_0728
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/9h61z3le
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.0292 - accuracy: 0.7468 - val_loss: 1.3186 - val_accuracy: 0.6612
# 	--- Save best at ep 1, val_loss: 1.3186, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth ---
# Epoch 2/100 - loss: 0.9985 - accuracy: 0.7577 - val_loss: 1.3188 - val_accuracy: 0.6590
# 	-!- No improvement: 1/20
# Epoch 3/100 - loss: 0.9969 - accuracy: 0.7575 - val_loss: 1.2640 - val_accuracy: 0.6687
# 	--- Save best at ep 3, val_loss: 1.2640, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth ---
# Epoch 4/100 - loss: 0.9915 - accuracy: 0.7581 - val_loss: 1.3283 - val_accuracy: 0.6525
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 0.9887 - accuracy: 0.7577 - val_loss: 1.2897 - val_accuracy: 0.6687
# 	-!- No improvement: 2/20
# Epoch 6/100 - loss: 0.9842 - accuracy: 0.7601 - val_loss: 1.2799 - val_accuracy: 0.6609
# 	-!- No improvement: 3/20
# Epoch 7/100 - loss: 0.9853 - accuracy: 0.7590 - val_loss: 1.2940 - val_accuracy: 0.6598
# 	-!- No improvement: 4/20
# Epoch 8/100 - loss: 0.9892 - accuracy: 0.7570 - val_loss: 1.2693 - val_accuracy: 0.6654
# 	-!- No improvement: 5/20
# Epoch 9/100 - loss: 0.9800 - accuracy: 0.7605 - val_loss: 1.3070 - val_accuracy: 0.6626
# 	-!- No improvement: 6/20
# Epoch 10/100 - loss: 0.9827 - accuracy: 0.7605 - val_loss: 1.2624 - val_accuracy: 0.6732
# 	--- Save best at ep 10, val_loss: 1.2624, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth ---
# Epoch 11/100 - loss: 0.9756 - accuracy: 0.7653 - val_loss: 1.3013 - val_accuracy: 0.6565
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 0.9785 - accuracy: 0.7575 - val_loss: 1.3302 - val_accuracy: 0.6617
# 	-!- No improvement: 2/20
# [CNNDictionary] All parameters UNFROZEN.
# [CNNDictionary] Param groups: backbone=185 tensors (lr=5e-05), head=35 tensors (lr=0.0003)
# [Trainer] Discriminative LR: backbone=5e-05, head=0.0003
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=7)
# [Trainer] Reset patience + best_val_loss for Phase 2.
# Epoch 13/100 - loss: 0.9557 - accuracy: 0.7660 - val_loss: 1.2940 - val_accuracy: 0.6673
# 	--- Save best at ep 13, val_loss: 1.2940, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth ---
# Epoch 14/100 - loss: 0.9453 - accuracy: 0.7682 - val_loss: 1.2852 - val_accuracy: 0.6662
# 	--- Save best at ep 14, val_loss: 1.2852, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth ---
# Epoch 15/100 - loss: 0.9379 - accuracy: 0.7708 - val_loss: 1.2880 - val_accuracy: 0.6704
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 0.9395 - accuracy: 0.7729 - val_loss: 1.2942 - val_accuracy: 0.6651
# 	-!- No improvement: 2/20
# Epoch 17/100 - loss: 0.9306 - accuracy: 0.7785 - val_loss: 1.2855 - val_accuracy: 0.6670
# 	-!- No improvement: 3/20
# Epoch 18/100 - loss: 0.9211 - accuracy: 0.7807 - val_loss: 1.2960 - val_accuracy: 0.6693
# 	-!- No improvement: 4/20
# Epoch 19/100 - loss: 0.9187 - accuracy: 0.7834 - val_loss: 1.2923 - val_accuracy: 0.6659
# 	-!- No improvement: 5/20
# Epoch 20/100 - loss: 0.9108 - accuracy: 0.7846 - val_loss: 1.3079 - val_accuracy: 0.6651
# 	-!- No improvement: 6/20
# Epoch 21/100 - loss: 0.9086 - accuracy: 0.7883 - val_loss: 1.3183 - val_accuracy: 0.6645
# 	-!- No improvement: 7/20
# Epoch 22/100 - loss: 0.9056 - accuracy: 0.7883 - val_loss: 1.2887 - val_accuracy: 0.6693
# 	-!- No improvement: 8/20
# Epoch 23/100 - loss: 0.9006 - accuracy: 0.7907 - val_loss: 1.2987 - val_accuracy: 0.6695
# 	-!- No improvement: 9/20
# Epoch 24/100 - loss: 0.8990 - accuracy: 0.7940 - val_loss: 1.3016 - val_accuracy: 0.6732
# 	-!- No improvement: 10/20
# Epoch 25/100 - loss: 0.8892 - accuracy: 0.7971 - val_loss: 1.3086 - val_accuracy: 0.6723
# 	-!- No improvement: 11/20
# Epoch 26/100 - loss: 0.8924 - accuracy: 0.7937 - val_loss: 1.3113 - val_accuracy: 0.6740
# 	-!- No improvement: 12/20
# Epoch 27/100 - loss: 0.8820 - accuracy: 0.7989 - val_loss: 1.3105 - val_accuracy: 0.6712
# 	-!- No improvement: 13/20
# Epoch 28/100 - loss: 0.8857 - accuracy: 0.7975 - val_loss: 1.3018 - val_accuracy: 0.6734
# 	-!- No improvement: 14/20
# Epoch 29/100 - loss: 0.8877 - accuracy: 0.7974 - val_loss: 1.3253 - val_accuracy: 0.6687
# 	-!- No improvement: 15/20
# Epoch 30/100 - loss: 0.8857 - accuracy: 0.7989 - val_loss: 1.3176 - val_accuracy: 0.6751
# 	-!- No improvement: 16/20
# Epoch 31/100 - loss: 0.8774 - accuracy: 0.8043 - val_loss: 1.3160 - val_accuracy: 0.6729
# 	-!- No improvement: 17/20
# Epoch 32/100 - loss: 0.8741 - accuracy: 0.8041 - val_loss: 1.3140 - val_accuracy: 0.6726
# 	-!- No improvement: 18/20
# Epoch 33/100 - loss: 0.8799 - accuracy: 0.8023 - val_loss: 1.3103 - val_accuracy: 0.6740
# 	-!- No improvement: 19/20
# Epoch 34/100 - loss: 0.8730 - accuracy: 0.8020 - val_loss: 1.3106 - val_accuracy: 0.6729
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=34
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_cnn_dict_v2_dong_17042026_0728.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_dong_17042026_0728_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 17.42it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.01%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.602794  0.615071  0.608871   491.000000
# disgust        0.755102  0.672727  0.711538    55.000000
# fear           0.514644  0.465909  0.489066   528.000000
# happy          0.904762  0.864619  0.884235   879.000000
# sad            0.525084  0.528620  0.526846   594.000000
# surprise       0.745690  0.831731  0.786364   416.000000
# neutral        0.661608  0.696486  0.678599   626.000000
# accuracy       0.680134  0.680134  0.680134     0.680134
# macro avg      0.672812  0.667880  0.669360  3589.000000
# weighted avg   0.680076  0.680134  0.679419  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
#
# --> [Attention Heatmap] Generating region attention visualization...
#
# --> Generating attention heatmap for 4 CORRECT samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_correct.png
# --> Generating attention heatmap for 4 WRONG samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_wrong.png
# --> [Attention Heatmap] Done!
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `cnn_dict_v2_dong_17042026_0728_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.5s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.5s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.5s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.5s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (0.5s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.0s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.0s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.5s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0728_best.pth 1.1MB/256.4MB (0.1s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.5s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0728_best.pth 1.1MB/256.4MB (0.1s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.5s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0728_best.pth 1.1MB/256.4MB (0.1s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.5s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0728_best.pth 1.1MB/256.4MB (0.1s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (1.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0728_best.pth 1.1MB/256.4MB (0.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.0s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0728_best.pth 16.2MB/256.4MB (0.6s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.0s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0728_best.pth 16.2MB/256.4MB (0.6s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.0s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0728_best.pth 16.2MB/256.4MB (0.6s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.0s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0728_best.pth 16.2MB/256.4MB (0.6s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0728_best.pth 16.2MB/256.4MB (0.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.5s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0728_best.pth 64.5MB/256.4MB (1.1s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.5s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0728_best.pth 64.5MB/256.4MB (1.1s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0728_best.pth 64.5MB/256.4MB (1.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.5s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0728_best.pth 64.5MB/256.4MB (1.1s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (2.5s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0728_best.pth 64.5MB/256.4MB (1.1s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.0s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0728_best.pth 112.8MB/256.4MB (1.6s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.0s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0728_best.pth 112.8MB/256.4MB (1.6s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0728_best.pth 112.8MB/256.4MB (1.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.0s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0728_best.pth 112.8MB/256.4MB (1.6s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.0s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0728_best.pth 112.8MB/256.4MB (1.6s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.5s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0728_best.pth 160.7MB/256.4MB (2.1s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.5s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0728_best.pth 160.7MB/256.4MB (2.1s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.5s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0728_best.pth 160.7MB/256.4MB (2.1s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.5s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0728_best.pth 160.7MB/256.4MB (2.1s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (3.5s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0728_best.pth 160.7MB/256.4MB (2.1s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.0s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0728_best.pth 208.8MB/256.4MB (2.6s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.0s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0728_best.pth 208.8MB/256.4MB (2.6s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.0s)
# wandb:   ↳ ⣻ cnn_dict_v2_dong_17042026_0728_best.pth 208.8MB/256.4MB (2.6s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.0s)
# wandb:   ↳ ⣽ cnn_dict_v2_dong_17042026_0728_best.pth 208.8MB/256.4MB (2.6s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.0s)
# wandb:   ↳ ⣾ cnn_dict_v2_dong_17042026_0728_best.pth 208.8MB/256.4MB (2.6s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.5s)
# wandb:   ↳ ⣷ cnn_dict_v2_dong_17042026_0728_best.pth 255.9MB/256.4MB (3.1s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.5s)
# wandb:   ↳ ⣯ cnn_dict_v2_dong_17042026_0728_best.pth 255.9MB/256.4MB (3.1s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.5s)
# wandb:   ↳ ⣟ cnn_dict_v2_dong_17042026_0728_best.pth 255.9MB/256.4MB (3.1s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.5s)
# wandb:   ↳ ⡿ cnn_dict_v2_dong_17042026_0728_best.pth 255.9MB/256.4MB (3.1s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (4.5s)
# wandb:   ↳ ⢿ cnn_dict_v2_dong_17042026_0728_best.pth 255.9MB/256.4MB (3.1s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.0s)
# wandb: ⣯ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.0s)
# wandb: ⣟ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.5s)
# wandb: ⡿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.5s)
# wandb: ⢿ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.5s)
# wandb: ⣻ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.5s)
# wandb: ⣽ uploading artifact cnn_dict_v2_dong_17042026_0728_9h61z3le (5.5s)
# wandb: ⣾ uploading summary, console lines 114-114 (0.1s)
# wandb: ⣷ uploading summary, console lines 114-114 (0.1s)
# wandb: ⣯ uploading summary, console lines 114-114 (0.1s)
# wandb: ⣟ uploading summary, console lines 114-114 (0.1s)
# wandb: ⡿ uploading summary, console lines 114-114 (0.1s)
# wandb: ⢿ uploading summary, console lines 114-114 (0.6s)
# wandb: ⣻ uploading summary, console lines 114-114 (0.6s)
# wandb: ⣽ uploading summary, console lines 114-114 (0.6s)
# wandb: ⣾ uploading summary, console lines 114-114 (0.6s)
# wandb: ⣷ uploading summary, console lines 114-114 (0.6s)
# wandb: ⣯ uploading summary, console lines 114-114 (1.1s)
# wandb: ⣟ uploading summary, console lines 114-114 (1.1s)
# wandb: ⡿ uploading summary, console lines 114-114 (1.1s)
# wandb: ⢿ uploading summary, console lines 114-114 (1.1s)
# wandb: ⣻ uploading summary, console lines 114-114 (1.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ████████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▂▂▂▃▂▂▃▃▃▂▃▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇████
# wandb:     Train/Loss █▇▇▆▆▆▆▆▆▆▆▆▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▂▂▂▁▁▁▁
# wandb:   Val/Accuracy ▄▃▆▁▆▄▃▅▄▇▂▄▆▅▇▅▅▆▅▅▅▆▆▇▇█▇▇▆█▇▇█▇
# wandb:       Val/Loss ▇▇▁█▄▃▄▂▆▁▅█▄▃▄▄▃▄▄▆▇▄▅▅▆▆▆▅▇▇▇▆▆▆
# wandb:
# wandb: Run summary:
# wandb:          Epoch 34
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.80201
# wandb:     Train/Loss 0.873
# wandb:   Val/Accuracy 0.67289
# wandb:       Val/Loss 1.31058
# wandb:
# wandb: 🚀 View run cnn_dict_v2_dong_17042026_0728 at: https://wandb.ai/phucga15062005/FER2013/runs/9h61z3le
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 6 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_072838-9h61z3le/logs
#
# 		DONE!
