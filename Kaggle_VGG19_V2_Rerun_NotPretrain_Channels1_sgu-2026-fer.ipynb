# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 337, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 337 (delta 1), reused 1 (delta 0), pack-reused 329 (from 1)
# Receiving objects: 100% (337/337), 1.72 MiB | 11.08 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg19 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run ayommh4l (0.2s)
# wandb: ⣾ setting up run ayommh4l (0.2s)
# wandb: ⣷ setting up run ayommh4l (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260403_144818-ayommh4l
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg19_03042026_1448
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/ayommh4l
#
# --> Start training in total 30 epochs with cuda device. Start...
#
# Epoch 1/30 - loss: 1.9576 - accuracy: 0.1721 - val_loss: 1.9441 - val_accuracy: 0.1301
# 	--- Save best at ep 1, val_loss: 1.9441, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_03042026_1448_best.pth ---
# Epoch 2/30 - loss: 1.9431 - accuracy: 0.1841 - val_loss: 1.9443 - val_accuracy: 0.1382
# 	-!- No improvement: 1/10
# Epoch 3/30 - loss: 1.9434 - accuracy: 0.1869 - val_loss: 1.9441 - val_accuracy: 0.2494
# 	--- Save best at ep 3, val_loss: 1.9441, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_03042026_1448_best.pth ---
# Epoch 4/30 - loss: 1.9433 - accuracy: 0.1773 - val_loss: 1.9441 - val_accuracy: 0.2494
# 	--- Save best at ep 4, val_loss: 1.9441, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_03042026_1448_best.pth ---
# Epoch 5/30 - loss: 1.9444 - accuracy: 0.2121 - val_loss: 1.9434 - val_accuracy: 0.1156
# 	--- Save best at ep 5, val_loss: 1.9434, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_03042026_1448_best.pth ---
# Epoch 6/30 - loss: 1.9442 - accuracy: 0.1748 - val_loss: 1.9439 - val_accuracy: 0.1691
# 	-!- No improvement: 1/10
# Epoch 7/30 - loss: 1.9431 - accuracy: 0.1727 - val_loss: 1.9444 - val_accuracy: 0.2494
# 	-!- No improvement: 2/10
# Epoch 8/30 - loss: 1.9434 - accuracy: 0.1960 - val_loss: 1.9442 - val_accuracy: 0.1301
# 	-!- No improvement: 3/10
# Epoch 9/30 - loss: 1.9435 - accuracy: 0.1738 - val_loss: 1.9439 - val_accuracy: 0.1382
# 	-!- No improvement: 4/10
# Epoch 10/30 - loss: 1.9432 - accuracy: 0.1962 - val_loss: 1.9438 - val_accuracy: 0.2494
# 	-!- No improvement: 5/10
# Epoch 11/30 - loss: 1.9426 - accuracy: 0.1979 - val_loss: 1.9437 - val_accuracy: 0.2494
# 	-!- No improvement: 6/10
# Epoch 12/30 - loss: 1.9429 - accuracy: 0.1909 - val_loss: 1.9439 - val_accuracy: 0.2494
# 	-!- No improvement: 7/10
# Epoch 13/30 - loss: 1.9428 - accuracy: 0.1882 - val_loss: 1.9440 - val_accuracy: 0.2494
# 	-!- No improvement: 8/10
# Epoch 14/30 - loss: 1.9427 - accuracy: 0.2179 - val_loss: 1.9439 - val_accuracy: 0.2494
# 	-!- No improvement: 9/10
# Epoch 15/30 - loss: 1.9429 - accuracy: 0.2252 - val_loss: 1.9439 - val_accuracy: 0.2494
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=15
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_03042026_1448_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|███████████████████| 113/113 [00:13<00:00,  8.15it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# --> Accuracy: 11.59%
# --> Report:
#                precision    recall  f1-score     support
# angry          0.000000  0.000000  0.000000   491.00000
# disgust        0.000000  0.000000  0.000000    55.00000
# fear           0.000000  0.000000  0.000000   528.00000
# happy          0.000000  0.000000  0.000000   879.00000
# sad            0.000000  0.000000  0.000000   594.00000
# surprise       0.115910  1.000000  0.207740   416.00000
# neutral        0.000000  0.000000  0.000000   626.00000
# accuracy       0.115910  0.115910  0.115910     0.11591
# macro avg      0.016559  0.142857  0.029677  3589.00000
# weighted avg   0.013435  0.115910  0.024079  3589.00000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg19_03042026_1448_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_ayommh4l (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_ayommh4l (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_ayommh4l (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_ayommh4l (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_ayommh4l (0.5s)
# wandb: ⣯ uploading artifact cnn_ayommh4l (0.5s)
# wandb: ⣟ uploading artifact cnn_ayommh4l (0.5s)
# wandb: ⡿ uploading artifact cnn_ayommh4l (0.5s)
# wandb: ⢿ uploading artifact cnn_ayommh4l (0.5s)
# wandb: ⣻ uploading artifact cnn_ayommh4l (1.0s)
# wandb:   ↳ ⣻ vgg19_03042026_1448_best.pth 55.0MB/254.7MB (0.5s)
# wandb: ⣽ uploading artifact cnn_ayommh4l (1.0s)
# wandb:   ↳ ⣽ vgg19_03042026_1448_best.pth 55.0MB/254.7MB (0.5s)
# wandb: ⣾ uploading artifact cnn_ayommh4l (1.0s)
# wandb:   ↳ ⣾ vgg19_03042026_1448_best.pth 55.0MB/254.7MB (0.5s)
# wandb: ⣷ uploading artifact cnn_ayommh4l (1.0s)
# wandb:   ↳ ⣷ vgg19_03042026_1448_best.pth 55.0MB/254.7MB (0.5s)
# wandb: ⣯ uploading artifact cnn_ayommh4l (1.0s)
# wandb:   ↳ ⣯ vgg19_03042026_1448_best.pth 55.0MB/254.7MB (0.5s)
# wandb: ⣟ uploading artifact cnn_ayommh4l (1.5s)
# wandb:   ↳ ⣟ vgg19_03042026_1448_best.pth 91.0MB/254.7MB (1.0s)
# wandb: ⡿ uploading artifact cnn_ayommh4l (1.5s)
# wandb:   ↳ ⡿ vgg19_03042026_1448_best.pth 91.0MB/254.7MB (1.0s)
# wandb: ⢿ uploading artifact cnn_ayommh4l (1.5s)
# wandb:   ↳ ⢿ vgg19_03042026_1448_best.pth 91.0MB/254.7MB (1.0s)
# wandb: ⣻ uploading artifact cnn_ayommh4l (1.5s)
# wandb:   ↳ ⣻ vgg19_03042026_1448_best.pth 91.0MB/254.7MB (1.0s)
# wandb: ⣽ uploading artifact cnn_ayommh4l (1.5s)
# wandb:   ↳ ⣽ vgg19_03042026_1448_best.pth 91.0MB/254.7MB (1.0s)
# wandb: ⣾ uploading artifact cnn_ayommh4l (2.0s)
# wandb:   ↳ ⣾ vgg19_03042026_1448_best.pth 149.5MB/254.7MB (1.5s)
# wandb: ⣷ uploading artifact cnn_ayommh4l (2.0s)
# wandb:   ↳ ⣷ vgg19_03042026_1448_best.pth 149.5MB/254.7MB (1.5s)
# wandb: ⣯ uploading artifact cnn_ayommh4l (2.0s)
# wandb:   ↳ ⣯ vgg19_03042026_1448_best.pth 149.5MB/254.7MB (1.5s)
# wandb: ⣟ uploading artifact cnn_ayommh4l (2.0s)
# wandb:   ↳ ⣟ vgg19_03042026_1448_best.pth 149.5MB/254.7MB (1.5s)
# wandb: ⡿ uploading artifact cnn_ayommh4l (2.0s)
# wandb:   ↳ ⡿ vgg19_03042026_1448_best.pth 149.5MB/254.7MB (1.5s)
# wandb: ⢿ uploading artifact cnn_ayommh4l (2.5s)
# wandb:   ↳ ⢿ vgg19_03042026_1448_best.pth 197.0MB/254.7MB (2.0s)
# wandb: ⣻ uploading artifact cnn_ayommh4l (2.5s)
# wandb:   ↳ ⣻ vgg19_03042026_1448_best.pth 197.0MB/254.7MB (2.0s)
# wandb: ⣽ uploading artifact cnn_ayommh4l (2.5s)
# wandb:   ↳ ⣽ vgg19_03042026_1448_best.pth 197.0MB/254.7MB (2.0s)
# wandb: ⣾ uploading artifact cnn_ayommh4l (2.5s)
# wandb:   ↳ ⣾ vgg19_03042026_1448_best.pth 197.0MB/254.7MB (2.0s)
# wandb: ⣷ uploading artifact cnn_ayommh4l (2.5s)
# wandb:   ↳ ⣷ vgg19_03042026_1448_best.pth 197.0MB/254.7MB (2.0s)
# wandb: ⣯ uploading artifact cnn_ayommh4l (3.0s)
# wandb:   ↳ ⣯ vgg19_03042026_1448_best.pth 242.2MB/254.7MB (2.5s)
# wandb: ⣟ uploading artifact cnn_ayommh4l (3.0s)
# wandb:   ↳ ⣟ vgg19_03042026_1448_best.pth 242.2MB/254.7MB (2.5s)
# wandb: ⡿ uploading artifact cnn_ayommh4l (3.0s)
# wandb:   ↳ ⡿ vgg19_03042026_1448_best.pth 242.2MB/254.7MB (2.5s)
# wandb: ⢿ uploading artifact cnn_ayommh4l (3.0s)
# wandb:   ↳ ⢿ vgg19_03042026_1448_best.pth 242.2MB/254.7MB (2.5s)
# wandb: ⣻ uploading artifact cnn_ayommh4l (3.0s)
# wandb:   ↳ ⣻ vgg19_03042026_1448_best.pth 242.2MB/254.7MB (2.5s)
# wandb: ⣽ uploading artifact cnn_ayommh4l (3.5s)
# wandb: ⣾ uploading artifact cnn_ayommh4l (3.5s)
# wandb: ⣷ uploading artifact cnn_ayommh4l (3.5s)
# wandb: ⣯ uploading artifact cnn_ayommh4l (3.5s)
# wandb: ⣟ uploading artifact cnn_ayommh4l (3.5s)
# wandb: ⡿ uploading history steps 14-16, summary, console lines 40-68 (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▂▃▃▃▄▅▅▅▆▇▇▇█
# wandb:  Learning_Rate █████████▃▃▃▃▁▁
# wandb: Train/Accuracy ▁▃▃▂▆▁▁▄▁▄▄▃▃▇█
# wandb:     Train/Loss █▁▁▁▂▂▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▂▂██▁▄█▂▂██████
# wandb:       Val/Loss ▆█▆▆▁▄█▆▅▄▄▅▅▄▄
# wandb:
# wandb: Run summary:
# wandb:          Epoch 15
# wandb:  Learning_Rate 0.00025
# wandb: Train/Accuracy 0.22523
# wandb:     Train/Loss 1.94288
# wandb:   Val/Accuracy 0.24937
# wandb:       Val/Loss 1.94385
# wandb:
# wandb: 🚀 View run vgg19_03042026_1448 at: https://wandb.ai/phucga15062005/FER2013/runs/ayommh4l
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260403_144818-ayommh4l/logs
#
# 		DONE!
