# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 4

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1777, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 1777 (delta 110), reused 98 (delta 93), pack-reused 1632 (from 1)
# Receiving objects: 100% (1777/1777), 6.19 MiB | 29.34 MiB/s, done.
# Resolving deltas: 100% (1266/1266), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config resnet35 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run tnlvmzf5 (0.3s)
# wandb: ⣷ setting up run tnlvmzf5 (0.3s)
# wandb: ⣯ setting up run tnlvmzf5 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260415_020435-tnlvmzf5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_15042026_0204
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/tnlvmzf5
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.0032 - accuracy: 0.1768 - val_loss: 1.9173 - val_accuracy: 0.1920
# 	--- Save best at ep 1, val_loss: 1.9173, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 2/100 - loss: 1.8600 - accuracy: 0.2373 - val_loss: 1.7075 - val_accuracy: 0.2619
# 	--- Save best at ep 2, val_loss: 1.7075, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 3/100 - loss: 1.7369 - accuracy: 0.3293 - val_loss: 1.7074 - val_accuracy: 0.3898
# 	--- Save best at ep 3, val_loss: 1.7074, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 4/100 - loss: 1.6272 - accuracy: 0.3892 - val_loss: 1.9218 - val_accuracy: 0.3399
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.5555 - accuracy: 0.4108 - val_loss: 1.4668 - val_accuracy: 0.4330
# 	--- Save best at ep 5, val_loss: 1.4668, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 6/100 - loss: 1.5037 - accuracy: 0.4299 - val_loss: 1.4553 - val_accuracy: 0.5024
# 	--- Save best at ep 6, val_loss: 1.4553, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 7/100 - loss: 1.4608 - accuracy: 0.4488 - val_loss: 1.5685 - val_accuracy: 0.4519
# 	-!- No improvement: 1/20
# Epoch 8/100 - loss: 1.4292 - accuracy: 0.4585 - val_loss: 1.4333 - val_accuracy: 0.4968
# 	--- Save best at ep 8, val_loss: 1.4333, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 9/100 - loss: 1.4049 - accuracy: 0.4658 - val_loss: 1.3335 - val_accuracy: 0.4909
# 	--- Save best at ep 9, val_loss: 1.3335, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 10/100 - loss: 1.3896 - accuracy: 0.4761 - val_loss: 1.3330 - val_accuracy: 0.5088
# 	--- Save best at ep 10, val_loss: 1.3330, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 11/100 - loss: 1.3471 - accuracy: 0.4875 - val_loss: 1.3646 - val_accuracy: 0.4597
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 1.3407 - accuracy: 0.4911 - val_loss: 1.2869 - val_accuracy: 0.5163
# 	--- Save best at ep 12, val_loss: 1.2869, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 13/100 - loss: 1.3468 - accuracy: 0.4926 - val_loss: 1.3280 - val_accuracy: 0.5269
# 	-!- No improvement: 1/20
# Epoch 14/100 - loss: 1.3145 - accuracy: 0.5020 - val_loss: 1.3314 - val_accuracy: 0.5216
# 	-!- No improvement: 2/20
# Epoch 15/100 - loss: 1.2957 - accuracy: 0.5103 - val_loss: 1.2858 - val_accuracy: 0.5185
# 	--- Save best at ep 15, val_loss: 1.2858, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 16/100 - loss: 1.2963 - accuracy: 0.5136 - val_loss: 1.2407 - val_accuracy: 0.5403
# 	--- Save best at ep 16, val_loss: 1.2407, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 17/100 - loss: 1.2634 - accuracy: 0.5187 - val_loss: 1.2878 - val_accuracy: 0.5430
# 	-!- No improvement: 1/20
# Epoch 18/100 - loss: 1.2511 - accuracy: 0.5246 - val_loss: 1.1750 - val_accuracy: 0.5548
# 	--- Save best at ep 18, val_loss: 1.1750, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 19/100 - loss: 1.2480 - accuracy: 0.5242 - val_loss: 1.2750 - val_accuracy: 0.5461
# 	-!- No improvement: 1/20
# Epoch 20/100 - loss: 1.2389 - accuracy: 0.5291 - val_loss: 1.2164 - val_accuracy: 0.5690
# 	-!- No improvement: 2/20
# Epoch 21/100 - loss: 1.2213 - accuracy: 0.5306 - val_loss: 1.2480 - val_accuracy: 0.5729
# 	-!- No improvement: 3/20
# Epoch 22/100 - loss: 1.2132 - accuracy: 0.5359 - val_loss: 1.2486 - val_accuracy: 0.5840
# 	-!- No improvement: 4/20
# Epoch 23/100 - loss: 1.1556 - accuracy: 0.5599 - val_loss: 1.1654 - val_accuracy: 0.5734
# 	--- Save best at ep 23, val_loss: 1.1654, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 24/100 - loss: 1.1292 - accuracy: 0.5654 - val_loss: 1.2030 - val_accuracy: 0.5874
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 1.1143 - accuracy: 0.5646 - val_loss: 1.1399 - val_accuracy: 0.5896
# 	--- Save best at ep 25, val_loss: 1.1399, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 26/100 - loss: 1.1100 - accuracy: 0.5713 - val_loss: 1.1552 - val_accuracy: 0.5821
# 	-!- No improvement: 1/20
# Epoch 27/100 - loss: 1.1006 - accuracy: 0.5750 - val_loss: 1.1573 - val_accuracy: 0.6049
# 	-!- No improvement: 2/20
# Epoch 28/100 - loss: 1.0946 - accuracy: 0.5774 - val_loss: 1.1264 - val_accuracy: 0.6049
# 	--- Save best at ep 28, val_loss: 1.1264, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 29/100 - loss: 1.0702 - accuracy: 0.5842 - val_loss: 1.1811 - val_accuracy: 0.5932
# 	-!- No improvement: 1/20
# Epoch 30/100 - loss: 1.0774 - accuracy: 0.5819 - val_loss: 1.1181 - val_accuracy: 0.6155
# 	--- Save best at ep 30, val_loss: 1.1181, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 31/100 - loss: 1.0609 - accuracy: 0.5872 - val_loss: 1.1337 - val_accuracy: 0.5893
# 	-!- No improvement: 1/20
# Epoch 32/100 - loss: 1.0583 - accuracy: 0.5885 - val_loss: 1.1721 - val_accuracy: 0.6004
# 	-!- No improvement: 2/20
# Epoch 33/100 - loss: 1.0349 - accuracy: 0.5925 - val_loss: 1.1520 - val_accuracy: 0.5773
# 	-!- No improvement: 3/20
# Epoch 34/100 - loss: 1.0489 - accuracy: 0.5887 - val_loss: 1.1403 - val_accuracy: 0.6002
# 	-!- No improvement: 4/20
# Epoch 35/100 - loss: 0.9931 - accuracy: 0.6078 - val_loss: 1.1029 - val_accuracy: 0.6158
# 	--- Save best at ep 35, val_loss: 1.1029, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 36/100 - loss: 0.9899 - accuracy: 0.6150 - val_loss: 1.1013 - val_accuracy: 0.6202
# 	--- Save best at ep 36, val_loss: 1.1013, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 37/100 - loss: 0.9718 - accuracy: 0.6176 - val_loss: 1.0906 - val_accuracy: 0.6152
# 	--- Save best at ep 37, val_loss: 1.0906, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 38/100 - loss: 0.9567 - accuracy: 0.6192 - val_loss: 1.0805 - val_accuracy: 0.6152
# 	--- Save best at ep 38, val_loss: 1.0805, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 39/100 - loss: 0.9635 - accuracy: 0.6200 - val_loss: 1.1244 - val_accuracy: 0.6096
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 0.9542 - accuracy: 0.6221 - val_loss: 1.1222 - val_accuracy: 0.6199
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 0.9448 - accuracy: 0.6251 - val_loss: 1.0673 - val_accuracy: 0.6289
# 	--- Save best at ep 41, val_loss: 1.0673, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 42/100 - loss: 0.9454 - accuracy: 0.6255 - val_loss: 1.1216 - val_accuracy: 0.6250
# 	-!- No improvement: 1/20
# Epoch 43/100 - loss: 0.9506 - accuracy: 0.6231 - val_loss: 1.0645 - val_accuracy: 0.6300
# 	--- Save best at ep 43, val_loss: 1.0645, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth ---
# Epoch 44/100 - loss: 0.9248 - accuracy: 0.6287 - val_loss: 1.0831 - val_accuracy: 0.6272
# 	-!- No improvement: 1/20
# Epoch 45/100 - loss: 0.9312 - accuracy: 0.6298 - val_loss: 1.0904 - val_accuracy: 0.6230
# 	-!- No improvement: 2/20
# Epoch 46/100 - loss: 0.9193 - accuracy: 0.6337 - val_loss: 1.1332 - val_accuracy: 0.6289
# 	-!- No improvement: 3/20
# Epoch 47/100 - loss: 0.9240 - accuracy: 0.6296 - val_loss: 1.1218 - val_accuracy: 0.6216
# 	-!- No improvement: 4/20
# Epoch 48/100 - loss: 0.8940 - accuracy: 0.6436 - val_loss: 1.1128 - val_accuracy: 0.6417
# 	-!- No improvement: 5/20
# Epoch 49/100 - loss: 0.8793 - accuracy: 0.6470 - val_loss: 1.0872 - val_accuracy: 0.6358
# 	-!- No improvement: 6/20
# Epoch 50/100 - loss: 0.8731 - accuracy: 0.6484 - val_loss: 1.0699 - val_accuracy: 0.6364
# 	-!- No improvement: 7/20
# Epoch 51/100 - loss: 0.8790 - accuracy: 0.6499 - val_loss: 1.0683 - val_accuracy: 0.6372
# 	-!- No improvement: 8/20
# Epoch 52/100 - loss: 0.8601 - accuracy: 0.6546 - val_loss: 1.0956 - val_accuracy: 0.6395
# 	-!- No improvement: 9/20
# Epoch 53/100 - loss: 0.8502 - accuracy: 0.6545 - val_loss: 1.0727 - val_accuracy: 0.6400
# 	-!- No improvement: 10/20
# Epoch 54/100 - loss: 0.8437 - accuracy: 0.6558 - val_loss: 1.1065 - val_accuracy: 0.6389
# 	-!- No improvement: 11/20
# Epoch 55/100 - loss: 0.8426 - accuracy: 0.6602 - val_loss: 1.0895 - val_accuracy: 0.6386
# 	-!- No improvement: 12/20
# Epoch 56/100 - loss: 0.8346 - accuracy: 0.6632 - val_loss: 1.0852 - val_accuracy: 0.6436
# 	-!- No improvement: 13/20
# Epoch 57/100 - loss: 0.8376 - accuracy: 0.6680 - val_loss: 1.1019 - val_accuracy: 0.6500
# 	-!- No improvement: 14/20
# Epoch 58/100 - loss: 0.8225 - accuracy: 0.6654 - val_loss: 1.1038 - val_accuracy: 0.6461
# 	-!- No improvement: 15/20
# Epoch 59/100 - loss: 0.8299 - accuracy: 0.6660 - val_loss: 1.0872 - val_accuracy: 0.6450
# 	-!- No improvement: 16/20
# Epoch 60/100 - loss: 0.8206 - accuracy: 0.6686 - val_loss: 1.0896 - val_accuracy: 0.6456
# 	-!- No improvement: 17/20
# Epoch 61/100 - loss: 0.8234 - accuracy: 0.6652 - val_loss: 1.1020 - val_accuracy: 0.6495
# 	-!- No improvement: 18/20
# Epoch 62/100 - loss: 0.8216 - accuracy: 0.6664 - val_loss: 1.0882 - val_accuracy: 0.6453
# 	-!- No improvement: 19/20
# Epoch 63/100 - loss: 0.8166 - accuracy: 0.6691 - val_loss: 1.0910 - val_accuracy: 0.6439
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=63
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0204_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:02<00:00, 22.32it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 64.86%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.535912  0.592668  0.562863   491.000000
# disgust        0.403846  0.763636  0.528302    55.000000
# fear           0.540107  0.382576  0.447894   528.000000
# happy          0.898204  0.853242  0.875146   879.000000
# sad            0.510676  0.483165  0.496540   594.000000
# surprise       0.716157  0.788462  0.750572   416.000000
# neutral        0.600281  0.683706  0.639283   626.000000
# accuracy       0.648649  0.648649  0.648649     0.648649
# macro avg      0.600740  0.649636  0.614371  3589.000000
# weighted avg   0.651179  0.648649  0.646012  3589.000000
# --> Grad-CAM Heatmap Active: Layer-4 Hooked!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.34663865..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6343283..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5019685..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5691964..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5141129..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41764706..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48755184..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4930693..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.787037..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3421053..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5141129..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5748031..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6960784..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.46544713..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48553717..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5641593..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.54487175..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1829268..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_15042026_0204_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_tnlvmzf5 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_tnlvmzf5 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_tnlvmzf5 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_tnlvmzf5 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_tnlvmzf5 (0.5s)
# wandb: ⣯ uploading artifact cnn_tnlvmzf5 (0.5s)
# wandb: ⣟ uploading artifact cnn_tnlvmzf5 (0.5s)
# wandb: ⡿ uploading artifact cnn_tnlvmzf5 (0.5s)
# wandb: ⢿ uploading artifact cnn_tnlvmzf5 (0.5s)
# wandb: ⣻ uploading artifact cnn_tnlvmzf5 (1.0s)
# wandb:   ↳ ⣻ resnet35_15042026_0204_best.pth 1.2MB/80.2MB (0.1s)
# wandb: ⣽ uploading artifact cnn_tnlvmzf5 (1.0s)
# wandb:   ↳ ⣽ resnet35_15042026_0204_best.pth 1.2MB/80.2MB (0.1s)
# wandb: ⣾ uploading artifact cnn_tnlvmzf5 (1.0s)
# wandb:   ↳ ⣾ resnet35_15042026_0204_best.pth 1.2MB/80.2MB (0.1s)
# wandb: ⣷ uploading artifact cnn_tnlvmzf5 (1.0s)
# wandb:   ↳ ⣷ resnet35_15042026_0204_best.pth 1.2MB/80.2MB (0.1s)
# wandb: ⣯ uploading artifact cnn_tnlvmzf5 (1.0s)
# wandb:   ↳ ⣯ resnet35_15042026_0204_best.pth 1.2MB/80.2MB (0.1s)
# wandb: ⣟ uploading artifact cnn_tnlvmzf5 (1.5s)
# wandb:   ↳ ⣟ resnet35_15042026_0204_best.pth 31.0MB/80.2MB (0.6s)
# wandb: ⡿ uploading artifact cnn_tnlvmzf5 (1.5s)
# wandb:   ↳ ⡿ resnet35_15042026_0204_best.pth 31.0MB/80.2MB (0.6s)
# wandb: ⢿ uploading artifact cnn_tnlvmzf5 (1.5s)
# wandb:   ↳ ⢿ resnet35_15042026_0204_best.pth 31.0MB/80.2MB (0.6s)
# wandb: ⣻ uploading artifact cnn_tnlvmzf5 (1.5s)
# wandb:   ↳ ⣻ resnet35_15042026_0204_best.pth 31.0MB/80.2MB (0.6s)
# wandb: ⣽ uploading artifact cnn_tnlvmzf5 (1.5s)
# wandb:   ↳ ⣽ resnet35_15042026_0204_best.pth 31.0MB/80.2MB (0.6s)
# wandb: ⣾ uploading artifact cnn_tnlvmzf5 (2.0s)
# wandb:   ↳ ⣾ resnet35_15042026_0204_best.pth 69.7MB/80.2MB (1.1s)
# wandb: ⣷ uploading artifact cnn_tnlvmzf5 (2.0s)
# wandb:   ↳ ⣷ resnet35_15042026_0204_best.pth 69.7MB/80.2MB (1.1s)
# wandb: ⣯ uploading artifact cnn_tnlvmzf5 (2.0s)
# wandb:   ↳ ⣯ resnet35_15042026_0204_best.pth 69.7MB/80.2MB (1.1s)
# wandb: ⣟ uploading artifact cnn_tnlvmzf5 (2.0s)
# wandb:   ↳ ⣟ resnet35_15042026_0204_best.pth 69.7MB/80.2MB (1.1s)
# wandb: ⡿ uploading artifact cnn_tnlvmzf5 (2.0s)
# wandb:   ↳ ⡿ resnet35_15042026_0204_best.pth 69.7MB/80.2MB (1.1s)
# wandb: ⢿ uploading artifact cnn_tnlvmzf5 (2.5s)
# wandb: ⣻ uploading artifact cnn_tnlvmzf5 (2.5s)
# wandb: ⣽ uploading artifact cnn_tnlvmzf5 (2.5s)
# wandb: ⣾ uploading artifact cnn_tnlvmzf5 (2.5s)
# wandb: ⣷ uploading artifact cnn_tnlvmzf5 (2.5s)
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb: ⡿ Finishing up...
# wandb: ⢿ Finishing up...
# wandb: ⣻ Finishing up...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ███████████████▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████
# wandb:     Train/Loss █▇▆▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▂▅▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█████▇█████████
# wandb:       Val/Loss ▆▆█▅▄▃▃▃▃▃▃▂▂▃▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 63
# wandb:  Learning_Rate 2e-05
# wandb: Train/Accuracy 0.66906
# wandb:     Train/Loss 0.81664
# wandb:   Val/Accuracy 0.64391
# wandb:       Val/Loss 1.091
# wandb:
# wandb: 🚀 View run resnet35_15042026_0204 at: https://wandb.ai/phucga15062005/FER2013/runs/tnlvmzf5
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260415_020435-tnlvmzf5/logs
#
# 		DONE!
