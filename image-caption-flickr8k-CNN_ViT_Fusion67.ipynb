# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 8095

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "image-captioning-flickr8k-iu"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'image-captioning-flickr8k-iu'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 211 (delta 107), reused 161 (delta 60), pack-reused 0 (from 0)
# Receiving objects: 100% (211/211), 54.89 KiB | 2.11 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# Repo ready: /kaggle/working/image-captioning-flickr8k-iu
#
# Current working dir: /kaggle/working/image-captioning-flickr8k-iu

# %%
# !python -m scripts.train --config transformer --env kaggle
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Image Dir: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/images
# --> Captions File: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/captions.txt
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 142MB/s]
# --> [Scheduler] StepLR (step_size=5, gamma=0.5)
#
# --> Train on 30000 samples, validate on 5000 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run akglfkkt (0.2s)
# wandb: ⣾ setting up run akglfkkt (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/image-captioning-flickr8k-iu/wandb/run-20260408_091459-akglfkkt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_08042026_0912
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/image-captioning
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/image-captioning/runs/akglfkkt
#
# --> Start training in total 30 epochs with cuda device. Start...
#
# Epoch 1/30 - loss: 3.7383 - val_loss: 3.2068
# 	--- Save best at ep 1, val_loss: 3.2068, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 2/30 - loss: 2.9775 - val_loss: 2.9425
# 	--- Save best at ep 2, val_loss: 2.9425, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 3/30 - loss: 2.7163 - val_loss: 2.8273
# 	--- Save best at ep 3, val_loss: 2.8273, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 4/30 - loss: 2.5464 - val_loss: 2.7612
# 	--- Save best at ep 4, val_loss: 2.7612, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 5/30 - loss: 2.4185 - val_loss: 2.7249
# 	--- Save best at ep 5, val_loss: 2.7249, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 6/30 - loss: 2.2820 - val_loss: 2.6957
# 	--- Save best at ep 6, val_loss: 2.6957, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 7/30 - loss: 2.2264 - val_loss: 2.6950
# 	--- Save best at ep 7, val_loss: 2.6950, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 8/30 - loss: 2.1794 - val_loss: 2.6868
# 	--- Save best at ep 8, val_loss: 2.6868, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 9/30 - loss: 2.1355 - val_loss: 2.6827
# 	--- Save best at ep 9, val_loss: 2.6827, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 10/30 - loss: 2.0936 - val_loss: 2.6848
# 	-!- No improvement: 1/10
# Epoch 11/30 - loss: 2.0334 - val_loss: 2.6799
# 	--- Save best at ep 11, val_loss: 2.6799, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth ---
# Epoch 12/30 - loss: 2.0096 - val_loss: 2.6826
# 	-!- No improvement: 1/10
# Epoch 13/30 - loss: 1.9908 - val_loss: 2.6860
# 	-!- No improvement: 2/10
# Epoch 14/30 - loss: 1.9714 - val_loss: 2.6921
# 	-!- No improvement: 3/10
# Epoch 15/30 - loss: 1.9525 - val_loss: 2.6976
# 	-!- No improvement: 4/10
# Epoch 16/30 - loss: 1.9228 - val_loss: 2.6960
# 	-!- No improvement: 5/10
# Epoch 17/30 - loss: 1.9121 - val_loss: 2.6957
# 	-!- No improvement: 6/10
# Epoch 18/30 - loss: 1.9017 - val_loss: 2.6998
# 	-!- No improvement: 7/10
# Epoch 19/30 - loss: 1.8922 - val_loss: 2.7035
# 	-!- No improvement: 8/10
# Epoch 20/30 - loss: 1.8835 - val_loss: 2.7073
# 	-!- No improvement: 9/10
# Epoch 21/30 - loss: 1.8678 - val_loss: 2.7075
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=21
#
# ===================================================
# Evaluate on Test set
# ===================================================
# --> [Evaluation] Đang gom nhóm và đánh giá trên 5000 mẫu (beam)...
#   0%|                                                   | 0/157 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/train.py", line 135, in <module>
#     main()
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/train.py", line 110, in main
#     test_metrics = evaluate_model(model, test_loader, vocab, device, method='beam')
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/evaluation/evaluator.py", line 34, in evaluate_model
#     pred_tokens = model.generate(img, vocab, method=method, beam_size=beam_size, max_len=max_len, device=device)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/models/transformer.py", line 69, in generate
#     return self._beam_search_decode(images, vocab, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/models/transformer.py", line 106, in _beam_search_decode
#     features = self.spatial_encoder(self.cnn_encoder(images)) # [B, 49, 512]
#                                     ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1965, in __getattr__
#     raise AttributeError(
# AttributeError: 'TransformerCaptionModel' object has no attribute 'cnn_encoder'
# wandb:
# wandb: 🚀 View run transformer_08042026_0912 at: https://wandb.ai/phucga15062005/image-captioning/runs/akglfkkt
# wandb: Find logs at: wandb/run-20260408_091459-akglfkkt/logs

# %%
# !python -m scripts.analyze_best --config transformer --env kaggle
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# --> [Analysis] Loading data from /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k...
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# --> [Analysis] Loading checkpoint: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0912_best.pth
# --> [Analysis] Đang trích xuất kết quả chi tiết...
#   0%|                                                   | 0/157 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/analyze_best.py", line 111, in <module>
#     main()
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/analyze_best.py", line 60, in main
#     detailed_results = get_detailed_results(model, test_loader, vocab, device, method='beam', beam_size=5)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/evaluation/evaluator.py", line 108, in get_detailed_results
#     pred_tokens = model.generate(img, vocab, method=method, beam_size=beam_size, max_len=max_len, device=device)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/models/transformer.py", line 69, in generate
#     return self._beam_search_decode(images, vocab, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/models/transformer.py", line 106, in _beam_search_decode
#     features = self.spatial_encoder(self.cnn_encoder(images)) # [B, 49, 512]
#                                     ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1965, in __getattr__
#     raise AttributeError(
# AttributeError: 'TransformerCaptionModel' object has no attribute 'cnn_encoder'
