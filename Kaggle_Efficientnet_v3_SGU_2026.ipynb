# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Tree"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 628, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 628 (delta 30), reused 33 (delta 26), pack-reused 580 (from 1)
# Receiving objects: 100% (628/628), 4.35 MiB | 20.62 MiB/s, done.
# Resolving deltas: 100% (391/391), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config efficientnet --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# [Loss] Using loss: focal_loss
# [Loss] gamma = 2.0, reduction = mean
# [Loss] class_weights = tensor([0.7991, 2.2189, 0.7977, 0.7850, 0.7907, 0.8187, 0.7899],
#        device='cuda:0')
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260404_165729-0wmg9949
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run efficientnet_fer2013_04042026_1657
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/0wmg9949
#
# --> Start training in total 50 epochs with cuda device. Start...
#
# Epoch 1/50 - loss: 0.9884 - accuracy: 0.3189 - val_loss: 0.9138 - val_accuracy: 0.3934
# 	--- Save best at ep 1, val_loss: 0.9138, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 2/50 - loss: 0.8014 - accuracy: 0.4415 - val_loss: 0.7686 - val_accuracy: 0.4539
# 	--- Save best at ep 2, val_loss: 0.7686, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 3/50 - loss: 0.7175 - accuracy: 0.4875 - val_loss: 0.7086 - val_accuracy: 0.4857
# 	--- Save best at ep 3, val_loss: 0.7086, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 4/50 - loss: 0.6663 - accuracy: 0.5163 - val_loss: 0.6378 - val_accuracy: 0.5325
# 	--- Save best at ep 4, val_loss: 0.6378, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 5/50 - loss: 0.6397 - accuracy: 0.5283 - val_loss: 0.6385 - val_accuracy: 0.5339
# 	-!- No improvement: 1/10
# Epoch 6/50 - loss: 0.6206 - accuracy: 0.5387 - val_loss: 0.5976 - val_accuracy: 0.5442
# 	--- Save best at ep 6, val_loss: 0.5976, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 7/50 - loss: 0.6020 - accuracy: 0.5494 - val_loss: 0.6283 - val_accuracy: 0.5497
# 	-!- No improvement: 1/10
# Epoch 8/50 - loss: 0.5851 - accuracy: 0.5575 - val_loss: 0.5717 - val_accuracy: 0.5754
# 	--- Save best at ep 8, val_loss: 0.5717, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 9/50 - loss: 0.5759 - accuracy: 0.5627 - val_loss: 0.5615 - val_accuracy: 0.5751
# 	--- Save best at ep 9, val_loss: 0.5615, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 10/50 - loss: 0.5589 - accuracy: 0.5715 - val_loss: 0.5536 - val_accuracy: 0.5801
# 	--- Save best at ep 10, val_loss: 0.5536, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 11/50 - loss: 0.5509 - accuracy: 0.5750 - val_loss: 0.5480 - val_accuracy: 0.5871
# 	--- Save best at ep 11, val_loss: 0.5480, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 12/50 - loss: 0.5453 - accuracy: 0.5783 - val_loss: 0.5529 - val_accuracy: 0.5782
# 	-!- No improvement: 1/10
# Epoch 13/50 - loss: 0.5401 - accuracy: 0.5831 - val_loss: 0.5484 - val_accuracy: 0.5929
# 	-!- No improvement: 2/10
# Epoch 14/50 - loss: 0.5365 - accuracy: 0.5836 - val_loss: 0.5460 - val_accuracy: 0.5910
# 	--- Save best at ep 14, val_loss: 0.5460, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 15/50 - loss: 0.5307 - accuracy: 0.5869 - val_loss: 0.5380 - val_accuracy: 0.5960
# 	--- Save best at ep 15, val_loss: 0.5380, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 16/50 - loss: 0.5207 - accuracy: 0.5929 - val_loss: 0.5341 - val_accuracy: 0.5968
# 	--- Save best at ep 16, val_loss: 0.5341, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 17/50 - loss: 0.5162 - accuracy: 0.5957 - val_loss: 0.5501 - val_accuracy: 0.5823
# 	-!- No improvement: 1/10
# Epoch 18/50 - loss: 0.5119 - accuracy: 0.5964 - val_loss: 0.5310 - val_accuracy: 0.5988
# 	--- Save best at ep 18, val_loss: 0.5310, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 19/50 - loss: 0.5068 - accuracy: 0.5972 - val_loss: 0.5424 - val_accuracy: 0.5952
# 	-!- No improvement: 1/10
# Epoch 20/50 - loss: 0.5024 - accuracy: 0.6027 - val_loss: 0.5185 - val_accuracy: 0.6080
# 	--- Save best at ep 20, val_loss: 0.5185, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 21/50 - loss: 0.5000 - accuracy: 0.6039 - val_loss: 0.5247 - val_accuracy: 0.6007
# 	-!- No improvement: 1/10
# Epoch 22/50 - loss: 0.4972 - accuracy: 0.6048 - val_loss: 0.5235 - val_accuracy: 0.5985
# 	-!- No improvement: 2/10
# Epoch 23/50 - loss: 0.4929 - accuracy: 0.6055 - val_loss: 0.5213 - val_accuracy: 0.6147
# 	-!- No improvement: 3/10
# Epoch 24/50 - loss: 0.4923 - accuracy: 0.6083 - val_loss: 0.5506 - val_accuracy: 0.5938
# 	-!- No improvement: 4/10
# Epoch 25/50 - loss: 0.4618 - accuracy: 0.6226 - val_loss: 0.4969 - val_accuracy: 0.6325
# 	--- Save best at ep 25, val_loss: 0.4969, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 26/50 - loss: 0.4491 - accuracy: 0.6310 - val_loss: 0.4859 - val_accuracy: 0.6317
# 	--- Save best at ep 26, val_loss: 0.4859, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 27/50 - loss: 0.4471 - accuracy: 0.6359 - val_loss: 0.4876 - val_accuracy: 0.6291
# 	-!- No improvement: 1/10
# Epoch 28/50 - loss: 0.4435 - accuracy: 0.6370 - val_loss: 0.4836 - val_accuracy: 0.6342
# 	--- Save best at ep 28, val_loss: 0.4836, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 29/50 - loss: 0.4424 - accuracy: 0.6348 - val_loss: 0.4881 - val_accuracy: 0.6211
# 	-!- No improvement: 1/10
# Epoch 30/50 - loss: 0.4379 - accuracy: 0.6391 - val_loss: 0.4738 - val_accuracy: 0.6317
# 	--- Save best at ep 30, val_loss: 0.4738, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 31/50 - loss: 0.4337 - accuracy: 0.6378 - val_loss: 0.4770 - val_accuracy: 0.6328
# 	-!- No improvement: 1/10
# Epoch 32/50 - loss: 0.4291 - accuracy: 0.6411 - val_loss: 0.4879 - val_accuracy: 0.6305
# 	-!- No improvement: 2/10
# Epoch 33/50 - loss: 0.4319 - accuracy: 0.6391 - val_loss: 0.4656 - val_accuracy: 0.6272
# 	--- Save best at ep 33, val_loss: 0.4656, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 34/50 - loss: 0.4285 - accuracy: 0.6411 - val_loss: 0.4905 - val_accuracy: 0.6138
# 	-!- No improvement: 1/10
# Epoch 35/50 - loss: 0.4290 - accuracy: 0.6421 - val_loss: 0.4772 - val_accuracy: 0.6294
# 	-!- No improvement: 2/10
# Epoch 36/50 - loss: 0.4206 - accuracy: 0.6477 - val_loss: 0.4799 - val_accuracy: 0.6325
# 	-!- No improvement: 3/10
# Epoch 37/50 - loss: 0.4233 - accuracy: 0.6455 - val_loss: 0.4816 - val_accuracy: 0.6344
# 	-!- No improvement: 4/10
# Epoch 38/50 - loss: 0.4018 - accuracy: 0.6578 - val_loss: 0.4691 - val_accuracy: 0.6378
# 	-!- No improvement: 5/10
# Epoch 39/50 - loss: 0.3945 - accuracy: 0.6610 - val_loss: 0.4682 - val_accuracy: 0.6395
# 	-!- No improvement: 6/10
# Epoch 40/50 - loss: 0.3911 - accuracy: 0.6643 - val_loss: 0.4737 - val_accuracy: 0.6328
# 	-!- No improvement: 7/10
# Epoch 41/50 - loss: 0.3912 - accuracy: 0.6634 - val_loss: 0.4754 - val_accuracy: 0.6375
# 	-!- No improvement: 8/10
# Epoch 42/50 - loss: 0.3782 - accuracy: 0.6734 - val_loss: 0.4640 - val_accuracy: 0.6378
# 	--- Save best at ep 42, val_loss: 0.4640, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 43/50 - loss: 0.3787 - accuracy: 0.6728 - val_loss: 0.4644 - val_accuracy: 0.6411
# 	-!- No improvement: 1/10
# Epoch 44/50 - loss: 0.3743 - accuracy: 0.6738 - val_loss: 0.4700 - val_accuracy: 0.6358
# 	-!- No improvement: 2/10
# Epoch 45/50 - loss: 0.3698 - accuracy: 0.6774 - val_loss: 0.4602 - val_accuracy: 0.6395
# 	--- Save best at ep 45, val_loss: 0.4602, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth ---
# Epoch 46/50 - loss: 0.3696 - accuracy: 0.6780 - val_loss: 0.4683 - val_accuracy: 0.6397
# 	-!- No improvement: 1/10
# Epoch 47/50 - loss: 0.3700 - accuracy: 0.6778 - val_loss: 0.4790 - val_accuracy: 0.6425
# 	-!- No improvement: 2/10
# Epoch 48/50 - loss: 0.3674 - accuracy: 0.6800 - val_loss: 0.4667 - val_accuracy: 0.6431
# 	-!- No improvement: 3/10
# Epoch 49/50 - loss: 0.3674 - accuracy: 0.6781 - val_loss: 0.4701 - val_accuracy: 0.6461
# 	-!- No improvement: 4/10
# Epoch 50/50 - loss: 0.3642 - accuracy: 0.6792 - val_loss: 0.4675 - val_accuracy: 0.6450
# 	-!- No improvement: 5/10
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1657_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 42.31it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 65.90%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.578641  0.606925  0.592445   491.000000
# disgust        0.493333  0.672727  0.569231    55.000000
# fear           0.532033  0.361742  0.430665   528.000000
# happy          0.878161  0.869170  0.873642   879.000000
# sad            0.511290  0.533670  0.522241   594.000000
# surprise       0.751825  0.742788  0.747279   416.000000
# neutral        0.607578  0.717252  0.657875   626.000000
# accuracy       0.658958  0.658958  0.658958     0.658958
# macro avg      0.621837  0.643468  0.627626  3589.000000
# weighted avg   0.657808  0.658958  0.654898  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `efficientnet_fer2013_04042026_1657_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_0wmg9949 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_0wmg9949 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_0wmg9949 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_0wmg9949 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_0wmg9949 (0.5s)
# wandb:   ↳ ⣷ efficientnet_fer2013_04042026_1657_best.pth 4.5MB/4.5MB (0.1s)
# wandb: ⣯ uploading artifact cnn_0wmg9949 (0.5s)
# wandb:   ↳ ⣯ efficientnet_fer2013_04042026_1657_best.pth 4.5MB/4.5MB (0.1s)
# wandb: ⣟ uploading artifact cnn_0wmg9949 (0.5s)
# wandb:   ↳ ⣟ efficientnet_fer2013_04042026_1657_best.pth 4.5MB/4.5MB (0.1s)
# wandb: ⡿ uploading artifact cnn_0wmg9949 (0.5s)
# wandb:   ↳ ⡿ efficientnet_fer2013_04042026_1657_best.pth 4.5MB/4.5MB (0.1s)
# wandb: ⢿ uploading artifact cnn_0wmg9949 (0.5s)
# wandb:   ↳ ⢿ efficientnet_fer2013_04042026_1657_best.pth 4.5MB/4.5MB (0.1s)
# wandb: ⣻ uploading artifact cnn_0wmg9949 (1.0s)
# wandb: ⣽ uploading artifact cnn_0wmg9949 (1.0s)
# wandb: ⣾ uploading artifact cnn_0wmg9949 (1.0s)
# wandb: ⣷ uploading artifact cnn_0wmg9949 (1.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ████████████████████▄▄▄▄▄▄▄▄▄▄▂▂▂▂▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████
# wandb:     Train/Loss █▆▅▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▅▅▅▆▆▆▆▆▆▇▇▆▇▇▇▇▇▇███▇██▇▇████████████
# wandb:       Val/Loss █▆▅▄▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 50
# wandb:  Learning_Rate 6e-05
# wandb: Train/Accuracy 0.67923
# wandb:     Train/Loss 0.36418
# wandb:   Val/Accuracy 0.64503
# wandb:       Val/Loss 0.46755
# wandb:
# wandb: 🚀 View run efficientnet_fer2013_04042026_1657 at: https://wandb.ai/phucga15062005/FER2013/runs/0wmg9949
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260404_165729-0wmg9949/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
