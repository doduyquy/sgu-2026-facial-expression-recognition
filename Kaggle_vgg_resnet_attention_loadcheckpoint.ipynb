# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1323, done.
# remote: Counting objects: 100% (296/296), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 1323 (delta 209), reused 181 (delta 130), pack-reused 1027 (from 1)
# Receiving objects: 100% (1323/1323), 6.05 MiB | 23.75 MiB/s, done.
# Resolving deltas: 100% (883/883), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_resnet_attention --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Multi-scale Fusion (Stage 3 + Stage 4), Feature dim: 1536
#
# ==================================================
# [Transfer Learning] Loading pretrained backbones...
# ==================================================
# [Transfer] VGG loaded: 56 params | skipped: 12 missing
# [Transfer] ResNet loaded: 292 params | skipped: 2 missing
# [Freeze] Backbones frozen. Trainable: 6,565,383 / 22,195,535 (29.6%)
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_082542-qzeg61nn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_resnet_attention_13042026_0825
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/qzeg61nn
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 0.9503 - accuracy: 0.6583 - val_loss: 1.0555 - val_accuracy: 0.6539
# 	--- Save best at ep 1, val_loss: 1.0555, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0825_best.pth ---
# Epoch 2/100 - loss: 0.8306 - accuracy: 0.6981 - val_loss: 1.1103 - val_accuracy: 0.6615
# 	-!- No improvement: 1/20
# Epoch 3/100 - loss: 0.7977 - accuracy: 0.7065 - val_loss: 0.9533 - val_accuracy: 0.6698
# 	--- Save best at ep 3, val_loss: 0.9533, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0825_best.pth ---
# Epoch 4/100 - loss: 0.7824 - accuracy: 0.7133 - val_loss: 1.0130 - val_accuracy: 0.6590
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 0.7638 - accuracy: 0.7150 - val_loss: 0.9688 - val_accuracy: 0.6670
# 	-!- No improvement: 2/20
# Epoch 6/100 - loss: 0.7495 - accuracy: 0.7182 - val_loss: 0.9840 - val_accuracy: 0.6737
# 	-!- No improvement: 3/20
# Epoch 7/100 - loss: 0.7524 - accuracy: 0.7158 - val_loss: 1.0659 - val_accuracy: 0.6723
# 	-!- No improvement: 4/20
# Epoch 8/100 - loss: 0.7290 - accuracy: 0.7251 - val_loss: 1.0156 - val_accuracy: 0.6684
# 	-!- No improvement: 5/20
# Epoch 9/100 - loss: 0.7181 - accuracy: 0.7237 - val_loss: 1.0293 - val_accuracy: 0.6757
# 	-!- No improvement: 6/20
# Epoch 10/100 - loss: 0.7154 - accuracy: 0.7269 - val_loss: 0.9540 - val_accuracy: 0.6715
# 	-!- No improvement: 7/20
# Epoch 11/100 - loss: 0.7184 - accuracy: 0.7288 - val_loss: 1.0146 - val_accuracy: 0.6773
# 	-!- No improvement: 8/20
# Epoch 12/100 - loss: 0.7012 - accuracy: 0.7325 - val_loss: 0.9663 - val_accuracy: 0.6715
# 	-!- No improvement: 9/20
# Epoch 13/100 - loss: 0.6976 - accuracy: 0.7331 - val_loss: 0.9964 - val_accuracy: 0.6726
# 	-!- No improvement: 10/20
# Epoch 14/100 - loss: 0.7008 - accuracy: 0.7321 - val_loss: 0.9753 - val_accuracy: 0.6754
# 	-!- No improvement: 11/20
# Epoch 15/100 - loss: 0.6920 - accuracy: 0.7317 - val_loss: 0.9902 - val_accuracy: 0.6690
# 	-!- No improvement: 12/20
# Epoch 16/100 - loss: 0.6917 - accuracy: 0.7349 - val_loss: 0.9851 - val_accuracy: 0.6726
# 	-!- No improvement: 13/20
# Epoch 17/100 - loss: 0.6894 - accuracy: 0.7355 - val_loss: 0.9984 - val_accuracy: 0.6793
# 	-!- No improvement: 14/20
# Epoch 18/100 - loss: 0.6818 - accuracy: 0.7351 - val_loss: 0.9863 - val_accuracy: 0.6771
# 	-!- No improvement: 15/20
# Epoch 19/100 - loss: 0.6852 - accuracy: 0.7339 - val_loss: 1.0033 - val_accuracy: 0.6743
# 	-!- No improvement: 16/20
# Epoch 20/100 - loss: 0.6802 - accuracy: 0.7375 - val_loss: 0.9615 - val_accuracy: 0.6726
# 	-!- No improvement: 17/20
#
# ==================================================
# [Phase 2] Epoch 21: Unfreezing backbones for fine-tuning!
# ==================================================
#
# [Unfreeze] All params trainable: 22,195,535
# [Trainer] Rebuilt optimizer with finetune_lr=1e-05 and reset patience.
# Epoch 21/100 - loss: 0.6830 - accuracy: 0.7361 - val_loss: 0.9952 - val_accuracy: 0.6762
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 0.6777 - accuracy: 0.7403 - val_loss: 0.9728 - val_accuracy: 0.6751
# 	-!- No improvement: 2/20
# Epoch 23/100 - loss: 0.6693 - accuracy: 0.7417 - val_loss: 1.0030 - val_accuracy: 0.6771
# 	-!- No improvement: 3/20
# Epoch 24/100 - loss: 0.6705 - accuracy: 0.7387 - val_loss: 0.9874 - val_accuracy: 0.6799
# 	-!- No improvement: 4/20
# Epoch 25/100 - loss: 0.6643 - accuracy: 0.7443 - val_loss: 0.9887 - val_accuracy: 0.6793
# 	-!- No improvement: 5/20
# Epoch 26/100 - loss: 0.6567 - accuracy: 0.7440 - val_loss: 1.0092 - val_accuracy: 0.6801
# 	-!- No improvement: 6/20
# Epoch 27/100 - loss: 0.6620 - accuracy: 0.7427 - val_loss: 1.0023 - val_accuracy: 0.6801
# 	-!- No improvement: 7/20
# Epoch 28/100 - loss: 0.6590 - accuracy: 0.7470 - val_loss: 1.0088 - val_accuracy: 0.6824
# 	-!- No improvement: 8/20
# Epoch 29/100 - loss: 0.6477 - accuracy: 0.7471 - val_loss: 1.0245 - val_accuracy: 0.6824
# 	-!- No improvement: 9/20
# Epoch 30/100 - loss: 0.6506 - accuracy: 0.7477 - val_loss: 1.0092 - val_accuracy: 0.6804
# 	-!- No improvement: 10/20
# Epoch 31/100 - loss: 0.6388 - accuracy: 0.7492 - val_loss: 1.0237 - val_accuracy: 0.6832
# 	-!- No improvement: 11/20
# Epoch 32/100 - loss: 0.6454 - accuracy: 0.7475 - val_loss: 1.0360 - val_accuracy: 0.6835
# 	-!- No improvement: 12/20
# Epoch 33/100 - loss: 0.6474 - accuracy: 0.7496 - val_loss: 1.0055 - val_accuracy: 0.6810
# 	-!- No improvement: 13/20
# Epoch 34/100 - loss: 0.6399 - accuracy: 0.7512 - val_loss: 1.0423 - val_accuracy: 0.6829
# 	-!- No improvement: 14/20
# Epoch 35/100 - loss: 0.6446 - accuracy: 0.7500 - val_loss: 1.0110 - val_accuracy: 0.6804
# 	-!- No improvement: 15/20
# Epoch 36/100 - loss: 0.6385 - accuracy: 0.7515 - val_loss: 1.0074 - val_accuracy: 0.6835
# 	-!- No improvement: 16/20
# Epoch 37/100 - loss: 0.6416 - accuracy: 0.7506 - val_loss: 1.0118 - val_accuracy: 0.6810
# 	-!- No improvement: 17/20
# Epoch 38/100 - loss: 0.6414 - accuracy: 0.7509 - val_loss: 0.9984 - val_accuracy: 0.6821
# 	-!- No improvement: 18/20
# Epoch 39/100 - loss: 0.6431 - accuracy: 0.7514 - val_loss: 1.0192 - val_accuracy: 0.6776
# 	-!- No improvement: 19/20
# Epoch 40/100 - loss: 0.6317 - accuracy: 0.7540 - val_loss: 1.0198 - val_accuracy: 0.6849
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=40
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0825_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 14.88it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.90%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.602251  0.653768  0.626953   491.000000
# disgust        0.505618  0.818182  0.625000    55.000000
# fear           0.557377  0.450758  0.498429   528.000000
# happy          0.918886  0.863481  0.890323   879.000000
# sad            0.504881  0.609428  0.552250   594.000000
# surprise       0.795511  0.766827  0.780906   416.000000
# neutral        0.659396  0.627796  0.643208   626.000000
# accuracy       0.679019  0.679019  0.679019     0.679019
# macro avg      0.649132  0.684320  0.659581  3589.000000
# weighted avg   0.687970  0.679019  0.680834  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_resnet_attention_13042026_0825_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_qzeg61nn (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_qzeg61nn (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_qzeg61nn (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_qzeg61nn (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_qzeg61nn (0.5s)
# wandb: ⣯ uploading artifact cnn_qzeg61nn (0.5s)
# wandb: ⣟ uploading artifact cnn_qzeg61nn (0.5s)
# wandb: ⡿ uploading artifact cnn_qzeg61nn (0.5s)
# wandb: ⢿ uploading artifact cnn_qzeg61nn (0.5s)
# wandb: ⣻ uploading artifact cnn_qzeg61nn (1.0s)
# wandb:   ↳ ⣻ vgg_resnet_attention_13042026_0825_best.pth 23.0MB/135.0MB (0.2s)
# wandb: ⣽ uploading artifact cnn_qzeg61nn (1.0s)
# wandb:   ↳ ⣽ vgg_resnet_attention_13042026_0825_best.pth 23.0MB/135.0MB (0.2s)
# wandb: ⣾ uploading artifact cnn_qzeg61nn (1.0s)
# wandb:   ↳ ⣾ vgg_resnet_attention_13042026_0825_best.pth 23.0MB/135.0MB (0.2s)
# wandb: ⣷ uploading artifact cnn_qzeg61nn (1.0s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0825_best.pth 23.0MB/135.0MB (0.2s)
# wandb: ⣯ uploading artifact cnn_qzeg61nn (1.0s)
# wandb:   ↳ ⣯ vgg_resnet_attention_13042026_0825_best.pth 23.0MB/135.0MB (0.2s)
# wandb: ⣟ uploading artifact cnn_qzeg61nn (1.5s)
# wandb:   ↳ ⣟ vgg_resnet_attention_13042026_0825_best.pth 59.0MB/135.0MB (0.7s)
# wandb: ⡿ uploading artifact cnn_qzeg61nn (1.5s)
# wandb:   ↳ ⡿ vgg_resnet_attention_13042026_0825_best.pth 59.0MB/135.0MB (0.7s)
# wandb: ⢿ uploading artifact cnn_qzeg61nn (1.5s)
# wandb:   ↳ ⢿ vgg_resnet_attention_13042026_0825_best.pth 59.0MB/135.0MB (0.7s)
# wandb: ⣻ uploading artifact cnn_qzeg61nn (1.5s)
# wandb:   ↳ ⣻ vgg_resnet_attention_13042026_0825_best.pth 59.0MB/135.0MB (0.7s)
# wandb: ⣽ uploading artifact cnn_qzeg61nn (1.5s)
# wandb:   ↳ ⣽ vgg_resnet_attention_13042026_0825_best.pth 59.0MB/135.0MB (0.7s)
# wandb: ⣾ uploading artifact cnn_qzeg61nn (2.0s)
# wandb:   ↳ ⣾ vgg_resnet_attention_13042026_0825_best.pth 104.9MB/135.0MB (1.2s)
# wandb: ⣷ uploading artifact cnn_qzeg61nn (2.0s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0825_best.pth 104.9MB/135.0MB (1.2s)
# wandb: ⣯ uploading artifact cnn_qzeg61nn (2.0s)
# wandb:   ↳ ⣯ vgg_resnet_attention_13042026_0825_best.pth 104.9MB/135.0MB (1.2s)
# wandb: ⣟ uploading artifact cnn_qzeg61nn (2.0s)
# wandb:   ↳ ⣟ vgg_resnet_attention_13042026_0825_best.pth 104.9MB/135.0MB (1.2s)
# wandb: ⡿ uploading artifact cnn_qzeg61nn (2.0s)
# wandb:   ↳ ⡿ vgg_resnet_attention_13042026_0825_best.pth 104.9MB/135.0MB (1.2s)
# wandb: ⢿ uploading artifact cnn_qzeg61nn (2.5s)
# wandb: ⣻ uploading artifact cnn_qzeg61nn (2.5s)
# wandb: ⣽ uploading artifact cnn_qzeg61nn (2.5s)
# wandb: ⣾ uploading artifact cnn_qzeg61nn (2.5s)
# wandb: ⣷ uploading artifact cnn_qzeg61nn (2.5s)
# wandb: ⣯ uploading history steps 40-41, summary, console lines 115-119 (0.0s)
# wandb: ⣟ uploading history steps 40-41, summary, console lines 115-119 (0.0s)
# wandb: ⡿ uploading history steps 40-41, summary, console lines 115-119 (0.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ███████▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████
# wandb:     Train/Loss █▅▅▄▄▄▄▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▃▅▂▄▅▅▄▆▅▆▅▅▆▄▅▇▆▆▅▆▆▆▇▇▇▇▇▇▇██▇█▇█▇▇▆█
# wandb:       Val/Loss ▆█▁▄▂▂▆▄▄▁▄▂▃▂▃▂▃▂▃▁▃▂▃▃▃▃▃▃▄▃▄▅▃▅▄▃▄▃▄▄
# wandb:
# wandb: Run summary:
# wandb:          Epoch 40
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.75398
# wandb:     Train/Loss 0.6317
# wandb:   Val/Accuracy 0.68487
# wandb:       Val/Loss 1.01978
# wandb:
# wandb: 🚀 View run vgg_resnet_attention_13042026_0825 at: https://wandb.ai/phucga15062005/FER2013/runs/qzeg61nn
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_082542-qzeg61nn/logs
#
# 		DONE!
