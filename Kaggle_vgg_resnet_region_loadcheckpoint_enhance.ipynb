# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1425, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 1425 (delta 99), reused 90 (delta 89), pack-reused 1303 (from 2)
# Receiving objects: 100% (1425/1425), 6.10 MiB | 36.52 MiB/s, done.
# Resolving deltas: 100% (952/952), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_resnet_region --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Multi-scale Fusion (Stage 3 + Stage 4), Feature dim: 1536
# --> Facial Region Dictionary: ['forehead', 'left_eye', 'right_eye', 'nose', 'mouth', 'chin']
#
# ==================================================
# [Transfer Learning] Loading pretrained backbones...
# ==================================================
# [RegionAligned] VGG loaded: 57 weights
# [RegionAligned] VGG skipped (shape mismatch): ['sa4.conv.weight']
# [RegionAligned] ResNet loaded: 292 weights
# [RegionAligned] Backbones FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Optimizer] SAM (base=adamw, rho=0.05, adaptive=False)
# --> [Scheduler] CosineAnnealingLR (T_max=100)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run 55ijyh15 (0.2s)
# wandb: ⣾ setting up run 55ijyh15 (0.2s)
# wandb: ⣷ setting up run 55ijyh15 (0.2s)
# wandb: ⣯ setting up run 55ijyh15 (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_120921-55ijyh15
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run region_aligned_fer_13042026_1209
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/55ijyh15
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.5365 - accuracy: 0.5771 - val_loss: 1.4556 - val_accuracy: 0.6517
# /kaggle/working/sgu-2026-facial-expression-recognition/src/training/trainer.py:177: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   self.scheduler.step()
# 	--- Save best at ep 1, val_loss: 1.4556, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 2/100 - loss: 1.4151 - accuracy: 0.6536 - val_loss: 1.4562 - val_accuracy: 0.6553
# 	-!- No improvement: 1/20
# Epoch 3/100 - loss: 1.3991 - accuracy: 0.6649 - val_loss: 1.4388 - val_accuracy: 0.6693
# 	--- Save best at ep 3, val_loss: 1.4388, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 4/100 - loss: 1.3867 - accuracy: 0.6711 - val_loss: 1.4483 - val_accuracy: 0.6665
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.3877 - accuracy: 0.6723 - val_loss: 1.4210 - val_accuracy: 0.6762
# 	--- Save best at ep 5, val_loss: 1.4210, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 6/100 - loss: 1.3874 - accuracy: 0.6772 - val_loss: 1.4542 - val_accuracy: 0.6718
# 	-!- No improvement: 1/20
# Epoch 7/100 - loss: 1.3817 - accuracy: 0.6752 - val_loss: 1.4515 - val_accuracy: 0.6734
# 	-!- No improvement: 2/20
# Epoch 8/100 - loss: 1.3714 - accuracy: 0.6808 - val_loss: 1.4197 - val_accuracy: 0.6684
# 	--- Save best at ep 8, val_loss: 1.4197, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 9/100 - loss: 1.3689 - accuracy: 0.6839 - val_loss: 1.4406 - val_accuracy: 0.6687
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 1.3763 - accuracy: 0.6803 - val_loss: 1.4225 - val_accuracy: 0.6690
# 	-!- No improvement: 2/20
# Epoch 11/100 - loss: 1.3760 - accuracy: 0.6820 - val_loss: 1.4164 - val_accuracy: 0.6751
# 	--- Save best at ep 11, val_loss: 1.4164, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 12/100 - loss: 1.3664 - accuracy: 0.6843 - val_loss: 1.4450 - val_accuracy: 0.6729
# 	-!- No improvement: 1/20
# Epoch 13/100 - loss: 1.3630 - accuracy: 0.6842 - val_loss: 1.4369 - val_accuracy: 0.6760
# 	-!- No improvement: 2/20
# Epoch 14/100 - loss: 1.3686 - accuracy: 0.6835 - val_loss: 1.4262 - val_accuracy: 0.6768
# 	-!- No improvement: 3/20
# Epoch 15/100 - loss: 1.3651 - accuracy: 0.6880 - val_loss: 1.4224 - val_accuracy: 0.6787
# 	-!- No improvement: 4/20
# Epoch 16/100 - loss: 1.3715 - accuracy: 0.6794 - val_loss: 1.4365 - val_accuracy: 0.6721
# 	-!- No improvement: 5/20
# Epoch 17/100 - loss: 1.3665 - accuracy: 0.6857 - val_loss: 1.4313 - val_accuracy: 0.6707
# 	-!- No improvement: 6/20
# Epoch 18/100 - loss: 1.3650 - accuracy: 0.6859 - val_loss: 1.4243 - val_accuracy: 0.6824
# 	-!- No improvement: 7/20
# Epoch 19/100 - loss: 1.3665 - accuracy: 0.6816 - val_loss: 1.4400 - val_accuracy: 0.6762
# 	-!- No improvement: 8/20
# Epoch 20/100 - loss: 1.3614 - accuracy: 0.6875 - val_loss: 1.4223 - val_accuracy: 0.6737
# 	-!- No improvement: 9/20
# [RegionAligned] All parameters UNFROZEN.
# --> [Optimizer] SAM (base=adamw, rho=0.05, adaptive=False)
# --> [Scheduler] CosineAnnealingLR (T_max=100)
# [Trainer] Rebuilt optimizer & scheduler with finetune_lr=2e-05 and reset patience.
# Epoch 21/100 - loss: 1.3579 - accuracy: 0.6818 - val_loss: 1.4110 - val_accuracy: 0.6785
# 	--- Save best at ep 21, val_loss: 1.4110, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 22/100 - loss: 1.3414 - accuracy: 0.6915 - val_loss: 1.4155 - val_accuracy: 0.6721
# 	-!- No improvement: 1/20
# Epoch 23/100 - loss: 1.3319 - accuracy: 0.6942 - val_loss: 1.4073 - val_accuracy: 0.6779
# 	--- Save best at ep 23, val_loss: 1.4073, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 24/100 - loss: 1.3344 - accuracy: 0.6955 - val_loss: 1.4084 - val_accuracy: 0.6796
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 1.3334 - accuracy: 0.6929 - val_loss: 1.4096 - val_accuracy: 0.6743
# 	-!- No improvement: 2/20
# Epoch 26/100 - loss: 1.3251 - accuracy: 0.6984 - val_loss: 1.4085 - val_accuracy: 0.6695
# 	-!- No improvement: 3/20
# Epoch 27/100 - loss: 1.3207 - accuracy: 0.7013 - val_loss: 1.4208 - val_accuracy: 0.6695
# 	-!- No improvement: 4/20
# Epoch 28/100 - loss: 1.3182 - accuracy: 0.7009 - val_loss: 1.4072 - val_accuracy: 0.6779
# 	--- Save best at ep 28, val_loss: 1.4072, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 29/100 - loss: 1.3162 - accuracy: 0.7037 - val_loss: 1.4003 - val_accuracy: 0.6746
# 	--- Save best at ep 29, val_loss: 1.4003, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 30/100 - loss: 1.3136 - accuracy: 0.7063 - val_loss: 1.4115 - val_accuracy: 0.6807
# 	-!- No improvement: 1/20
# Epoch 31/100 - loss: 1.3082 - accuracy: 0.7046 - val_loss: 1.4050 - val_accuracy: 0.6760
# 	-!- No improvement: 2/20
# Epoch 32/100 - loss: 1.3057 - accuracy: 0.7072 - val_loss: 1.4092 - val_accuracy: 0.6751
# 	-!- No improvement: 3/20
# Epoch 33/100 - loss: 1.3005 - accuracy: 0.7096 - val_loss: 1.4123 - val_accuracy: 0.6793
# 	-!- No improvement: 4/20
# Epoch 34/100 - loss: 1.2998 - accuracy: 0.7141 - val_loss: 1.4080 - val_accuracy: 0.6751
# 	-!- No improvement: 5/20
# Epoch 35/100 - loss: 1.3018 - accuracy: 0.7088 - val_loss: 1.4140 - val_accuracy: 0.6782
# 	-!- No improvement: 6/20
# Epoch 36/100 - loss: 1.3061 - accuracy: 0.7091 - val_loss: 1.3941 - val_accuracy: 0.6796
# 	--- Save best at ep 36, val_loss: 1.3941, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 37/100 - loss: 1.2875 - accuracy: 0.7146 - val_loss: 1.4068 - val_accuracy: 0.6815
# 	-!- No improvement: 1/20
# Epoch 38/100 - loss: 1.2958 - accuracy: 0.7134 - val_loss: 1.4075 - val_accuracy: 0.6793
# 	-!- No improvement: 2/20
# Epoch 39/100 - loss: 1.2935 - accuracy: 0.7158 - val_loss: 1.4003 - val_accuracy: 0.6804
# 	-!- No improvement: 3/20
# Epoch 40/100 - loss: 1.2895 - accuracy: 0.7156 - val_loss: 1.4070 - val_accuracy: 0.6835
# 	-!- No improvement: 4/20
# Epoch 41/100 - loss: 1.2803 - accuracy: 0.7203 - val_loss: 1.4109 - val_accuracy: 0.6815
# 	-!- No improvement: 5/20
# Epoch 42/100 - loss: 1.2901 - accuracy: 0.7137 - val_loss: 1.4059 - val_accuracy: 0.6773
# 	-!- No improvement: 6/20
# Epoch 43/100 - loss: 1.2793 - accuracy: 0.7171 - val_loss: 1.4053 - val_accuracy: 0.6779
# 	-!- No improvement: 7/20
# Epoch 44/100 - loss: 1.2824 - accuracy: 0.7211 - val_loss: 1.4045 - val_accuracy: 0.6751
# 	-!- No improvement: 8/20
# Epoch 45/100 - loss: 1.2766 - accuracy: 0.7206 - val_loss: 1.4087 - val_accuracy: 0.6760
# 	-!- No improvement: 9/20
# Epoch 46/100 - loss: 1.2756 - accuracy: 0.7218 - val_loss: 1.3964 - val_accuracy: 0.6790
# 	-!- No improvement: 10/20
# Epoch 47/100 - loss: 1.2767 - accuracy: 0.7223 - val_loss: 1.3985 - val_accuracy: 0.6804
# 	-!- No improvement: 11/20
# Epoch 48/100 - loss: 1.2790 - accuracy: 0.7214 - val_loss: 1.4032 - val_accuracy: 0.6796
# 	-!- No improvement: 12/20
# Epoch 49/100 - loss: 1.2739 - accuracy: 0.7211 - val_loss: 1.3945 - val_accuracy: 0.6804
# 	-!- No improvement: 13/20
# Epoch 50/100 - loss: 1.2663 - accuracy: 0.7272 - val_loss: 1.3965 - val_accuracy: 0.6826
# 	-!- No improvement: 14/20
# Epoch 51/100 - loss: 1.2738 - accuracy: 0.7201 - val_loss: 1.4065 - val_accuracy: 0.6832
# 	-!- No improvement: 15/20
# Epoch 52/100 - loss: 1.2682 - accuracy: 0.7269 - val_loss: 1.4011 - val_accuracy: 0.6851
# 	-!- No improvement: 16/20
# Epoch 53/100 - loss: 1.2627 - accuracy: 0.7286 - val_loss: 1.3975 - val_accuracy: 0.6787
# 	-!- No improvement: 17/20
# Epoch 54/100 - loss: 1.2716 - accuracy: 0.7247 - val_loss: 1.3875 - val_accuracy: 0.6857
# 	--- Save best at ep 54, val_loss: 1.3875, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth ---
# Epoch 55/100 - loss: 1.2672 - accuracy: 0.7272 - val_loss: 1.3909 - val_accuracy: 0.6838
# 	-!- No improvement: 1/20
# Epoch 56/100 - loss: 1.2626 - accuracy: 0.7283 - val_loss: 1.3948 - val_accuracy: 0.6849
# 	-!- No improvement: 2/20
# Epoch 57/100 - loss: 1.2662 - accuracy: 0.7295 - val_loss: 1.4073 - val_accuracy: 0.6810
# 	-!- No improvement: 3/20
# Epoch 58/100 - loss: 1.2640 - accuracy: 0.7272 - val_loss: 1.4000 - val_accuracy: 0.6840
# 	-!- No improvement: 4/20
# Epoch 59/100 - loss: 1.2588 - accuracy: 0.7293 - val_loss: 1.3980 - val_accuracy: 0.6846
# 	-!- No improvement: 5/20
# Epoch 60/100 - loss: 1.2585 - accuracy: 0.7316 - val_loss: 1.3942 - val_accuracy: 0.6840
# 	-!- No improvement: 6/20
# Epoch 61/100 - loss: 1.2536 - accuracy: 0.7341 - val_loss: 1.3998 - val_accuracy: 0.6838
# 	-!- No improvement: 7/20
# Epoch 62/100 - loss: 1.2545 - accuracy: 0.7328 - val_loss: 1.3975 - val_accuracy: 0.6804
# 	-!- No improvement: 8/20
# Epoch 63/100 - loss: 1.2559 - accuracy: 0.7321 - val_loss: 1.4038 - val_accuracy: 0.6874
# 	-!- No improvement: 9/20
# Epoch 64/100 - loss: 1.2615 - accuracy: 0.7334 - val_loss: 1.3947 - val_accuracy: 0.6857
# 	-!- No improvement: 10/20
# Epoch 65/100 - loss: 1.2588 - accuracy: 0.7341 - val_loss: 1.3998 - val_accuracy: 0.6879
# 	-!- No improvement: 11/20
# Epoch 66/100 - loss: 1.2567 - accuracy: 0.7341 - val_loss: 1.3942 - val_accuracy: 0.6843
# 	-!- No improvement: 12/20
# Epoch 67/100 - loss: 1.2548 - accuracy: 0.7320 - val_loss: 1.3979 - val_accuracy: 0.6832
# 	-!- No improvement: 13/20
# Epoch 68/100 - loss: 1.2516 - accuracy: 0.7370 - val_loss: 1.4003 - val_accuracy: 0.6849
# 	-!- No improvement: 14/20
# Epoch 69/100 - loss: 1.2522 - accuracy: 0.7330 - val_loss: 1.3980 - val_accuracy: 0.6849
# 	-!- No improvement: 15/20
# Epoch 70/100 - loss: 1.2430 - accuracy: 0.7371 - val_loss: 1.3938 - val_accuracy: 0.6840
# 	-!- No improvement: 16/20
# Epoch 71/100 - loss: 1.2498 - accuracy: 0.7352 - val_loss: 1.3952 - val_accuracy: 0.6863
# 	-!- No improvement: 17/20
# Epoch 72/100 - loss: 1.2514 - accuracy: 0.7371 - val_loss: 1.3989 - val_accuracy: 0.6807
# 	-!- No improvement: 18/20
# Epoch 73/100 - loss: 1.2444 - accuracy: 0.7399 - val_loss: 1.3953 - val_accuracy: 0.6826
# 	-!- No improvement: 19/20
# Epoch 74/100 - loss: 1.2404 - accuracy: 0.7417 - val_loss: 1.3990 - val_accuracy: 0.6868
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=74
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/region_aligned_fer/region_aligned_fer_13042026_1209_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:04<00:00, 14.15it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 70.55%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.668058  0.651731  0.659794   491.000000
# disgust        0.611111  0.800000  0.692913    55.000000
# fear           0.569845  0.486742  0.525026   528.000000
# happy          0.903869  0.877133  0.890300   879.000000
# sad            0.599271  0.553872  0.575678   594.000000
# surprise       0.797619  0.805288  0.801435   416.000000
# neutral        0.622222  0.760383  0.684400   626.000000
# accuracy       0.705489  0.705489  0.705489     0.705489
# macro avg      0.681714  0.705022  0.689935  3589.000000
# weighted avg   0.706128  0.705489  0.703717  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `region_aligned_fer_13042026_1209_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_55ijyh15 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_55ijyh15 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_55ijyh15 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_55ijyh15 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_55ijyh15 (0.5s)
# wandb: ⣯ uploading artifact cnn_55ijyh15 (0.5s)
# wandb: ⣟ uploading artifact cnn_55ijyh15 (0.5s)
# wandb: ⡿ uploading artifact cnn_55ijyh15 (0.5s)
# wandb: ⢿ uploading artifact cnn_55ijyh15 (0.5s)
# wandb: ⣻ uploading artifact cnn_55ijyh15 (1.0s)
# wandb:   ↳ ⣻ region_aligned_fer_13042026_1209_best.pth 2.7MB/88.0MB (0.2s)
# wandb: ⣽ uploading artifact cnn_55ijyh15 (1.0s)
# wandb:   ↳ ⣽ region_aligned_fer_13042026_1209_best.pth 2.7MB/88.0MB (0.2s)
# wandb: ⣾ uploading artifact cnn_55ijyh15 (1.0s)
# wandb:   ↳ ⣾ region_aligned_fer_13042026_1209_best.pth 2.7MB/88.0MB (0.2s)
# wandb: ⣷ uploading artifact cnn_55ijyh15 (1.0s)
# wandb:   ↳ ⣷ region_aligned_fer_13042026_1209_best.pth 2.7MB/88.0MB (0.2s)
# wandb: ⣯ uploading artifact cnn_55ijyh15 (1.0s)
# wandb:   ↳ ⣯ region_aligned_fer_13042026_1209_best.pth 2.7MB/88.0MB (0.2s)
# wandb: ⣟ uploading artifact cnn_55ijyh15 (1.5s)
# wandb:   ↳ ⣟ region_aligned_fer_13042026_1209_best.pth 53.3MB/88.0MB (0.7s)
# wandb: ⡿ uploading artifact cnn_55ijyh15 (1.5s)
# wandb:   ↳ ⡿ region_aligned_fer_13042026_1209_best.pth 53.3MB/88.0MB (0.7s)
# wandb: ⢿ uploading artifact cnn_55ijyh15 (1.5s)
# wandb:   ↳ ⢿ region_aligned_fer_13042026_1209_best.pth 53.3MB/88.0MB (0.7s)
# wandb: ⣻ uploading artifact cnn_55ijyh15 (1.5s)
# wandb:   ↳ ⣻ region_aligned_fer_13042026_1209_best.pth 53.3MB/88.0MB (0.7s)
# wandb: ⣽ uploading artifact cnn_55ijyh15 (1.5s)
# wandb:   ↳ ⣽ region_aligned_fer_13042026_1209_best.pth 53.3MB/88.0MB (0.7s)
# wandb: ⣾ uploading artifact cnn_55ijyh15 (2.0s)
# wandb:   ↳ ⣾ region_aligned_fer_13042026_1209_best.pth 88.0MB/88.0MB (1.2s)
# wandb: ⣷ uploading artifact cnn_55ijyh15 (2.0s)
# wandb:   ↳ ⣷ region_aligned_fer_13042026_1209_best.pth 88.0MB/88.0MB (1.2s)
# wandb: ⣯ uploading artifact cnn_55ijyh15 (2.0s)
# wandb:   ↳ ⣯ region_aligned_fer_13042026_1209_best.pth 88.0MB/88.0MB (1.2s)
# wandb: ⣟ uploading artifact cnn_55ijyh15 (2.0s)
# wandb:   ↳ ⣟ region_aligned_fer_13042026_1209_best.pth 88.0MB/88.0MB (1.2s)
# wandb: ⡿ uploading artifact cnn_55ijyh15 (2.0s)
# wandb:   ↳ ⡿ region_aligned_fer_13042026_1209_best.pth 88.0MB/88.0MB (1.2s)
# wandb: ⢿ uploading artifact cnn_55ijyh15 (2.5s)
# wandb: ⢿ uploading output.log 12.5KB/12.5KB (0.2s)
# wandb: ⢿ uploading wandb-summary.json 1.0KB/1.0KB (0.2s)
# wandb: ⣻ uploading artifact cnn_55ijyh15 (2.5s)
# wandb: ⣻ uploading output.log 12.5KB/12.5KB (0.2s)
# wandb: ⣻ uploading wandb-summary.json 1.0KB/1.0KB (0.2s)
# wandb: ⣽ uploading artifact cnn_55ijyh15 (2.5s)
# wandb: ⣽ uploading output.log 12.5KB/12.5KB (0.2s)
# wandb: ⣽ uploading wandb-summary.json 1.0KB/1.0KB (0.2s)
# wandb: ⣾ uploading artifact cnn_55ijyh15 (2.5s)
# wandb: ⣾ uploading output.log 12.5KB/12.5KB (0.2s)
# wandb: ⣾ uploading wandb-summary.json 1.0KB/1.0KB (0.2s)
# wandb: ⣷ uploading artifact cnn_55ijyh15 (2.5s)
# wandb: ⣷ uploading output.log 12.5KB/12.5KB (0.2s)
# wandb: ⣷ uploading wandb-summary.json 1.0KB/1.0KB (0.2s)
# wandb: ⣯ uploading data (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█
# wandb:  Learning_Rate ███████▇▇▇▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▄▅▅▅▅▆▆▆▆▅▆▆▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████
# wandb:     Train/Loss █▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁
# wandb:   Val/Accuracy ▁▄▃▅▄▅▆▅▄▅▅▆▅▅▅▆▆▇▆▆▆▅▅▆▆▇▇▇▇▇███▇▇▇▇█▆█
# wandb:       Val/Loss █▆▇▄█▄▆▆▄▆▄▄▃▃▃▄▃▂▃▃▃▁▂▃▂▃▂▂▂▁▂▁▂▁▁▁▂▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 74
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.74168
# wandb:     Train/Loss 1.24042
# wandb:   Val/Accuracy 0.68682
# wandb:       Val/Loss 1.39897
# wandb:
# wandb: 🚀 View run region_aligned_fer_13042026_1209 at: https://wandb.ai/phucga15062005/FER2013/runs/55ijyh15
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_120921-55ijyh15/logs
#
# 		DONE!
