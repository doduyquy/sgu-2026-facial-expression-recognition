# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 411, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 411 (delta 46), reused 45 (delta 21), pack-reused 329 (from 1)
# Receiving objects: 100% (411/411), 1.85 MiB | 27.84 MiB/s, done.
# Resolving deltas: 100% (234/234), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x1 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run m2puwecw (0.3s)
# wandb: ⣷ setting up run m2puwecw (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260404_064630-m2puwecw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg19_04042026_0646
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/m2puwecw
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.9465 - accuracy: 0.1532 - val_loss: 1.9461 - val_accuracy: 0.1301
# 	--- Save best at ep 1, val_loss: 1.9461, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 2/100 - loss: 1.9453 - accuracy: 0.1643 - val_loss: 1.9460 - val_accuracy: 0.1382
# 	--- Save best at ep 2, val_loss: 1.9460, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 3/100 - loss: 1.9453 - accuracy: 0.1899 - val_loss: 1.9460 - val_accuracy: 0.1301
# 	--- Save best at ep 3, val_loss: 1.9460, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 4/100 - loss: 1.9453 - accuracy: 0.1538 - val_loss: 1.9462 - val_accuracy: 0.1301
# 	-!- No improvement: 1/10
# Epoch 5/100 - loss: 1.9452 - accuracy: 0.1650 - val_loss: 1.9460 - val_accuracy: 0.2494
# 	-!- No improvement: 2/10
# Epoch 6/100 - loss: 1.9450 - accuracy: 0.1856 - val_loss: 1.9459 - val_accuracy: 0.2494
# 	--- Save best at ep 6, val_loss: 1.9459, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 7/100 - loss: 1.9450 - accuracy: 0.1940 - val_loss: 1.9461 - val_accuracy: 0.1382
# 	-!- No improvement: 1/10
# Epoch 8/100 - loss: 1.9454 - accuracy: 0.2036 - val_loss: 1.9459 - val_accuracy: 0.2494
# 	-!- No improvement: 2/10
# Epoch 9/100 - loss: 1.9451 - accuracy: 0.1946 - val_loss: 1.9459 - val_accuracy: 0.1819
# 	--- Save best at ep 9, val_loss: 1.9459, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 10/100 - loss: 1.9452 - accuracy: 0.1633 - val_loss: 1.9458 - val_accuracy: 0.1819
# 	--- Save best at ep 10, val_loss: 1.9458, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 11/100 - loss: 1.9452 - accuracy: 0.1985 - val_loss: 1.9458 - val_accuracy: 0.1819
# 	--- Save best at ep 11, val_loss: 1.9458, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth ---
# Epoch 12/100 - loss: 1.9451 - accuracy: 0.1931 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 1/10
# Epoch 13/100 - loss: 1.9451 - accuracy: 0.1957 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 2/10
# Epoch 14/100 - loss: 1.9449 - accuracy: 0.1913 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 3/10
# Epoch 15/100 - loss: 1.9450 - accuracy: 0.2047 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 4/10
# Epoch 16/100 - loss: 1.9450 - accuracy: 0.2130 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 5/10
# Epoch 17/100 - loss: 1.9449 - accuracy: 0.2056 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 6/10
# Epoch 18/100 - loss: 1.9452 - accuracy: 0.2039 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 7/10
# Epoch 19/100 - loss: 1.9451 - accuracy: 0.2112 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 8/10
# Epoch 20/100 - loss: 1.9452 - accuracy: 0.2106 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 9/10
# Epoch 21/100 - loss: 1.9452 - accuracy: 0.2003 - val_loss: 1.9458 - val_accuracy: 0.2494
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=21
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0646_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 45.80it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# --> Accuracy: 16.55%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.000000  0.000000  0.000000   491.000000
# disgust        0.000000  0.000000  0.000000    55.000000
# fear           0.000000  0.000000  0.000000   528.000000
# happy          0.000000  0.000000  0.000000   879.000000
# sad            0.165506  1.000000  0.284007   594.000000
# surprise       0.000000  0.000000  0.000000   416.000000
# neutral        0.000000  0.000000  0.000000   626.000000
# accuracy       0.165506  0.165506  0.165506     0.165506
# macro avg      0.023644  0.142857  0.040572  3589.000000
# weighted avg   0.027392  0.165506  0.047005  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg19_04042026_0646_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_m2puwecw (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_m2puwecw (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_m2puwecw (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_m2puwecw (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_m2puwecw (0.5s)
# wandb:   ↳ ⣷ vgg19_04042026_0646_best.pth 0B/80.7MB (0.0s)
# wandb: ⣯ uploading artifact cnn_m2puwecw (0.5s)
# wandb:   ↳ ⣯ vgg19_04042026_0646_best.pth 0B/80.7MB (0.0s)
# wandb: ⣟ uploading artifact cnn_m2puwecw (0.5s)
# wandb:   ↳ ⣟ vgg19_04042026_0646_best.pth 0B/80.7MB (0.0s)
# wandb: ⡿ uploading artifact cnn_m2puwecw (0.5s)
# wandb:   ↳ ⡿ vgg19_04042026_0646_best.pth 0B/80.7MB (0.0s)
# wandb: ⢿ uploading artifact cnn_m2puwecw (0.5s)
# wandb:   ↳ ⢿ vgg19_04042026_0646_best.pth 0B/80.7MB (0.0s)
# wandb: ⣻ uploading artifact cnn_m2puwecw (1.0s)
# wandb:   ↳ ⣻ vgg19_04042026_0646_best.pth 5.0MB/80.7MB (0.5s)
# wandb: ⣽ uploading artifact cnn_m2puwecw (1.0s)
# wandb:   ↳ ⣽ vgg19_04042026_0646_best.pth 5.0MB/80.7MB (0.5s)
# wandb: ⣾ uploading artifact cnn_m2puwecw (1.0s)
# wandb:   ↳ ⣾ vgg19_04042026_0646_best.pth 5.0MB/80.7MB (0.5s)
# wandb: ⣷ uploading artifact cnn_m2puwecw (1.0s)
# wandb:   ↳ ⣷ vgg19_04042026_0646_best.pth 5.0MB/80.7MB (0.5s)
# wandb: ⣯ uploading artifact cnn_m2puwecw (1.0s)
# wandb:   ↳ ⣯ vgg19_04042026_0646_best.pth 5.0MB/80.7MB (0.5s)
# wandb: ⣟ uploading artifact cnn_m2puwecw (1.5s)
# wandb:   ↳ ⣟ vgg19_04042026_0646_best.pth 58.6MB/80.7MB (1.0s)
# wandb: ⡿ uploading artifact cnn_m2puwecw (1.5s)
# wandb:   ↳ ⡿ vgg19_04042026_0646_best.pth 58.6MB/80.7MB (1.0s)
# wandb: ⢿ uploading artifact cnn_m2puwecw (1.5s)
# wandb:   ↳ ⢿ vgg19_04042026_0646_best.pth 58.6MB/80.7MB (1.0s)
# wandb: ⣻ uploading artifact cnn_m2puwecw (1.5s)
# wandb:   ↳ ⣻ vgg19_04042026_0646_best.pth 58.6MB/80.7MB (1.0s)
# wandb: ⣽ uploading artifact cnn_m2puwecw (1.5s)
# wandb:   ↳ ⣽ vgg19_04042026_0646_best.pth 58.6MB/80.7MB (1.0s)
# wandb: ⣾ uploading artifact cnn_m2puwecw (2.0s)
# wandb: ⣷ uploading artifact cnn_m2puwecw (2.0s)
# wandb: ⣯ uploading artifact cnn_m2puwecw (2.0s)
# wandb: ⣟ uploading artifact cnn_m2puwecw (2.0s)
# wandb: ⡿ uploading artifact cnn_m2puwecw (2.0s)
# wandb: ⢿ uploading artifact cnn_m2puwecw (2.5s)
# wandb: ⣻ uploading artifact cnn_m2puwecw (2.5s)
# wandb: ⣽ uploading artifact cnn_m2puwecw (2.5s)
# wandb: ⣾ uploading artifact cnn_m2puwecw (2.5s)
# wandb: ⣷ uploading artifact cnn_m2puwecw (2.5s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██
# wandb:  Learning_Rate █████▄▄▄▄▄▂▂▂▂▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▅▁▂▅▆▇▆▂▆▆▆▅▇█▇▇██▇
# wandb:     Train/Loss █▃▃▃▂▂▁▃▂▂▂▂▂▁▁▂▁▂▂▂▂
# wandb:   Val/Accuracy ▁▁▁▁██▁█▄▄▄██████████
# wandb:       Val/Loss ▆▅▅█▅▂▆▃▂▁▁▂▁▂▂▂▂▂▂▂▂
# wandb:
# wandb: Run summary:
# wandb:          Epoch 21
# wandb:  Learning_Rate 6e-05
# wandb: Train/Accuracy 0.20029
# wandb:     Train/Loss 1.94519
# wandb:   Val/Accuracy 0.24937
# wandb:       Val/Loss 1.94582
# wandb:
# wandb: 🚀 View run vgg19_04042026_0646 at: https://wandb.ai/phucga15062005/FER2013/runs/m2puwecw
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260404_064630-m2puwecw/logs
#
# 		DONE!
