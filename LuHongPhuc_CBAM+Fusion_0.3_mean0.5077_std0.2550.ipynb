# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 990, done.
# remote: Counting objects: 100% (239/239), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 990 (delta 180), reused 160 (delta 126), pack-reused 751 (from 2)
# Receiving objects: 100% (990/990), 5.90 MiB | 23.40 MiB/s, done.
# Resolving deltas: 100% (620/620), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using CBAM + Fusion
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run encqx463 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_113502-encqx463
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_cbam_10042026_1134
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/encqx463
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.6893 - accuracy: 0.1805 - val_loss: 1.9289 - val_accuracy: 0.3282
# 	--- Save best at ep 1, val_loss: 1.9289, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 2/100 - loss: 2.4718 - accuracy: 0.3400 - val_loss: 1.7371 - val_accuracy: 0.4622
# 	--- Save best at ep 2, val_loss: 1.7371, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 3/100 - loss: 2.3688 - accuracy: 0.3999 - val_loss: 1.6955 - val_accuracy: 0.4829
# 	--- Save best at ep 3, val_loss: 1.6955, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 4/100 - loss: 2.3062 - accuracy: 0.4396 - val_loss: 1.6733 - val_accuracy: 0.4965
# 	--- Save best at ep 4, val_loss: 1.6733, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 5/100 - loss: 2.2560 - accuracy: 0.4633 - val_loss: 1.6970 - val_accuracy: 0.5205
# 	-!- No improvement: 1/20
# Epoch 6/100 - loss: 2.2234 - accuracy: 0.4800 - val_loss: 1.6762 - val_accuracy: 0.5082
# 	-!- No improvement: 2/20
# Epoch 7/100 - loss: 2.2065 - accuracy: 0.4894 - val_loss: 1.6423 - val_accuracy: 0.4999
# 	--- Save best at ep 7, val_loss: 1.6423, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 8/100 - loss: 2.1866 - accuracy: 0.4987 - val_loss: 1.5906 - val_accuracy: 0.5294
# 	--- Save best at ep 8, val_loss: 1.5906, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 9/100 - loss: 2.1543 - accuracy: 0.5121 - val_loss: 1.5714 - val_accuracy: 0.5570
# 	--- Save best at ep 9, val_loss: 1.5714, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 10/100 - loss: 2.1375 - accuracy: 0.5219 - val_loss: 1.5935 - val_accuracy: 0.5776
# 	-!- No improvement: 1/20
# Epoch 11/100 - loss: 2.1220 - accuracy: 0.5326 - val_loss: 1.5672 - val_accuracy: 0.5779
# 	--- Save best at ep 11, val_loss: 1.5672, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 12/100 - loss: 2.1121 - accuracy: 0.5354 - val_loss: 1.5524 - val_accuracy: 0.5876
# 	--- Save best at ep 12, val_loss: 1.5524, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 13/100 - loss: 2.0976 - accuracy: 0.5415 - val_loss: 1.5365 - val_accuracy: 0.6010
# 	--- Save best at ep 13, val_loss: 1.5365, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 14/100 - loss: 2.0873 - accuracy: 0.5449 - val_loss: 1.5285 - val_accuracy: 0.5938
# 	--- Save best at ep 14, val_loss: 1.5285, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 15/100 - loss: 2.0776 - accuracy: 0.5553 - val_loss: 1.5313 - val_accuracy: 0.6046
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 2.0651 - accuracy: 0.5591 - val_loss: 1.5195 - val_accuracy: 0.6004
# 	--- Save best at ep 16, val_loss: 1.5195, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 17/100 - loss: 2.0518 - accuracy: 0.5614 - val_loss: 1.5573 - val_accuracy: 0.6071
# 	-!- No improvement: 1/20
# Epoch 18/100 - loss: 2.0330 - accuracy: 0.5695 - val_loss: 1.5233 - val_accuracy: 0.5924
# 	-!- No improvement: 2/20
# Epoch 19/100 - loss: 2.0407 - accuracy: 0.5692 - val_loss: 1.5249 - val_accuracy: 0.6152
# 	-!- No improvement: 3/20
# Epoch 20/100 - loss: 2.0302 - accuracy: 0.5750 - val_loss: 1.5377 - val_accuracy: 0.6016
# 	-!- No improvement: 4/20
# Epoch 21/100 - loss: 1.9850 - accuracy: 0.5949 - val_loss: 1.4973 - val_accuracy: 0.6197
# 	--- Save best at ep 21, val_loss: 1.4973, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 22/100 - loss: 1.9673 - accuracy: 0.5997 - val_loss: 1.4918 - val_accuracy: 0.6222
# 	--- Save best at ep 22, val_loss: 1.4918, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 23/100 - loss: 1.9597 - accuracy: 0.6024 - val_loss: 1.4928 - val_accuracy: 0.6330
# 	-!- No improvement: 1/20
# Epoch 24/100 - loss: 1.9398 - accuracy: 0.6164 - val_loss: 1.4705 - val_accuracy: 0.6239
# 	--- Save best at ep 24, val_loss: 1.4705, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 25/100 - loss: 1.9373 - accuracy: 0.6141 - val_loss: 1.4823 - val_accuracy: 0.6386
# 	-!- No improvement: 1/20
# Epoch 26/100 - loss: 1.9293 - accuracy: 0.6171 - val_loss: 1.4742 - val_accuracy: 0.6350
# 	-!- No improvement: 2/20
# Epoch 27/100 - loss: 1.9215 - accuracy: 0.6212 - val_loss: 1.4709 - val_accuracy: 0.6375
# 	-!- No improvement: 3/20
# Epoch 28/100 - loss: 1.9160 - accuracy: 0.6266 - val_loss: 1.4852 - val_accuracy: 0.6336
# 	-!- No improvement: 4/20
# Epoch 29/100 - loss: 1.8883 - accuracy: 0.6375 - val_loss: 1.4626 - val_accuracy: 0.6498
# 	--- Save best at ep 29, val_loss: 1.4626, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 30/100 - loss: 1.8813 - accuracy: 0.6380 - val_loss: 1.4649 - val_accuracy: 0.6495
# 	-!- No improvement: 1/20
# Epoch 31/100 - loss: 1.8666 - accuracy: 0.6436 - val_loss: 1.4556 - val_accuracy: 0.6486
# 	--- Save best at ep 31, val_loss: 1.4556, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 32/100 - loss: 1.8613 - accuracy: 0.6468 - val_loss: 1.4605 - val_accuracy: 0.6592
# 	-!- No improvement: 1/20
# Epoch 33/100 - loss: 1.8634 - accuracy: 0.6474 - val_loss: 1.4501 - val_accuracy: 0.6545
# 	--- Save best at ep 33, val_loss: 1.4501, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 34/100 - loss: 1.8553 - accuracy: 0.6488 - val_loss: 1.4546 - val_accuracy: 0.6562
# 	-!- No improvement: 1/20
# Epoch 35/100 - loss: 1.8472 - accuracy: 0.6555 - val_loss: 1.4684 - val_accuracy: 0.6584
# 	-!- No improvement: 2/20
# Epoch 36/100 - loss: 1.8365 - accuracy: 0.6591 - val_loss: 1.4582 - val_accuracy: 0.6592
# 	-!- No improvement: 3/20
# Epoch 37/100 - loss: 1.8301 - accuracy: 0.6607 - val_loss: 1.4412 - val_accuracy: 0.6581
# 	--- Save best at ep 37, val_loss: 1.4412, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 38/100 - loss: 1.8320 - accuracy: 0.6609 - val_loss: 1.4544 - val_accuracy: 0.6631
# 	-!- No improvement: 1/20
# Epoch 39/100 - loss: 1.8253 - accuracy: 0.6637 - val_loss: 1.4543 - val_accuracy: 0.6629
# 	-!- No improvement: 2/20
# Epoch 40/100 - loss: 1.8245 - accuracy: 0.6630 - val_loss: 1.4412 - val_accuracy: 0.6634
# 	-!- No improvement: 3/20
# Epoch 41/100 - loss: 1.8170 - accuracy: 0.6684 - val_loss: 1.4548 - val_accuracy: 0.6645
# 	-!- No improvement: 4/20
# Epoch 42/100 - loss: 1.7991 - accuracy: 0.6732 - val_loss: 1.4466 - val_accuracy: 0.6676
# 	-!- No improvement: 5/20
# Epoch 43/100 - loss: 1.8008 - accuracy: 0.6735 - val_loss: 1.4436 - val_accuracy: 0.6673
# 	-!- No improvement: 6/20
# Epoch 44/100 - loss: 1.7868 - accuracy: 0.6801 - val_loss: 1.4505 - val_accuracy: 0.6740
# 	-!- No improvement: 7/20
# Epoch 45/100 - loss: 1.7838 - accuracy: 0.6842 - val_loss: 1.4463 - val_accuracy: 0.6718
# 	-!- No improvement: 8/20
# Epoch 46/100 - loss: 1.7734 - accuracy: 0.6879 - val_loss: 1.4450 - val_accuracy: 0.6726
# 	-!- No improvement: 9/20
# Epoch 47/100 - loss: 1.7688 - accuracy: 0.6888 - val_loss: 1.4487 - val_accuracy: 0.6693
# 	-!- No improvement: 10/20
# Epoch 48/100 - loss: 1.7587 - accuracy: 0.6910 - val_loss: 1.4507 - val_accuracy: 0.6729
# 	-!- No improvement: 11/20
# Epoch 49/100 - loss: 1.7612 - accuracy: 0.6924 - val_loss: 1.4367 - val_accuracy: 0.6726
# 	--- Save best at ep 49, val_loss: 1.4367, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth ---
# Epoch 50/100 - loss: 1.7640 - accuracy: 0.6913 - val_loss: 1.4401 - val_accuracy: 0.6754
# 	-!- No improvement: 1/20
# Epoch 51/100 - loss: 1.7595 - accuracy: 0.6886 - val_loss: 1.4482 - val_accuracy: 0.6737
# 	-!- No improvement: 2/20
# Epoch 52/100 - loss: 1.7583 - accuracy: 0.6922 - val_loss: 1.4427 - val_accuracy: 0.6709
# 	-!- No improvement: 3/20
# Epoch 53/100 - loss: 1.7530 - accuracy: 0.6932 - val_loss: 1.4436 - val_accuracy: 0.6698
# 	-!- No improvement: 4/20
# Epoch 54/100 - loss: 1.7529 - accuracy: 0.6966 - val_loss: 1.4458 - val_accuracy: 0.6721
# 	-!- No improvement: 5/20
# Epoch 55/100 - loss: 1.7461 - accuracy: 0.6975 - val_loss: 1.4447 - val_accuracy: 0.6701
# 	-!- No improvement: 6/20
# Epoch 56/100 - loss: 1.7474 - accuracy: 0.6978 - val_loss: 1.4488 - val_accuracy: 0.6695
# 	-!- No improvement: 7/20
# Epoch 57/100 - loss: 1.7447 - accuracy: 0.6976 - val_loss: 1.4451 - val_accuracy: 0.6721
# 	-!- No improvement: 8/20
# Epoch 58/100 - loss: 1.7402 - accuracy: 0.7040 - val_loss: 1.4447 - val_accuracy: 0.6743
# 	-!- No improvement: 9/20
# Epoch 59/100 - loss: 1.7430 - accuracy: 0.7018 - val_loss: 1.4484 - val_accuracy: 0.6760
# 	-!- No improvement: 10/20
# Epoch 60/100 - loss: 1.7347 - accuracy: 0.7044 - val_loss: 1.4476 - val_accuracy: 0.6760
# 	-!- No improvement: 11/20
# Epoch 61/100 - loss: 1.7386 - accuracy: 0.7023 - val_loss: 1.4448 - val_accuracy: 0.6771
# 	-!- No improvement: 12/20
# Epoch 62/100 - loss: 1.7358 - accuracy: 0.7037 - val_loss: 1.4462 - val_accuracy: 0.6785
# 	-!- No improvement: 13/20
# Epoch 63/100 - loss: 1.7371 - accuracy: 0.7052 - val_loss: 1.4423 - val_accuracy: 0.6751
# 	-!- No improvement: 14/20
# Epoch 64/100 - loss: 1.7407 - accuracy: 0.7006 - val_loss: 1.4424 - val_accuracy: 0.6760
# 	-!- No improvement: 15/20
# Epoch 65/100 - loss: 1.7359 - accuracy: 0.7022 - val_loss: 1.4478 - val_accuracy: 0.6760
# 	-!- No improvement: 16/20
# Epoch 66/100 - loss: 1.7372 - accuracy: 0.7042 - val_loss: 1.4431 - val_accuracy: 0.6762
# 	-!- No improvement: 17/20
# Epoch 67/100 - loss: 1.7349 - accuracy: 0.7027 - val_loss: 1.4478 - val_accuracy: 0.6757
# 	-!- No improvement: 18/20
# Epoch 68/100 - loss: 1.7344 - accuracy: 0.6986 - val_loss: 1.4418 - val_accuracy: 0.6726
# 	-!- No improvement: 19/20
# Epoch 69/100 - loss: 1.7403 - accuracy: 0.6993 - val_loss: 1.4448 - val_accuracy: 0.6754
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=69
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_cbam/vgg_cbam_10042026_1134_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 42.39it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.46%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.628450  0.602851  0.615385   491.000000
# disgust        0.478723  0.818182  0.604027    55.000000
# fear           0.566502  0.435606  0.492505   528.000000
# happy          0.892899  0.872582  0.882624   879.000000
# sad            0.555556  0.555556  0.555556   594.000000
# surprise       0.746667  0.807692  0.775982   416.000000
# neutral        0.633566  0.723642  0.675615   626.000000
# accuracy       0.684592  0.684592  0.684592     0.684592
# macro avg      0.643195  0.688016  0.657385  3589.000000
# weighted avg   0.684340  0.684592  0.681802  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_cbam_10042026_1134_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_encqx463 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_encqx463 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_encqx463 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_encqx463 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_encqx463 (0.5s)
# wandb:   ↳ ⣷ vgg_cbam_10042026_1134_best.pth 37.0MB/101.5MB (0.2s)
# wandb: ⣯ uploading artifact cnn_encqx463 (0.5s)
# wandb:   ↳ ⣯ vgg_cbam_10042026_1134_best.pth 37.0MB/101.5MB (0.2s)
# wandb: ⣟ uploading artifact cnn_encqx463 (0.5s)
# wandb:   ↳ ⣟ vgg_cbam_10042026_1134_best.pth 37.0MB/101.5MB (0.2s)
# wandb: ⡿ uploading artifact cnn_encqx463 (0.5s)
# wandb:   ↳ ⡿ vgg_cbam_10042026_1134_best.pth 37.0MB/101.5MB (0.2s)
# wandb: ⢿ uploading artifact cnn_encqx463 (0.5s)
# wandb:   ↳ ⢿ vgg_cbam_10042026_1134_best.pth 37.0MB/101.5MB (0.2s)
# wandb: ⣻ uploading artifact cnn_encqx463 (1.0s)
# wandb:   ↳ ⣻ vgg_cbam_10042026_1134_best.pth 98.9MB/101.5MB (0.7s)
# wandb: ⣽ uploading artifact cnn_encqx463 (1.0s)
# wandb:   ↳ ⣽ vgg_cbam_10042026_1134_best.pth 98.9MB/101.5MB (0.7s)
# wandb: ⣾ uploading artifact cnn_encqx463 (1.0s)
# wandb:   ↳ ⣾ vgg_cbam_10042026_1134_best.pth 98.9MB/101.5MB (0.7s)
# wandb: ⣷ uploading artifact cnn_encqx463 (1.0s)
# wandb:   ↳ ⣷ vgg_cbam_10042026_1134_best.pth 98.9MB/101.5MB (0.7s)
# wandb: ⣯ uploading artifact cnn_encqx463 (1.0s)
# wandb:   ↳ ⣯ vgg_cbam_10042026_1134_best.pth 98.9MB/101.5MB (0.7s)
# wandb: ⣟ uploading artifact cnn_encqx463 (1.5s)
# wandb: ⡿ uploading artifact cnn_encqx463 (1.5s)
# wandb: ⢿ uploading artifact cnn_encqx463 (1.5s)
# wandb: ⣻ uploading artifact cnn_encqx463 (1.5s)
# wandb: ⣽ uploading artifact cnn_encqx463 (1.5s)
# wandb: ⣾ uploading media/images/Evaluation/Wrong_Samples_70_a59909c1d5fe2236c...
# wandb: ⣾ uploading output.log 12.3KB/12.3KB (0.1s)
# wandb: ⣾ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣾ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣾ uploading media/images/Evaluation/Confusion_Matrix_68_52dbf2b07d1605...
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_69_a34b4dfc2c81e0a...
# wandb: ⣷ uploading media/images/Evaluation/Wrong_Samples_70_a59909c1d5fe2236c...
# wandb: ⣷ uploading output.log 12.3KB/12.3KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣷ uploading config.yaml 3.5KB/3.5KB (0.1s)
# wandb: ⣷ uploading media/images/Evaluation/Confusion_Matrix_68_52dbf2b07d1605...
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_69_a34b4dfc2c81e0a...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██
# wandb:  Learning_Rate ███████████▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:     Train/Loss █▅▅▄▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▄▄▅▄▆▆▆▇▆▇▇▇▇▇▇▇▇█████████████████████
# wandb:       Val/Loss █▅▅▄▃▃▃▂▂▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 69
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.69933
# wandb:     Train/Loss 1.74033
# wandb:   Val/Accuracy 0.6754
# wandb:       Val/Loss 1.4448
# wandb:
# wandb: 🚀 View run vgg_cbam_10042026_1134 at: https://wandb.ai/phucga15062005/FER2013/runs/encqx463
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_113502-encqx463/logs
#
# 		DONE!
