# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 4

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1738, done.
# remote: Counting objects: 100% (435/435), done.
# remote: Compressing objects: 100% (238/238), done.
# remote: Total 1738 (delta 328), reused 270 (delta 197), pack-reused 1303 (from 2)
# Receiving objects: 100% (1738/1738), 6.22 MiB | 36.60 MiB/s, done.
# Resolving deltas: 100% (1181/1181), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config resnet35 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run iw0ec973 (0.3s)
# wandb: ⣷ setting up run iw0ec973 (0.3s)
# wandb: ⣯ setting up run iw0ec973 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260414_173500-iw0ec973
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_14042026_1734
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/iw0ec973
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.9345 - accuracy: 0.1908 - val_loss: 1.8945 - val_accuracy: 0.2527
# 	--- Save best at ep 1, val_loss: 1.8945, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 2/100 - loss: 1.8157 - accuracy: 0.2757 - val_loss: 1.7473 - val_accuracy: 0.2920
# 	--- Save best at ep 2, val_loss: 1.7473, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 3/100 - loss: 1.6843 - accuracy: 0.3498 - val_loss: 1.5929 - val_accuracy: 0.4048
# 	--- Save best at ep 3, val_loss: 1.5929, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 4/100 - loss: 1.6029 - accuracy: 0.3868 - val_loss: 1.4494 - val_accuracy: 0.4411
# 	--- Save best at ep 4, val_loss: 1.4494, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 5/100 - loss: 1.5445 - accuracy: 0.4124 - val_loss: 1.4433 - val_accuracy: 0.4550
# 	--- Save best at ep 5, val_loss: 1.4433, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 6/100 - loss: 1.4856 - accuracy: 0.4317 - val_loss: 1.3704 - val_accuracy: 0.4606
# 	--- Save best at ep 6, val_loss: 1.3704, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 7/100 - loss: 1.4646 - accuracy: 0.4447 - val_loss: 1.3513 - val_accuracy: 0.4907
# 	--- Save best at ep 7, val_loss: 1.3513, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 8/100 - loss: 1.4226 - accuracy: 0.4566 - val_loss: 1.3005 - val_accuracy: 0.5183
# 	--- Save best at ep 8, val_loss: 1.3005, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 9/100 - loss: 1.4047 - accuracy: 0.4682 - val_loss: 1.3731 - val_accuracy: 0.5130
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 1.3740 - accuracy: 0.4796 - val_loss: 1.3293 - val_accuracy: 0.4965
# 	-!- No improvement: 2/20
# Epoch 11/100 - loss: 1.3641 - accuracy: 0.4840 - val_loss: 1.3363 - val_accuracy: 0.5046
# 	-!- No improvement: 3/20
# Epoch 12/100 - loss: 1.3256 - accuracy: 0.4920 - val_loss: 1.2836 - val_accuracy: 0.5288
# 	--- Save best at ep 12, val_loss: 1.2836, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 13/100 - loss: 1.3239 - accuracy: 0.5018 - val_loss: 1.3475 - val_accuracy: 0.5227
# 	-!- No improvement: 1/20
# Epoch 14/100 - loss: 1.3074 - accuracy: 0.4998 - val_loss: 1.2990 - val_accuracy: 0.5169
# 	-!- No improvement: 2/20
# Epoch 15/100 - loss: 1.2963 - accuracy: 0.5058 - val_loss: 1.3368 - val_accuracy: 0.5397
# 	-!- No improvement: 3/20
# Epoch 16/100 - loss: 1.2769 - accuracy: 0.5126 - val_loss: 1.3313 - val_accuracy: 0.5169
# 	-!- No improvement: 4/20
# Epoch 17/100 - loss: 1.2101 - accuracy: 0.5382 - val_loss: 1.2061 - val_accuracy: 0.5542
# 	--- Save best at ep 17, val_loss: 1.2061, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 18/100 - loss: 1.1994 - accuracy: 0.5390 - val_loss: 1.1916 - val_accuracy: 0.5684
# 	--- Save best at ep 18, val_loss: 1.1916, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 19/100 - loss: 1.1761 - accuracy: 0.5485 - val_loss: 1.1726 - val_accuracy: 0.5879
# 	--- Save best at ep 19, val_loss: 1.1726, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 20/100 - loss: 1.1695 - accuracy: 0.5475 - val_loss: 1.1867 - val_accuracy: 0.5684
# 	-!- No improvement: 1/20
# Epoch 21/100 - loss: 1.1542 - accuracy: 0.5573 - val_loss: 1.2949 - val_accuracy: 0.5681
# 	-!- No improvement: 2/20
# Epoch 22/100 - loss: 1.1458 - accuracy: 0.5580 - val_loss: 1.1538 - val_accuracy: 0.5779
# 	--- Save best at ep 22, val_loss: 1.1538, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 23/100 - loss: 1.1381 - accuracy: 0.5624 - val_loss: 1.1736 - val_accuracy: 0.5776
# 	-!- No improvement: 1/20
# Epoch 24/100 - loss: 1.1384 - accuracy: 0.5621 - val_loss: 1.2354 - val_accuracy: 0.5801
# 	-!- No improvement: 2/20
# Epoch 25/100 - loss: 1.1187 - accuracy: 0.5679 - val_loss: 1.1688 - val_accuracy: 0.5868
# 	-!- No improvement: 3/20
# Epoch 26/100 - loss: 1.1121 - accuracy: 0.5682 - val_loss: 1.1200 - val_accuracy: 0.5684
# 	--- Save best at ep 26, val_loss: 1.1200, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 27/100 - loss: 1.1060 - accuracy: 0.5729 - val_loss: 1.0853 - val_accuracy: 0.6046
# 	--- Save best at ep 27, val_loss: 1.0853, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 28/100 - loss: 1.0941 - accuracy: 0.5750 - val_loss: 1.1146 - val_accuracy: 0.5871
# 	-!- No improvement: 1/20
# Epoch 29/100 - loss: 1.0934 - accuracy: 0.5750 - val_loss: 1.1160 - val_accuracy: 0.5832
# 	-!- No improvement: 2/20
# Epoch 30/100 - loss: 1.0901 - accuracy: 0.5770 - val_loss: 1.1065 - val_accuracy: 0.5782
# 	-!- No improvement: 3/20
# Epoch 31/100 - loss: 1.0843 - accuracy: 0.5777 - val_loss: 1.1224 - val_accuracy: 0.5890
# 	-!- No improvement: 4/20
# Epoch 32/100 - loss: 1.0309 - accuracy: 0.5960 - val_loss: 1.1290 - val_accuracy: 0.6032
# 	-!- No improvement: 5/20
# Epoch 33/100 - loss: 1.0241 - accuracy: 0.5932 - val_loss: 1.0716 - val_accuracy: 0.6130
# 	--- Save best at ep 33, val_loss: 1.0716, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 34/100 - loss: 1.0092 - accuracy: 0.6024 - val_loss: 1.0641 - val_accuracy: 0.6074
# 	--- Save best at ep 34, val_loss: 1.0641, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 35/100 - loss: 1.0090 - accuracy: 0.6028 - val_loss: 1.0865 - val_accuracy: 0.6119
# 	-!- No improvement: 1/20
# Epoch 36/100 - loss: 0.9969 - accuracy: 0.6082 - val_loss: 1.0583 - val_accuracy: 0.6225
# 	--- Save best at ep 36, val_loss: 1.0583, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 37/100 - loss: 0.9828 - accuracy: 0.6128 - val_loss: 1.0667 - val_accuracy: 0.6110
# 	-!- No improvement: 1/20
# Epoch 38/100 - loss: 0.9783 - accuracy: 0.6141 - val_loss: 1.0456 - val_accuracy: 0.6169
# 	--- Save best at ep 38, val_loss: 1.0456, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 39/100 - loss: 0.9801 - accuracy: 0.6124 - val_loss: 1.0637 - val_accuracy: 0.6091
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 0.9756 - accuracy: 0.6133 - val_loss: 1.0728 - val_accuracy: 0.6227
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 0.9681 - accuracy: 0.6159 - val_loss: 1.0469 - val_accuracy: 0.6255
# 	-!- No improvement: 3/20
# Epoch 42/100 - loss: 0.9633 - accuracy: 0.6226 - val_loss: 1.0592 - val_accuracy: 0.6197
# 	-!- No improvement: 4/20
# Epoch 43/100 - loss: 0.9388 - accuracy: 0.6278 - val_loss: 1.0173 - val_accuracy: 0.6353
# 	--- Save best at ep 43, val_loss: 1.0173, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth ---
# Epoch 44/100 - loss: 0.9277 - accuracy: 0.6309 - val_loss: 1.0490 - val_accuracy: 0.6319
# 	-!- No improvement: 1/20
# Epoch 45/100 - loss: 0.9253 - accuracy: 0.6344 - val_loss: 1.0516 - val_accuracy: 0.6297
# 	-!- No improvement: 2/20
# Epoch 46/100 - loss: 0.9135 - accuracy: 0.6334 - val_loss: 1.0497 - val_accuracy: 0.6308
# 	-!- No improvement: 3/20
# Epoch 47/100 - loss: 0.9067 - accuracy: 0.6383 - val_loss: 1.0327 - val_accuracy: 0.6445
# 	-!- No improvement: 4/20
# Epoch 48/100 - loss: 0.8921 - accuracy: 0.6417 - val_loss: 1.0839 - val_accuracy: 0.6364
# 	-!- No improvement: 5/20
# Epoch 49/100 - loss: 0.8838 - accuracy: 0.6433 - val_loss: 1.0586 - val_accuracy: 0.6358
# 	-!- No improvement: 6/20
# Epoch 50/100 - loss: 0.8849 - accuracy: 0.6484 - val_loss: 1.0234 - val_accuracy: 0.6369
# 	-!- No improvement: 7/20
# Epoch 51/100 - loss: 0.8802 - accuracy: 0.6429 - val_loss: 1.0419 - val_accuracy: 0.6372
# 	-!- No improvement: 8/20
# Epoch 52/100 - loss: 0.8726 - accuracy: 0.6459 - val_loss: 1.0414 - val_accuracy: 0.6411
# 	-!- No improvement: 9/20
# Epoch 53/100 - loss: 0.8701 - accuracy: 0.6512 - val_loss: 1.0471 - val_accuracy: 0.6381
# 	-!- No improvement: 10/20
# Epoch 54/100 - loss: 0.8723 - accuracy: 0.6473 - val_loss: 1.0287 - val_accuracy: 0.6428
# 	-!- No improvement: 11/20
# Epoch 55/100 - loss: 0.8703 - accuracy: 0.6508 - val_loss: 1.0343 - val_accuracy: 0.6411
# 	-!- No improvement: 12/20
# Epoch 56/100 - loss: 0.8573 - accuracy: 0.6555 - val_loss: 1.0487 - val_accuracy: 0.6408
# 	-!- No improvement: 13/20
# Epoch 57/100 - loss: 0.8604 - accuracy: 0.6532 - val_loss: 1.0336 - val_accuracy: 0.6442
# 	-!- No improvement: 14/20
# Epoch 58/100 - loss: 0.8627 - accuracy: 0.6537 - val_loss: 1.0500 - val_accuracy: 0.6436
# 	-!- No improvement: 15/20
# Epoch 59/100 - loss: 0.8599 - accuracy: 0.6555 - val_loss: 1.0430 - val_accuracy: 0.6436
# 	-!- No improvement: 16/20
# Epoch 60/100 - loss: 0.8596 - accuracy: 0.6491 - val_loss: 1.0343 - val_accuracy: 0.6442
# 	-!- No improvement: 17/20
# Epoch 61/100 - loss: 0.8544 - accuracy: 0.6522 - val_loss: 1.0378 - val_accuracy: 0.6420
# 	-!- No improvement: 18/20
# Epoch 62/100 - loss: 0.8467 - accuracy: 0.6590 - val_loss: 1.0509 - val_accuracy: 0.6406
# 	-!- No improvement: 19/20
# Epoch 63/100 - loss: 0.8567 - accuracy: 0.6545 - val_loss: 1.0404 - val_accuracy: 0.6414
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=63
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1734_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:02<00:00, 26.99it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 64.50%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.529197  0.590631  0.558229   491.000000
# disgust        0.437500  0.763636  0.556291    55.000000
# fear           0.538905  0.354167  0.427429   528.000000
# happy          0.880952  0.841866  0.860966   879.000000
# sad            0.520677  0.466330  0.492007   594.000000
# surprise       0.694444  0.841346  0.760870   416.000000
# neutral        0.594183  0.685304  0.636499   626.000000
# accuracy       0.645026  0.645026  0.645026     0.645026
# macro avg      0.599408  0.649040  0.613184  3589.000000
# weighted avg   0.644449  0.645026  0.639281  3589.000000
# --> Grad-CAM Heatmap Active: Layer-4 Hooked!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.36995515..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.508982..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5691964..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5141129..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41764706..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4958506..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49015746..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.787037..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.47942385..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1074376..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5120482..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.576923..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5344036..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7006579..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.46169353..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.57174885..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1829268..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41443297..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_14042026_1734_best.pth` to cloud successfully!
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (4.1s)
# wandb: ⢿ uploading artifact cnn_iw0ec973 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (4.1s)
# wandb: ⣻ uploading artifact cnn_iw0ec973 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (4.1s)
# wandb: ⣽ uploading artifact cnn_iw0ec973 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (4.1s)
# wandb: ⣾ uploading artifact cnn_iw0ec973 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (4.6s)
# wandb: ⣷ uploading artifact cnn_iw0ec973 (0.5s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (4.6s)
# wandb: ⣯ uploading artifact cnn_iw0ec973 (0.5s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (4.6s)
# wandb: ⣟ uploading artifact cnn_iw0ec973 (0.5s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (4.6s)
# wandb: ⡿ uploading artifact cnn_iw0ec973 (0.5s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (4.6s)
# wandb: ⢿ uploading artifact cnn_iw0ec973 (0.5s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (5.1s)
# wandb: ⣻ uploading artifact cnn_iw0ec973 (1.0s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (5.1s)
# wandb: ⣽ uploading artifact cnn_iw0ec973 (1.0s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (5.1s)
# wandb: ⣾ uploading artifact cnn_iw0ec973 (1.0s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (5.1s)
# wandb: ⣷ uploading artifact cnn_iw0ec973 (1.0s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (5.1s)
# wandb: ⣯ uploading artifact cnn_iw0ec973 (1.0s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (5.6s)
# wandb: ⣟ uploading artifact cnn_iw0ec973 (1.5s)
# wandb:   ↳ ⣟ resnet35_14042026_1734_best.pth 1.2MB/72.7MB (0.1s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (5.6s)
# wandb: ⡿ uploading artifact cnn_iw0ec973 (1.5s)
# wandb:   ↳ ⡿ resnet35_14042026_1734_best.pth 1.2MB/72.7MB (0.1s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (5.6s)
# wandb: ⢿ uploading artifact cnn_iw0ec973 (1.5s)
# wandb:   ↳ ⢿ resnet35_14042026_1734_best.pth 1.2MB/72.7MB (0.1s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (5.6s)
# wandb: ⣻ uploading artifact cnn_iw0ec973 (1.5s)
# wandb:   ↳ ⣻ resnet35_14042026_1734_best.pth 1.2MB/72.7MB (0.1s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (5.6s)
# wandb: ⣽ uploading artifact cnn_iw0ec973 (1.5s)
# wandb:   ↳ ⣽ resnet35_14042026_1734_best.pth 1.2MB/72.7MB (0.1s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (6.1s)
# wandb: ⣾ uploading artifact cnn_iw0ec973 (2.0s)
# wandb:   ↳ ⣾ resnet35_14042026_1734_best.pth 48.0MB/72.7MB (0.6s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (6.1s)
# wandb: ⣷ uploading artifact cnn_iw0ec973 (2.0s)
# wandb:   ↳ ⣷ resnet35_14042026_1734_best.pth 48.0MB/72.7MB (0.6s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (6.1s)
# wandb: ⣯ uploading artifact cnn_iw0ec973 (2.0s)
# wandb:   ↳ ⣯ resnet35_14042026_1734_best.pth 48.0MB/72.7MB (0.6s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (6.1s)
# wandb: ⣟ uploading artifact cnn_iw0ec973 (2.0s)
# wandb:   ↳ ⣟ resnet35_14042026_1734_best.pth 48.0MB/72.7MB (0.6s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (6.1s)
# wandb: ⡿ uploading artifact cnn_iw0ec973 (2.0s)
# wandb:   ↳ ⡿ resnet35_14042026_1734_best.pth 48.0MB/72.7MB (0.6s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (6.6s)
# wandb: ⢿ uploading artifact cnn_iw0ec973 (2.5s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (6.6s)
# wandb: ⣻ uploading artifact cnn_iw0ec973 (2.5s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (6.6s)
# wandb: ⣽ uploading artifact cnn_iw0ec973 (2.5s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (6.6s)
# wandb: ⣾ uploading artifact cnn_iw0ec973 (2.5s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (6.6s)
# wandb: ⣷ uploading artifact cnn_iw0ec973 (2.5s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (7.1s)
# wandb: ⣯ uploading artifact cnn_iw0ec973 (3.0s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (7.1s)
# wandb: ⣟ uploading artifact cnn_iw0ec973 (3.0s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (7.1s)
# wandb: ⡿ uploading artifact cnn_iw0ec973 (3.0s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (7.1s)
# wandb: ⢿ uploading artifact cnn_iw0ec973 (3.0s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (7.1s)
# wandb: ⣻ uploading artifact cnn_iw0ec973 (3.0s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (7.6s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (7.6s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (7.6s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (7.6s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (7.6s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (8.1s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (8.1s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (8.1s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (8.1s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (8.1s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (8.6s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (8.6s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (8.6s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (8.6s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (8.6s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (9.1s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (9.1s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (9.1s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (9.1s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (9.1s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (9.6s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (9.6s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (9.6s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (9.6s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (9.6s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (10s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (10s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (10s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (10s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (10s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (11s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (12s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (13s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (14s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⡿ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⢿ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣻ uploading history steps 61-62, summary, console lines 127-152 (15s)
# wandb: ⣽ uploading history steps 61-62, summary, console lines 127-152 (16s)
# wandb: ⣾ uploading history steps 61-62, summary, console lines 127-152 (16s)
# wandb: ⣷ uploading history steps 61-62, summary, console lines 127-152 (16s)
# wandb: ⣯ uploading history steps 61-62, summary, console lines 127-152 (16s)
# wandb: ⣟ uploading history steps 61-62, summary, console lines 127-152 (16s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (0.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (0.2s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (0.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (0.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (0.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (0.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (0.7s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (0.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (0.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (0.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (1.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (1.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (1.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (1.2s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (1.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (1.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (1.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (1.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (1.7s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (1.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (2.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (2.2s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (2.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (2.2s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (2.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (2.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (2.7s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (2.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (2.7s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (2.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (3.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (3.2s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (3.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (3.2s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (3.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (3.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (3.7s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (3.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (3.7s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (3.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (4.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (4.2s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (4.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (4.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (4.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (4.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (4.7s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (4.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (4.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (4.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (5.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (5.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (5.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (5.2s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (5.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (5.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (5.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (5.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (5.7s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (5.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (6.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (6.2s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (6.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (6.2s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (6.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (6.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (6.7s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (6.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (6.7s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (6.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (7.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (7.2s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (7.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (7.2s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (7.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (7.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (7.7s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (7.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (7.7s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (7.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (8.2s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (8.2s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (8.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (8.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (8.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (8.7s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (8.7s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (8.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (8.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (8.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (9.2s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (9.2s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (9.2s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (9.2s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (9.2s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (9.7s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (9.7s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (9.7s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (9.7s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (9.7s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (10s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (10s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (10s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (10s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (10s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (11s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (12s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (13s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (14s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (15s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (16s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (17s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣯ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⣟ uploading history steps 63-64, summary, console lines 153-179 (18s)
# wandb: ⡿ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb: ⢿ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb: ⣻ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb: ⣽ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb: ⣾ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb: ⣷ uploading history steps 63-64, summary, console lines 153-179 (19s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇████
# wandb:  Learning_Rate ██████████▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:     Train/Loss █▇▆▆▅▅▅▅▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▄▅▅▆▆▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█▇██████████████
# wandb:       Val/Loss █▇▄▄▄▃▃▄▄▃▂▃▂▂▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 63
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.65446
# wandb:     Train/Loss 0.8567
# wandb:   Val/Accuracy 0.6414
# wandb:       Val/Loss 1.04038
# wandb:
# wandb: 🚀 View run resnet35_14042026_1734 at: https://wandb.ai/phucga15062005/FER2013/runs/iw0ec973
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260414_173500-iw0ec973/logs
#
# 		DONE!
