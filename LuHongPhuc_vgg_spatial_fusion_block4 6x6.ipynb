# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1050, done.
# remote: Counting objects: 100% (299/299), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 1050 (delta 223), reused 186 (delta 138), pack-reused 751 (from 2)
# Receiving objects: 100% (1050/1050), 5.93 MiB | 24.29 MiB/s, done.
# Resolving deltas: 100% (663/663), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config vgg_spatial_6x6 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion (Grid: 6x6)
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 5y38ocms (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_171734-5y38ocms
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_spatial_10042026_1717
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/5y38ocms
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.2828 - accuracy: 0.2928 - val_loss: 1.7222 - val_accuracy: 0.3449
# 	--- Save best at ep 1, val_loss: 1.7222, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 2/100 - loss: 2.0986 - accuracy: 0.3772 - val_loss: 1.5294 - val_accuracy: 0.4082
# 	--- Save best at ep 2, val_loss: 1.5294, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 3/100 - loss: 1.9628 - accuracy: 0.4231 - val_loss: 1.4145 - val_accuracy: 0.4525
# 	--- Save best at ep 3, val_loss: 1.4145, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 4/100 - loss: 1.8672 - accuracy: 0.4573 - val_loss: 1.3106 - val_accuracy: 0.4943
# 	--- Save best at ep 4, val_loss: 1.3106, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 5/100 - loss: 1.7996 - accuracy: 0.4801 - val_loss: 1.3009 - val_accuracy: 0.5099
# 	--- Save best at ep 5, val_loss: 1.3009, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 6/100 - loss: 1.7411 - accuracy: 0.4988 - val_loss: 1.2411 - val_accuracy: 0.5313
# 	--- Save best at ep 6, val_loss: 1.2411, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 7/100 - loss: 1.6932 - accuracy: 0.5104 - val_loss: 1.2017 - val_accuracy: 0.5439
# 	--- Save best at ep 7, val_loss: 1.2017, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 8/100 - loss: 1.6620 - accuracy: 0.5257 - val_loss: 1.1851 - val_accuracy: 0.5456
# 	--- Save best at ep 8, val_loss: 1.1851, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 9/100 - loss: 1.6313 - accuracy: 0.5313 - val_loss: 1.1811 - val_accuracy: 0.5520
# 	--- Save best at ep 9, val_loss: 1.1811, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 10/100 - loss: 1.6038 - accuracy: 0.5419 - val_loss: 1.1369 - val_accuracy: 0.5684
# 	--- Save best at ep 10, val_loss: 1.1369, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 11/100 - loss: 1.5804 - accuracy: 0.5543 - val_loss: 1.1339 - val_accuracy: 0.5645
# 	--- Save best at ep 11, val_loss: 1.1339, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 12/100 - loss: 1.5559 - accuracy: 0.5562 - val_loss: 1.1135 - val_accuracy: 0.5748
# 	--- Save best at ep 12, val_loss: 1.1135, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 13/100 - loss: 1.5423 - accuracy: 0.5590 - val_loss: 1.1019 - val_accuracy: 0.5812
# 	--- Save best at ep 13, val_loss: 1.1019, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 14/100 - loss: 1.5302 - accuracy: 0.5663 - val_loss: 1.0678 - val_accuracy: 0.5952
# 	--- Save best at ep 14, val_loss: 1.0678, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 15/100 - loss: 1.5095 - accuracy: 0.5674 - val_loss: 1.0768 - val_accuracy: 0.5918
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 1.4947 - accuracy: 0.5775 - val_loss: 1.0674 - val_accuracy: 0.5940
# 	--- Save best at ep 16, val_loss: 1.0674, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 17/100 - loss: 1.4832 - accuracy: 0.5807 - val_loss: 1.0536 - val_accuracy: 0.6007
# 	--- Save best at ep 17, val_loss: 1.0536, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 18/100 - loss: 1.4593 - accuracy: 0.5847 - val_loss: 1.0747 - val_accuracy: 0.6032
# 	-!- No improvement: 1/20
# Epoch 19/100 - loss: 1.4498 - accuracy: 0.5885 - val_loss: 1.0339 - val_accuracy: 0.6113
# 	--- Save best at ep 19, val_loss: 1.0339, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 20/100 - loss: 1.4457 - accuracy: 0.5954 - val_loss: 1.0404 - val_accuracy: 0.6127
# 	-!- No improvement: 1/20
# Epoch 21/100 - loss: 1.4298 - accuracy: 0.5948 - val_loss: 1.0453 - val_accuracy: 0.6102
# 	-!- No improvement: 2/20
# Epoch 22/100 - loss: 1.4153 - accuracy: 0.6006 - val_loss: 1.0111 - val_accuracy: 0.6247
# 	--- Save best at ep 22, val_loss: 1.0111, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 23/100 - loss: 1.4069 - accuracy: 0.6056 - val_loss: 1.0167 - val_accuracy: 0.6227
# 	-!- No improvement: 1/20
# Epoch 24/100 - loss: 1.3945 - accuracy: 0.6084 - val_loss: 1.0232 - val_accuracy: 0.6250
# 	-!- No improvement: 2/20
# Epoch 25/100 - loss: 1.3888 - accuracy: 0.6084 - val_loss: 0.9864 - val_accuracy: 0.6328
# 	--- Save best at ep 25, val_loss: 0.9864, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 26/100 - loss: 1.3751 - accuracy: 0.6130 - val_loss: 0.9990 - val_accuracy: 0.6286
# 	-!- No improvement: 1/20
# Epoch 27/100 - loss: 1.3722 - accuracy: 0.6137 - val_loss: 1.0038 - val_accuracy: 0.6269
# 	-!- No improvement: 2/20
# Epoch 28/100 - loss: 1.3596 - accuracy: 0.6174 - val_loss: 0.9868 - val_accuracy: 0.6291
# 	-!- No improvement: 3/20
# Epoch 29/100 - loss: 1.3524 - accuracy: 0.6201 - val_loss: 0.9856 - val_accuracy: 0.6367
# 	--- Save best at ep 29, val_loss: 0.9856, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 30/100 - loss: 1.3406 - accuracy: 0.6221 - val_loss: 0.9918 - val_accuracy: 0.6375
# 	-!- No improvement: 1/20
# Epoch 31/100 - loss: 1.3347 - accuracy: 0.6263 - val_loss: 0.9746 - val_accuracy: 0.6442
# 	--- Save best at ep 31, val_loss: 0.9746, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 32/100 - loss: 1.3203 - accuracy: 0.6302 - val_loss: 0.9646 - val_accuracy: 0.6397
# 	--- Save best at ep 32, val_loss: 0.9646, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 33/100 - loss: 1.3196 - accuracy: 0.6313 - val_loss: 0.9650 - val_accuracy: 0.6431
# 	-!- No improvement: 1/20
# Epoch 34/100 - loss: 1.3103 - accuracy: 0.6352 - val_loss: 0.9710 - val_accuracy: 0.6461
# 	-!- No improvement: 2/20
# Epoch 35/100 - loss: 1.3070 - accuracy: 0.6351 - val_loss: 0.9672 - val_accuracy: 0.6439
# 	-!- No improvement: 3/20
# Epoch 36/100 - loss: 1.2979 - accuracy: 0.6361 - val_loss: 0.9719 - val_accuracy: 0.6447
# 	-!- No improvement: 4/20
# Epoch 37/100 - loss: 1.2672 - accuracy: 0.6473 - val_loss: 0.9549 - val_accuracy: 0.6520
# 	--- Save best at ep 37, val_loss: 0.9549, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 38/100 - loss: 1.2517 - accuracy: 0.6537 - val_loss: 0.9396 - val_accuracy: 0.6578
# 	--- Save best at ep 38, val_loss: 0.9396, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 39/100 - loss: 1.2395 - accuracy: 0.6607 - val_loss: 0.9446 - val_accuracy: 0.6612
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 1.2301 - accuracy: 0.6597 - val_loss: 0.9425 - val_accuracy: 0.6570
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 1.2264 - accuracy: 0.6659 - val_loss: 0.9307 - val_accuracy: 0.6612
# 	--- Save best at ep 41, val_loss: 0.9307, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 42/100 - loss: 1.2282 - accuracy: 0.6599 - val_loss: 0.9295 - val_accuracy: 0.6606
# 	--- Save best at ep 42, val_loss: 0.9295, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 43/100 - loss: 1.2141 - accuracy: 0.6652 - val_loss: 0.9396 - val_accuracy: 0.6559
# 	-!- No improvement: 1/20
# Epoch 44/100 - loss: 1.2150 - accuracy: 0.6648 - val_loss: 0.9280 - val_accuracy: 0.6617
# 	--- Save best at ep 44, val_loss: 0.9280, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 45/100 - loss: 1.2045 - accuracy: 0.6704 - val_loss: 0.9289 - val_accuracy: 0.6606
# 	-!- No improvement: 1/20
# Epoch 46/100 - loss: 1.1966 - accuracy: 0.6726 - val_loss: 0.9290 - val_accuracy: 0.6673
# 	-!- No improvement: 2/20
# Epoch 47/100 - loss: 1.1979 - accuracy: 0.6710 - val_loss: 0.9235 - val_accuracy: 0.6679
# 	--- Save best at ep 47, val_loss: 0.9235, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 48/100 - loss: 1.1947 - accuracy: 0.6713 - val_loss: 0.9279 - val_accuracy: 0.6645
# 	-!- No improvement: 1/20
# Epoch 49/100 - loss: 1.1837 - accuracy: 0.6759 - val_loss: 0.9329 - val_accuracy: 0.6676
# 	-!- No improvement: 2/20
# Epoch 50/100 - loss: 1.1787 - accuracy: 0.6769 - val_loss: 0.9358 - val_accuracy: 0.6695
# 	-!- No improvement: 3/20
# Epoch 51/100 - loss: 1.1781 - accuracy: 0.6815 - val_loss: 0.9321 - val_accuracy: 0.6748
# 	-!- No improvement: 4/20
# Epoch 52/100 - loss: 1.1487 - accuracy: 0.6893 - val_loss: 0.9197 - val_accuracy: 0.6732
# 	--- Save best at ep 52, val_loss: 0.9197, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 53/100 - loss: 1.1383 - accuracy: 0.6915 - val_loss: 0.9262 - val_accuracy: 0.6723
# 	-!- No improvement: 1/20
# Epoch 54/100 - loss: 1.1426 - accuracy: 0.6908 - val_loss: 0.9185 - val_accuracy: 0.6760
# 	--- Save best at ep 54, val_loss: 0.9185, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 55/100 - loss: 1.1392 - accuracy: 0.6916 - val_loss: 0.9314 - val_accuracy: 0.6701
# 	-!- No improvement: 1/20
# Epoch 56/100 - loss: 1.1317 - accuracy: 0.6925 - val_loss: 0.9245 - val_accuracy: 0.6709
# 	-!- No improvement: 2/20
# Epoch 57/100 - loss: 1.1312 - accuracy: 0.6943 - val_loss: 0.9262 - val_accuracy: 0.6698
# 	-!- No improvement: 3/20
# Epoch 58/100 - loss: 1.1267 - accuracy: 0.6958 - val_loss: 0.9230 - val_accuracy: 0.6740
# 	-!- No improvement: 4/20
# Epoch 59/100 - loss: 1.1107 - accuracy: 0.7004 - val_loss: 0.9224 - val_accuracy: 0.6762
# 	-!- No improvement: 5/20
# Epoch 60/100 - loss: 1.1092 - accuracy: 0.7001 - val_loss: 0.9202 - val_accuracy: 0.6760
# 	-!- No improvement: 6/20
# Epoch 61/100 - loss: 1.1051 - accuracy: 0.7027 - val_loss: 0.9232 - val_accuracy: 0.6746
# 	-!- No improvement: 7/20
# Epoch 62/100 - loss: 1.1043 - accuracy: 0.7045 - val_loss: 0.9174 - val_accuracy: 0.6782
# 	--- Save best at ep 62, val_loss: 0.9174, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth ---
# Epoch 63/100 - loss: 1.1020 - accuracy: 0.7060 - val_loss: 0.9275 - val_accuracy: 0.6723
# 	-!- No improvement: 1/20
# Epoch 64/100 - loss: 1.0978 - accuracy: 0.7064 - val_loss: 0.9277 - val_accuracy: 0.6690
# 	-!- No improvement: 2/20
# Epoch 65/100 - loss: 1.0943 - accuracy: 0.7078 - val_loss: 0.9248 - val_accuracy: 0.6715
# 	-!- No improvement: 3/20
# Epoch 66/100 - loss: 1.0933 - accuracy: 0.7072 - val_loss: 0.9292 - val_accuracy: 0.6737
# 	-!- No improvement: 4/20
# Epoch 67/100 - loss: 1.0883 - accuracy: 0.7100 - val_loss: 0.9268 - val_accuracy: 0.6743
# 	-!- No improvement: 5/20
# Epoch 68/100 - loss: 1.0830 - accuracy: 0.7118 - val_loss: 0.9255 - val_accuracy: 0.6748
# 	-!- No improvement: 6/20
# Epoch 69/100 - loss: 1.0843 - accuracy: 0.7123 - val_loss: 0.9226 - val_accuracy: 0.6751
# 	-!- No improvement: 7/20
# Epoch 70/100 - loss: 1.0815 - accuracy: 0.7121 - val_loss: 0.9190 - val_accuracy: 0.6782
# 	-!- No improvement: 8/20
# Epoch 71/100 - loss: 1.0786 - accuracy: 0.7109 - val_loss: 0.9257 - val_accuracy: 0.6779
# 	-!- No improvement: 9/20
# Epoch 72/100 - loss: 1.0807 - accuracy: 0.7109 - val_loss: 0.9194 - val_accuracy: 0.6751
# 	-!- No improvement: 10/20
# Epoch 73/100 - loss: 1.0753 - accuracy: 0.7115 - val_loss: 0.9245 - val_accuracy: 0.6765
# 	-!- No improvement: 11/20
# Epoch 74/100 - loss: 1.0794 - accuracy: 0.7090 - val_loss: 0.9278 - val_accuracy: 0.6765
# 	-!- No improvement: 12/20
# Epoch 75/100 - loss: 1.0743 - accuracy: 0.7130 - val_loss: 0.9229 - val_accuracy: 0.6757
# 	-!- No improvement: 13/20
# Epoch 76/100 - loss: 1.0736 - accuracy: 0.7142 - val_loss: 0.9251 - val_accuracy: 0.6760
# 	-!- No improvement: 14/20
# Epoch 77/100 - loss: 1.0728 - accuracy: 0.7170 - val_loss: 0.9271 - val_accuracy: 0.6760
# 	-!- No improvement: 15/20
# Epoch 78/100 - loss: 1.0725 - accuracy: 0.7127 - val_loss: 0.9256 - val_accuracy: 0.6765
# 	-!- No improvement: 16/20
# Epoch 79/100 - loss: 1.0759 - accuracy: 0.7117 - val_loss: 0.9273 - val_accuracy: 0.6760
# 	-!- No improvement: 17/20
# Epoch 80/100 - loss: 1.0733 - accuracy: 0.7144 - val_loss: 0.9214 - val_accuracy: 0.6771
# 	-!- No improvement: 18/20
# Epoch 81/100 - loss: 1.0768 - accuracy: 0.7138 - val_loss: 0.9254 - val_accuracy: 0.6754
# 	-!- No improvement: 19/20
# Epoch 82/100 - loss: 1.0799 - accuracy: 0.7117 - val_loss: 0.9274 - val_accuracy: 0.6762
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=82
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1717_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 42.12it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.93%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.645652  0.604888  0.624606   491.000000
# disgust        0.780488  0.581818  0.666667    55.000000
# fear           0.590296  0.414773  0.487208   528.000000
# happy          0.904268  0.891923  0.898053   879.000000
# sad            0.523659  0.558923  0.540717   594.000000
# surprise       0.789346  0.783654  0.786490   416.000000
# neutral        0.602740  0.773163  0.677397   626.000000
# accuracy       0.689329  0.689329  0.689329     0.689329
# macro avg      0.690921  0.658449  0.668734  3589.000000
# weighted avg   0.691894  0.689329  0.686096  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_spatial_10042026_1717_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_5y38ocms (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_5y38ocms (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_5y38ocms (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_5y38ocms (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_5y38ocms (0.5s)
# wandb: ⣯ uploading artifact cnn_5y38ocms (0.5s)
# wandb: ⣟ uploading artifact cnn_5y38ocms (0.5s)
# wandb: ⡿ uploading artifact cnn_5y38ocms (0.5s)
# wandb: ⢿ uploading artifact cnn_5y38ocms (0.5s)
# wandb: ⣻ uploading artifact cnn_5y38ocms (1.0s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1717_best.pth 53.0MB/242.8MB (0.5s)
# wandb: ⣽ uploading artifact cnn_5y38ocms (1.0s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1717_best.pth 53.0MB/242.8MB (0.5s)
# wandb: ⣾ uploading artifact cnn_5y38ocms (1.0s)
# wandb:   ↳ ⣾ vgg_spatial_10042026_1717_best.pth 53.0MB/242.8MB (0.5s)
# wandb: ⣷ uploading artifact cnn_5y38ocms (1.0s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1717_best.pth 53.0MB/242.8MB (0.5s)
# wandb: ⣯ uploading artifact cnn_5y38ocms (1.0s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1717_best.pth 53.0MB/242.8MB (0.5s)
# wandb: ⣟ uploading artifact cnn_5y38ocms (1.5s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1717_best.pth 106.8MB/242.8MB (1.0s)
# wandb: ⡿ uploading artifact cnn_5y38ocms (1.5s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1717_best.pth 106.8MB/242.8MB (1.0s)
# wandb: ⢿ uploading artifact cnn_5y38ocms (1.5s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1717_best.pth 106.8MB/242.8MB (1.0s)
# wandb: ⣻ uploading artifact cnn_5y38ocms (1.5s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1717_best.pth 106.8MB/242.8MB (1.0s)
# wandb: ⣽ uploading artifact cnn_5y38ocms (1.5s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1717_best.pth 106.8MB/242.8MB (1.0s)
# wandb: ⣾ uploading artifact cnn_5y38ocms (2.0s)
# wandb:   ↳ ⣾ vgg_spatial_10042026_1717_best.pth 156.9MB/242.8MB (1.5s)
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_82_8e99f67d9fecb0c...
# wandb: ⣾ uploading media/images/Evaluation/Wrong_Samples_83_7eb982eb17ca3b74b...
# wandb: ⣾ uploading output.log 15.4KB/15.4KB (0.1s)
# wandb: + 3 more task(s)
# wandb: ⣷ uploading artifact cnn_5y38ocms (2.0s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1717_best.pth 156.9MB/242.8MB (1.5s)
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_82_8e99f67d9fecb0c...
# wandb: ⣷ uploading media/images/Evaluation/Wrong_Samples_83_7eb982eb17ca3b74b...
# wandb: ⣷ uploading output.log 15.4KB/15.4KB (0.1s)
# wandb: + 3 more task(s)
# wandb: ⣯ uploading artifact cnn_5y38ocms (2.0s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1717_best.pth 156.9MB/242.8MB (1.5s)
# wandb: ⣯ uploading media/images/Evaluation/Correct_Samples_82_8e99f67d9fecb0c...
# wandb: ⣯ uploading media/images/Evaluation/Wrong_Samples_83_7eb982eb17ca3b74b...
# wandb: ⣯ uploading output.log 15.4KB/15.4KB (0.1s)
# wandb: + 3 more task(s)
# wandb: ⣟ uploading artifact cnn_5y38ocms (2.0s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1717_best.pth 156.9MB/242.8MB (1.5s)
# wandb: ⣟ uploading media/images/Evaluation/Correct_Samples_82_8e99f67d9fecb0c...
# wandb: ⣟ uploading media/images/Evaluation/Wrong_Samples_83_7eb982eb17ca3b74b...
# wandb: ⣟ uploading output.log 15.4KB/15.4KB (0.1s)
# wandb: + 3 more task(s)
# wandb: ⡿ uploading artifact cnn_5y38ocms (2.0s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1717_best.pth 156.9MB/242.8MB (1.5s)
# wandb: ⡿ uploading media/images/Evaluation/Correct_Samples_82_8e99f67d9fecb0c...
# wandb: ⡿ uploading media/images/Evaluation/Wrong_Samples_83_7eb982eb17ca3b74b...
# wandb: ⡿ uploading output.log 15.4KB/15.4KB (0.1s)
# wandb: + 3 more task(s)
# wandb: ⢿ uploading artifact cnn_5y38ocms (2.5s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1717_best.pth 205.1MB/242.8MB (2.0s)
# wandb: ⣻ uploading artifact cnn_5y38ocms (2.5s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1717_best.pth 205.1MB/242.8MB (2.0s)
# wandb: ⣽ uploading artifact cnn_5y38ocms (2.5s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1717_best.pth 205.1MB/242.8MB (2.0s)
# wandb: ⣾ uploading artifact cnn_5y38ocms (2.5s)
# wandb:   ↳ ⣾ vgg_spatial_10042026_1717_best.pth 205.1MB/242.8MB (2.0s)
# wandb: ⣷ uploading artifact cnn_5y38ocms (2.5s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1717_best.pth 205.1MB/242.8MB (2.0s)
# wandb: ⣯ uploading artifact cnn_5y38ocms (3.0s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1717_best.pth 242.8MB/242.8MB (2.5s)
# wandb: ⣟ uploading artifact cnn_5y38ocms (3.0s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1717_best.pth 242.8MB/242.8MB (2.5s)
# wandb: ⡿ uploading artifact cnn_5y38ocms (3.0s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1717_best.pth 242.8MB/242.8MB (2.5s)
# wandb: ⢿ uploading artifact cnn_5y38ocms (3.0s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1717_best.pth 242.8MB/242.8MB (2.5s)
# wandb: ⣻ uploading artifact cnn_5y38ocms (3.0s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1717_best.pth 242.8MB/242.8MB (2.5s)
# wandb: ⣽ uploading artifact cnn_5y38ocms (3.5s)
# wandb: ⣽ uploading history steps 80-83, summary, console lines 165-196 (0.0s)
# wandb: ⣾ uploading artifact cnn_5y38ocms (3.5s)
# wandb: ⣾ uploading history steps 80-83, summary, console lines 165-196 (0.0s)
# wandb: ⣷ uploading artifact cnn_5y38ocms (3.5s)
# wandb: ⣷ uploading history steps 80-83, summary, console lines 165-196 (0.0s)
# wandb: ⣯ uploading artifact cnn_5y38ocms (3.5s)
# wandb: ⣯ uploading history steps 80-83, summary, console lines 165-196 (0.0s)
# wandb: ⣟ uploading artifact cnn_5y38ocms (3.5s)
# wandb: ⣟ uploading history steps 80-83, summary, console lines 165-196 (0.0s)
# wandb: ⡿ uploading history steps 80-83, summary, console lines 165-196 (0.5s)
# wandb: ⢿ uploading history steps 80-83, summary, console lines 165-196 (0.5s)
# wandb: ⣻ uploading history steps 80-83, summary, console lines 165-196 (0.5s)
# wandb: ⣽ uploading history steps 80-83, summary, console lines 165-196 (0.5s)
# wandb: ⣾ uploading history steps 80-83, summary, console lines 165-196 (0.5s)
# wandb: ⣷ uploading history steps 80-83, summary, console lines 165-196 (1.0s)
# wandb: ⣯ uploading history steps 80-83, summary, console lines 165-196 (1.0s)
# wandb: ⣟ uploading history steps 80-83, summary, console lines 165-196 (1.0s)
# wandb: ⡿ uploading history steps 80-83, summary, console lines 165-196 (1.0s)
# wandb: ⢿ uploading history steps 80-83, summary, console lines 165-196 (1.0s)
# wandb: ⣻ uploading history steps 80-83, summary, console lines 165-196 (1.5s)
# wandb: ⣽ uploading history steps 80-83, summary, console lines 165-196 (1.5s)
# wandb: ⣾ uploading history steps 80-83, summary, console lines 165-196 (1.5s)
# wandb: ⣷ uploading history steps 80-83, summary, console lines 165-196 (1.5s)
# wandb: ⣯ uploading history steps 80-83, summary, console lines 165-196 (1.5s)
# wandb: ⣟ uploading history steps 80-83, summary, console lines 165-196 (2.0s)
# wandb: ⡿ uploading history steps 80-83, summary, console lines 165-196 (2.0s)
# wandb: ⢿ uploading history steps 80-83, summary, console lines 165-196 (2.0s)
# wandb: ⣻ uploading history steps 80-83, summary, console lines 165-196 (2.0s)
# wandb: ⣽ uploading history steps 80-83, summary, console lines 165-196 (2.0s)
# wandb: ⣾ uploading history steps 80-83, summary, console lines 165-196 (2.5s)
# wandb: ⣷ uploading history steps 80-83, summary, console lines 165-196 (2.5s)
# wandb: ⣯ uploading history steps 80-83, summary, console lines 165-196 (2.5s)
# wandb: ⣟ uploading history steps 80-83, summary, console lines 165-196 (2.5s)
# wandb: ⡿ uploading history steps 80-83, summary, console lines 165-196 (2.5s)
# wandb: ⢿ uploading history steps 80-83, summary, console lines 165-196 (3.0s)
# wandb: ⣻ uploading history steps 80-83, summary, console lines 165-196 (3.0s)
# wandb: ⣽ uploading history steps 80-83, summary, console lines 165-196 (3.0s)
# wandb: ⣾ uploading history steps 80-83, summary, console lines 165-196 (3.0s)
# wandb: ⣷ uploading history steps 80-83, summary, console lines 165-196 (3.0s)
# wandb: ⣯ uploading history steps 80-83, summary, console lines 165-196 (3.5s)
# wandb: ⣟ uploading history steps 80-83, summary, console lines 165-196 (3.5s)
# wandb: ⡿ uploading history steps 80-83, summary, console lines 165-196 (3.5s)
# wandb: ⢿ uploading history steps 80-83, summary, console lines 165-196 (3.5s)
# wandb: ⣻ uploading history steps 80-83, summary, console lines 165-196 (3.5s)
# wandb: ⣽ uploading data (0.3s)
# wandb: ⣾ uploading data (0.3s)
# wandb: ⣷ uploading data (0.3s)
# wandb: ⣯ uploading data (0.3s)
# wandb: ⣟ uploading data (0.3s)
# wandb: ⡿ uploading data (0.8s)
# wandb: ⢿ uploading data (0.8s)
# wandb: ⣻ uploading data (0.8s)
# wandb: ⣽ uploading data (0.8s)
# wandb: ⣾ uploading data (0.8s)
# wandb: ⣷ uploading data (1.3s)
# wandb: ⣯ uploading data (1.3s)
# wandb: ⣟ uploading data (1.3s)
# wandb: ⡿ uploading data (1.3s)
# wandb: ⢿ uploading data (1.3s)
# wandb: ⣻ uploading data (1.8s)
# wandb: ⣽ uploading data (1.8s)
# wandb: ⣾ uploading data (1.8s)
# wandb: ⣷ uploading data (1.8s)
# wandb: ⣯ uploading data (1.8s)
# wandb: ⣟ uploading data (2.3s)
# wandb: ⡿ uploading data (2.3s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██
# wandb:  Learning_Rate ██████████████████▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▄▄▄▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████████████████
# wandb:     Train/Loss █▇▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▂▃▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████████████
# wandb:       Val/Loss █▅▅▅▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 82
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.71166
# wandb:     Train/Loss 1.07986
# wandb:   Val/Accuracy 0.67623
# wandb:       Val/Loss 0.92737
# wandb:
# wandb: 🚀 View run vgg_spatial_10042026_1717 at: https://wandb.ai/phucga15062005/FER2013/runs/5y38ocms
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_171734-5y38ocms/logs
#
# 		DONE!
