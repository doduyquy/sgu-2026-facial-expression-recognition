# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 4

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1785, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 1785 (delta 114), reused 99 (delta 93), pack-reused 1632 (from 1)
# Receiving objects: 100% (1785/1785), 6.19 MiB | 34.65 MiB/s, done.
# Resolving deltas: 100% (1270/1270), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config resnet35 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=5)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run rj0wpgqn (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260415_021828-rj0wpgqn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_15042026_0218
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/rj0wpgqn
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.1259 - accuracy: 0.0574 - val_loss: 2.0569 - val_accuracy: 0.1315
# 	--- Save best at ep 1, val_loss: 2.0569, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 2/100 - loss: 2.0136 - accuracy: 0.1636 - val_loss: 1.9230 - val_accuracy: 0.1984
# 	--- Save best at ep 2, val_loss: 1.9230, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 3/100 - loss: 1.9494 - accuracy: 0.2402 - val_loss: 1.8500 - val_accuracy: 0.3801
# 	--- Save best at ep 3, val_loss: 1.8500, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 4/100 - loss: 1.9098 - accuracy: 0.2948 - val_loss: 1.9957 - val_accuracy: 0.3614
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.8671 - accuracy: 0.3400 - val_loss: 1.7794 - val_accuracy: 0.3179
# 	--- Save best at ep 5, val_loss: 1.7794, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 6/100 - loss: 1.8394 - accuracy: 0.3782 - val_loss: 1.7284 - val_accuracy: 0.4330
# 	--- Save best at ep 6, val_loss: 1.7284, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 7/100 - loss: 1.8037 - accuracy: 0.4046 - val_loss: 1.7273 - val_accuracy: 0.4706
# 	--- Save best at ep 7, val_loss: 1.7273, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 8/100 - loss: 1.7937 - accuracy: 0.4143 - val_loss: 1.7625 - val_accuracy: 0.4611
# 	-!- No improvement: 1/20
# Epoch 9/100 - loss: 1.7797 - accuracy: 0.4343 - val_loss: 1.7029 - val_accuracy: 0.4745
# 	--- Save best at ep 9, val_loss: 1.7029, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 10/100 - loss: 1.7571 - accuracy: 0.4411 - val_loss: 1.6785 - val_accuracy: 0.4653
# 	--- Save best at ep 10, val_loss: 1.6785, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 11/100 - loss: 1.7507 - accuracy: 0.4488 - val_loss: 1.6958 - val_accuracy: 0.4528
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 1.7381 - accuracy: 0.4567 - val_loss: 1.6800 - val_accuracy: 0.5183
# 	-!- No improvement: 2/20
# Epoch 13/100 - loss: 1.7245 - accuracy: 0.4752 - val_loss: 1.6376 - val_accuracy: 0.4837
# 	--- Save best at ep 13, val_loss: 1.6376, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 14/100 - loss: 1.7157 - accuracy: 0.4802 - val_loss: 1.6576 - val_accuracy: 0.5177
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 1.7087 - accuracy: 0.4840 - val_loss: 1.6474 - val_accuracy: 0.5291
# 	-!- No improvement: 2/20
# Epoch 16/100 - loss: 1.6970 - accuracy: 0.4909 - val_loss: 1.6209 - val_accuracy: 0.5110
# 	--- Save best at ep 16, val_loss: 1.6209, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 17/100 - loss: 1.6845 - accuracy: 0.5050 - val_loss: 1.6435 - val_accuracy: 0.5386
# 	-!- No improvement: 1/20
# Epoch 18/100 - loss: 1.6819 - accuracy: 0.5077 - val_loss: 1.5952 - val_accuracy: 0.5425
# 	--- Save best at ep 18, val_loss: 1.5952, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 19/100 - loss: 1.6756 - accuracy: 0.5112 - val_loss: 1.5925 - val_accuracy: 0.5720
# 	--- Save best at ep 19, val_loss: 1.5925, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 20/100 - loss: 1.6534 - accuracy: 0.5198 - val_loss: 1.6096 - val_accuracy: 0.5489
# 	-!- No improvement: 1/20
# Epoch 21/100 - loss: 1.6453 - accuracy: 0.5280 - val_loss: 1.5691 - val_accuracy: 0.5637
# 	--- Save best at ep 21, val_loss: 1.5691, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 22/100 - loss: 1.6463 - accuracy: 0.5292 - val_loss: 1.5957 - val_accuracy: 0.5561
# 	-!- No improvement: 1/20
# Epoch 23/100 - loss: 1.6356 - accuracy: 0.5371 - val_loss: 1.5734 - val_accuracy: 0.5453
# 	-!- No improvement: 2/20
# Epoch 24/100 - loss: 1.6294 - accuracy: 0.5384 - val_loss: 1.5564 - val_accuracy: 0.5840
# 	--- Save best at ep 24, val_loss: 1.5564, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 25/100 - loss: 1.6238 - accuracy: 0.5457 - val_loss: 1.5997 - val_accuracy: 0.5684
# 	-!- No improvement: 1/20
# Epoch 26/100 - loss: 1.6154 - accuracy: 0.5484 - val_loss: 1.5756 - val_accuracy: 0.5503
# 	-!- No improvement: 2/20
# Epoch 27/100 - loss: 1.6187 - accuracy: 0.5489 - val_loss: 1.5462 - val_accuracy: 0.6004
# 	--- Save best at ep 27, val_loss: 1.5462, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 28/100 - loss: 1.6044 - accuracy: 0.5527 - val_loss: 1.5636 - val_accuracy: 0.5690
# 	-!- No improvement: 1/20
# Epoch 29/100 - loss: 1.6023 - accuracy: 0.5587 - val_loss: 1.5653 - val_accuracy: 0.5754
# 	-!- No improvement: 2/20
# Epoch 30/100 - loss: 1.5876 - accuracy: 0.5665 - val_loss: 1.5500 - val_accuracy: 0.5798
# 	-!- No improvement: 3/20
# Epoch 31/100 - loss: 1.5837 - accuracy: 0.5723 - val_loss: 1.5621 - val_accuracy: 0.5715
# 	-!- No improvement: 4/20
# Epoch 32/100 - loss: 1.5811 - accuracy: 0.5706 - val_loss: 1.5329 - val_accuracy: 0.5974
# 	--- Save best at ep 32, val_loss: 1.5329, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 33/100 - loss: 1.5776 - accuracy: 0.5742 - val_loss: 1.5247 - val_accuracy: 0.6043
# 	--- Save best at ep 33, val_loss: 1.5247, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 34/100 - loss: 1.5725 - accuracy: 0.5773 - val_loss: 1.5385 - val_accuracy: 0.5882
# 	-!- No improvement: 1/20
# Epoch 35/100 - loss: 1.5668 - accuracy: 0.5757 - val_loss: 1.5409 - val_accuracy: 0.5979
# 	-!- No improvement: 2/20
# Epoch 36/100 - loss: 1.5634 - accuracy: 0.5787 - val_loss: 1.5372 - val_accuracy: 0.5865
# 	-!- No improvement: 3/20
# Epoch 37/100 - loss: 1.5608 - accuracy: 0.5812 - val_loss: 1.5212 - val_accuracy: 0.6043
# 	--- Save best at ep 37, val_loss: 1.5212, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 38/100 - loss: 1.5570 - accuracy: 0.5855 - val_loss: 1.5171 - val_accuracy: 0.5907
# 	--- Save best at ep 38, val_loss: 1.5171, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 39/100 - loss: 1.5458 - accuracy: 0.5916 - val_loss: 1.4976 - val_accuracy: 0.6199
# 	--- Save best at ep 39, val_loss: 1.4976, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 40/100 - loss: 1.5436 - accuracy: 0.5926 - val_loss: 1.5088 - val_accuracy: 0.5974
# 	-!- No improvement: 1/20
# Epoch 41/100 - loss: 1.5360 - accuracy: 0.5935 - val_loss: 1.5107 - val_accuracy: 0.5929
# 	-!- No improvement: 2/20
# Epoch 42/100 - loss: 1.5362 - accuracy: 0.5985 - val_loss: 1.4989 - val_accuracy: 0.6239
# 	-!- No improvement: 3/20
# Epoch 43/100 - loss: 1.5307 - accuracy: 0.5970 - val_loss: 1.4907 - val_accuracy: 0.6183
# 	--- Save best at ep 43, val_loss: 1.4907, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 44/100 - loss: 1.5243 - accuracy: 0.6032 - val_loss: 1.4946 - val_accuracy: 0.6197
# 	-!- No improvement: 1/20
# Epoch 45/100 - loss: 1.5215 - accuracy: 0.6056 - val_loss: 1.4876 - val_accuracy: 0.6183
# 	--- Save best at ep 45, val_loss: 1.4876, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 46/100 - loss: 1.5153 - accuracy: 0.6089 - val_loss: 1.4942 - val_accuracy: 0.6010
# 	-!- No improvement: 1/20
# Epoch 47/100 - loss: 1.5148 - accuracy: 0.6064 - val_loss: 1.5071 - val_accuracy: 0.6252
# 	-!- No improvement: 2/20
# Epoch 48/100 - loss: 1.5112 - accuracy: 0.6079 - val_loss: 1.4705 - val_accuracy: 0.6169
# 	--- Save best at ep 48, val_loss: 1.4705, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 49/100 - loss: 1.5069 - accuracy: 0.6119 - val_loss: 1.4943 - val_accuracy: 0.6030
# 	-!- No improvement: 1/20
# Epoch 50/100 - loss: 1.5053 - accuracy: 0.6129 - val_loss: 1.4582 - val_accuracy: 0.6408
# 	--- Save best at ep 50, val_loss: 1.4582, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 51/100 - loss: 1.4920 - accuracy: 0.6156 - val_loss: 1.4894 - val_accuracy: 0.6392
# 	-!- No improvement: 1/20
# Epoch 52/100 - loss: 1.4966 - accuracy: 0.6156 - val_loss: 1.4783 - val_accuracy: 0.6278
# 	-!- No improvement: 2/20
# Epoch 53/100 - loss: 1.5001 - accuracy: 0.6143 - val_loss: 1.4811 - val_accuracy: 0.6372
# 	-!- No improvement: 3/20
# Epoch 54/100 - loss: 1.4905 - accuracy: 0.6210 - val_loss: 1.4827 - val_accuracy: 0.6264
# 	-!- No improvement: 4/20
# Epoch 55/100 - loss: 1.4819 - accuracy: 0.6214 - val_loss: 1.5447 - val_accuracy: 0.6074
# 	-!- No improvement: 5/20
# Epoch 56/100 - loss: 1.4866 - accuracy: 0.6231 - val_loss: 1.4935 - val_accuracy: 0.6294
# 	-!- No improvement: 6/20
# Epoch 57/100 - loss: 1.4481 - accuracy: 0.6399 - val_loss: 1.4598 - val_accuracy: 0.6592
# 	-!- No improvement: 7/20
# Epoch 58/100 - loss: 1.4407 - accuracy: 0.6435 - val_loss: 1.4594 - val_accuracy: 0.6428
# 	-!- No improvement: 8/20
# Epoch 59/100 - loss: 1.4266 - accuracy: 0.6524 - val_loss: 1.4375 - val_accuracy: 0.6442
# 	--- Save best at ep 59, val_loss: 1.4375, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 60/100 - loss: 1.4282 - accuracy: 0.6487 - val_loss: 1.4470 - val_accuracy: 0.6484
# 	-!- No improvement: 1/20
# Epoch 61/100 - loss: 1.4237 - accuracy: 0.6517 - val_loss: 1.4489 - val_accuracy: 0.6408
# 	-!- No improvement: 2/20
# Epoch 62/100 - loss: 1.4229 - accuracy: 0.6556 - val_loss: 1.4426 - val_accuracy: 0.6478
# 	-!- No improvement: 3/20
# Epoch 63/100 - loss: 1.4136 - accuracy: 0.6586 - val_loss: 1.4544 - val_accuracy: 0.6528
# 	-!- No improvement: 4/20
# Epoch 64/100 - loss: 1.4137 - accuracy: 0.6576 - val_loss: 1.4420 - val_accuracy: 0.6565
# 	-!- No improvement: 5/20
# Epoch 65/100 - loss: 1.4101 - accuracy: 0.6593 - val_loss: 1.4453 - val_accuracy: 0.6601
# 	-!- No improvement: 6/20
# Epoch 66/100 - loss: 1.3868 - accuracy: 0.6686 - val_loss: 1.4307 - val_accuracy: 0.6670
# 	--- Save best at ep 66, val_loss: 1.4307, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 67/100 - loss: 1.3850 - accuracy: 0.6753 - val_loss: 1.4298 - val_accuracy: 0.6609
# 	--- Save best at ep 67, val_loss: 1.4298, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 68/100 - loss: 1.3810 - accuracy: 0.6764 - val_loss: 1.4261 - val_accuracy: 0.6615
# 	--- Save best at ep 68, val_loss: 1.4261, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 69/100 - loss: 1.3753 - accuracy: 0.6789 - val_loss: 1.4276 - val_accuracy: 0.6665
# 	-!- No improvement: 1/20
# Epoch 70/100 - loss: 1.3740 - accuracy: 0.6759 - val_loss: 1.4215 - val_accuracy: 0.6612
# 	--- Save best at ep 70, val_loss: 1.4215, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 71/100 - loss: 1.3750 - accuracy: 0.6771 - val_loss: 1.4178 - val_accuracy: 0.6604
# 	--- Save best at ep 71, val_loss: 1.4178, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 72/100 - loss: 1.3681 - accuracy: 0.6825 - val_loss: 1.4255 - val_accuracy: 0.6679
# 	-!- No improvement: 1/20
# Epoch 73/100 - loss: 1.3632 - accuracy: 0.6843 - val_loss: 1.4243 - val_accuracy: 0.6631
# 	-!- No improvement: 2/20
# Epoch 74/100 - loss: 1.3630 - accuracy: 0.6860 - val_loss: 1.4227 - val_accuracy: 0.6665
# 	-!- No improvement: 3/20
# Epoch 75/100 - loss: 1.3623 - accuracy: 0.6865 - val_loss: 1.4227 - val_accuracy: 0.6687
# 	-!- No improvement: 4/20
# Epoch 76/100 - loss: 1.3588 - accuracy: 0.6885 - val_loss: 1.4281 - val_accuracy: 0.6643
# 	-!- No improvement: 5/20
# Epoch 77/100 - loss: 1.3531 - accuracy: 0.6913 - val_loss: 1.4149 - val_accuracy: 0.6670
# 	--- Save best at ep 77, val_loss: 1.4149, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 78/100 - loss: 1.3560 - accuracy: 0.6875 - val_loss: 1.4240 - val_accuracy: 0.6620
# 	-!- No improvement: 1/20
# Epoch 79/100 - loss: 1.3534 - accuracy: 0.6904 - val_loss: 1.4259 - val_accuracy: 0.6684
# 	-!- No improvement: 2/20
# Epoch 80/100 - loss: 1.3433 - accuracy: 0.6939 - val_loss: 1.4241 - val_accuracy: 0.6665
# 	-!- No improvement: 3/20
# Epoch 81/100 - loss: 1.3490 - accuracy: 0.6930 - val_loss: 1.4346 - val_accuracy: 0.6617
# 	-!- No improvement: 4/20
# Epoch 82/100 - loss: 1.3480 - accuracy: 0.6924 - val_loss: 1.4137 - val_accuracy: 0.6743
# 	--- Save best at ep 82, val_loss: 1.4137, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 83/100 - loss: 1.3438 - accuracy: 0.6934 - val_loss: 1.4245 - val_accuracy: 0.6665
# 	-!- No improvement: 1/20
# Epoch 84/100 - loss: 1.3371 - accuracy: 0.6982 - val_loss: 1.4361 - val_accuracy: 0.6656
# 	-!- No improvement: 2/20
# Epoch 85/100 - loss: 1.3403 - accuracy: 0.6977 - val_loss: 1.4271 - val_accuracy: 0.6707
# 	-!- No improvement: 3/20
# Epoch 86/100 - loss: 1.3382 - accuracy: 0.6990 - val_loss: 1.4245 - val_accuracy: 0.6707
# 	-!- No improvement: 4/20
# Epoch 87/100 - loss: 1.3377 - accuracy: 0.6991 - val_loss: 1.4204 - val_accuracy: 0.6648
# 	-!- No improvement: 5/20
# Epoch 88/100 - loss: 1.3386 - accuracy: 0.6990 - val_loss: 1.4113 - val_accuracy: 0.6665
# 	--- Save best at ep 88, val_loss: 1.4113, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth ---
# Epoch 89/100 - loss: 1.3329 - accuracy: 0.7041 - val_loss: 1.4374 - val_accuracy: 0.6567
# 	-!- No improvement: 1/20
# Epoch 90/100 - loss: 1.3390 - accuracy: 0.6984 - val_loss: 1.4268 - val_accuracy: 0.6626
# 	-!- No improvement: 2/20
# Epoch 91/100 - loss: 1.3310 - accuracy: 0.7039 - val_loss: 1.4259 - val_accuracy: 0.6670
# 	-!- No improvement: 3/20
# Epoch 92/100 - loss: 1.3260 - accuracy: 0.7021 - val_loss: 1.4207 - val_accuracy: 0.6718
# 	-!- No improvement: 4/20
# Epoch 93/100 - loss: 1.3348 - accuracy: 0.7018 - val_loss: 1.4401 - val_accuracy: 0.6701
# 	-!- No improvement: 5/20
# Epoch 94/100 - loss: 1.3205 - accuracy: 0.7072 - val_loss: 1.4326 - val_accuracy: 0.6690
# 	-!- No improvement: 6/20
# Epoch 95/100 - loss: 1.3164 - accuracy: 0.7118 - val_loss: 1.4176 - val_accuracy: 0.6721
# 	-!- No improvement: 7/20
# Epoch 96/100 - loss: 1.3068 - accuracy: 0.7163 - val_loss: 1.4220 - val_accuracy: 0.6684
# 	-!- No improvement: 8/20
# Epoch 97/100 - loss: 1.3024 - accuracy: 0.7151 - val_loss: 1.4190 - val_accuracy: 0.6718
# 	-!- No improvement: 9/20
# Epoch 98/100 - loss: 1.3018 - accuracy: 0.7176 - val_loss: 1.4330 - val_accuracy: 0.6707
# 	-!- No improvement: 10/20
# Epoch 99/100 - loss: 1.3067 - accuracy: 0.7182 - val_loss: 1.4220 - val_accuracy: 0.6721
# 	-!- No improvement: 11/20
# Epoch 100/100 - loss: 1.2952 - accuracy: 0.7160 - val_loss: 1.4278 - val_accuracy: 0.6704
# 	-!- No improvement: 12/20
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_15042026_0218_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:02<00:00, 22.53it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.57%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.584158  0.600815  0.592369   491.000000
# disgust        0.483146  0.781818  0.597222    55.000000
# fear           0.561538  0.414773  0.477124   528.000000
# happy          0.895487  0.857793  0.876235   879.000000
# sad            0.539405  0.518519  0.528755   594.000000
# surprise       0.751634  0.829327  0.788571   416.000000
# neutral        0.628922  0.736422  0.678440   626.000000
# accuracy       0.675676  0.675676  0.675676     0.675676
# macro avg      0.634899  0.677067  0.648388  3589.000000
# weighted avg   0.675345  0.675676  0.672238  3589.000000
# --> Grad-CAM Heatmap Active: Layer-4 Hooked!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.37585422..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5019685..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5691964..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5141129..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41764706..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4958506..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49015746..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9042553..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.46626982..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0282258..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5161943..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.576923..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5344036..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8068181..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50888884..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5666666..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1829268..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.43318963..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_15042026_0218_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_rj0wpgqn (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_rj0wpgqn (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_rj0wpgqn (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_rj0wpgqn (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_rj0wpgqn (0.5s)
# wandb: ⣯ uploading artifact cnn_rj0wpgqn (0.5s)
# wandb: ⣟ uploading artifact cnn_rj0wpgqn (0.5s)
# wandb: ⡿ uploading artifact cnn_rj0wpgqn (0.5s)
# wandb: ⢿ uploading artifact cnn_rj0wpgqn (0.5s)
# wandb: ⣻ uploading artifact cnn_rj0wpgqn (1.0s)
# wandb:   ↳ ⣻ resnet35_15042026_0218_best.pth 1.5MB/83.1MB (0.1s)
# wandb: ⣽ uploading artifact cnn_rj0wpgqn (1.0s)
# wandb:   ↳ ⣽ resnet35_15042026_0218_best.pth 1.5MB/83.1MB (0.1s)
# wandb: ⣾ uploading artifact cnn_rj0wpgqn (1.0s)
# wandb:   ↳ ⣾ resnet35_15042026_0218_best.pth 1.5MB/83.1MB (0.1s)
# wandb: ⣷ uploading artifact cnn_rj0wpgqn (1.0s)
# wandb:   ↳ ⣷ resnet35_15042026_0218_best.pth 1.5MB/83.1MB (0.1s)
# wandb: ⣯ uploading artifact cnn_rj0wpgqn (1.0s)
# wandb:   ↳ ⣯ resnet35_15042026_0218_best.pth 1.5MB/83.1MB (0.1s)
# wandb: ⣟ uploading artifact cnn_rj0wpgqn (1.5s)
# wandb:   ↳ ⣟ resnet35_15042026_0218_best.pth 52.7MB/83.1MB (0.6s)
# wandb: ⡿ uploading artifact cnn_rj0wpgqn (1.5s)
# wandb:   ↳ ⡿ resnet35_15042026_0218_best.pth 52.7MB/83.1MB (0.6s)
# wandb: ⢿ uploading artifact cnn_rj0wpgqn (1.5s)
# wandb:   ↳ ⢿ resnet35_15042026_0218_best.pth 52.7MB/83.1MB (0.6s)
# wandb: ⣻ uploading artifact cnn_rj0wpgqn (1.5s)
# wandb:   ↳ ⣻ resnet35_15042026_0218_best.pth 52.7MB/83.1MB (0.6s)
# wandb: ⣽ uploading artifact cnn_rj0wpgqn (1.5s)
# wandb:   ↳ ⣽ resnet35_15042026_0218_best.pth 52.7MB/83.1MB (0.6s)
# wandb: ⣾ uploading artifact cnn_rj0wpgqn (2.0s)
# wandb: ⣷ uploading artifact cnn_rj0wpgqn (2.0s)
# wandb: ⣯ uploading artifact cnn_rj0wpgqn (2.0s)
# wandb: ⣟ uploading artifact cnn_rj0wpgqn (2.0s)
# wandb: ⡿ uploading artifact cnn_rj0wpgqn (2.0s)
# wandb: ⢿ uploading summary, console lines 252-252 (0.0s)
# wandb: ⣻ uploading summary, console lines 252-252 (0.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▇▇▇████
# wandb:  Learning_Rate ██████████████████████▄▄▄▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁
# wandb: Train/Accuracy ▁▂▃▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇███████████████
# wandb:     Train/Loss █▇▆▆▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▃▅▅▅▆▆▆▆▆▇▇▆▇▇▇▇▇▇▇▇███████████████████
# wandb:       Val/Loss ▆█▅▅▄▄▄▄▃▄▃▃▃▃▂▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 100
# wandb:  Learning_Rate 0.00013
# wandb: Train/Accuracy 0.71598
# wandb:     Train/Loss 1.29519
# wandb:   Val/Accuracy 0.67038
# wandb:       Val/Loss 1.42782
# wandb:
# wandb: 🚀 View run resnet35_15042026_0218 at: https://wandb.ai/phucga15062005/FER2013/runs/rj0wpgqn
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260415_021828-rj0wpgqn/logs
#
# 		DONE!
