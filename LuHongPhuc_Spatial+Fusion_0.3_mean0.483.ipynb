# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 948, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 948 (delta 151), reused 134 (delta 115), pack-reused 751 (from 2)
# Receiving objects: 100% (948/948), 5.89 MiB | 34.44 MiB/s, done.
# Resolving deltas: 100% (591/591), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_spatial_fusion --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 7n9dxoj1 (0.3s)
# wandb: ⣷ setting up run 7n9dxoj1 (0.3s)
# wandb: ⣯ setting up run 7n9dxoj1 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_101135-7n9dxoj1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_spatial_10042026_1011
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/7n9dxoj1
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.6881 - accuracy: 0.1836 - val_loss: 1.9165 - val_accuracy: 0.3438
# 	--- Save best at ep 1, val_loss: 1.9165, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 2/100 - loss: 2.4931 - accuracy: 0.3347 - val_loss: 1.7573 - val_accuracy: 0.4118
# 	--- Save best at ep 2, val_loss: 1.7573, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 3/100 - loss: 2.3774 - accuracy: 0.3945 - val_loss: 1.7358 - val_accuracy: 0.4517
# 	--- Save best at ep 3, val_loss: 1.7358, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 4/100 - loss: 2.3223 - accuracy: 0.4331 - val_loss: 1.6721 - val_accuracy: 0.4985
# 	--- Save best at ep 4, val_loss: 1.6721, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 5/100 - loss: 2.2766 - accuracy: 0.4615 - val_loss: 1.6509 - val_accuracy: 0.5283
# 	--- Save best at ep 5, val_loss: 1.6509, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 6/100 - loss: 2.2441 - accuracy: 0.4735 - val_loss: 1.6407 - val_accuracy: 0.5093
# 	--- Save best at ep 6, val_loss: 1.6407, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 7/100 - loss: 2.2129 - accuracy: 0.4859 - val_loss: 1.6195 - val_accuracy: 0.5428
# 	--- Save best at ep 7, val_loss: 1.6195, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 8/100 - loss: 2.1911 - accuracy: 0.5016 - val_loss: 1.6161 - val_accuracy: 0.5422
# 	--- Save best at ep 8, val_loss: 1.6161, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 9/100 - loss: 2.1685 - accuracy: 0.5109 - val_loss: 1.6255 - val_accuracy: 0.5642
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 2.1523 - accuracy: 0.5214 - val_loss: 1.5624 - val_accuracy: 0.5667
# 	--- Save best at ep 10, val_loss: 1.5624, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 11/100 - loss: 2.1399 - accuracy: 0.5292 - val_loss: 1.5681 - val_accuracy: 0.5651
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 2.1262 - accuracy: 0.5343 - val_loss: 1.5619 - val_accuracy: 0.5885
# 	--- Save best at ep 12, val_loss: 1.5619, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 13/100 - loss: 2.1150 - accuracy: 0.5392 - val_loss: 1.5968 - val_accuracy: 0.5807
# 	-!- No improvement: 1/20
# Epoch 14/100 - loss: 2.0972 - accuracy: 0.5481 - val_loss: 1.5296 - val_accuracy: 0.5860
# 	--- Save best at ep 14, val_loss: 1.5296, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 15/100 - loss: 2.0896 - accuracy: 0.5535 - val_loss: 1.5390 - val_accuracy: 0.6024
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 2.0790 - accuracy: 0.5565 - val_loss: 1.5326 - val_accuracy: 0.5935
# 	-!- No improvement: 2/20
# Epoch 17/100 - loss: 2.0697 - accuracy: 0.5623 - val_loss: 1.5347 - val_accuracy: 0.5940
# 	-!- No improvement: 3/20
# Epoch 18/100 - loss: 2.0592 - accuracy: 0.5631 - val_loss: 1.5386 - val_accuracy: 0.6010
# 	-!- No improvement: 4/20
# Epoch 19/100 - loss: 2.0095 - accuracy: 0.5871 - val_loss: 1.5077 - val_accuracy: 0.6328
# 	--- Save best at ep 19, val_loss: 1.5077, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 20/100 - loss: 2.0006 - accuracy: 0.5980 - val_loss: 1.4862 - val_accuracy: 0.6297
# 	--- Save best at ep 20, val_loss: 1.4862, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 21/100 - loss: 1.9879 - accuracy: 0.5990 - val_loss: 1.5069 - val_accuracy: 0.6350
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 1.9758 - accuracy: 0.6020 - val_loss: 1.4965 - val_accuracy: 0.6300
# 	-!- No improvement: 2/20
# Epoch 23/100 - loss: 1.9674 - accuracy: 0.6081 - val_loss: 1.4782 - val_accuracy: 0.6314
# 	--- Save best at ep 23, val_loss: 1.4782, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 24/100 - loss: 1.9582 - accuracy: 0.6160 - val_loss: 1.4981 - val_accuracy: 0.6350
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 1.9441 - accuracy: 0.6207 - val_loss: 1.4993 - val_accuracy: 0.6283
# 	-!- No improvement: 2/20
# Epoch 26/100 - loss: 1.9437 - accuracy: 0.6228 - val_loss: 1.5129 - val_accuracy: 0.6160
# 	-!- No improvement: 3/20
# Epoch 27/100 - loss: 1.9363 - accuracy: 0.6219 - val_loss: 1.5007 - val_accuracy: 0.6261
# 	-!- No improvement: 4/20
# Epoch 28/100 - loss: 1.9143 - accuracy: 0.6326 - val_loss: 1.4633 - val_accuracy: 0.6534
# 	--- Save best at ep 28, val_loss: 1.4633, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 29/100 - loss: 1.8866 - accuracy: 0.6449 - val_loss: 1.4815 - val_accuracy: 0.6489
# 	-!- No improvement: 1/20
# Epoch 30/100 - loss: 1.8861 - accuracy: 0.6426 - val_loss: 1.4646 - val_accuracy: 0.6517
# 	-!- No improvement: 2/20
# Epoch 31/100 - loss: 1.8793 - accuracy: 0.6479 - val_loss: 1.4600 - val_accuracy: 0.6551
# 	--- Save best at ep 31, val_loss: 1.4600, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 32/100 - loss: 1.8822 - accuracy: 0.6474 - val_loss: 1.4733 - val_accuracy: 0.6450
# 	-!- No improvement: 1/20
# Epoch 33/100 - loss: 1.8629 - accuracy: 0.6525 - val_loss: 1.4723 - val_accuracy: 0.6551
# 	-!- No improvement: 2/20
# Epoch 34/100 - loss: 1.8600 - accuracy: 0.6567 - val_loss: 1.4650 - val_accuracy: 0.6525
# 	-!- No improvement: 3/20
# Epoch 35/100 - loss: 1.8513 - accuracy: 0.6599 - val_loss: 1.4784 - val_accuracy: 0.6581
# 	-!- No improvement: 4/20
# Epoch 36/100 - loss: 1.8353 - accuracy: 0.6677 - val_loss: 1.4633 - val_accuracy: 0.6592
# 	-!- No improvement: 5/20
# Epoch 37/100 - loss: 1.8233 - accuracy: 0.6709 - val_loss: 1.4553 - val_accuracy: 0.6601
# 	--- Save best at ep 37, val_loss: 1.4553, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 38/100 - loss: 1.8220 - accuracy: 0.6750 - val_loss: 1.4585 - val_accuracy: 0.6595
# 	-!- No improvement: 1/20
# Epoch 39/100 - loss: 1.8211 - accuracy: 0.6732 - val_loss: 1.4487 - val_accuracy: 0.6668
# 	--- Save best at ep 39, val_loss: 1.4487, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 40/100 - loss: 1.8118 - accuracy: 0.6789 - val_loss: 1.4482 - val_accuracy: 0.6679
# 	--- Save best at ep 40, val_loss: 1.4482, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth ---
# Epoch 41/100 - loss: 1.8106 - accuracy: 0.6796 - val_loss: 1.4572 - val_accuracy: 0.6676
# 	-!- No improvement: 1/20
# Epoch 42/100 - loss: 1.7988 - accuracy: 0.6837 - val_loss: 1.4688 - val_accuracy: 0.6656
# 	-!- No improvement: 2/20
# Epoch 43/100 - loss: 1.8003 - accuracy: 0.6860 - val_loss: 1.4616 - val_accuracy: 0.6643
# 	-!- No improvement: 3/20
# Epoch 44/100 - loss: 1.7996 - accuracy: 0.6844 - val_loss: 1.4598 - val_accuracy: 0.6654
# 	-!- No improvement: 4/20
# Epoch 45/100 - loss: 1.7828 - accuracy: 0.6903 - val_loss: 1.4634 - val_accuracy: 0.6726
# 	-!- No improvement: 5/20
# Epoch 46/100 - loss: 1.7847 - accuracy: 0.6886 - val_loss: 1.4571 - val_accuracy: 0.6701
# 	-!- No improvement: 6/20
# Epoch 47/100 - loss: 1.7757 - accuracy: 0.6947 - val_loss: 1.4583 - val_accuracy: 0.6704
# 	-!- No improvement: 7/20
# Epoch 48/100 - loss: 1.7688 - accuracy: 0.7009 - val_loss: 1.4578 - val_accuracy: 0.6698
# 	-!- No improvement: 8/20
# Epoch 49/100 - loss: 1.7651 - accuracy: 0.6961 - val_loss: 1.4587 - val_accuracy: 0.6718
# 	-!- No improvement: 9/20
# Epoch 50/100 - loss: 1.7696 - accuracy: 0.6987 - val_loss: 1.4540 - val_accuracy: 0.6718
# 	-!- No improvement: 10/20
# Epoch 51/100 - loss: 1.7609 - accuracy: 0.6995 - val_loss: 1.4592 - val_accuracy: 0.6721
# 	-!- No improvement: 11/20
# Epoch 52/100 - loss: 1.7622 - accuracy: 0.7019 - val_loss: 1.4571 - val_accuracy: 0.6737
# 	-!- No improvement: 12/20
# Epoch 53/100 - loss: 1.7597 - accuracy: 0.7031 - val_loss: 1.4595 - val_accuracy: 0.6701
# 	-!- No improvement: 13/20
# Epoch 54/100 - loss: 1.7531 - accuracy: 0.7038 - val_loss: 1.4613 - val_accuracy: 0.6709
# 	-!- No improvement: 14/20
# Epoch 55/100 - loss: 1.7505 - accuracy: 0.7088 - val_loss: 1.4584 - val_accuracy: 0.6718
# 	-!- No improvement: 15/20
# Epoch 56/100 - loss: 1.7576 - accuracy: 0.7025 - val_loss: 1.4588 - val_accuracy: 0.6729
# 	-!- No improvement: 16/20
# Epoch 57/100 - loss: 1.7588 - accuracy: 0.7055 - val_loss: 1.4573 - val_accuracy: 0.6746
# 	-!- No improvement: 17/20
# Epoch 58/100 - loss: 1.7457 - accuracy: 0.7061 - val_loss: 1.4601 - val_accuracy: 0.6737
# 	-!- No improvement: 18/20
# Epoch 59/100 - loss: 1.7498 - accuracy: 0.7061 - val_loss: 1.4603 - val_accuracy: 0.6757
# 	-!- No improvement: 19/20
# Epoch 60/100 - loss: 1.7451 - accuracy: 0.7097 - val_loss: 1.4637 - val_accuracy: 0.6729
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=60
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1011_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 44.86it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.88%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.662309  0.619145  0.640000   491.000000
# disgust        0.529412  0.818182  0.642857    55.000000
# fear           0.550562  0.464015  0.503597   528.000000
# happy          0.917791  0.850967  0.883117   879.000000
# sad            0.558059  0.542088  0.549957   594.000000
# surprise       0.771363  0.802885  0.786808   416.000000
# neutral        0.611613  0.757188  0.676660   626.000000
# accuracy       0.688771  0.688771  0.688771     0.688771
# macro avg      0.657301  0.693496  0.668999  3589.000000
# weighted avg   0.692948  0.688771  0.688028  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_spatial_10042026_1011_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_7n9dxoj1 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_7n9dxoj1 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_7n9dxoj1 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_7n9dxoj1 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_7n9dxoj1 (0.5s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1011_best.pth 1.0MB/101.1MB (0.0s)
# wandb: ⣯ uploading artifact cnn_7n9dxoj1 (0.5s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1011_best.pth 1.0MB/101.1MB (0.0s)
# wandb: ⣟ uploading artifact cnn_7n9dxoj1 (0.5s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1011_best.pth 1.0MB/101.1MB (0.0s)
# wandb: ⡿ uploading artifact cnn_7n9dxoj1 (0.5s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1011_best.pth 1.0MB/101.1MB (0.0s)
# wandb: ⢿ uploading artifact cnn_7n9dxoj1 (0.5s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1011_best.pth 1.0MB/101.1MB (0.0s)
# wandb: ⣻ uploading artifact cnn_7n9dxoj1 (1.0s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1011_best.pth 38.8MB/101.1MB (0.5s)
# wandb: ⣽ uploading artifact cnn_7n9dxoj1 (1.0s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1011_best.pth 38.8MB/101.1MB (0.5s)
# wandb: ⣾ uploading artifact cnn_7n9dxoj1 (1.0s)
# wandb:   ↳ ⣾ vgg_spatial_10042026_1011_best.pth 38.8MB/101.1MB (0.5s)
# wandb: ⣷ uploading artifact cnn_7n9dxoj1 (1.0s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1011_best.pth 38.8MB/101.1MB (0.5s)
# wandb: ⣯ uploading artifact cnn_7n9dxoj1 (1.0s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1011_best.pth 38.8MB/101.1MB (0.5s)
# wandb: ⣟ uploading artifact cnn_7n9dxoj1 (1.5s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1011_best.pth 93.1MB/101.1MB (1.0s)
# wandb: ⡿ uploading artifact cnn_7n9dxoj1 (1.5s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1011_best.pth 93.1MB/101.1MB (1.0s)
# wandb: ⢿ uploading artifact cnn_7n9dxoj1 (1.5s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1011_best.pth 93.1MB/101.1MB (1.0s)
# wandb: ⣻ uploading artifact cnn_7n9dxoj1 (1.5s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1011_best.pth 93.1MB/101.1MB (1.0s)
# wandb: ⣽ uploading artifact cnn_7n9dxoj1 (1.5s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1011_best.pth 93.1MB/101.1MB (1.0s)
# wandb: ⣾ uploading artifact cnn_7n9dxoj1 (2.0s)
# wandb: ⣷ uploading artifact cnn_7n9dxoj1 (2.0s)
# wandb: ⣯ uploading artifact cnn_7n9dxoj1 (2.0s)
# wandb: ⣟ uploading artifact cnn_7n9dxoj1 (2.0s)
# wandb: ⡿ uploading artifact cnn_7n9dxoj1 (2.0s)
# wandb: ⢿ uploading media/images/Evaluation/Confusion_Matrix_59_1eec82b2031f4f...
# wandb: ⢿ uploading media/images/Evaluation/Correct_Samples_60_f6e6631584a9874...
# wandb: ⢿ uploading media/images/Evaluation/Wrong_Samples_61_565a791b0c950127e...
# wandb: ⢿ uploading output.log 11.2KB/11.2KB (0.1s)
# wandb: ⢿ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⢿ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⣻ uploading media/images/Evaluation/Confusion_Matrix_59_1eec82b2031f4f...
# wandb: ⣻ uploading media/images/Evaluation/Correct_Samples_60_f6e6631584a9874...
# wandb: ⣻ uploading media/images/Evaluation/Wrong_Samples_61_565a791b0c950127e...
# wandb: ⣻ uploading output.log 11.2KB/11.2KB (0.1s)
# wandb: ⣻ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣻ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⣽ uploading media/images/Evaluation/Confusion_Matrix_59_1eec82b2031f4f...
# wandb: ⣽ uploading media/images/Evaluation/Correct_Samples_60_f6e6631584a9874...
# wandb: ⣽ uploading media/images/Evaluation/Wrong_Samples_61_565a791b0c950127e...
# wandb: ⣽ uploading output.log 11.2KB/11.2KB (0.1s)
# wandb: ⣽ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣽ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ███████████▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:     Train/Loss █▇▆▅▅▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▂▃▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇██▇█████████████████
# wandb:       Val/Loss █▅▄▄▄▃▃▃▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 60
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.70971
# wandb:     Train/Loss 1.74515
# wandb:   Val/Accuracy 0.67289
# wandb:       Val/Loss 1.46375
# wandb:
# wandb: 🚀 View run vgg_spatial_10042026_1011 at: https://wandb.ai/phucga15062005/FER2013/runs/7n9dxoj1
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_101135-7n9dxoj1/logs
#
# 		DONE!
