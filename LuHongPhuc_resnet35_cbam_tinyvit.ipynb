# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 6

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2028, done.
# remote: Counting objects: 100% (396/396), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 2028 (delta 288), reused 223 (delta 164), pack-reused 1632 (from 1)
# Receiving objects: 100% (2028/2028), 6.30 MiB | 21.07 MiB/s, done.
# Resolving deltas: 100% (1444/1444), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config resnet35_cbam_tinyvit --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: resnet35_cbam_tinyvit_17042026_0654
#
# ==================================================
# [Transfer Learning] Loading pretrained backbone...
# ==================================================
# [ResNet35_CBAM_ViT] Backbone loaded: 296 weights
# [ResNet35_CBAM_ViT] Backbone FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=4)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run y6paiqc2 (0.3s)
# wandb: ⣷ setting up run y6paiqc2 (0.3s)
# wandb: ⣯ setting up run y6paiqc2 (0.3s)
# wandb: ⣟ setting up run y6paiqc2 (0.3s)
# wandb: ⡿ setting up run y6paiqc2 (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_065428-y6paiqc2
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_cbam_tinyvit_17042026_0654
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/y6paiqc2
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.0596 - accuracy: 0.7340 - val_loss: 1.2837 - val_accuracy: 0.6670
# 	--- Save best at ep 1, val_loss: 1.2837, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth ---
# Epoch 2/100 - loss: 1.0142 - accuracy: 0.7496 - val_loss: 1.3181 - val_accuracy: 0.6517
# 	-!- No improvement: 1/20
# Epoch 3/100 - loss: 0.9987 - accuracy: 0.7526 - val_loss: 1.2941 - val_accuracy: 0.6592
# 	-!- No improvement: 2/20
# Epoch 4/100 - loss: 1.0051 - accuracy: 0.7491 - val_loss: 1.2933 - val_accuracy: 0.6682
# 	-!- No improvement: 3/20
# Epoch 5/100 - loss: 0.9945 - accuracy: 0.7544 - val_loss: 1.3206 - val_accuracy: 0.6629
# 	-!- No improvement: 4/20
# Epoch 6/100 - loss: 0.9958 - accuracy: 0.7555 - val_loss: 1.3268 - val_accuracy: 0.6726
# 	-!- No improvement: 5/20
# [ResNet35_CBAM_ViT] All parameters UNFROZEN.
# [ResNet35_CBAM_ViT] Param groups: backbone=185 tensors (lr=5e-05), head=33 tensors (lr=0.0005)
# [Trainer] Discriminative LR: backbone=5e-05, head=0.0005
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=4)
# [Trainer] Reset patience + best_val_loss for Phase 2.
# Epoch 7/100 - loss: 0.9889 - accuracy: 0.7574 - val_loss: 1.2759 - val_accuracy: 0.6615
# 	--- Save best at ep 7, val_loss: 1.2759, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth ---
# Epoch 8/100 - loss: 0.9781 - accuracy: 0.7619 - val_loss: 1.2761 - val_accuracy: 0.6704
# 	-!- No improvement: 1/20
# Epoch 9/100 - loss: 0.9755 - accuracy: 0.7656 - val_loss: 1.2833 - val_accuracy: 0.6718
# 	-!- No improvement: 2/20
# Epoch 10/100 - loss: 0.9687 - accuracy: 0.7644 - val_loss: 1.2708 - val_accuracy: 0.6682
# 	--- Save best at ep 10, val_loss: 1.2708, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth ---
# Epoch 11/100 - loss: 0.9589 - accuracy: 0.7719 - val_loss: 1.2774 - val_accuracy: 0.6695
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 0.9645 - accuracy: 0.7677 - val_loss: 1.2888 - val_accuracy: 0.6676
# 	-!- No improvement: 2/20
# Epoch 13/100 - loss: 0.9579 - accuracy: 0.7692 - val_loss: 1.2684 - val_accuracy: 0.6598
# 	--- Save best at ep 13, val_loss: 1.2684, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth ---
# Epoch 14/100 - loss: 0.9546 - accuracy: 0.7742 - val_loss: 1.2901 - val_accuracy: 0.6651
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 0.9509 - accuracy: 0.7741 - val_loss: 1.3081 - val_accuracy: 0.6676
# 	-!- No improvement: 2/20
# Epoch 16/100 - loss: 0.9484 - accuracy: 0.7755 - val_loss: 1.3064 - val_accuracy: 0.6693
# 	-!- No improvement: 3/20
# Epoch 17/100 - loss: 0.9427 - accuracy: 0.7794 - val_loss: 1.2637 - val_accuracy: 0.6651
# 	--- Save best at ep 17, val_loss: 1.2637, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth ---
# Epoch 18/100 - loss: 0.9423 - accuracy: 0.7768 - val_loss: 1.3128 - val_accuracy: 0.6581
# 	-!- No improvement: 1/20
# Epoch 19/100 - loss: 0.9421 - accuracy: 0.7780 - val_loss: 1.3204 - val_accuracy: 0.6698
# 	-!- No improvement: 2/20
# Epoch 20/100 - loss: 0.9363 - accuracy: 0.7779 - val_loss: 1.3310 - val_accuracy: 0.6673
# 	-!- No improvement: 3/20
# Epoch 21/100 - loss: 0.9287 - accuracy: 0.7835 - val_loss: 1.3013 - val_accuracy: 0.6665
# 	-!- No improvement: 4/20
# Epoch 22/100 - loss: 0.9338 - accuracy: 0.7812 - val_loss: 1.3157 - val_accuracy: 0.6634
# 	-!- No improvement: 5/20
# Epoch 23/100 - loss: 0.9228 - accuracy: 0.7846 - val_loss: 1.3103 - val_accuracy: 0.6693
# 	-!- No improvement: 6/20
# Epoch 24/100 - loss: 0.9114 - accuracy: 0.7891 - val_loss: 1.3109 - val_accuracy: 0.6645
# 	-!- No improvement: 7/20
# Epoch 25/100 - loss: 0.9187 - accuracy: 0.7870 - val_loss: 1.2941 - val_accuracy: 0.6684
# 	-!- No improvement: 8/20
# Epoch 26/100 - loss: 0.9141 - accuracy: 0.7888 - val_loss: 1.2978 - val_accuracy: 0.6684
# 	-!- No improvement: 9/20
# Epoch 27/100 - loss: 0.9181 - accuracy: 0.7891 - val_loss: 1.2903 - val_accuracy: 0.6698
# 	-!- No improvement: 10/20
# Epoch 28/100 - loss: 0.9060 - accuracy: 0.7923 - val_loss: 1.3056 - val_accuracy: 0.6693
# 	-!- No improvement: 11/20
# Epoch 29/100 - loss: 0.9081 - accuracy: 0.7900 - val_loss: 1.3082 - val_accuracy: 0.6709
# 	-!- No improvement: 12/20
# Epoch 30/100 - loss: 0.8992 - accuracy: 0.7927 - val_loss: 1.2958 - val_accuracy: 0.6732
# 	-!- No improvement: 13/20
# Epoch 31/100 - loss: 0.9067 - accuracy: 0.7928 - val_loss: 1.2943 - val_accuracy: 0.6737
# 	-!- No improvement: 14/20
# Epoch 32/100 - loss: 0.9015 - accuracy: 0.7928 - val_loss: 1.3042 - val_accuracy: 0.6693
# 	-!- No improvement: 15/20
# Epoch 33/100 - loss: 0.8932 - accuracy: 0.7968 - val_loss: 1.3031 - val_accuracy: 0.6726
# 	-!- No improvement: 16/20
# Epoch 34/100 - loss: 0.8995 - accuracy: 0.7945 - val_loss: 1.2996 - val_accuracy: 0.6712
# 	-!- No improvement: 17/20
# Epoch 35/100 - loss: 0.8968 - accuracy: 0.7932 - val_loss: 1.2919 - val_accuracy: 0.6718
# 	-!- No improvement: 18/20
# Epoch 36/100 - loss: 0.8926 - accuracy: 0.7965 - val_loss: 1.2938 - val_accuracy: 0.6673
# 	-!- No improvement: 19/20
# Epoch 37/100 - loss: 0.8951 - accuracy: 0.7962 - val_loss: 1.3023 - val_accuracy: 0.6704
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=37
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_resnet35_cbam_tinyvit_17042026_0654.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35_cbam_tinyvit/resnet35_cbam_tinyvit_17042026_0654_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 17.50it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.62%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.624733  0.596741  0.610417   491.000000
# disgust        0.541667  0.709091  0.614173    55.000000
# fear           0.503006  0.475379  0.488802   528.000000
# happy          0.898585  0.866894  0.882455   879.000000
# sad            0.514431  0.510101  0.512257   594.000000
# surprise       0.787529  0.819712  0.803298   416.000000
# neutral        0.645066  0.699681  0.671264   626.000000
# accuracy       0.676233  0.676233  0.676233     0.676233
# macro avg      0.645002  0.668228  0.654667  3589.000000
# weighted avg   0.676783  0.676233  0.675933  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_cbam_tinyvit_17042026_0654_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.5s)
# wandb: ⣯ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.5s)
# wandb: ⣟ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.5s)
# wandb: ⡿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.5s)
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (0.5s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.0s)
# wandb:   ↳ ⣻ resnet35_cbam_tinyvit_17042026_0654_best.pth 30.3MB/137.3MB (0.3s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.0s)
# wandb:   ↳ ⣽ resnet35_cbam_tinyvit_17042026_0654_best.pth 30.3MB/137.3MB (0.3s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.0s)
# wandb:   ↳ ⣾ resnet35_cbam_tinyvit_17042026_0654_best.pth 30.3MB/137.3MB (0.3s)
# wandb: ⣷ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.0s)
# wandb:   ↳ ⣷ resnet35_cbam_tinyvit_17042026_0654_best.pth 30.3MB/137.3MB (0.3s)
# wandb: ⣯ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.0s)
# wandb:   ↳ ⣯ resnet35_cbam_tinyvit_17042026_0654_best.pth 30.3MB/137.3MB (0.3s)
# wandb: ⣟ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.5s)
# wandb:   ↳ ⣟ resnet35_cbam_tinyvit_17042026_0654_best.pth 65.4MB/137.3MB (0.8s)
# wandb: ⡿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.5s)
# wandb:   ↳ ⡿ resnet35_cbam_tinyvit_17042026_0654_best.pth 65.4MB/137.3MB (0.8s)
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.5s)
# wandb:   ↳ ⢿ resnet35_cbam_tinyvit_17042026_0654_best.pth 65.4MB/137.3MB (0.8s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.5s)
# wandb:   ↳ ⣻ resnet35_cbam_tinyvit_17042026_0654_best.pth 65.4MB/137.3MB (0.8s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (1.5s)
# wandb:   ↳ ⣽ resnet35_cbam_tinyvit_17042026_0654_best.pth 65.4MB/137.3MB (0.8s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.0s)
# wandb:   ↳ ⣾ resnet35_cbam_tinyvit_17042026_0654_best.pth 103.0MB/137.3MB (1.3s)
# wandb: ⣷ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.0s)
# wandb:   ↳ ⣷ resnet35_cbam_tinyvit_17042026_0654_best.pth 103.0MB/137.3MB (1.3s)
# wandb: ⣯ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.0s)
# wandb:   ↳ ⣯ resnet35_cbam_tinyvit_17042026_0654_best.pth 103.0MB/137.3MB (1.3s)
# wandb: ⣟ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.0s)
# wandb:   ↳ ⣟ resnet35_cbam_tinyvit_17042026_0654_best.pth 103.0MB/137.3MB (1.3s)
# wandb: ⡿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.0s)
# wandb:   ↳ ⡿ resnet35_cbam_tinyvit_17042026_0654_best.pth 103.0MB/137.3MB (1.3s)
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.5s)
# wandb:   ↳ ⢿ resnet35_cbam_tinyvit_17042026_0654_best.pth 137.0MB/137.3MB (1.8s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.5s)
# wandb:   ↳ ⣻ resnet35_cbam_tinyvit_17042026_0654_best.pth 137.0MB/137.3MB (1.8s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.5s)
# wandb:   ↳ ⣽ resnet35_cbam_tinyvit_17042026_0654_best.pth 137.0MB/137.3MB (1.8s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.5s)
# wandb:   ↳ ⣾ resnet35_cbam_tinyvit_17042026_0654_best.pth 137.0MB/137.3MB (1.8s)
# wandb: ⣷ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (2.5s)
# wandb:   ↳ ⣷ resnet35_cbam_tinyvit_17042026_0654_best.pth 137.0MB/137.3MB (1.8s)
# wandb: ⣯ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.0s)
# wandb: ⣟ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.0s)
# wandb: ⡿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.0s)
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.0s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.0s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.5s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.5s)
# wandb: ⣷ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.5s)
# wandb: ⣯ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.5s)
# wandb: ⣟ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (3.5s)
# wandb: ⡿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (4.0s)
# wandb: ⢿ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (4.0s)
# wandb: ⣻ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (4.0s)
# wandb: ⣽ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (4.0s)
# wandb: ⣾ uploading artifact resnet35_cbam_tinyvit_17042026_0654_y6paiqc2 (4.0s)
# wandb: ⣷ uploading history steps 35-39, summary, console lines 80-112 (0.4s)
# wandb: ⣯ uploading history steps 35-39, summary, console lines 80-112 (0.4s)
# wandb: ⣟ uploading history steps 35-39, summary, console lines 80-112 (0.4s)
# wandb: ⡿ uploading history steps 35-39, summary, console lines 80-112 (0.4s)
# wandb: ⢿ uploading history steps 35-39, summary, console lines 80-112 (0.4s)
# wandb: ⣻ uploading history steps 35-39, summary, console lines 80-112 (0.9s)
# wandb: ⣽ uploading history steps 35-39, summary, console lines 80-112 (0.9s)
# wandb: ⣾ uploading history steps 35-39, summary, console lines 80-112 (0.9s)
# wandb: ⣷ uploading history steps 35-39, summary, console lines 80-112 (0.9s)
# wandb: ⣯ uploading history steps 35-39, summary, console lines 80-112 (0.9s)
# wandb: ⣟ uploading history steps 35-39, summary, console lines 80-112 (1.4s)
# wandb: ⡿ uploading history steps 35-39, summary, console lines 80-112 (1.4s)
# wandb: ⢿ uploading history steps 35-39, summary, console lines 80-112 (1.4s)
# wandb: ⣻ uploading history steps 35-39, summary, console lines 80-112 (1.4s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ██████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▃▃▃▃▄▄▅▄▅▅▅▅▅▆▆▆▆▆▇▆▇▇▇▇▇█▇████████
# wandb:     Train/Loss █▆▅▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁
# wandb:   Val/Accuracy ▆▁▃▆▅█▄▇▇▆▇▆▄▅▆▇▅▃▇▆▆▅▇▅▆▆▇▇▇██▇█▇▇▆▇
# wandb:       Val/Loss ▃▇▄▄▇█▂▂▃▂▂▄▁▄▆▅▁▆▇█▅▆▆▆▄▅▄▅▆▄▄▅▅▅▄▄▅
# wandb:
# wandb: Run summary:
# wandb:          Epoch 37
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.79616
# wandb:     Train/Loss 0.89508
# wandb:   Val/Accuracy 0.67038
# wandb:       Val/Loss 1.30234
# wandb:
# wandb: 🚀 View run resnet35_cbam_tinyvit_17042026_0654 at: https://wandb.ai/phucga15062005/FER2013/runs/y6paiqc2
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 4 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_065428-y6paiqc2/logs
#
# 		DONE!
