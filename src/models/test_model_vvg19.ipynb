# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch

# config giả giống project của bạn
config = {
    'data': {
        'num_classes': 7
    },
    'model': {
        'dropout_block': 0.3,
        'dropout_dense': 0.5
    }
}

# %%
from vgg import VGG19

# %% [markdown]
# test 1: [1,48,48]

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model=VGG19(config,channels=1)
x=torch.randn(8,1,224,224) #batch=8
y=model(x)
print("Output shape:", y.shape)
# Out:
# Output shape: torch.Size([8, 7])

# %%
model = VGG19(config, channels=3)
x = torch.randn(8, 3, 224, 224)
y = model(x)
print(y.shape)
# Out:
# torch.Size([8, 7])
