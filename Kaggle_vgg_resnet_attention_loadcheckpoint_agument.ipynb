# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1337, done.
# remote: Counting objects: 100% (310/310), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 1337 (delta 219), reused 185 (delta 131), pack-reused 1027 (from 1)
# Receiving objects: 100% (1337/1337), 6.06 MiB | 25.54 MiB/s, done.
# Resolving deltas: 100% (893/893), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_resnet_attention --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Multi-scale Fusion (Stage 3 + Stage 4), Feature dim: 1536
#
# ==================================================
# [Transfer Learning] Loading pretrained backbones...
# ==================================================
# [Transfer] VGG loaded: 56 params | skipped: 12 missing
# [Transfer] ResNet loaded: 292 params | skipped: 2 missing
# [Freeze] Backbones frozen. Trainable: 6,565,383 / 22,195,535 (29.6%)
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run v58poq8z (0.2s)
# wandb: ⣾ setting up run v58poq8z (0.2s)
# wandb: ⣷ setting up run v58poq8z (0.2s)
# wandb: ⣯ setting up run v58poq8z (0.2s)
# wandb: ⣟ setting up run v58poq8z (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_090436-v58poq8z
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_resnet_attention_13042026_0904
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/v58poq8z
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.5141 - accuracy: 0.6146 - val_loss: 1.4795 - val_accuracy: 0.6325
# 	--- Save best at ep 1, val_loss: 1.4795, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 2/100 - loss: 1.4392 - accuracy: 0.6545 - val_loss: 1.4637 - val_accuracy: 0.6673
# 	--- Save best at ep 2, val_loss: 1.4637, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 3/100 - loss: 1.4289 - accuracy: 0.6600 - val_loss: 1.4139 - val_accuracy: 0.6673
# 	--- Save best at ep 3, val_loss: 1.4139, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 4/100 - loss: 1.4215 - accuracy: 0.6591 - val_loss: 1.4210 - val_accuracy: 0.6701
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.4106 - accuracy: 0.6631 - val_loss: 1.4363 - val_accuracy: 0.6601
# 	-!- No improvement: 2/20
# Epoch 6/100 - loss: 1.4101 - accuracy: 0.6685 - val_loss: 1.4336 - val_accuracy: 0.6634
# 	-!- No improvement: 3/20
# Epoch 7/100 - loss: 1.3986 - accuracy: 0.6687 - val_loss: 1.4874 - val_accuracy: 0.6565
# 	-!- No improvement: 4/20
# Epoch 8/100 - loss: 1.3723 - accuracy: 0.6799 - val_loss: 1.4351 - val_accuracy: 0.6743
# 	-!- No improvement: 5/20
# Epoch 9/100 - loss: 1.3679 - accuracy: 0.6816 - val_loss: 1.4306 - val_accuracy: 0.6665
# 	-!- No improvement: 6/20
# Epoch 10/100 - loss: 1.3739 - accuracy: 0.6777 - val_loss: 1.4169 - val_accuracy: 0.6645
# 	-!- No improvement: 7/20
# Epoch 11/100 - loss: 1.3708 - accuracy: 0.6810 - val_loss: 1.4457 - val_accuracy: 0.6726
# 	-!- No improvement: 8/20
# Epoch 12/100 - loss: 1.3570 - accuracy: 0.6863 - val_loss: 1.4261 - val_accuracy: 0.6687
# 	-!- No improvement: 9/20
# Epoch 13/100 - loss: 1.3529 - accuracy: 0.6853 - val_loss: 1.4134 - val_accuracy: 0.6709
# 	--- Save best at ep 13, val_loss: 1.4134, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 14/100 - loss: 1.3537 - accuracy: 0.6871 - val_loss: 1.4163 - val_accuracy: 0.6687
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 1.3541 - accuracy: 0.6856 - val_loss: 1.4255 - val_accuracy: 0.6682
# 	-!- No improvement: 2/20
# Epoch 16/100 - loss: 1.3516 - accuracy: 0.6883 - val_loss: 1.4248 - val_accuracy: 0.6704
# 	-!- No improvement: 3/20
# Epoch 17/100 - loss: 1.3514 - accuracy: 0.6900 - val_loss: 1.4390 - val_accuracy: 0.6682
# 	-!- No improvement: 4/20
# Epoch 18/100 - loss: 1.3414 - accuracy: 0.6896 - val_loss: 1.4163 - val_accuracy: 0.6746
# 	-!- No improvement: 5/20
# Epoch 19/100 - loss: 1.3436 - accuracy: 0.6906 - val_loss: 1.4228 - val_accuracy: 0.6746
# 	-!- No improvement: 6/20
# Epoch 20/100 - loss: 1.3410 - accuracy: 0.6902 - val_loss: 1.4095 - val_accuracy: 0.6673
# 	--- Save best at ep 20, val_loss: 1.4095, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
#
# ==================================================
# [Phase 2] Epoch 21: Unfreezing backbones for fine-tuning!
# ==================================================
#
# [Unfreeze] All params trainable: 22,195,535
# [Trainer] Rebuilt optimizer with finetune_lr=1e-05 and reset patience.
# Epoch 21/100 - loss: 1.3359 - accuracy: 0.6920 - val_loss: 1.4174 - val_accuracy: 0.6746
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 1.3233 - accuracy: 0.6996 - val_loss: 1.4111 - val_accuracy: 0.6779
# 	-!- No improvement: 2/20
# Epoch 23/100 - loss: 1.3242 - accuracy: 0.6974 - val_loss: 1.4169 - val_accuracy: 0.6762
# 	-!- No improvement: 3/20
# Epoch 24/100 - loss: 1.3212 - accuracy: 0.7020 - val_loss: 1.4101 - val_accuracy: 0.6765
# 	-!- No improvement: 4/20
# Epoch 25/100 - loss: 1.3198 - accuracy: 0.7030 - val_loss: 1.4137 - val_accuracy: 0.6773
# 	-!- No improvement: 5/20
# Epoch 26/100 - loss: 1.3146 - accuracy: 0.7044 - val_loss: 1.4181 - val_accuracy: 0.6790
# 	-!- No improvement: 6/20
# Epoch 27/100 - loss: 1.3152 - accuracy: 0.7051 - val_loss: 1.4131 - val_accuracy: 0.6771
# 	-!- No improvement: 7/20
# Epoch 28/100 - loss: 1.3087 - accuracy: 0.7062 - val_loss: 1.4097 - val_accuracy: 0.6721
# 	-!- No improvement: 8/20
# Epoch 29/100 - loss: 1.3082 - accuracy: 0.7097 - val_loss: 1.4171 - val_accuracy: 0.6793
# 	-!- No improvement: 9/20
# Epoch 30/100 - loss: 1.3019 - accuracy: 0.7097 - val_loss: 1.4096 - val_accuracy: 0.6801
# 	-!- No improvement: 10/20
# Epoch 31/100 - loss: 1.2954 - accuracy: 0.7101 - val_loss: 1.4142 - val_accuracy: 0.6762
# 	-!- No improvement: 11/20
# Epoch 32/100 - loss: 1.3007 - accuracy: 0.7139 - val_loss: 1.4146 - val_accuracy: 0.6832
# 	-!- No improvement: 12/20
# Epoch 33/100 - loss: 1.2966 - accuracy: 0.7147 - val_loss: 1.4069 - val_accuracy: 0.6779
# 	--- Save best at ep 33, val_loss: 1.4069, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 34/100 - loss: 1.2948 - accuracy: 0.7121 - val_loss: 1.4094 - val_accuracy: 0.6801
# 	-!- No improvement: 1/20
# Epoch 35/100 - loss: 1.3006 - accuracy: 0.7092 - val_loss: 1.4083 - val_accuracy: 0.6799
# 	-!- No improvement: 2/20
# Epoch 36/100 - loss: 1.2983 - accuracy: 0.7147 - val_loss: 1.4072 - val_accuracy: 0.6812
# 	-!- No improvement: 3/20
# Epoch 37/100 - loss: 1.2900 - accuracy: 0.7209 - val_loss: 1.4042 - val_accuracy: 0.6773
# 	--- Save best at ep 37, val_loss: 1.4042, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 38/100 - loss: 1.2928 - accuracy: 0.7156 - val_loss: 1.4041 - val_accuracy: 0.6776
# 	--- Save best at ep 38, val_loss: 1.4041, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 39/100 - loss: 1.2842 - accuracy: 0.7180 - val_loss: 1.4132 - val_accuracy: 0.6810
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 1.2916 - accuracy: 0.7146 - val_loss: 1.4105 - val_accuracy: 0.6815
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 1.2885 - accuracy: 0.7165 - val_loss: 1.4114 - val_accuracy: 0.6812
# 	-!- No improvement: 3/20
# Epoch 42/100 - loss: 1.2849 - accuracy: 0.7216 - val_loss: 1.4159 - val_accuracy: 0.6779
# 	-!- No improvement: 4/20
# Epoch 43/100 - loss: 1.2837 - accuracy: 0.7190 - val_loss: 1.4104 - val_accuracy: 0.6796
# 	-!- No improvement: 5/20
# Epoch 44/100 - loss: 1.2814 - accuracy: 0.7210 - val_loss: 1.4038 - val_accuracy: 0.6796
# 	--- Save best at ep 44, val_loss: 1.4038, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 45/100 - loss: 1.2810 - accuracy: 0.7228 - val_loss: 1.4036 - val_accuracy: 0.6746
# 	--- Save best at ep 45, val_loss: 1.4036, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 46/100 - loss: 1.2770 - accuracy: 0.7245 - val_loss: 1.4015 - val_accuracy: 0.6793
# 	--- Save best at ep 46, val_loss: 1.4015, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth ---
# Epoch 47/100 - loss: 1.2828 - accuracy: 0.7194 - val_loss: 1.4050 - val_accuracy: 0.6760
# 	-!- No improvement: 1/20
# Epoch 48/100 - loss: 1.2768 - accuracy: 0.7269 - val_loss: 1.4062 - val_accuracy: 0.6765
# 	-!- No improvement: 2/20
# Epoch 49/100 - loss: 1.2711 - accuracy: 0.7255 - val_loss: 1.4055 - val_accuracy: 0.6801
# 	-!- No improvement: 3/20
# Epoch 50/100 - loss: 1.2723 - accuracy: 0.7255 - val_loss: 1.4065 - val_accuracy: 0.6812
# 	-!- No improvement: 4/20
# Epoch 51/100 - loss: 1.2742 - accuracy: 0.7261 - val_loss: 1.4024 - val_accuracy: 0.6810
# 	-!- No improvement: 5/20
# Epoch 52/100 - loss: 1.2728 - accuracy: 0.7263 - val_loss: 1.4087 - val_accuracy: 0.6832
# 	-!- No improvement: 6/20
# Epoch 53/100 - loss: 1.2668 - accuracy: 0.7274 - val_loss: 1.4078 - val_accuracy: 0.6829
# 	-!- No improvement: 7/20
# Epoch 54/100 - loss: 1.2652 - accuracy: 0.7296 - val_loss: 1.4084 - val_accuracy: 0.6826
# 	-!- No improvement: 8/20
# Epoch 55/100 - loss: 1.2679 - accuracy: 0.7279 - val_loss: 1.4072 - val_accuracy: 0.6804
# 	-!- No improvement: 9/20
# Epoch 56/100 - loss: 1.2659 - accuracy: 0.7281 - val_loss: 1.4110 - val_accuracy: 0.6835
# 	-!- No improvement: 10/20
# Epoch 57/100 - loss: 1.2686 - accuracy: 0.7280 - val_loss: 1.4041 - val_accuracy: 0.6801
# 	-!- No improvement: 11/20
# Epoch 58/100 - loss: 1.2681 - accuracy: 0.7256 - val_loss: 1.4101 - val_accuracy: 0.6812
# 	-!- No improvement: 12/20
# Epoch 59/100 - loss: 1.2601 - accuracy: 0.7319 - val_loss: 1.4030 - val_accuracy: 0.6801
# 	-!- No improvement: 13/20
# Epoch 60/100 - loss: 1.2693 - accuracy: 0.7280 - val_loss: 1.4041 - val_accuracy: 0.6815
# 	-!- No improvement: 14/20
# Epoch 61/100 - loss: 1.2623 - accuracy: 0.7310 - val_loss: 1.4072 - val_accuracy: 0.6807
# 	-!- No improvement: 15/20
# Epoch 62/100 - loss: 1.2578 - accuracy: 0.7318 - val_loss: 1.4143 - val_accuracy: 0.6835
# 	-!- No improvement: 16/20
# Epoch 63/100 - loss: 1.2618 - accuracy: 0.7336 - val_loss: 1.4050 - val_accuracy: 0.6768
# 	-!- No improvement: 17/20
# Epoch 64/100 - loss: 1.2576 - accuracy: 0.7314 - val_loss: 1.4141 - val_accuracy: 0.6796
# 	-!- No improvement: 18/20
# Epoch 65/100 - loss: 1.2571 - accuracy: 0.7351 - val_loss: 1.4058 - val_accuracy: 0.6818
# 	-!- No improvement: 19/20
# Epoch 66/100 - loss: 1.2577 - accuracy: 0.7342 - val_loss: 1.4084 - val_accuracy: 0.6826
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=66
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_resnet_attention/vgg_resnet_attention_13042026_0904_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 15.22it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 69.55%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.616412  0.657841  0.636453   491.000000
# disgust        0.488889  0.800000  0.606897    55.000000
# fear           0.583979  0.428030  0.493989   528.000000
# happy          0.909305  0.878271  0.893519   879.000000
# sad            0.565878  0.563973  0.564924   594.000000
# surprise       0.766147  0.826923  0.795376   416.000000
# neutral        0.647564  0.722045  0.682779   626.000000
# accuracy       0.695458  0.695458  0.695458     0.695458
# macro avg      0.654025  0.696726  0.667705  3589.000000
# weighted avg   0.695846  0.695458  0.692663  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_resnet_attention_13042026_0904_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_v58poq8z (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_v58poq8z (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_v58poq8z (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_v58poq8z (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_v58poq8z (0.5s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0904_best.pth 28.9MB/227.4MB (0.2s)
# wandb: ⣯ uploading artifact cnn_v58poq8z (0.5s)
# wandb:   ↳ ⣯ vgg_resnet_attention_13042026_0904_best.pth 28.9MB/227.4MB (0.2s)
# wandb: ⣟ uploading artifact cnn_v58poq8z (0.5s)
# wandb:   ↳ ⣟ vgg_resnet_attention_13042026_0904_best.pth 28.9MB/227.4MB (0.2s)
# wandb: ⡿ uploading artifact cnn_v58poq8z (0.5s)
# wandb:   ↳ ⡿ vgg_resnet_attention_13042026_0904_best.pth 28.9MB/227.4MB (0.2s)
# wandb: ⢿ uploading artifact cnn_v58poq8z (0.5s)
# wandb:   ↳ ⢿ vgg_resnet_attention_13042026_0904_best.pth 28.9MB/227.4MB (0.2s)
# wandb: ⣻ uploading artifact cnn_v58poq8z (1.0s)
# wandb:   ↳ ⣻ vgg_resnet_attention_13042026_0904_best.pth 77.0MB/227.4MB (0.7s)
# wandb: ⣽ uploading artifact cnn_v58poq8z (1.0s)
# wandb:   ↳ ⣽ vgg_resnet_attention_13042026_0904_best.pth 77.0MB/227.4MB (0.7s)
# wandb: ⣾ uploading artifact cnn_v58poq8z (1.0s)
# wandb:   ↳ ⣾ vgg_resnet_attention_13042026_0904_best.pth 77.0MB/227.4MB (0.7s)
# wandb: ⣷ uploading artifact cnn_v58poq8z (1.0s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0904_best.pth 77.0MB/227.4MB (0.7s)
# wandb: ⣯ uploading artifact cnn_v58poq8z (1.0s)
# wandb:   ↳ ⣯ vgg_resnet_attention_13042026_0904_best.pth 77.0MB/227.4MB (0.7s)
# wandb: ⣟ uploading artifact cnn_v58poq8z (1.5s)
# wandb:   ↳ ⣟ vgg_resnet_attention_13042026_0904_best.pth 126.7MB/227.4MB (1.2s)
# wandb: ⡿ uploading artifact cnn_v58poq8z (1.5s)
# wandb:   ↳ ⡿ vgg_resnet_attention_13042026_0904_best.pth 126.7MB/227.4MB (1.2s)
# wandb: ⢿ uploading artifact cnn_v58poq8z (1.5s)
# wandb:   ↳ ⢿ vgg_resnet_attention_13042026_0904_best.pth 126.7MB/227.4MB (1.2s)
# wandb: ⣻ uploading artifact cnn_v58poq8z (1.5s)
# wandb:   ↳ ⣻ vgg_resnet_attention_13042026_0904_best.pth 126.7MB/227.4MB (1.2s)
# wandb: ⣽ uploading artifact cnn_v58poq8z (1.5s)
# wandb:   ↳ ⣽ vgg_resnet_attention_13042026_0904_best.pth 126.7MB/227.4MB (1.2s)
# wandb: ⣾ uploading artifact cnn_v58poq8z (2.0s)
# wandb:   ↳ ⣾ vgg_resnet_attention_13042026_0904_best.pth 171.9MB/227.4MB (1.7s)
# wandb: ⣾ uploading media/images/Evaluation/Confusion_Matrix_65_aeef3834bbd2fa...
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_66_5c0e8d0eb7ce3dd...
# wandb: ⣾ uploading media/images/Evaluation/Wrong_Samples_67_9fd967c2397113122...
# wandb: + 3 more task(s)
# wandb: ⣷ uploading artifact cnn_v58poq8z (2.0s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0904_best.pth 171.9MB/227.4MB (1.7s)
# wandb: ⣷ uploading media/images/Evaluation/Confusion_Matrix_65_aeef3834bbd2fa...
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_66_5c0e8d0eb7ce3dd...
# wandb: ⣷ uploading media/images/Evaluation/Wrong_Samples_67_9fd967c2397113122...
# wandb: + 3 more task(s)
# wandb: ⣯ uploading artifact cnn_v58poq8z (2.0s)
# wandb:   ↳ ⣯ vgg_resnet_attention_13042026_0904_best.pth 171.9MB/227.4MB (1.7s)
# wandb: ⣯ uploading media/images/Evaluation/Confusion_Matrix_65_aeef3834bbd2fa...
# wandb: ⣯ uploading media/images/Evaluation/Correct_Samples_66_5c0e8d0eb7ce3dd...
# wandb: ⣯ uploading media/images/Evaluation/Wrong_Samples_67_9fd967c2397113122...
# wandb: + 3 more task(s)
# wandb: ⣟ uploading artifact cnn_v58poq8z (2.0s)
# wandb:   ↳ ⣟ vgg_resnet_attention_13042026_0904_best.pth 171.9MB/227.4MB (1.7s)
# wandb: ⣟ uploading media/images/Evaluation/Confusion_Matrix_65_aeef3834bbd2fa...
# wandb: ⣟ uploading media/images/Evaluation/Correct_Samples_66_5c0e8d0eb7ce3dd...
# wandb: ⣟ uploading media/images/Evaluation/Wrong_Samples_67_9fd967c2397113122...
# wandb: + 3 more task(s)
# wandb: ⡿ uploading artifact cnn_v58poq8z (2.0s)
# wandb:   ↳ ⡿ vgg_resnet_attention_13042026_0904_best.pth 171.9MB/227.4MB (1.7s)
# wandb: ⡿ uploading media/images/Evaluation/Confusion_Matrix_65_aeef3834bbd2fa...
# wandb: ⡿ uploading media/images/Evaluation/Correct_Samples_66_5c0e8d0eb7ce3dd...
# wandb: ⡿ uploading media/images/Evaluation/Wrong_Samples_67_9fd967c2397113122...
# wandb: + 3 more task(s)
# wandb: ⢿ uploading artifact cnn_v58poq8z (2.5s)
# wandb:   ↳ ⢿ vgg_resnet_attention_13042026_0904_best.pth 217.5MB/227.4MB (2.2s)
# wandb: ⣻ uploading artifact cnn_v58poq8z (2.5s)
# wandb:   ↳ ⣻ vgg_resnet_attention_13042026_0904_best.pth 217.5MB/227.4MB (2.2s)
# wandb: ⣽ uploading artifact cnn_v58poq8z (2.5s)
# wandb:   ↳ ⣽ vgg_resnet_attention_13042026_0904_best.pth 217.5MB/227.4MB (2.2s)
# wandb: ⣾ uploading artifact cnn_v58poq8z (2.5s)
# wandb:   ↳ ⣾ vgg_resnet_attention_13042026_0904_best.pth 217.5MB/227.4MB (2.2s)
# wandb: ⣷ uploading artifact cnn_v58poq8z (2.5s)
# wandb:   ↳ ⣷ vgg_resnet_attention_13042026_0904_best.pth 217.5MB/227.4MB (2.2s)
# wandb: ⣯ uploading artifact cnn_v58poq8z (3.0s)
# wandb: ⣟ uploading artifact cnn_v58poq8z (3.0s)
# wandb: ⡿ uploading artifact cnn_v58poq8z (3.0s)
# wandb: ⢿ uploading artifact cnn_v58poq8z (3.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇██
# wandb:  Learning_Rate █████▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████▇████
# wandb:     Train/Loss █▆▆▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▆▆▄▅▆▆▆▆▆▆▇▇▇▇▆▇█▇▇██▇██▇▇▇▇▇██████████
# wandb:       Val/Loss █▂▃▄▄▄▂▅▃▂▃▃▄▃▂▂▂▂▂▁▂▂▁▁▂▂▂▁▁▁▁▂▂▂▁▁▁▂▂▂
# wandb:
# wandb: Run summary:
# wandb:          Epoch 66
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.73416
# wandb:     Train/Loss 1.2577
# wandb:   Val/Accuracy 0.68264
# wandb:       Val/Loss 1.4084
# wandb:
# wandb: 🚀 View run vgg_resnet_attention_13042026_0904 at: https://wandb.ai/phucga15062005/FER2013/runs/v58poq8z
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_090436-v58poq8z/logs
#
# 		DONE!
