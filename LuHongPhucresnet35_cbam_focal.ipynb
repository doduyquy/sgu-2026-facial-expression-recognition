# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 6

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2017, done.
# remote: Counting objects: 100% (385/385), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 2017 (delta 280), reused 218 (delta 162), pack-reused 1632 (from 1)
# Receiving objects: 100% (2017/2017), 6.29 MiB | 17.14 MiB/s, done.
# Resolving deltas: 100% (1436/1436), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config resnet35_cbam_focal --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: resnet35_cbam_focal_17042026_0542
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=7)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 0gufvkl9 (0.2s)
# wandb: ⣽ setting up run 0gufvkl9 (0.2s)
# wandb: ⣾ setting up run 0gufvkl9 (0.2s)
# wandb: ⣷ setting up run 0gufvkl9 (0.2s)
# wandb: ⣯ setting up run 0gufvkl9 (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_054310-0gufvkl9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_cbam_focal_17042026_0542
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/0gufvkl9
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.3806 - accuracy: 0.2029 - val_loss: 1.2627 - val_accuracy: 0.2887
# 	--- Save best at ep 1, val_loss: 1.2627, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 2/100 - loss: 1.2207 - accuracy: 0.3241 - val_loss: 1.1026 - val_accuracy: 0.3121
# 	--- Save best at ep 2, val_loss: 1.1026, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 3/100 - loss: 1.1135 - accuracy: 0.3784 - val_loss: 0.9996 - val_accuracy: 0.4344
# 	--- Save best at ep 3, val_loss: 0.9996, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 4/100 - loss: 1.0294 - accuracy: 0.4145 - val_loss: 0.9523 - val_accuracy: 0.4544
# 	--- Save best at ep 4, val_loss: 0.9523, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 5/100 - loss: 0.9816 - accuracy: 0.4304 - val_loss: 0.9912 - val_accuracy: 0.3842
# 	-!- No improvement: 1/20
# Epoch 6/100 - loss: 0.9399 - accuracy: 0.4552 - val_loss: 0.9060 - val_accuracy: 0.4904
# 	--- Save best at ep 6, val_loss: 0.9060, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 7/100 - loss: 0.8971 - accuracy: 0.4701 - val_loss: 0.9733 - val_accuracy: 0.4918
# 	-!- No improvement: 1/20
# Epoch 8/100 - loss: 0.8712 - accuracy: 0.4795 - val_loss: 0.8578 - val_accuracy: 0.4943
# 	--- Save best at ep 8, val_loss: 0.8578, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 9/100 - loss: 0.8328 - accuracy: 0.4912 - val_loss: 0.8235 - val_accuracy: 0.5099
# 	--- Save best at ep 9, val_loss: 0.8235, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 10/100 - loss: 0.8160 - accuracy: 0.5004 - val_loss: 0.8310 - val_accuracy: 0.5261
# 	-!- No improvement: 1/20
# Epoch 11/100 - loss: 0.7985 - accuracy: 0.5064 - val_loss: 0.7907 - val_accuracy: 0.5291
# 	--- Save best at ep 11, val_loss: 0.7907, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 12/100 - loss: 0.7716 - accuracy: 0.5182 - val_loss: 0.9403 - val_accuracy: 0.5107
# 	-!- No improvement: 1/20
# Epoch 13/100 - loss: 0.7543 - accuracy: 0.5247 - val_loss: 0.8003 - val_accuracy: 0.5249
# 	-!- No improvement: 2/20
# Epoch 14/100 - loss: 0.7400 - accuracy: 0.5309 - val_loss: 0.7884 - val_accuracy: 0.5469
# 	--- Save best at ep 14, val_loss: 0.7884, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 15/100 - loss: 0.7176 - accuracy: 0.5363 - val_loss: 0.7799 - val_accuracy: 0.5255
# 	--- Save best at ep 15, val_loss: 0.7799, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth ---
# Epoch 16/100 - loss: 0.7024 - accuracy: 0.5374 - val_loss: 0.7829 - val_accuracy: 0.5386
# 	-!- No improvement: 1/20
# Epoch 17/100 - loss: 0.6840 - accuracy: 0.5493 - val_loss: 0.8104 - val_accuracy: 0.5065
# 	-!- No improvement: 2/20
# Epoch 18/100 - loss: 0.6708 - accuracy: 0.5536 - val_loss: 0.8008 - val_accuracy: 0.5667
# 	-!- No improvement: 3/20
# Epoch 19/100 - loss: 0.6626 - accuracy: 0.5597 - val_loss: 0.9009 - val_accuracy: 0.5598
# 	-!- No improvement: 4/20
# Epoch 20/100 - loss: 0.6392 - accuracy: 0.5704 - val_loss: 0.8032 - val_accuracy: 0.5809
# 	-!- No improvement: 5/20
# Epoch 21/100 - loss: 0.6347 - accuracy: 0.5670 - val_loss: 0.8032 - val_accuracy: 0.5623
# 	-!- No improvement: 6/20
# Epoch 22/100 - loss: 0.6176 - accuracy: 0.5780 - val_loss: 0.8336 - val_accuracy: 0.5704
# 	-!- No improvement: 7/20
# Epoch 23/100 - loss: 0.6101 - accuracy: 0.5844 - val_loss: 0.8235 - val_accuracy: 0.5726
# 	-!- No improvement: 8/20
# Epoch 24/100 - loss: 0.5503 - accuracy: 0.6097 - val_loss: 0.7882 - val_accuracy: 0.6060
# 	-!- No improvement: 9/20
# Epoch 25/100 - loss: 0.5213 - accuracy: 0.6185 - val_loss: 0.7936 - val_accuracy: 0.5809
# 	-!- No improvement: 10/20
# Epoch 26/100 - loss: 0.5186 - accuracy: 0.6259 - val_loss: 0.8191 - val_accuracy: 0.5952
# 	-!- No improvement: 11/20
# Epoch 27/100 - loss: 0.5011 - accuracy: 0.6315 - val_loss: 0.7800 - val_accuracy: 0.6085
# 	-!- No improvement: 12/20
# Epoch 28/100 - loss: 0.4895 - accuracy: 0.6332 - val_loss: 0.8002 - val_accuracy: 0.6138
# 	-!- No improvement: 13/20
# Epoch 29/100 - loss: 0.4708 - accuracy: 0.6450 - val_loss: 0.8234 - val_accuracy: 0.6021
# 	-!- No improvement: 14/20
# Epoch 30/100 - loss: 0.4729 - accuracy: 0.6454 - val_loss: 0.8065 - val_accuracy: 0.6121
# 	-!- No improvement: 15/20
# Epoch 31/100 - loss: 0.4627 - accuracy: 0.6505 - val_loss: 0.8566 - val_accuracy: 0.6239
# 	-!- No improvement: 16/20
# Epoch 32/100 - loss: 0.4263 - accuracy: 0.6672 - val_loss: 0.8679 - val_accuracy: 0.6205
# 	-!- No improvement: 17/20
# Epoch 33/100 - loss: 0.4092 - accuracy: 0.6754 - val_loss: 0.8380 - val_accuracy: 0.6169
# 	-!- No improvement: 18/20
# Epoch 34/100 - loss: 0.4002 - accuracy: 0.6785 - val_loss: 0.8965 - val_accuracy: 0.6199
# 	-!- No improvement: 19/20
# Epoch 35/100 - loss: 0.3873 - accuracy: 0.6849 - val_loss: 0.9041 - val_accuracy: 0.6177
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=35
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_resnet35_cbam_focal_17042026_0542.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_cbam_focal_17042026_0542_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:02<00:00, 19.56it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 53.61%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.404891  0.303462  0.346915   491.000000
# disgust        0.180000  0.818182  0.295082    55.000000
# fear           0.288462  0.113636  0.163043   528.000000
# happy          0.819512  0.764505  0.791054   879.000000
# sad            0.409619  0.415825  0.412698   594.000000
# surprise       0.666667  0.769231  0.714286   416.000000
# neutral        0.501163  0.688498  0.580081   626.000000
# accuracy       0.536082  0.536082  0.536082     0.536082
# macro avg      0.467188  0.553334  0.471880  3589.000000
# weighted avg   0.533780  0.536082  0.521985  3589.000000
# --> Grad-CAM Heatmap Active: Layer-4 Hooked!
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5334728..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5019685..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5141129..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4958506..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49015746..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.787037..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45744678..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45476186..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49215686..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.34663865..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0282258..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.57954544..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5883838..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6960784..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5691964..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41764706..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.46169353..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.48353907..1.0].
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_cbam_focal_17042026_0542_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.5s)
# wandb: ⣯ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.5s)
# wandb: ⣟ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.5s)
# wandb: ⡿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.5s)
# wandb: ⢿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (0.5s)
# wandb: ⣻ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.0s)
# wandb:   ↳ ⣻ resnet35_cbam_focal_17042026_0542_best.pth 1.1MB/83.4MB (0.1s)
# wandb: ⣽ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.0s)
# wandb:   ↳ ⣽ resnet35_cbam_focal_17042026_0542_best.pth 1.1MB/83.4MB (0.1s)
# wandb: ⣾ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.0s)
# wandb:   ↳ ⣾ resnet35_cbam_focal_17042026_0542_best.pth 1.1MB/83.4MB (0.1s)
# wandb: ⣷ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.0s)
# wandb:   ↳ ⣷ resnet35_cbam_focal_17042026_0542_best.pth 1.1MB/83.4MB (0.1s)
# wandb: ⣯ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.0s)
# wandb:   ↳ ⣯ resnet35_cbam_focal_17042026_0542_best.pth 1.1MB/83.4MB (0.1s)
# wandb: ⣟ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.5s)
# wandb:   ↳ ⣟ resnet35_cbam_focal_17042026_0542_best.pth 55.2MB/83.4MB (0.6s)
# wandb: ⡿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.5s)
# wandb:   ↳ ⡿ resnet35_cbam_focal_17042026_0542_best.pth 55.2MB/83.4MB (0.6s)
# wandb: ⢿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.5s)
# wandb:   ↳ ⢿ resnet35_cbam_focal_17042026_0542_best.pth 55.2MB/83.4MB (0.6s)
# wandb: ⣻ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.5s)
# wandb:   ↳ ⣻ resnet35_cbam_focal_17042026_0542_best.pth 55.2MB/83.4MB (0.6s)
# wandb: ⣽ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (1.5s)
# wandb:   ↳ ⣽ resnet35_cbam_focal_17042026_0542_best.pth 55.2MB/83.4MB (0.6s)
# wandb: ⣾ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.0s)
# wandb: ⣷ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.0s)
# wandb: ⣯ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.0s)
# wandb: ⣟ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.0s)
# wandb: ⡿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.0s)
# wandb: ⢿ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.5s)
# wandb: ⢿ uploading history steps 33-37, summary, console lines 71-124 (0.1s)
# wandb: ⣻ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.5s)
# wandb: ⣻ uploading history steps 33-37, summary, console lines 71-124 (0.1s)
# wandb: ⣽ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.5s)
# wandb: ⣽ uploading history steps 33-37, summary, console lines 71-124 (0.1s)
# wandb: ⣾ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.5s)
# wandb: ⣾ uploading history steps 33-37, summary, console lines 71-124 (0.1s)
# wandb: ⣷ uploading artifact resnet35_cbam_focal_17042026_0542_0gufvkl9 (2.5s)
# wandb: ⣷ uploading history steps 33-37, summary, console lines 71-124 (0.1s)
# wandb: ⣯ uploading data (0.3s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ███████████████████████▃▃▃▃▃▃▃▃▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████
# wandb:     Train/Loss █▇▆▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:   Val/Accuracy ▁▁▄▄▃▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇█▇▇█████████
# wandb:       Val/Loss █▆▄▄▄▃▄▂▂▂▁▃▁▁▁▁▁▁▃▁▁▂▂▁▁▂▁▁▂▁▂▂▂▃▃
# wandb:
# wandb: Run summary:
# wandb:          Epoch 35
# wandb:  Learning_Rate 0.00017
# wandb: Train/Accuracy 0.68491
# wandb:     Train/Loss 0.38726
# wandb:   Val/Accuracy 0.61772
# wandb:       Val/Loss 0.9041
# wandb:
# wandb: 🚀 View run resnet35_cbam_focal_17042026_0542 at: https://wandb.ai/phucga15062005/FER2013/runs/0gufvkl9
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 4 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_054310-0gufvkl9/logs
#
# 		DONE!
