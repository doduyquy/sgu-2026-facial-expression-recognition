# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1038, done.
# remote: Counting objects: 100% (287/287), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 1038 (delta 215), reused 181 (delta 136), pack-reused 751 (from 2)
# Receiving objects: 100% (1038/1038), 5.93 MiB | 37.23 MiB/s, done.
# Resolving deltas: 100% (655/655), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config vgg_transformer_v2 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 077j6n5d (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_155014-077j6n5d
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_transformer_v2_10042026_1550
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/077j6n5d
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.7766 - accuracy: 0.2654 - val_loss: 1.6867 - val_accuracy: 0.3302
# 	--- Save best at ep 1, val_loss: 1.6867, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 2/100 - loss: 1.5623 - accuracy: 0.3881 - val_loss: 1.6173 - val_accuracy: 0.4146
# 	--- Save best at ep 2, val_loss: 1.6173, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 3/100 - loss: 1.4524 - accuracy: 0.4403 - val_loss: 1.3412 - val_accuracy: 0.4870
# 	--- Save best at ep 3, val_loss: 1.3412, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 4/100 - loss: 1.3784 - accuracy: 0.4687 - val_loss: 1.3273 - val_accuracy: 0.5099
# 	--- Save best at ep 4, val_loss: 1.3273, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 5/100 - loss: 1.3225 - accuracy: 0.4957 - val_loss: 1.3131 - val_accuracy: 0.5010
# 	--- Save best at ep 5, val_loss: 1.3131, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 6/100 - loss: 1.2852 - accuracy: 0.5095 - val_loss: 1.2279 - val_accuracy: 0.5263
# 	--- Save best at ep 6, val_loss: 1.2279, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 7/100 - loss: 1.2526 - accuracy: 0.5233 - val_loss: 1.2619 - val_accuracy: 0.5230
# 	-!- No improvement: 1/20
# Epoch 8/100 - loss: 1.2240 - accuracy: 0.5334 - val_loss: 1.1898 - val_accuracy: 0.5500
# 	--- Save best at ep 8, val_loss: 1.1898, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 9/100 - loss: 1.2001 - accuracy: 0.5411 - val_loss: 1.1481 - val_accuracy: 0.5731
# 	--- Save best at ep 9, val_loss: 1.1481, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 10/100 - loss: 1.1777 - accuracy: 0.5492 - val_loss: 1.1686 - val_accuracy: 0.5606
# 	-!- No improvement: 1/20
# Epoch 11/100 - loss: 1.1674 - accuracy: 0.5569 - val_loss: 1.1493 - val_accuracy: 0.5698
# 	-!- No improvement: 2/20
# Epoch 12/100 - loss: 1.1462 - accuracy: 0.5659 - val_loss: 1.1003 - val_accuracy: 0.5804
# 	--- Save best at ep 12, val_loss: 1.1003, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 13/100 - loss: 1.1300 - accuracy: 0.5698 - val_loss: 1.1105 - val_accuracy: 0.5790
# 	-!- No improvement: 1/20
# Epoch 14/100 - loss: 1.1197 - accuracy: 0.5757 - val_loss: 1.0971 - val_accuracy: 0.5846
# 	--- Save best at ep 14, val_loss: 1.0971, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 15/100 - loss: 1.1109 - accuracy: 0.5795 - val_loss: 1.0916 - val_accuracy: 0.5904
# 	--- Save best at ep 15, val_loss: 1.0916, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 16/100 - loss: 1.0961 - accuracy: 0.5851 - val_loss: 1.0934 - val_accuracy: 0.5868
# 	-!- No improvement: 1/20
# Epoch 17/100 - loss: 1.0869 - accuracy: 0.5865 - val_loss: 1.0688 - val_accuracy: 0.5993
# 	--- Save best at ep 17, val_loss: 1.0688, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 18/100 - loss: 1.0755 - accuracy: 0.5921 - val_loss: 1.0468 - val_accuracy: 0.6013
# 	--- Save best at ep 18, val_loss: 1.0468, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 19/100 - loss: 1.0625 - accuracy: 0.6001 - val_loss: 1.0416 - val_accuracy: 0.6038
# 	--- Save best at ep 19, val_loss: 1.0416, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 20/100 - loss: 1.0508 - accuracy: 0.6036 - val_loss: 1.0308 - val_accuracy: 0.6102
# 	--- Save best at ep 20, val_loss: 1.0308, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 21/100 - loss: 1.0439 - accuracy: 0.6044 - val_loss: 1.0588 - val_accuracy: 0.6099
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 1.0332 - accuracy: 0.6085 - val_loss: 1.0016 - val_accuracy: 0.6172
# 	--- Save best at ep 22, val_loss: 1.0016, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 23/100 - loss: 1.0247 - accuracy: 0.6122 - val_loss: 1.0185 - val_accuracy: 0.6297
# 	-!- No improvement: 1/20
# Epoch 24/100 - loss: 1.0124 - accuracy: 0.6189 - val_loss: 1.0062 - val_accuracy: 0.6283
# 	-!- No improvement: 2/20
# Epoch 25/100 - loss: 1.0106 - accuracy: 0.6178 - val_loss: 1.0223 - val_accuracy: 0.6186
# 	-!- No improvement: 3/20
# Epoch 26/100 - loss: 1.0018 - accuracy: 0.6222 - val_loss: 1.0330 - val_accuracy: 0.6135
# 	-!- No improvement: 4/20
# Epoch 27/100 - loss: 0.9672 - accuracy: 0.6358 - val_loss: 0.9882 - val_accuracy: 0.6289
# 	--- Save best at ep 27, val_loss: 0.9882, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 28/100 - loss: 0.9546 - accuracy: 0.6421 - val_loss: 0.9896 - val_accuracy: 0.6367
# 	-!- No improvement: 1/20
# Epoch 29/100 - loss: 0.9506 - accuracy: 0.6426 - val_loss: 0.9836 - val_accuracy: 0.6350
# 	--- Save best at ep 29, val_loss: 0.9836, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 30/100 - loss: 0.9458 - accuracy: 0.6434 - val_loss: 0.9638 - val_accuracy: 0.6509
# 	--- Save best at ep 30, val_loss: 0.9638, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 31/100 - loss: 0.9379 - accuracy: 0.6447 - val_loss: 0.9918 - val_accuracy: 0.6342
# 	-!- No improvement: 1/20
# Epoch 32/100 - loss: 0.9324 - accuracy: 0.6494 - val_loss: 0.9948 - val_accuracy: 0.6375
# 	-!- No improvement: 2/20
# Epoch 33/100 - loss: 0.9278 - accuracy: 0.6520 - val_loss: 0.9826 - val_accuracy: 0.6453
# 	-!- No improvement: 3/20
# Epoch 34/100 - loss: 0.9200 - accuracy: 0.6554 - val_loss: 0.9726 - val_accuracy: 0.6459
# 	-!- No improvement: 4/20
# Epoch 35/100 - loss: 0.9063 - accuracy: 0.6586 - val_loss: 0.9601 - val_accuracy: 0.6475
# 	--- Save best at ep 35, val_loss: 0.9601, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 36/100 - loss: 0.8953 - accuracy: 0.6642 - val_loss: 0.9560 - val_accuracy: 0.6551
# 	--- Save best at ep 36, val_loss: 0.9560, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 37/100 - loss: 0.8891 - accuracy: 0.6631 - val_loss: 0.9613 - val_accuracy: 0.6506
# 	-!- No improvement: 1/20
# Epoch 38/100 - loss: 0.8803 - accuracy: 0.6701 - val_loss: 0.9576 - val_accuracy: 0.6517
# 	-!- No improvement: 2/20
# Epoch 39/100 - loss: 0.8824 - accuracy: 0.6699 - val_loss: 0.9512 - val_accuracy: 0.6525
# 	--- Save best at ep 39, val_loss: 0.9512, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 40/100 - loss: 0.8845 - accuracy: 0.6675 - val_loss: 0.9556 - val_accuracy: 0.6500
# 	-!- No improvement: 1/20
# Epoch 41/100 - loss: 0.8808 - accuracy: 0.6708 - val_loss: 0.9759 - val_accuracy: 0.6512
# 	-!- No improvement: 2/20
# Epoch 42/100 - loss: 0.8759 - accuracy: 0.6730 - val_loss: 0.9546 - val_accuracy: 0.6573
# 	-!- No improvement: 3/20
# Epoch 43/100 - loss: 0.8691 - accuracy: 0.6749 - val_loss: 0.9677 - val_accuracy: 0.6517
# 	-!- No improvement: 4/20
# Epoch 44/100 - loss: 0.8606 - accuracy: 0.6783 - val_loss: 0.9510 - val_accuracy: 0.6553
# 	--- Save best at ep 44, val_loss: 0.9510, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 45/100 - loss: 0.8570 - accuracy: 0.6805 - val_loss: 0.9481 - val_accuracy: 0.6601
# 	--- Save best at ep 45, val_loss: 0.9481, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 46/100 - loss: 0.8484 - accuracy: 0.6824 - val_loss: 0.9562 - val_accuracy: 0.6556
# 	-!- No improvement: 1/20
# Epoch 47/100 - loss: 0.8534 - accuracy: 0.6791 - val_loss: 0.9469 - val_accuracy: 0.6581
# 	--- Save best at ep 47, val_loss: 0.9469, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 48/100 - loss: 0.8498 - accuracy: 0.6810 - val_loss: 0.9516 - val_accuracy: 0.6601
# 	-!- No improvement: 1/20
# Epoch 49/100 - loss: 0.8514 - accuracy: 0.6828 - val_loss: 0.9531 - val_accuracy: 0.6578
# 	-!- No improvement: 2/20
# Epoch 50/100 - loss: 0.8484 - accuracy: 0.6861 - val_loss: 0.9413 - val_accuracy: 0.6617
# 	--- Save best at ep 50, val_loss: 0.9413, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth ---
# Epoch 51/100 - loss: 0.8446 - accuracy: 0.6848 - val_loss: 0.9586 - val_accuracy: 0.6553
# 	-!- No improvement: 1/20
# Epoch 52/100 - loss: 0.8409 - accuracy: 0.6827 - val_loss: 0.9487 - val_accuracy: 0.6626
# 	-!- No improvement: 2/20
# Epoch 53/100 - loss: 0.8441 - accuracy: 0.6817 - val_loss: 0.9471 - val_accuracy: 0.6567
# 	-!- No improvement: 3/20
# Epoch 54/100 - loss: 0.8429 - accuracy: 0.6863 - val_loss: 0.9463 - val_accuracy: 0.6567
# 	-!- No improvement: 4/20
# Epoch 55/100 - loss: 0.8329 - accuracy: 0.6885 - val_loss: 0.9419 - val_accuracy: 0.6609
# 	-!- No improvement: 5/20
# Epoch 56/100 - loss: 0.8307 - accuracy: 0.6881 - val_loss: 0.9441 - val_accuracy: 0.6598
# 	-!- No improvement: 6/20
# Epoch 57/100 - loss: 0.8321 - accuracy: 0.6881 - val_loss: 0.9499 - val_accuracy: 0.6584
# 	-!- No improvement: 7/20
# Epoch 58/100 - loss: 0.8288 - accuracy: 0.6914 - val_loss: 0.9448 - val_accuracy: 0.6617
# 	-!- No improvement: 8/20
# Epoch 59/100 - loss: 0.8254 - accuracy: 0.6917 - val_loss: 0.9484 - val_accuracy: 0.6587
# 	-!- No improvement: 9/20
# Epoch 60/100 - loss: 0.8253 - accuracy: 0.6904 - val_loss: 0.9493 - val_accuracy: 0.6573
# 	-!- No improvement: 10/20
# Epoch 61/100 - loss: 0.8269 - accuracy: 0.6925 - val_loss: 0.9446 - val_accuracy: 0.6595
# 	-!- No improvement: 11/20
# Epoch 62/100 - loss: 0.8235 - accuracy: 0.6925 - val_loss: 0.9481 - val_accuracy: 0.6592
# 	-!- No improvement: 12/20
# Epoch 63/100 - loss: 0.8206 - accuracy: 0.6903 - val_loss: 0.9465 - val_accuracy: 0.6606
# 	-!- No improvement: 13/20
# Epoch 64/100 - loss: 0.8230 - accuracy: 0.6933 - val_loss: 0.9510 - val_accuracy: 0.6606
# 	-!- No improvement: 14/20
# Epoch 65/100 - loss: 0.8260 - accuracy: 0.6919 - val_loss: 0.9428 - val_accuracy: 0.6609
# 	-!- No improvement: 15/20
# Epoch 66/100 - loss: 0.8250 - accuracy: 0.6914 - val_loss: 0.9457 - val_accuracy: 0.6598
# 	-!- No improvement: 16/20
# Epoch 67/100 - loss: 0.8227 - accuracy: 0.6930 - val_loss: 0.9474 - val_accuracy: 0.6623
# 	-!- No improvement: 17/20
# Epoch 68/100 - loss: 0.8183 - accuracy: 0.6927 - val_loss: 0.9484 - val_accuracy: 0.6612
# 	-!- No improvement: 18/20
# Epoch 69/100 - loss: 0.8194 - accuracy: 0.6915 - val_loss: 0.9480 - val_accuracy: 0.6623
# 	-!- No improvement: 19/20
# Epoch 70/100 - loss: 0.8198 - accuracy: 0.6936 - val_loss: 0.9487 - val_accuracy: 0.6609
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=70
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_transformer_v2/vgg_transformer_v2_10042026_1550_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 42.97it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.46%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.627957  0.594705  0.610879   491.000000
# disgust        0.730769  0.690909  0.710280    55.000000
# fear           0.566860  0.369318  0.447248   528.000000
# happy          0.863886  0.895336  0.879330   879.000000
# sad            0.534483  0.521886  0.528109   594.000000
# surprise       0.765909  0.810096  0.787383   416.000000
# neutral        0.579674  0.738019  0.649332   626.000000
# accuracy       0.674561  0.674561  0.674561     0.674561
# macro avg      0.667077  0.660038  0.658937  3589.000000
# weighted avg   0.670425  0.674561  0.667544  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_transformer_v2_10042026_1550_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_077j6n5d (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_077j6n5d (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_077j6n5d (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_077j6n5d (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_077j6n5d (0.5s)
# wandb: ⣯ uploading artifact cnn_077j6n5d (0.5s)
# wandb: ⣟ uploading artifact cnn_077j6n5d (0.5s)
# wandb: ⡿ uploading artifact cnn_077j6n5d (0.5s)
# wandb: ⢿ uploading artifact cnn_077j6n5d (0.5s)
# wandb: ⣻ uploading artifact cnn_077j6n5d (1.0s)
# wandb:   ↳ ⣻ vgg_transformer_v2_10042026_1550_best.pth 1.1MB/144.0MB (0.0s)
# wandb: ⣽ uploading artifact cnn_077j6n5d (1.0s)
# wandb:   ↳ ⣽ vgg_transformer_v2_10042026_1550_best.pth 1.1MB/144.0MB (0.0s)
# wandb: ⣾ uploading artifact cnn_077j6n5d (1.0s)
# wandb:   ↳ ⣾ vgg_transformer_v2_10042026_1550_best.pth 1.1MB/144.0MB (0.0s)
# wandb: ⣷ uploading artifact cnn_077j6n5d (1.0s)
# wandb:   ↳ ⣷ vgg_transformer_v2_10042026_1550_best.pth 1.1MB/144.0MB (0.0s)
# wandb: ⣯ uploading artifact cnn_077j6n5d (1.0s)
# wandb:   ↳ ⣯ vgg_transformer_v2_10042026_1550_best.pth 1.1MB/144.0MB (0.0s)
# wandb: ⣟ uploading artifact cnn_077j6n5d (1.5s)
# wandb:   ↳ ⣟ vgg_transformer_v2_10042026_1550_best.pth 46.8MB/144.0MB (0.5s)
# wandb: ⡿ uploading artifact cnn_077j6n5d (1.5s)
# wandb:   ↳ ⡿ vgg_transformer_v2_10042026_1550_best.pth 46.8MB/144.0MB (0.5s)
# wandb: ⢿ uploading artifact cnn_077j6n5d (1.5s)
# wandb:   ↳ ⢿ vgg_transformer_v2_10042026_1550_best.pth 46.8MB/144.0MB (0.5s)
# wandb: ⣻ uploading artifact cnn_077j6n5d (1.5s)
# wandb:   ↳ ⣻ vgg_transformer_v2_10042026_1550_best.pth 46.8MB/144.0MB (0.5s)
# wandb: ⣽ uploading artifact cnn_077j6n5d (1.5s)
# wandb:   ↳ ⣽ vgg_transformer_v2_10042026_1550_best.pth 46.8MB/144.0MB (0.5s)
# wandb: ⣾ uploading artifact cnn_077j6n5d (2.0s)
# wandb:   ↳ ⣾ vgg_transformer_v2_10042026_1550_best.pth 109.8MB/144.0MB (1.0s)
# wandb: ⣷ uploading artifact cnn_077j6n5d (2.0s)
# wandb:   ↳ ⣷ vgg_transformer_v2_10042026_1550_best.pth 109.8MB/144.0MB (1.0s)
# wandb: ⣯ uploading artifact cnn_077j6n5d (2.0s)
# wandb:   ↳ ⣯ vgg_transformer_v2_10042026_1550_best.pth 109.8MB/144.0MB (1.0s)
# wandb: ⣟ uploading artifact cnn_077j6n5d (2.0s)
# wandb:   ↳ ⣟ vgg_transformer_v2_10042026_1550_best.pth 109.8MB/144.0MB (1.0s)
# wandb: ⡿ uploading artifact cnn_077j6n5d (2.0s)
# wandb:   ↳ ⡿ vgg_transformer_v2_10042026_1550_best.pth 109.8MB/144.0MB (1.0s)
# wandb: ⢿ uploading artifact cnn_077j6n5d (2.5s)
# wandb:   ↳ ⢿ vgg_transformer_v2_10042026_1550_best.pth 144.0MB/144.0MB (1.6s)
# wandb: ⢿ uploading media/images/Evaluation/Confusion_Matrix_69_42b4fdcda8406c...
# wandb: ⢿ uploading media/images/Evaluation/Correct_Samples_70_997d1936e6055f2...
# wandb: ⢿ uploading output.log 13.7KB/13.7KB (0.1s)
# wandb: + 2 more task(s)
# wandb: ⣻ uploading artifact cnn_077j6n5d (2.5s)
# wandb:   ↳ ⣻ vgg_transformer_v2_10042026_1550_best.pth 144.0MB/144.0MB (1.6s)
# wandb: ⣻ uploading media/images/Evaluation/Confusion_Matrix_69_42b4fdcda8406c...
# wandb: ⣻ uploading media/images/Evaluation/Correct_Samples_70_997d1936e6055f2...
# wandb: ⣻ uploading output.log 13.7KB/13.7KB (0.1s)
# wandb: + 2 more task(s)
# wandb: ⣽ uploading artifact cnn_077j6n5d (2.5s)
# wandb:   ↳ ⣽ vgg_transformer_v2_10042026_1550_best.pth 144.0MB/144.0MB (1.6s)
# wandb: ⣽ uploading media/images/Evaluation/Confusion_Matrix_69_42b4fdcda8406c...
# wandb: ⣽ uploading media/images/Evaluation/Correct_Samples_70_997d1936e6055f2...
# wandb: ⣽ uploading output.log 13.7KB/13.7KB (0.1s)
# wandb: + 2 more task(s)
# wandb: ⣾ uploading artifact cnn_077j6n5d (2.5s)
# wandb:   ↳ ⣾ vgg_transformer_v2_10042026_1550_best.pth 144.0MB/144.0MB (1.6s)
# wandb: ⣾ uploading media/images/Evaluation/Confusion_Matrix_69_42b4fdcda8406c...
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_70_997d1936e6055f2...
# wandb: ⣾ uploading output.log 13.7KB/13.7KB (0.1s)
# wandb: + 2 more task(s)
# wandb: ⣷ uploading artifact cnn_077j6n5d (2.5s)
# wandb:   ↳ ⣷ vgg_transformer_v2_10042026_1550_best.pth 144.0MB/144.0MB (1.6s)
# wandb: ⣷ uploading media/images/Evaluation/Confusion_Matrix_69_42b4fdcda8406c...
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_70_997d1936e6055f2...
# wandb: ⣷ uploading output.log 13.7KB/13.7KB (0.1s)
# wandb: + 2 more task(s)
# wandb: ⣯ uploading artifact cnn_077j6n5d (3.0s)
# wandb: ⣟ uploading artifact cnn_077j6n5d (3.0s)
# wandb: ⡿ uploading artifact cnn_077j6n5d (3.0s)
# wandb: ⢿ uploading artifact cnn_077j6n5d (3.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███
# wandb:  Learning_Rate ██████████████▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████
# wandb:     Train/Loss █▆▆▅▅▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████
# wandb:       Val/Loss █▅▅▄▄▃▂▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 70
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.69362
# wandb:     Train/Loss 0.81985
# wandb:   Val/Accuracy 0.66091
# wandb:       Val/Loss 0.9487
# wandb:
# wandb: 🚀 View run vgg_transformer_v2_10042026_1550 at: https://wandb.ai/phucga15062005/FER2013/runs/077j6n5d
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_155014-077j6n5d/logs
#
# 		DONE!
