# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 8095

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "image-captioning-flickr8k-iu"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'image-captioning-flickr8k-iu'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 152 (delta 64), reused 120 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 38.92 KiB | 2.59 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# Repo ready: /kaggle/working/image-captioning-flickr8k-iu
#
# Current working dir: /kaggle/working/image-captioning-flickr8k-iu

# %%
# !python -m scripts.train --config transformer --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Image Dir: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/images
# --> Captions File: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/captions.txt
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 140MB/s]
# --> [Scheduler] StepLR (step_size=5, gamma=0.5)
#
# --> Train on 30000 samples, validate on 5000 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run loontecf (0.3s)
# wandb: ⣾ setting up run loontecf (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/image-captioning-flickr8k-iu/wandb/run-20260408_034933-loontecf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_08042026_0348
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/image-captioning
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/image-captioning/runs/loontecf
#
# --> Start training in total 50 epochs with cuda device. Start...
#
# Epoch 1/50 - loss: 3.4445 - val_loss: 2.9894
# 	--- Save best at ep 1, val_loss: 2.9894, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 2/50 - loss: 2.7166 - val_loss: 2.7678
# 	--- Save best at ep 2, val_loss: 2.7678, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 3/50 - loss: 2.4575 - val_loss: 2.6903
# 	--- Save best at ep 3, val_loss: 2.6903, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 4/50 - loss: 2.2826 - val_loss: 2.6510
# 	--- Save best at ep 4, val_loss: 2.6510, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 5/50 - loss: 2.1460 - val_loss: 2.6378
# 	--- Save best at ep 5, val_loss: 2.6378, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 6/50 - loss: 1.9623 - val_loss: 2.6214
# 	--- Save best at ep 6, val_loss: 2.6214, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0348_best.pth ---
# Epoch 7/50 - loss: 1.8908 - val_loss: 2.6368
# 	-!- No improvement: 1/10
# Epoch 8/50 - loss: 1.8339 - val_loss: 2.6442
# 	-!- No improvement: 2/10
# Epoch 9/50 - loss: 1.7801 - val_loss: 2.6577
# 	-!- No improvement: 3/10
# Epoch 10/50 - loss: 1.7289 - val_loss: 2.6783
# 	-!- No improvement: 4/10
# Epoch 11/50 - loss: 1.6339 - val_loss: 2.6887
# 	-!- No improvement: 5/10
# Epoch 12/50 - loss: 1.6021 - val_loss: 2.7054
# 	-!- No improvement: 6/10
# Epoch 13/50 - loss: 1.5758 - val_loss: 2.7205
# 	-!- No improvement: 7/10
# Epoch 14/50 - loss: 1.5511 - val_loss: 2.7329
# 	-!- No improvement: 8/10
# Epoch 15/50 - loss: 1.5258 - val_loss: 2.7537
# 	-!- No improvement: 9/10
# Epoch 16/50 - loss: 1.4759 - val_loss: 2.7635
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=16
#
# ===================================================
# Evaluate on Test set
# ===================================================
# --> [Evaluation] Đang đánh giá trên 5000 mẫu (greedy)...
#   0%|                                                   | 0/157 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/train.py", line 129, in <module>
#     main()
#   File "/kaggle/working/image-captioning-flickr8k-iu/scripts/train.py", line 110, in main
#     evaluate_model(model, test_loader, vocab, device, method='greedy')
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/evaluation/evaluator.py", line 27, in evaluate_model
#     pred_tokens = model.generate(img, vocab, method=method, beam_size=beam_size, max_len=max_len, device=device)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/image-captioning-flickr8k-iu/src/models/transformer.py", line 67, in generate
#     return self._greedy_decode(images, vocab, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: TransformerCaptionModel._greedy_decode() got an unexpected keyword argument 'beam_size'
# wandb:
# wandb: 🚀 View run transformer_08042026_0348 at: https://wandb.ai/phucga15062005/image-captioning/runs/loontecf
# wandb: Find logs at: wandb/run-20260408_034933-loontecf/logs
