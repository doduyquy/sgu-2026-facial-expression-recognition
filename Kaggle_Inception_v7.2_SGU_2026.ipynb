# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "TreeV2"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1276, done.
# remote: Counting objects: 100% (249/249), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 1276 (delta 177), reused 150 (delta 108), pack-reused 1027 (from 1)
# Receiving objects: 100% (1276/1276), 6.04 MiB | 23.50 MiB/s, done.
# Resolving deltas: 100% (851/851), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config inception --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run ccd4azio (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_062428-ccd4azio
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run inception_13042026_0624
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/ccd4azio
#
# --> Start training in total 101 epochs with cuda device. Start...
#
# Epoch 1/101 - loss: 1.7123 - accuracy: 0.2999 - val_loss: 1.8819 - val_accuracy: 0.3291
# 	--- Save best at ep 1, val_loss: 1.8819, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 2/101 - loss: 1.4725 - accuracy: 0.4252 - val_loss: 1.4139 - val_accuracy: 0.4500
# 	--- Save best at ep 2, val_loss: 1.4139, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 3/101 - loss: 1.3579 - accuracy: 0.4746 - val_loss: 1.4273 - val_accuracy: 0.4500
# 	-!- No improvement: 1/20
# Epoch 4/101 - loss: 1.2848 - accuracy: 0.5031 - val_loss: 1.2874 - val_accuracy: 0.5001
# 	--- Save best at ep 4, val_loss: 1.2874, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 5/101 - loss: 1.2326 - accuracy: 0.5255 - val_loss: 1.2700 - val_accuracy: 0.5032
# 	--- Save best at ep 5, val_loss: 1.2700, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 6/101 - loss: 1.1851 - accuracy: 0.5451 - val_loss: 1.2589 - val_accuracy: 0.5302
# 	--- Save best at ep 6, val_loss: 1.2589, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 7/101 - loss: 1.1523 - accuracy: 0.5564 - val_loss: 1.3338 - val_accuracy: 0.5235
# 	-!- No improvement: 1/20
# Epoch 8/101 - loss: 1.1234 - accuracy: 0.5727 - val_loss: 1.1546 - val_accuracy: 0.5620
# 	--- Save best at ep 8, val_loss: 1.1546, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 9/101 - loss: 1.0985 - accuracy: 0.5835 - val_loss: 1.1070 - val_accuracy: 0.5823
# 	--- Save best at ep 9, val_loss: 1.1070, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 10/101 - loss: 1.0770 - accuracy: 0.5907 - val_loss: 1.2723 - val_accuracy: 0.5341
# 	-!- No improvement: 1/20
# Epoch 11/101 - loss: 1.0590 - accuracy: 0.5977 - val_loss: 1.1017 - val_accuracy: 0.5887
# 	--- Save best at ep 11, val_loss: 1.1017, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 12/101 - loss: 1.0436 - accuracy: 0.6035 - val_loss: 1.1154 - val_accuracy: 0.5807
# 	-!- No improvement: 1/20
# Epoch 13/101 - loss: 1.0284 - accuracy: 0.6098 - val_loss: 1.0607 - val_accuracy: 0.6016
# 	--- Save best at ep 13, val_loss: 1.0607, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 14/101 - loss: 1.0137 - accuracy: 0.6148 - val_loss: 1.0865 - val_accuracy: 0.5965
# 	-!- No improvement: 1/20
# Epoch 15/101 - loss: 1.0021 - accuracy: 0.6216 - val_loss: 1.1884 - val_accuracy: 0.5701
# 	-!- No improvement: 2/20
# Epoch 16/101 - loss: 0.9897 - accuracy: 0.6287 - val_loss: 1.1274 - val_accuracy: 0.5807
# 	-!- No improvement: 3/20
# Epoch 17/101 - loss: 0.9798 - accuracy: 0.6293 - val_loss: 1.0885 - val_accuracy: 0.5938
# 	-!- No improvement: 4/20
# Epoch 18/101 - loss: 0.9219 - accuracy: 0.6524 - val_loss: 1.0378 - val_accuracy: 0.6119
# 	--- Save best at ep 18, val_loss: 1.0378, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 19/101 - loss: 0.8990 - accuracy: 0.6628 - val_loss: 1.0424 - val_accuracy: 0.6144
# 	-!- No improvement: 1/20
# Epoch 20/101 - loss: 0.8858 - accuracy: 0.6677 - val_loss: 1.0037 - val_accuracy: 0.6225
# 	--- Save best at ep 20, val_loss: 1.0037, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 21/101 - loss: 0.8787 - accuracy: 0.6716 - val_loss: 1.0230 - val_accuracy: 0.6183
# 	-!- No improvement: 1/20
# Epoch 22/101 - loss: 0.8642 - accuracy: 0.6747 - val_loss: 1.0170 - val_accuracy: 0.6144
# 	-!- No improvement: 2/20
# Epoch 23/101 - loss: 0.8531 - accuracy: 0.6802 - val_loss: 1.0077 - val_accuracy: 0.6233
# 	-!- No improvement: 3/20
# Epoch 24/101 - loss: 0.8453 - accuracy: 0.6827 - val_loss: 1.0098 - val_accuracy: 0.6194
# 	-!- No improvement: 4/20
# Epoch 25/101 - loss: 0.7992 - accuracy: 0.6992 - val_loss: 0.9834 - val_accuracy: 0.6450
# 	--- Save best at ep 25, val_loss: 0.9834, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 26/101 - loss: 0.7857 - accuracy: 0.7055 - val_loss: 0.9789 - val_accuracy: 0.6305
# 	--- Save best at ep 26, val_loss: 0.9789, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 27/101 - loss: 0.7691 - accuracy: 0.7123 - val_loss: 0.9793 - val_accuracy: 0.6347
# 	-!- No improvement: 1/20
# Epoch 28/101 - loss: 0.7660 - accuracy: 0.7156 - val_loss: 1.0310 - val_accuracy: 0.6211
# 	-!- No improvement: 2/20
# Epoch 29/101 - loss: 0.7554 - accuracy: 0.7202 - val_loss: 0.9950 - val_accuracy: 0.6389
# 	-!- No improvement: 3/20
# Epoch 30/101 - loss: 0.7463 - accuracy: 0.7228 - val_loss: 0.9751 - val_accuracy: 0.6381
# 	--- Save best at ep 30, val_loss: 0.9751, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth ---
# Epoch 31/101 - loss: 0.7384 - accuracy: 0.7257 - val_loss: 0.9954 - val_accuracy: 0.6325
# 	-!- No improvement: 1/20
# Epoch 32/101 - loss: 0.7226 - accuracy: 0.7316 - val_loss: 1.0572 - val_accuracy: 0.6202
# 	-!- No improvement: 2/20
# Epoch 33/101 - loss: 0.7173 - accuracy: 0.7329 - val_loss: 1.0342 - val_accuracy: 0.6264
# 	-!- No improvement: 3/20
# Epoch 34/101 - loss: 0.7078 - accuracy: 0.7346 - val_loss: 1.0258 - val_accuracy: 0.6439
# 	-!- No improvement: 4/20
# Epoch 35/101 - loss: 0.6710 - accuracy: 0.7517 - val_loss: 1.0049 - val_accuracy: 0.6439
# 	-!- No improvement: 5/20
# Epoch 36/101 - loss: 0.6588 - accuracy: 0.7569 - val_loss: 0.9965 - val_accuracy: 0.6442
# 	-!- No improvement: 6/20
# Epoch 37/101 - loss: 0.6486 - accuracy: 0.7627 - val_loss: 1.0221 - val_accuracy: 0.6445
# 	-!- No improvement: 7/20
# Epoch 38/101 - loss: 0.6385 - accuracy: 0.7648 - val_loss: 1.0071 - val_accuracy: 0.6556
# 	-!- No improvement: 8/20
# Epoch 39/101 - loss: 0.6200 - accuracy: 0.7724 - val_loss: 1.0137 - val_accuracy: 0.6414
# 	-!- No improvement: 9/20
# Epoch 40/101 - loss: 0.6154 - accuracy: 0.7721 - val_loss: 1.0171 - val_accuracy: 0.6481
# 	-!- No improvement: 10/20
# Epoch 41/101 - loss: 0.6043 - accuracy: 0.7787 - val_loss: 1.0259 - val_accuracy: 0.6470
# 	-!- No improvement: 11/20
# Epoch 42/101 - loss: 0.6017 - accuracy: 0.7797 - val_loss: 1.0390 - val_accuracy: 0.6470
# 	-!- No improvement: 12/20
# Epoch 43/101 - loss: 0.5905 - accuracy: 0.7836 - val_loss: 1.0350 - val_accuracy: 0.6489
# 	-!- No improvement: 13/20
# Epoch 44/101 - loss: 0.5840 - accuracy: 0.7861 - val_loss: 1.0521 - val_accuracy: 0.6442
# 	-!- No improvement: 14/20
# Epoch 45/101 - loss: 0.5812 - accuracy: 0.7857 - val_loss: 1.0396 - val_accuracy: 0.6453
# 	-!- No improvement: 15/20
# Epoch 46/101 - loss: 0.5801 - accuracy: 0.7878 - val_loss: 1.0402 - val_accuracy: 0.6478
# 	-!- No improvement: 16/20
# Epoch 47/101 - loss: 0.5735 - accuracy: 0.7918 - val_loss: 1.0370 - val_accuracy: 0.6464
# 	-!- No improvement: 17/20
# Epoch 48/101 - loss: 0.5670 - accuracy: 0.7939 - val_loss: 1.0437 - val_accuracy: 0.6484
# 	-!- No improvement: 18/20
# Epoch 49/101 - loss: 0.5669 - accuracy: 0.7929 - val_loss: 1.0473 - val_accuracy: 0.6467
# 	-!- No improvement: 19/20
# Epoch 50/101 - loss: 0.5637 - accuracy: 0.7957 - val_loss: 1.0450 - val_accuracy: 0.6509
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=50
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0624_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:07<00:00,  7.42it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 66.37%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.600437  0.560081  0.579557   491.000000
# disgust        0.559322  0.600000  0.578947    55.000000
# fear           0.552163  0.410985  0.471227   528.000000
# happy          0.847420  0.878271  0.862570   879.000000
# sad            0.497758  0.560606  0.527316   594.000000
# surprise       0.754673  0.776442  0.765403   416.000000
# neutral        0.639344  0.685304  0.661527   626.000000
# accuracy       0.663695  0.663695  0.663695     0.663695
# macro avg      0.635874  0.638813  0.635221  3589.000000
# weighted avg   0.660865  0.663695  0.660117  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `inception_13042026_0624_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_ccd4azio (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_ccd4azio (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_ccd4azio (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_ccd4azio (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_ccd4azio (0.5s)
# wandb: ⣯ uploading artifact cnn_ccd4azio (0.5s)
# wandb: ⣟ uploading artifact cnn_ccd4azio (0.5s)
# wandb: ⡿ uploading artifact cnn_ccd4azio (0.5s)
# wandb: ⢿ uploading artifact cnn_ccd4azio (0.5s)
# wandb: ⣻ uploading artifact cnn_ccd4azio (1.0s)
# wandb:   ↳ ⣻ inception_13042026_0624_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣽ uploading artifact cnn_ccd4azio (1.0s)
# wandb:   ↳ ⣽ inception_13042026_0624_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣾ uploading artifact cnn_ccd4azio (1.0s)
# wandb:   ↳ ⣾ inception_13042026_0624_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣷ uploading artifact cnn_ccd4azio (1.0s)
# wandb:   ↳ ⣷ inception_13042026_0624_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣯ uploading artifact cnn_ccd4azio (1.0s)
# wandb:   ↳ ⣯ inception_13042026_0624_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣟ uploading artifact cnn_ccd4azio (1.5s)
# wandb: ⡿ uploading artifact cnn_ccd4azio (1.5s)
# wandb: ⢿ uploading artifact cnn_ccd4azio (1.5s)
# wandb: ⣻ uploading artifact cnn_ccd4azio (1.5s)
# wandb: ⣽ uploading artifact cnn_ccd4azio (1.5s)
# wandb: ⣾ uploading history steps 49-51, summary, console lines 127-132 (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ███████████████▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▃▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇███████████
# wandb:     Train/Loss █▇▆▅▅▅▄▄▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▄▅▅▅▆▆▅▇▇▇▆▆▇▇▇▇▇▇█▇█▇█▇▇█████████████
# wandb:       Val/Loss █▄▄▃▃▄▂▂▃▂▂▂▃▂▂▂▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▂▁▂▂
# wandb:
# wandb: Run summary:
# wandb:          Epoch 50
# wandb:  Learning_Rate 2e-05
# wandb: Train/Accuracy 0.79571
# wandb:     Train/Loss 0.56365
# wandb:   Val/Accuracy 0.65088
# wandb:       Val/Loss 1.04495
# wandb:
# wandb: 🚀 View run inception_13042026_0624 at: https://wandb.ai/phucga15062005/FER2013/runs/ccd4azio
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_062428-ccd4azio/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
