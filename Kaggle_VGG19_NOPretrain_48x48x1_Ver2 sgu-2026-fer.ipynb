# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 462, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 462 (delta 76), reused 74 (delta 35), pack-reused 329 (from 1)
# Receiving objects: 100% (462/462), 3.09 MiB | 19.66 MiB/s, done.
# Resolving deltas: 100% (264/264), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x1 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run pwnimsf9 (0.2s)
# wandb: ⣾ setting up run pwnimsf9 (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260404_092637-pwnimsf9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg19_04042026_0926
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/pwnimsf9
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.8782 - accuracy: 0.2208 - val_loss: 1.7422 - val_accuracy: 0.3405
# 	--- Save best at ep 1, val_loss: 1.7422, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 2/100 - loss: 1.7528 - accuracy: 0.3213 - val_loss: 1.6833 - val_accuracy: 0.3472
# 	--- Save best at ep 2, val_loss: 1.6833, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 3/100 - loss: 1.6356 - accuracy: 0.3763 - val_loss: 1.4587 - val_accuracy: 0.4489
# 	--- Save best at ep 3, val_loss: 1.4587, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 4/100 - loss: 1.5245 - accuracy: 0.4195 - val_loss: 1.4975 - val_accuracy: 0.4611
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.4695 - accuracy: 0.4431 - val_loss: 1.3761 - val_accuracy: 0.4784
# 	--- Save best at ep 5, val_loss: 1.3761, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 6/100 - loss: 1.4343 - accuracy: 0.4569 - val_loss: 1.3105 - val_accuracy: 0.4865
# 	--- Save best at ep 6, val_loss: 1.3105, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 7/100 - loss: 1.3967 - accuracy: 0.4741 - val_loss: 1.2810 - val_accuracy: 0.5079
# 	--- Save best at ep 7, val_loss: 1.2810, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 8/100 - loss: 1.3745 - accuracy: 0.4840 - val_loss: 1.2828 - val_accuracy: 0.5166
# 	-!- No improvement: 1/20
# Epoch 9/100 - loss: 1.3428 - accuracy: 0.4931 - val_loss: 1.2763 - val_accuracy: 0.5104
# 	--- Save best at ep 9, val_loss: 1.2763, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 10/100 - loss: 1.3281 - accuracy: 0.5000 - val_loss: 1.2704 - val_accuracy: 0.5091
# 	--- Save best at ep 10, val_loss: 1.2704, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 11/100 - loss: 1.3105 - accuracy: 0.5074 - val_loss: 1.3201 - val_accuracy: 0.4801
# 	-!- No improvement: 1/20
# Epoch 12/100 - loss: 1.2965 - accuracy: 0.5058 - val_loss: 1.3132 - val_accuracy: 0.5266
# 	-!- No improvement: 2/20
# Epoch 13/100 - loss: 1.2819 - accuracy: 0.5120 - val_loss: 1.2224 - val_accuracy: 0.5213
# 	--- Save best at ep 13, val_loss: 1.2224, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 14/100 - loss: 1.2658 - accuracy: 0.5197 - val_loss: 1.2291 - val_accuracy: 0.5528
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 1.2589 - accuracy: 0.5227 - val_loss: 1.1781 - val_accuracy: 0.5531
# 	--- Save best at ep 15, val_loss: 1.1781, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 16/100 - loss: 1.2457 - accuracy: 0.5235 - val_loss: 1.2166 - val_accuracy: 0.5548
# 	-!- No improvement: 1/20
# Epoch 17/100 - loss: 1.2326 - accuracy: 0.5300 - val_loss: 1.1383 - val_accuracy: 0.5798
# 	--- Save best at ep 17, val_loss: 1.1383, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 18/100 - loss: 1.2283 - accuracy: 0.5331 - val_loss: 1.1434 - val_accuracy: 0.5623
# 	-!- No improvement: 1/20
# Epoch 19/100 - loss: 1.2200 - accuracy: 0.5366 - val_loss: 1.1876 - val_accuracy: 0.5756
# 	-!- No improvement: 2/20
# Epoch 20/100 - loss: 1.2130 - accuracy: 0.5413 - val_loss: 1.1143 - val_accuracy: 0.5862
# 	--- Save best at ep 20, val_loss: 1.1143, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 21/100 - loss: 1.1931 - accuracy: 0.5478 - val_loss: 1.1411 - val_accuracy: 0.5793
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 1.1890 - accuracy: 0.5477 - val_loss: 1.1372 - val_accuracy: 0.5798
# 	-!- No improvement: 2/20
# Epoch 23/100 - loss: 1.1705 - accuracy: 0.5496 - val_loss: 1.0855 - val_accuracy: 0.5893
# 	--- Save best at ep 23, val_loss: 1.0855, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 24/100 - loss: 1.1716 - accuracy: 0.5582 - val_loss: 1.1266 - val_accuracy: 0.5768
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 1.1692 - accuracy: 0.5526 - val_loss: 1.2168 - val_accuracy: 0.5414
# 	-!- No improvement: 2/20
# Epoch 26/100 - loss: 1.1446 - accuracy: 0.5629 - val_loss: 1.1502 - val_accuracy: 0.5807
# 	-!- No improvement: 3/20
# Epoch 27/100 - loss: 1.1540 - accuracy: 0.5598 - val_loss: 1.1154 - val_accuracy: 0.5899
# 	-!- No improvement: 4/20
# Epoch 28/100 - loss: 1.0901 - accuracy: 0.5817 - val_loss: 1.0866 - val_accuracy: 0.6069
# 	-!- No improvement: 5/20
# Epoch 29/100 - loss: 1.0542 - accuracy: 0.5909 - val_loss: 1.0049 - val_accuracy: 0.6336
# 	--- Save best at ep 29, val_loss: 1.0049, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 30/100 - loss: 1.0549 - accuracy: 0.5940 - val_loss: 1.0099 - val_accuracy: 0.6135
# 	-!- No improvement: 1/20
# Epoch 31/100 - loss: 1.0374 - accuracy: 0.5985 - val_loss: 1.0559 - val_accuracy: 0.6208
# 	-!- No improvement: 2/20
# Epoch 32/100 - loss: 1.0371 - accuracy: 0.5982 - val_loss: 1.0291 - val_accuracy: 0.6239
# 	-!- No improvement: 3/20
# Epoch 33/100 - loss: 1.0318 - accuracy: 0.5983 - val_loss: 1.0328 - val_accuracy: 0.6250
# 	-!- No improvement: 4/20
# Epoch 34/100 - loss: 0.9988 - accuracy: 0.6107 - val_loss: 1.0152 - val_accuracy: 0.6319
# 	-!- No improvement: 5/20
# Epoch 35/100 - loss: 0.9672 - accuracy: 0.6182 - val_loss: 1.0409 - val_accuracy: 0.6389
# 	-!- No improvement: 6/20
# Epoch 36/100 - loss: 0.9641 - accuracy: 0.6197 - val_loss: 1.0554 - val_accuracy: 0.6403
# 	-!- No improvement: 7/20
# Epoch 37/100 - loss: 0.9506 - accuracy: 0.6239 - val_loss: 1.0188 - val_accuracy: 0.6303
# 	-!- No improvement: 8/20
# Epoch 38/100 - loss: 0.9427 - accuracy: 0.6285 - val_loss: 1.0221 - val_accuracy: 0.6492
# 	-!- No improvement: 9/20
# Epoch 39/100 - loss: 0.9192 - accuracy: 0.6372 - val_loss: 1.0186 - val_accuracy: 0.6459
# 	-!- No improvement: 10/20
# Epoch 40/100 - loss: 0.9199 - accuracy: 0.6354 - val_loss: 1.0164 - val_accuracy: 0.6500
# 	-!- No improvement: 11/20
# Epoch 41/100 - loss: 0.9130 - accuracy: 0.6360 - val_loss: 1.0448 - val_accuracy: 0.6512
# 	-!- No improvement: 12/20
# Epoch 42/100 - loss: 0.9020 - accuracy: 0.6403 - val_loss: 1.0127 - val_accuracy: 0.6545
# 	-!- No improvement: 13/20
# Epoch 43/100 - loss: 0.8978 - accuracy: 0.6422 - val_loss: 1.0120 - val_accuracy: 0.6534
# 	-!- No improvement: 14/20
# Epoch 44/100 - loss: 0.8898 - accuracy: 0.6458 - val_loss: 1.0108 - val_accuracy: 0.6500
# 	-!- No improvement: 15/20
# Epoch 45/100 - loss: 0.8933 - accuracy: 0.6483 - val_loss: 1.0004 - val_accuracy: 0.6551
# 	--- Save best at ep 45, val_loss: 1.0004, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth ---
# Epoch 46/100 - loss: 0.8880 - accuracy: 0.6443 - val_loss: 1.0165 - val_accuracy: 0.6523
# 	-!- No improvement: 1/20
# Epoch 47/100 - loss: 0.8853 - accuracy: 0.6452 - val_loss: 1.0016 - val_accuracy: 0.6545
# 	-!- No improvement: 2/20
# Epoch 48/100 - loss: 0.8779 - accuracy: 0.6487 - val_loss: 1.0168 - val_accuracy: 0.6601
# 	-!- No improvement: 3/20
# Epoch 49/100 - loss: 0.8717 - accuracy: 0.6512 - val_loss: 1.0102 - val_accuracy: 0.6584
# 	-!- No improvement: 4/20
# Epoch 50/100 - loss: 0.8684 - accuracy: 0.6513 - val_loss: 1.0227 - val_accuracy: 0.6592
# 	-!- No improvement: 5/20
# Epoch 51/100 - loss: 0.8688 - accuracy: 0.6525 - val_loss: 1.0148 - val_accuracy: 0.6576
# 	-!- No improvement: 6/20
# Epoch 52/100 - loss: 0.8590 - accuracy: 0.6541 - val_loss: 1.0139 - val_accuracy: 0.6551
# 	-!- No improvement: 7/20
# Epoch 53/100 - loss: 0.8587 - accuracy: 0.6560 - val_loss: 1.0149 - val_accuracy: 0.6545
# 	-!- No improvement: 8/20
# Epoch 54/100 - loss: 0.8543 - accuracy: 0.6585 - val_loss: 1.0149 - val_accuracy: 0.6576
# 	-!- No improvement: 9/20
# Epoch 55/100 - loss: 0.8584 - accuracy: 0.6551 - val_loss: 1.0198 - val_accuracy: 0.6606
# 	-!- No improvement: 10/20
# Epoch 56/100 - loss: 0.8536 - accuracy: 0.6579 - val_loss: 1.0079 - val_accuracy: 0.6567
# 	-!- No improvement: 11/20
# Epoch 57/100 - loss: 0.8588 - accuracy: 0.6533 - val_loss: 1.0134 - val_accuracy: 0.6612
# 	-!- No improvement: 12/20
# Epoch 58/100 - loss: 0.8583 - accuracy: 0.6572 - val_loss: 1.0138 - val_accuracy: 0.6623
# 	-!- No improvement: 13/20
# Epoch 59/100 - loss: 0.8545 - accuracy: 0.6594 - val_loss: 1.0236 - val_accuracy: 0.6587
# 	-!- No improvement: 14/20
# Epoch 60/100 - loss: 0.8505 - accuracy: 0.6562 - val_loss: 1.0113 - val_accuracy: 0.6615
# 	-!- No improvement: 15/20
# Epoch 61/100 - loss: 0.8457 - accuracy: 0.6571 - val_loss: 1.0161 - val_accuracy: 0.6584
# 	-!- No improvement: 16/20
# Epoch 62/100 - loss: 0.8496 - accuracy: 0.6598 - val_loss: 1.0176 - val_accuracy: 0.6604
# 	-!- No improvement: 17/20
# Epoch 63/100 - loss: 0.8540 - accuracy: 0.6603 - val_loss: 1.0202 - val_accuracy: 0.6604
# 	-!- No improvement: 18/20
# Epoch 64/100 - loss: 0.8475 - accuracy: 0.6573 - val_loss: 1.0152 - val_accuracy: 0.6609
# 	-!- No improvement: 19/20
# Epoch 65/100 - loss: 0.8467 - accuracy: 0.6610 - val_loss: 1.0262 - val_accuracy: 0.6604
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=65
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg19/vgg19_04042026_0926_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 46.07it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 66.90%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.602767  0.621181  0.611836   491.000000
# disgust        0.560000  0.763636  0.646154    55.000000
# fear           0.540260  0.393939  0.455641   528.000000
# happy          0.911942  0.860068  0.885246   879.000000
# sad            0.534031  0.515152  0.524422   594.000000
# surprise       0.722467  0.788462  0.754023   416.000000
# neutral        0.594524  0.728435  0.654702   626.000000
# accuracy       0.668989  0.668989  0.668989     0.668989
# macro avg      0.637999  0.667268  0.647432  3589.000000
# weighted avg   0.669698  0.668989  0.665835  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg19_04042026_0926_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_pwnimsf9 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_pwnimsf9 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_pwnimsf9 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_pwnimsf9 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_pwnimsf9 (0.5s)
# wandb:   ↳ ⣷ vgg19_04042026_0926_best.pth 19.6MB/80.8MB (0.1s)
# wandb: ⣯ uploading artifact cnn_pwnimsf9 (0.5s)
# wandb:   ↳ ⣯ vgg19_04042026_0926_best.pth 19.6MB/80.8MB (0.1s)
# wandb: ⣟ uploading artifact cnn_pwnimsf9 (0.5s)
# wandb:   ↳ ⣟ vgg19_04042026_0926_best.pth 19.6MB/80.8MB (0.1s)
# wandb: ⡿ uploading artifact cnn_pwnimsf9 (0.5s)
# wandb:   ↳ ⡿ vgg19_04042026_0926_best.pth 19.6MB/80.8MB (0.1s)
# wandb: ⢿ uploading artifact cnn_pwnimsf9 (0.5s)
# wandb:   ↳ ⢿ vgg19_04042026_0926_best.pth 19.6MB/80.8MB (0.1s)
# wandb: ⣻ uploading artifact cnn_pwnimsf9 (1.0s)
# wandb:   ↳ ⣻ vgg19_04042026_0926_best.pth 75.0MB/80.8MB (0.6s)
# wandb: ⣽ uploading artifact cnn_pwnimsf9 (1.0s)
# wandb:   ↳ ⣽ vgg19_04042026_0926_best.pth 75.0MB/80.8MB (0.6s)
# wandb: ⣾ uploading artifact cnn_pwnimsf9 (1.0s)
# wandb:   ↳ ⣾ vgg19_04042026_0926_best.pth 75.0MB/80.8MB (0.6s)
# wandb: ⣷ uploading artifact cnn_pwnimsf9 (1.0s)
# wandb:   ↳ ⣷ vgg19_04042026_0926_best.pth 75.0MB/80.8MB (0.6s)
# wandb: ⣯ uploading artifact cnn_pwnimsf9 (1.0s)
# wandb:   ↳ ⣯ vgg19_04042026_0926_best.pth 75.0MB/80.8MB (0.6s)
# wandb: ⣟ uploading artifact cnn_pwnimsf9 (1.5s)
# wandb: ⡿ uploading artifact cnn_pwnimsf9 (1.5s)
# wandb: ⢿ uploading artifact cnn_pwnimsf9 (1.5s)
# wandb: ⣻ uploading artifact cnn_pwnimsf9 (1.5s)
# wandb: ⣽ uploading artifact cnn_pwnimsf9 (1.5s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██
# wandb:  Learning_Rate ███████████████▄▄▄▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▃▄▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇██████████████
# wandb:     Train/Loss █▆▆▅▅▅▄▄▄▄▄▄▄▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▄▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇█▇███████████████
# wandb:       Val/Loss █▇▅▆▅▄▄▄▃▃▃▂▃▂▂▂▂▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 65
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.66101
# wandb:     Train/Loss 0.84668
# wandb:   Val/Accuracy 0.66035
# wandb:       Val/Loss 1.02618
# wandb:
# wandb: 🚀 View run vgg19_04042026_0926 at: https://wandb.ai/phucga15062005/FER2013/runs/pwnimsf9
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260404_092637-pwnimsf9/logs
#
# 		DONE!
