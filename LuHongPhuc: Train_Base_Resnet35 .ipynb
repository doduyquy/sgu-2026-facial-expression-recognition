# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 4

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1701, done.
# remote: Counting objects: 100% (398/398), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 1701 (delta 304), reused 250 (delta 187), pack-reused 1303 (from 2)
# Receiving objects: 100% (1701/1701), 6.20 MiB | 23.88 MiB/s, done.
# Resolving deltas: 100% (1157/1157), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config resnet35 --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run a5tzg2ec (0.3s)
# wandb: ⣷ setting up run a5tzg2ec (0.3s)
# wandb: ⣯ setting up run a5tzg2ec (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260414_135033-a5tzg2ec
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet35_14042026_1350
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/a5tzg2ec
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 1.9875 - accuracy: 0.1763 - val_loss: 1.8841 - val_accuracy: 0.2421
# 	--- Save best at ep 1, val_loss: 1.8841, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 2/100 - loss: 1.8052 - accuracy: 0.2929 - val_loss: 1.6335 - val_accuracy: 0.3840
# 	--- Save best at ep 2, val_loss: 1.6335, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 3/100 - loss: 1.6735 - accuracy: 0.3582 - val_loss: 1.5112 - val_accuracy: 0.4238
# 	--- Save best at ep 3, val_loss: 1.5112, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 4/100 - loss: 1.5832 - accuracy: 0.3987 - val_loss: 1.6513 - val_accuracy: 0.3943
# 	-!- No improvement: 1/20
# Epoch 5/100 - loss: 1.5223 - accuracy: 0.4258 - val_loss: 1.6068 - val_accuracy: 0.4316
# 	-!- No improvement: 2/20
# Epoch 6/100 - loss: 1.4768 - accuracy: 0.4441 - val_loss: 1.3681 - val_accuracy: 0.4745
# 	--- Save best at ep 6, val_loss: 1.3681, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 7/100 - loss: 1.4427 - accuracy: 0.4534 - val_loss: 1.4385 - val_accuracy: 0.4464
# 	-!- No improvement: 1/20
# Epoch 8/100 - loss: 1.4067 - accuracy: 0.4672 - val_loss: 1.3255 - val_accuracy: 0.4923
# 	--- Save best at ep 8, val_loss: 1.3255, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 9/100 - loss: 1.3926 - accuracy: 0.4735 - val_loss: 1.3347 - val_accuracy: 0.5305
# 	-!- No improvement: 1/20
# Epoch 10/100 - loss: 1.3626 - accuracy: 0.4834 - val_loss: 1.3761 - val_accuracy: 0.4965
# 	-!- No improvement: 2/20
# Epoch 11/100 - loss: 1.3519 - accuracy: 0.4886 - val_loss: 1.3616 - val_accuracy: 0.5071
# 	-!- No improvement: 3/20
# Epoch 12/100 - loss: 1.3260 - accuracy: 0.4975 - val_loss: 8.0423 - val_accuracy: 0.0911
# 	-!- No improvement: 4/20
# Epoch 13/100 - loss: 1.2556 - accuracy: 0.5228 - val_loss: 1.2102 - val_accuracy: 0.5469
# 	--- Save best at ep 13, val_loss: 1.2102, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 14/100 - loss: 1.2243 - accuracy: 0.5298 - val_loss: 1.2273 - val_accuracy: 0.5478
# 	-!- No improvement: 1/20
# Epoch 15/100 - loss: 1.2122 - accuracy: 0.5375 - val_loss: 1.2872 - val_accuracy: 0.5386
# 	-!- No improvement: 2/20
# Epoch 16/100 - loss: 1.1989 - accuracy: 0.5429 - val_loss: 1.1907 - val_accuracy: 0.5651
# 	--- Save best at ep 16, val_loss: 1.1907, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 17/100 - loss: 1.1842 - accuracy: 0.5436 - val_loss: 1.2157 - val_accuracy: 0.5430
# 	-!- No improvement: 1/20
# Epoch 18/100 - loss: 1.1846 - accuracy: 0.5457 - val_loss: 1.1871 - val_accuracy: 0.5589
# 	--- Save best at ep 18, val_loss: 1.1871, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 19/100 - loss: 1.1615 - accuracy: 0.5504 - val_loss: 1.1792 - val_accuracy: 0.5762
# 	--- Save best at ep 19, val_loss: 1.1792, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 20/100 - loss: 1.1426 - accuracy: 0.5583 - val_loss: 1.1902 - val_accuracy: 0.5748
# 	-!- No improvement: 1/20
# Epoch 21/100 - loss: 1.1382 - accuracy: 0.5556 - val_loss: 1.2092 - val_accuracy: 0.5759
# 	-!- No improvement: 2/20
# Epoch 22/100 - loss: 1.1320 - accuracy: 0.5655 - val_loss: 1.1501 - val_accuracy: 0.5550
# 	--- Save best at ep 22, val_loss: 1.1501, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 23/100 - loss: 1.1377 - accuracy: 0.5598 - val_loss: 1.1960 - val_accuracy: 0.5840
# 	-!- No improvement: 1/20
# Epoch 24/100 - loss: 1.1189 - accuracy: 0.5712 - val_loss: 1.1714 - val_accuracy: 0.5600
# 	-!- No improvement: 2/20
# Epoch 25/100 - loss: 1.1135 - accuracy: 0.5691 - val_loss: 1.1201 - val_accuracy: 0.5754
# 	--- Save best at ep 25, val_loss: 1.1201, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 26/100 - loss: 1.1015 - accuracy: 0.5754 - val_loss: 1.1092 - val_accuracy: 0.5954
# 	--- Save best at ep 26, val_loss: 1.1092, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 27/100 - loss: 1.1049 - accuracy: 0.5732 - val_loss: 1.1840 - val_accuracy: 0.5840
# 	-!- No improvement: 1/20
# Epoch 28/100 - loss: 1.0909 - accuracy: 0.5789 - val_loss: 1.1285 - val_accuracy: 0.5988
# 	-!- No improvement: 2/20
# Epoch 29/100 - loss: 1.0766 - accuracy: 0.5842 - val_loss: 1.0943 - val_accuracy: 0.6027
# 	--- Save best at ep 29, val_loss: 1.0943, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 30/100 - loss: 1.0787 - accuracy: 0.5813 - val_loss: 1.1435 - val_accuracy: 0.5965
# 	-!- No improvement: 1/20
# Epoch 31/100 - loss: 1.0663 - accuracy: 0.5855 - val_loss: 1.1649 - val_accuracy: 0.6052
# 	-!- No improvement: 2/20
# Epoch 32/100 - loss: 1.0676 - accuracy: 0.5857 - val_loss: 1.1601 - val_accuracy: 0.5809
# 	-!- No improvement: 3/20
# Epoch 33/100 - loss: 1.0521 - accuracy: 0.5913 - val_loss: 1.1799 - val_accuracy: 0.6060
# 	-!- No improvement: 4/20
# Epoch 34/100 - loss: 0.9898 - accuracy: 0.6114 - val_loss: 1.1041 - val_accuracy: 0.6133
# 	-!- No improvement: 5/20
# Epoch 35/100 - loss: 0.9781 - accuracy: 0.6171 - val_loss: 1.0607 - val_accuracy: 0.6275
# 	--- Save best at ep 35, val_loss: 1.0607, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 36/100 - loss: 0.9712 - accuracy: 0.6179 - val_loss: 1.0878 - val_accuracy: 0.6250
# 	-!- No improvement: 1/20
# Epoch 37/100 - loss: 0.9674 - accuracy: 0.6174 - val_loss: 1.0733 - val_accuracy: 0.6291
# 	-!- No improvement: 2/20
# Epoch 38/100 - loss: 0.9679 - accuracy: 0.6205 - val_loss: 1.0327 - val_accuracy: 0.6289
# 	--- Save best at ep 38, val_loss: 1.0327, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 39/100 - loss: 0.9459 - accuracy: 0.6237 - val_loss: 1.0874 - val_accuracy: 0.6303
# 	-!- No improvement: 1/20
# Epoch 40/100 - loss: 0.9378 - accuracy: 0.6272 - val_loss: 1.0631 - val_accuracy: 0.6264
# 	-!- No improvement: 2/20
# Epoch 41/100 - loss: 0.9437 - accuracy: 0.6298 - val_loss: 1.0887 - val_accuracy: 0.6266
# 	-!- No improvement: 3/20
# Epoch 42/100 - loss: 0.9284 - accuracy: 0.6300 - val_loss: 1.0316 - val_accuracy: 0.6311
# 	--- Save best at ep 42, val_loss: 1.0316, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 43/100 - loss: 0.9339 - accuracy: 0.6338 - val_loss: 1.1100 - val_accuracy: 0.6291
# 	-!- No improvement: 1/20
# Epoch 44/100 - loss: 0.9218 - accuracy: 0.6359 - val_loss: 1.0671 - val_accuracy: 0.6152
# 	-!- No improvement: 2/20
# Epoch 45/100 - loss: 0.9266 - accuracy: 0.6332 - val_loss: 1.0471 - val_accuracy: 0.6339
# 	-!- No improvement: 3/20
# Epoch 46/100 - loss: 0.9244 - accuracy: 0.6352 - val_loss: 1.0353 - val_accuracy: 0.6328
# 	-!- No improvement: 4/20
# Epoch 47/100 - loss: 0.8795 - accuracy: 0.6465 - val_loss: 1.0408 - val_accuracy: 0.6389
# 	-!- No improvement: 5/20
# Epoch 48/100 - loss: 0.8657 - accuracy: 0.6527 - val_loss: 1.0583 - val_accuracy: 0.6381
# 	-!- No improvement: 6/20
# Epoch 49/100 - loss: 0.8616 - accuracy: 0.6536 - val_loss: 1.0593 - val_accuracy: 0.6431
# 	-!- No improvement: 7/20
# Epoch 50/100 - loss: 0.8550 - accuracy: 0.6563 - val_loss: 1.0274 - val_accuracy: 0.6397
# 	--- Save best at ep 50, val_loss: 1.0274, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 51/100 - loss: 0.8515 - accuracy: 0.6565 - val_loss: 1.0590 - val_accuracy: 0.6333
# 	-!- No improvement: 1/20
# Epoch 52/100 - loss: 0.8645 - accuracy: 0.6575 - val_loss: 1.0706 - val_accuracy: 0.6408
# 	-!- No improvement: 2/20
# Epoch 53/100 - loss: 0.8420 - accuracy: 0.6574 - val_loss: 1.0443 - val_accuracy: 0.6500
# 	-!- No improvement: 3/20
# Epoch 54/100 - loss: 0.8282 - accuracy: 0.6642 - val_loss: 1.0214 - val_accuracy: 0.6461
# 	--- Save best at ep 54, val_loss: 1.0214, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 55/100 - loss: 0.8357 - accuracy: 0.6636 - val_loss: 1.0230 - val_accuracy: 0.6456
# 	-!- No improvement: 1/20
# Epoch 56/100 - loss: 0.8371 - accuracy: 0.6666 - val_loss: 1.0126 - val_accuracy: 0.6417
# 	--- Save best at ep 56, val_loss: 1.0126, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth ---
# Epoch 57/100 - loss: 0.8373 - accuracy: 0.6683 - val_loss: 1.0539 - val_accuracy: 0.6537
# 	-!- No improvement: 1/20
# Epoch 58/100 - loss: 0.8273 - accuracy: 0.6666 - val_loss: 1.0319 - val_accuracy: 0.6509
# 	-!- No improvement: 2/20
# Epoch 59/100 - loss: 0.8241 - accuracy: 0.6678 - val_loss: 1.0239 - val_accuracy: 0.6453
# 	-!- No improvement: 3/20
# Epoch 60/100 - loss: 0.8299 - accuracy: 0.6670 - val_loss: 1.0235 - val_accuracy: 0.6531
# 	-!- No improvement: 4/20
# Epoch 61/100 - loss: 0.7957 - accuracy: 0.6783 - val_loss: 1.0383 - val_accuracy: 0.6539
# 	-!- No improvement: 5/20
# Epoch 62/100 - loss: 0.7962 - accuracy: 0.6787 - val_loss: 1.0453 - val_accuracy: 0.6545
# 	-!- No improvement: 6/20
# Epoch 63/100 - loss: 0.7931 - accuracy: 0.6809 - val_loss: 1.0564 - val_accuracy: 0.6601
# 	-!- No improvement: 7/20
# Epoch 64/100 - loss: 0.7915 - accuracy: 0.6807 - val_loss: 1.0280 - val_accuracy: 0.6567
# 	-!- No improvement: 8/20
# Epoch 65/100 - loss: 0.7648 - accuracy: 0.6889 - val_loss: 1.0650 - val_accuracy: 0.6601
# 	-!- No improvement: 9/20
# Epoch 66/100 - loss: 0.7668 - accuracy: 0.6906 - val_loss: 1.0647 - val_accuracy: 0.6623
# 	-!- No improvement: 10/20
# Epoch 67/100 - loss: 0.7703 - accuracy: 0.6864 - val_loss: 1.0558 - val_accuracy: 0.6598
# 	-!- No improvement: 11/20
# Epoch 68/100 - loss: 0.7722 - accuracy: 0.6900 - val_loss: 1.0649 - val_accuracy: 0.6576
# 	-!- No improvement: 12/20
# Epoch 69/100 - loss: 0.7699 - accuracy: 0.6887 - val_loss: 1.0601 - val_accuracy: 0.6620
# 	-!- No improvement: 13/20
# Epoch 70/100 - loss: 0.7617 - accuracy: 0.6926 - val_loss: 1.0606 - val_accuracy: 0.6665
# 	-!- No improvement: 14/20
# Epoch 71/100 - loss: 0.7590 - accuracy: 0.6895 - val_loss: 1.0434 - val_accuracy: 0.6645
# 	-!- No improvement: 15/20
# Epoch 72/100 - loss: 0.7666 - accuracy: 0.6927 - val_loss: 1.0535 - val_accuracy: 0.6626
# 	-!- No improvement: 16/20
# Epoch 73/100 - loss: 0.7547 - accuracy: 0.6951 - val_loss: 1.0426 - val_accuracy: 0.6640
# 	-!- No improvement: 17/20
# Epoch 74/100 - loss: 0.7514 - accuracy: 0.6923 - val_loss: 1.0502 - val_accuracy: 0.6670
# 	-!- No improvement: 18/20
# Epoch 75/100 - loss: 0.7475 - accuracy: 0.6947 - val_loss: 1.0468 - val_accuracy: 0.6640
# 	-!- No improvement: 19/20
# Epoch 76/100 - loss: 0.7532 - accuracy: 0.6907 - val_loss: 1.0510 - val_accuracy: 0.6648
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=76
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/resnet35/resnet35_14042026_1350_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 28.60it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 66.17%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.558621  0.659878  0.605042   491.000000
# disgust        0.500000  0.781818  0.609929    55.000000
# fear           0.532134  0.392045  0.451472   528.000000
# happy          0.891924  0.854380  0.872748   879.000000
# sad            0.525217  0.508418  0.516681   594.000000
# surprise       0.713987  0.822115  0.764246   416.000000
# neutral        0.636364  0.648562  0.642405   626.000000
# accuracy       0.661744  0.661744  0.661744     0.661744
# macro avg      0.622607  0.666745  0.637503  3589.000000
# weighted avg   0.661497  0.661744  0.658436  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `resnet35_14042026_1350_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_a5tzg2ec (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_a5tzg2ec (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_a5tzg2ec (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_a5tzg2ec (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_a5tzg2ec (0.5s)
# wandb:   ↳ ⣷ resnet35_14042026_1350_best.pth 7.1MB/72.6MB (0.1s)
# wandb: ⣯ uploading artifact cnn_a5tzg2ec (0.5s)
# wandb:   ↳ ⣯ resnet35_14042026_1350_best.pth 7.1MB/72.6MB (0.1s)
# wandb: ⣟ uploading artifact cnn_a5tzg2ec (0.5s)
# wandb:   ↳ ⣟ resnet35_14042026_1350_best.pth 7.1MB/72.6MB (0.1s)
# wandb: ⡿ uploading artifact cnn_a5tzg2ec (0.5s)
# wandb:   ↳ ⡿ resnet35_14042026_1350_best.pth 7.1MB/72.6MB (0.1s)
# wandb: ⢿ uploading artifact cnn_a5tzg2ec (0.5s)
# wandb:   ↳ ⢿ resnet35_14042026_1350_best.pth 7.1MB/72.6MB (0.1s)
# wandb: ⣻ uploading artifact cnn_a5tzg2ec (1.0s)
# wandb:   ↳ ⣻ resnet35_14042026_1350_best.pth 65.0MB/72.6MB (0.6s)
# wandb: ⣽ uploading artifact cnn_a5tzg2ec (1.0s)
# wandb:   ↳ ⣽ resnet35_14042026_1350_best.pth 65.0MB/72.6MB (0.6s)
# wandb: ⣾ uploading artifact cnn_a5tzg2ec (1.0s)
# wandb:   ↳ ⣾ resnet35_14042026_1350_best.pth 65.0MB/72.6MB (0.6s)
# wandb: ⣷ uploading artifact cnn_a5tzg2ec (1.0s)
# wandb:   ↳ ⣷ resnet35_14042026_1350_best.pth 65.0MB/72.6MB (0.6s)
# wandb: ⣯ uploading artifact cnn_a5tzg2ec (1.0s)
# wandb:   ↳ ⣯ resnet35_14042026_1350_best.pth 65.0MB/72.6MB (0.6s)
# wandb: ⣟ uploading artifact cnn_a5tzg2ec (1.5s)
# wandb: ⡿ uploading artifact cnn_a5tzg2ec (1.5s)
# wandb: ⢿ uploading artifact cnn_a5tzg2ec (1.5s)
# wandb: ⣻ uploading artifact cnn_a5tzg2ec (1.5s)
# wandb: ⣽ uploading artifact cnn_a5tzg2ec (1.5s)
# wandb: ⣾ Finishing up...
# wandb: ⣷ Finishing up...
# wandb: ⣯ Finishing up...
# wandb: ⣟ Finishing up...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█████
# wandb:  Learning_Rate █████▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▂▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████
# wandb:     Train/Loss █▇▆▆▅▅▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▂▁▃▃▄▅▅▅▅▆▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████
# wandb:       Val/Loss █▆▆▄▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 76
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.69069
# wandb:     Train/Loss 0.75319
# wandb:   Val/Accuracy 0.66481
# wandb:       Val/Loss 1.05097
# wandb:
# wandb: 🚀 View run resnet35_14042026_1350 at: https://wandb.ai/phucga15062005/FER2013/runs/a5tzg2ec
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260414_135033-a5tzg2ec/logs
#
# 		DONE!
