# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1253, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 1253 (delta 161), reused 143 (delta 103), pack-reused 1027 (from 1)
# Receiving objects: 100% (1253/1253), 6.03 MiB | 22.77 MiB/s, done.
# Resolving deltas: 100% (835/835), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config inception --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run bqugiraj (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_055327-bqugiraj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run inception_13042026_0553
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/bqugiraj
#
# --> Start training in total 101 epochs with cuda device. Start...
#
# Epoch 1/101 - loss: 1.7454 - accuracy: 0.2813 - val_loss: 1.6300 - val_accuracy: 0.3307
# 	--- Save best at ep 1, val_loss: 1.6300, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 2/101 - loss: 1.5818 - accuracy: 0.3755 - val_loss: 1.4534 - val_accuracy: 0.4413
# 	--- Save best at ep 2, val_loss: 1.4534, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 3/101 - loss: 1.4328 - accuracy: 0.4448 - val_loss: 1.4175 - val_accuracy: 0.4542
# 	--- Save best at ep 3, val_loss: 1.4175, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 4/101 - loss: 1.3574 - accuracy: 0.4804 - val_loss: 1.4333 - val_accuracy: 0.4519
# 	-!- No improvement: 1/20
# Epoch 5/101 - loss: 1.2995 - accuracy: 0.5056 - val_loss: 1.3162 - val_accuracy: 0.5099
# 	--- Save best at ep 5, val_loss: 1.3162, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 6/101 - loss: 1.2588 - accuracy: 0.5195 - val_loss: 1.2634 - val_accuracy: 0.5216
# 	--- Save best at ep 6, val_loss: 1.2634, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 7/101 - loss: 1.2223 - accuracy: 0.5358 - val_loss: 1.3296 - val_accuracy: 0.4951
# 	-!- No improvement: 1/20
# Epoch 8/101 - loss: 1.2019 - accuracy: 0.5416 - val_loss: 1.3022 - val_accuracy: 0.5160
# 	-!- No improvement: 2/20
# Epoch 9/101 - loss: 1.1744 - accuracy: 0.5533 - val_loss: 1.1927 - val_accuracy: 0.5514
# 	--- Save best at ep 9, val_loss: 1.1927, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 10/101 - loss: 1.1674 - accuracy: 0.5546 - val_loss: 1.5488 - val_accuracy: 0.4363
# 	-!- No improvement: 1/20
# Epoch 11/101 - loss: 1.1458 - accuracy: 0.5651 - val_loss: 1.3664 - val_accuracy: 0.4993
# 	-!- No improvement: 2/20
# Epoch 12/101 - loss: 1.1233 - accuracy: 0.5724 - val_loss: 1.1770 - val_accuracy: 0.5539
# 	--- Save best at ep 12, val_loss: 1.1770, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 13/101 - loss: 1.1127 - accuracy: 0.5770 - val_loss: 1.1333 - val_accuracy: 0.5653
# 	--- Save best at ep 13, val_loss: 1.1333, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 14/101 - loss: 1.1005 - accuracy: 0.5812 - val_loss: 1.1501 - val_accuracy: 0.5737
# 	-!- No improvement: 1/20
# Epoch 15/101 - loss: 1.0844 - accuracy: 0.5901 - val_loss: 1.1030 - val_accuracy: 0.5826
# 	--- Save best at ep 15, val_loss: 1.1030, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 16/101 - loss: 1.0683 - accuracy: 0.5955 - val_loss: 1.1086 - val_accuracy: 0.5837
# 	-!- No improvement: 1/20
# Epoch 17/101 - loss: 1.0641 - accuracy: 0.5977 - val_loss: 1.1965 - val_accuracy: 0.5631
# 	-!- No improvement: 2/20
# Epoch 18/101 - loss: 1.0538 - accuracy: 0.6000 - val_loss: 1.1233 - val_accuracy: 0.5807
# 	-!- No improvement: 3/20
# Epoch 19/101 - loss: 1.0435 - accuracy: 0.6059 - val_loss: 1.1031 - val_accuracy: 0.5876
# 	-!- No improvement: 4/20
# Epoch 20/101 - loss: 0.9932 - accuracy: 0.6244 - val_loss: 1.0015 - val_accuracy: 0.6144
# 	--- Save best at ep 20, val_loss: 1.0015, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 21/101 - loss: 0.9801 - accuracy: 0.6296 - val_loss: 1.0198 - val_accuracy: 0.6180
# 	-!- No improvement: 1/20
# Epoch 22/101 - loss: 0.9780 - accuracy: 0.6308 - val_loss: 0.9954 - val_accuracy: 0.6208
# 	--- Save best at ep 22, val_loss: 0.9954, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 23/101 - loss: 0.9648 - accuracy: 0.6372 - val_loss: 1.0275 - val_accuracy: 0.6166
# 	-!- No improvement: 1/20
# Epoch 24/101 - loss: 0.9538 - accuracy: 0.6406 - val_loss: 1.0093 - val_accuracy: 0.6258
# 	-!- No improvement: 2/20
# Epoch 25/101 - loss: 0.9524 - accuracy: 0.6389 - val_loss: 1.0583 - val_accuracy: 0.6043
# 	-!- No improvement: 3/20
# Epoch 26/101 - loss: 0.9463 - accuracy: 0.6436 - val_loss: 0.9965 - val_accuracy: 0.6319
# 	-!- No improvement: 4/20
# Epoch 27/101 - loss: 0.9123 - accuracy: 0.6567 - val_loss: 0.9678 - val_accuracy: 0.6305
# 	--- Save best at ep 27, val_loss: 0.9678, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 28/101 - loss: 0.8973 - accuracy: 0.6619 - val_loss: 0.9579 - val_accuracy: 0.6464
# 	--- Save best at ep 28, val_loss: 0.9579, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 29/101 - loss: 0.8951 - accuracy: 0.6647 - val_loss: 0.9690 - val_accuracy: 0.6414
# 	-!- No improvement: 1/20
# Epoch 30/101 - loss: 0.8847 - accuracy: 0.6653 - val_loss: 0.9649 - val_accuracy: 0.6403
# 	-!- No improvement: 2/20
# Epoch 31/101 - loss: 0.8778 - accuracy: 0.6714 - val_loss: 0.9736 - val_accuracy: 0.6339
# 	-!- No improvement: 3/20
# Epoch 32/101 - loss: 0.8740 - accuracy: 0.6676 - val_loss: 0.9577 - val_accuracy: 0.6372
# 	--- Save best at ep 32, val_loss: 0.9577, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 33/101 - loss: 0.8654 - accuracy: 0.6763 - val_loss: 0.9574 - val_accuracy: 0.6392
# 	--- Save best at ep 33, val_loss: 0.9574, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 34/101 - loss: 0.8633 - accuracy: 0.6733 - val_loss: 0.9721 - val_accuracy: 0.6439
# 	-!- No improvement: 1/20
# Epoch 35/101 - loss: 0.8608 - accuracy: 0.6762 - val_loss: 0.9646 - val_accuracy: 0.6453
# 	-!- No improvement: 2/20
# Epoch 36/101 - loss: 0.8561 - accuracy: 0.6784 - val_loss: 0.9550 - val_accuracy: 0.6414
# 	--- Save best at ep 36, val_loss: 0.9550, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 37/101 - loss: 0.8489 - accuracy: 0.6831 - val_loss: 0.9533 - val_accuracy: 0.6525
# 	--- Save best at ep 37, val_loss: 0.9533, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 38/101 - loss: 0.8437 - accuracy: 0.6845 - val_loss: 1.0079 - val_accuracy: 0.6381
# 	-!- No improvement: 1/20
# Epoch 39/101 - loss: 0.8420 - accuracy: 0.6830 - val_loss: 0.9418 - val_accuracy: 0.6484
# 	--- Save best at ep 39, val_loss: 0.9418, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 40/101 - loss: 0.8331 - accuracy: 0.6873 - val_loss: 0.9678 - val_accuracy: 0.6428
# 	-!- No improvement: 1/20
# Epoch 41/101 - loss: 0.8371 - accuracy: 0.6856 - val_loss: 0.9418 - val_accuracy: 0.6500
# 	-!- No improvement: 2/20
# Epoch 42/101 - loss: 0.8236 - accuracy: 0.6932 - val_loss: 0.9707 - val_accuracy: 0.6422
# 	-!- No improvement: 3/20
# Epoch 43/101 - loss: 0.8235 - accuracy: 0.6907 - val_loss: 0.9938 - val_accuracy: 0.6280
# 	-!- No improvement: 4/20
# Epoch 44/101 - loss: 0.7928 - accuracy: 0.7027 - val_loss: 0.9436 - val_accuracy: 0.6545
# 	-!- No improvement: 5/20
# Epoch 45/101 - loss: 0.7842 - accuracy: 0.7078 - val_loss: 0.9401 - val_accuracy: 0.6576
# 	--- Save best at ep 45, val_loss: 0.9401, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 46/101 - loss: 0.7884 - accuracy: 0.7087 - val_loss: 0.9347 - val_accuracy: 0.6601
# 	--- Save best at ep 46, val_loss: 0.9347, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 47/101 - loss: 0.7825 - accuracy: 0.7066 - val_loss: 0.9670 - val_accuracy: 0.6542
# 	-!- No improvement: 1/20
# Epoch 48/101 - loss: 0.7814 - accuracy: 0.7055 - val_loss: 0.9420 - val_accuracy: 0.6604
# 	-!- No improvement: 2/20
# Epoch 49/101 - loss: 0.7755 - accuracy: 0.7103 - val_loss: 0.9386 - val_accuracy: 0.6595
# 	-!- No improvement: 3/20
# Epoch 50/101 - loss: 0.7672 - accuracy: 0.7151 - val_loss: 0.9570 - val_accuracy: 0.6584
# 	-!- No improvement: 4/20
# Epoch 51/101 - loss: 0.7542 - accuracy: 0.7188 - val_loss: 0.9358 - val_accuracy: 0.6584
# 	-!- No improvement: 5/20
# Epoch 52/101 - loss: 0.7445 - accuracy: 0.7214 - val_loss: 0.9496 - val_accuracy: 0.6576
# 	-!- No improvement: 6/20
# Epoch 53/101 - loss: 0.7429 - accuracy: 0.7219 - val_loss: 0.9474 - val_accuracy: 0.6598
# 	-!- No improvement: 7/20
# Epoch 54/101 - loss: 0.7460 - accuracy: 0.7238 - val_loss: 0.9337 - val_accuracy: 0.6620
# 	--- Save best at ep 54, val_loss: 0.9337, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth ---
# Epoch 55/101 - loss: 0.7381 - accuracy: 0.7249 - val_loss: 0.9364 - val_accuracy: 0.6623
# 	-!- No improvement: 1/20
# Epoch 56/101 - loss: 0.7404 - accuracy: 0.7240 - val_loss: 0.9571 - val_accuracy: 0.6567
# 	-!- No improvement: 2/20
# Epoch 57/101 - loss: 0.7362 - accuracy: 0.7261 - val_loss: 0.9338 - val_accuracy: 0.6612
# 	-!- No improvement: 3/20
# Epoch 58/101 - loss: 0.7294 - accuracy: 0.7264 - val_loss: 0.9437 - val_accuracy: 0.6620
# 	-!- No improvement: 4/20
# Epoch 59/101 - loss: 0.7233 - accuracy: 0.7298 - val_loss: 0.9392 - val_accuracy: 0.6634
# 	-!- No improvement: 5/20
# Epoch 60/101 - loss: 0.7123 - accuracy: 0.7336 - val_loss: 0.9416 - val_accuracy: 0.6654
# 	-!- No improvement: 6/20
# Epoch 61/101 - loss: 0.7171 - accuracy: 0.7316 - val_loss: 0.9428 - val_accuracy: 0.6645
# 	-!- No improvement: 7/20
# Epoch 62/101 - loss: 0.7162 - accuracy: 0.7335 - val_loss: 0.9468 - val_accuracy: 0.6665
# 	-!- No improvement: 8/20
# Epoch 63/101 - loss: 0.7109 - accuracy: 0.7355 - val_loss: 0.9385 - val_accuracy: 0.6645
# 	-!- No improvement: 9/20
# Epoch 64/101 - loss: 0.7099 - accuracy: 0.7361 - val_loss: 0.9398 - val_accuracy: 0.6645
# 	-!- No improvement: 10/20
# Epoch 65/101 - loss: 0.7088 - accuracy: 0.7343 - val_loss: 0.9420 - val_accuracy: 0.6665
# 	-!- No improvement: 11/20
# Epoch 66/101 - loss: 0.7065 - accuracy: 0.7376 - val_loss: 0.9443 - val_accuracy: 0.6634
# 	-!- No improvement: 12/20
# Epoch 67/101 - loss: 0.7022 - accuracy: 0.7398 - val_loss: 0.9433 - val_accuracy: 0.6645
# 	-!- No improvement: 13/20
# Epoch 68/101 - loss: 0.7056 - accuracy: 0.7390 - val_loss: 0.9407 - val_accuracy: 0.6668
# 	-!- No improvement: 14/20
# Epoch 69/101 - loss: 0.7001 - accuracy: 0.7425 - val_loss: 0.9421 - val_accuracy: 0.6648
# 	-!- No improvement: 15/20
# Epoch 70/101 - loss: 0.7032 - accuracy: 0.7371 - val_loss: 0.9429 - val_accuracy: 0.6615
# 	-!- No improvement: 16/20
# Epoch 71/101 - loss: 0.6985 - accuracy: 0.7423 - val_loss: 0.9468 - val_accuracy: 0.6643
# 	-!- No improvement: 17/20
# Epoch 72/101 - loss: 0.6961 - accuracy: 0.7413 - val_loss: 0.9444 - val_accuracy: 0.6676
# 	-!- No improvement: 18/20
# Epoch 73/101 - loss: 0.7051 - accuracy: 0.7377 - val_loss: 0.9458 - val_accuracy: 0.6645
# 	-!- No improvement: 19/20
# Epoch 74/101 - loss: 0.7018 - accuracy: 0.7391 - val_loss: 0.9463 - val_accuracy: 0.6662
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=74
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_0553_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:06<00:00,  8.21it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.21%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.644028  0.560081  0.599129   491.000000
# disgust        0.622642  0.600000  0.611111    55.000000
# fear           0.557789  0.420455  0.479482   528.000000
# happy          0.875831  0.898749  0.887142   879.000000
# sad            0.505618  0.606061  0.551302   594.000000
# surprise       0.784314  0.769231  0.776699   416.000000
# neutral        0.650218  0.715655  0.681369   626.000000
# accuracy       0.682084  0.682084  0.682084     0.682084
# macro avg      0.662920  0.652890  0.655176  3589.000000
# weighted avg   0.682218  0.682084  0.679260  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `inception_13042026_0553_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_bqugiraj (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_bqugiraj (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_bqugiraj (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_bqugiraj (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_bqugiraj (0.5s)
# wandb:   ↳ ⣷ inception_13042026_0553_best.pth 4.0MB/25.8MB (0.0s)
# wandb: ⣯ uploading artifact cnn_bqugiraj (0.5s)
# wandb:   ↳ ⣯ inception_13042026_0553_best.pth 4.0MB/25.8MB (0.0s)
# wandb: ⣟ uploading artifact cnn_bqugiraj (0.5s)
# wandb:   ↳ ⣟ inception_13042026_0553_best.pth 4.0MB/25.8MB (0.0s)
# wandb: ⡿ uploading artifact cnn_bqugiraj (0.5s)
# wandb:   ↳ ⡿ inception_13042026_0553_best.pth 4.0MB/25.8MB (0.0s)
# wandb: ⢿ uploading artifact cnn_bqugiraj (0.5s)
# wandb:   ↳ ⢿ inception_13042026_0553_best.pth 4.0MB/25.8MB (0.0s)
# wandb: ⣻ uploading artifact cnn_bqugiraj (1.0s)
# wandb: ⣽ uploading artifact cnn_bqugiraj (1.0s)
# wandb: ⣾ uploading artifact cnn_bqugiraj (1.0s)
# wandb: ⣷ uploading artifact cnn_bqugiraj (1.0s)
# wandb: ⣯ uploading artifact cnn_bqugiraj (1.0s)
# wandb: ⣟ uploading history steps 73-75, summary, console lines 175-180 (0.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:  Learning_Rate ██████████▄▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▃▃▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████
# wandb:     Train/Loss █▇▆▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▁▁▃▃▃▅▅▅▆▆▇▆▇▇▇▇▇▇▇▇▇██████████████████
# wandb:       Val/Loss █▆▆▅▅▇▅▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 74
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.73914
# wandb:     Train/Loss 0.70179
# wandb:   Val/Accuracy 0.6662
# wandb:       Val/Loss 0.94633
# wandb:
# wandb: 🚀 View run inception_13042026_0553 at: https://wandb.ai/phucga15062005/FER2013/runs/bqugiraj
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_055327-bqugiraj/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
