# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "TreeV2"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 1376, done.
# remote: Counting objects: 100% (349/349), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 1376 (delta 251), reused 193 (delta 136), pack-reused 1027 (from 1)
# Receiving objects: 100% (1376/1376), 6.08 MiB | 25.20 MiB/s, done.
# Resolving deltas: 100% (925/925), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config inception --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Balanced Class Weights to handle imbalance...
# Train class distribution:
# emotion
# 0    3995
# 1     436
# 2    4097
# 3    7215
# 4    4830
# 5    3171
# 6    4965
# Name: count, dtype: int64
# Balanced class weights:
# tensor([1.0266, 9.4066, 1.0010, 0.5684, 0.8491, 1.2934, 0.8260],
#        device='cuda:0')
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260413_113416-7nqtjsxx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run inception_13042026_1134
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/7nqtjsxx
#
# --> Start training in total 101 epochs with cuda device. Start...
#
# Epoch 1/101 - loss: 1.8562 - accuracy: 0.2223 - val_loss: 1.8124 - val_accuracy: 0.1936
# 	--- Save best at ep 1, val_loss: 1.8124, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 2/101 - loss: 1.7352 - accuracy: 0.3067 - val_loss: 1.7333 - val_accuracy: 0.3814
# 	--- Save best at ep 2, val_loss: 1.7333, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 3/101 - loss: 1.6005 - accuracy: 0.3999 - val_loss: 1.6627 - val_accuracy: 0.4101
# 	--- Save best at ep 3, val_loss: 1.6627, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 4/101 - loss: 1.5192 - accuracy: 0.4283 - val_loss: 1.5005 - val_accuracy: 0.4581
# 	--- Save best at ep 4, val_loss: 1.5005, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 5/101 - loss: 1.4522 - accuracy: 0.4517 - val_loss: 1.4188 - val_accuracy: 0.4809
# 	--- Save best at ep 5, val_loss: 1.4188, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 6/101 - loss: 1.3975 - accuracy: 0.4692 - val_loss: 1.4543 - val_accuracy: 0.4753
# 	-!- No improvement: 1/20
# Epoch 7/101 - loss: 1.3572 - accuracy: 0.4847 - val_loss: 1.4224 - val_accuracy: 0.5130
# 	-!- No improvement: 2/20
# Epoch 8/101 - loss: 1.3179 - accuracy: 0.4992 - val_loss: 1.4233 - val_accuracy: 0.4622
# 	-!- No improvement: 3/20
# Epoch 9/101 - loss: 1.2890 - accuracy: 0.5100 - val_loss: 1.4274 - val_accuracy: 0.5074
# 	-!- No improvement: 4/20
# Epoch 10/101 - loss: 1.2008 - accuracy: 0.5345 - val_loss: 1.2857 - val_accuracy: 0.5052
# 	--- Save best at ep 10, val_loss: 1.2857, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 11/101 - loss: 1.1872 - accuracy: 0.5466 - val_loss: 1.2212 - val_accuracy: 0.5280
# 	--- Save best at ep 11, val_loss: 1.2212, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 12/101 - loss: 1.1627 - accuracy: 0.5489 - val_loss: 1.2910 - val_accuracy: 0.5116
# 	-!- No improvement: 1/20
# Epoch 13/101 - loss: 1.1402 - accuracy: 0.5589 - val_loss: 1.2328 - val_accuracy: 0.5210
# 	-!- No improvement: 2/20
# Epoch 14/101 - loss: 1.1250 - accuracy: 0.5621 - val_loss: 1.2222 - val_accuracy: 0.5483
# 	-!- No improvement: 3/20
# Epoch 15/101 - loss: 1.1021 - accuracy: 0.5736 - val_loss: 1.2013 - val_accuracy: 0.5659
# 	--- Save best at ep 15, val_loss: 1.2013, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 16/101 - loss: 1.0992 - accuracy: 0.5728 - val_loss: 1.2513 - val_accuracy: 0.5595
# 	-!- No improvement: 1/20
# Epoch 17/101 - loss: 1.0736 - accuracy: 0.5850 - val_loss: 1.2081 - val_accuracy: 0.5350
# 	-!- No improvement: 2/20
# Epoch 18/101 - loss: 1.0704 - accuracy: 0.5806 - val_loss: 1.2346 - val_accuracy: 0.5726
# 	-!- No improvement: 3/20
# Epoch 19/101 - loss: 1.0543 - accuracy: 0.5872 - val_loss: 1.2942 - val_accuracy: 0.5319
# 	-!- No improvement: 4/20
# Epoch 20/101 - loss: 1.0056 - accuracy: 0.6031 - val_loss: 1.1535 - val_accuracy: 0.5768
# 	--- Save best at ep 20, val_loss: 1.1535, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 21/101 - loss: 0.9816 - accuracy: 0.6095 - val_loss: 1.1724 - val_accuracy: 0.5667
# 	-!- No improvement: 1/20
# Epoch 22/101 - loss: 0.9737 - accuracy: 0.6123 - val_loss: 1.1835 - val_accuracy: 0.5901
# 	-!- No improvement: 2/20
# Epoch 23/101 - loss: 0.9639 - accuracy: 0.6174 - val_loss: 1.1644 - val_accuracy: 0.5957
# 	-!- No improvement: 3/20
# Epoch 24/101 - loss: 0.9571 - accuracy: 0.6209 - val_loss: 1.2033 - val_accuracy: 0.5974
# 	-!- No improvement: 4/20
# Epoch 25/101 - loss: 0.9199 - accuracy: 0.6314 - val_loss: 1.1557 - val_accuracy: 0.5896
# 	-!- No improvement: 5/20
# Epoch 26/101 - loss: 0.9056 - accuracy: 0.6367 - val_loss: 1.1478 - val_accuracy: 0.6055
# 	--- Save best at ep 26, val_loss: 1.1478, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth ---
# Epoch 27/101 - loss: 0.9005 - accuracy: 0.6406 - val_loss: 1.1504 - val_accuracy: 0.6043
# 	-!- No improvement: 1/20
# Epoch 28/101 - loss: 0.8899 - accuracy: 0.6394 - val_loss: 1.1850 - val_accuracy: 0.5985
# 	-!- No improvement: 2/20
# Epoch 29/101 - loss: 0.8785 - accuracy: 0.6424 - val_loss: 1.1558 - val_accuracy: 0.6121
# 	-!- No improvement: 3/20
# Epoch 30/101 - loss: 0.8753 - accuracy: 0.6460 - val_loss: 1.1575 - val_accuracy: 0.6018
# 	-!- No improvement: 4/20
# Epoch 31/101 - loss: 0.8568 - accuracy: 0.6516 - val_loss: 1.1598 - val_accuracy: 0.6105
# 	-!- No improvement: 5/20
# Epoch 32/101 - loss: 0.8521 - accuracy: 0.6550 - val_loss: 1.1605 - val_accuracy: 0.6096
# 	-!- No improvement: 6/20
# Epoch 33/101 - loss: 0.8410 - accuracy: 0.6597 - val_loss: 1.1561 - val_accuracy: 0.6166
# 	-!- No improvement: 7/20
# Epoch 34/101 - loss: 0.8416 - accuracy: 0.6551 - val_loss: 1.1695 - val_accuracy: 0.6133
# 	-!- No improvement: 8/20
# Epoch 35/101 - loss: 0.8327 - accuracy: 0.6614 - val_loss: 1.1607 - val_accuracy: 0.6119
# 	-!- No improvement: 9/20
# Epoch 36/101 - loss: 0.8242 - accuracy: 0.6622 - val_loss: 1.1578 - val_accuracy: 0.6141
# 	-!- No improvement: 10/20
# Epoch 37/101 - loss: 0.8222 - accuracy: 0.6652 - val_loss: 1.1596 - val_accuracy: 0.6216
# 	-!- No improvement: 11/20
# Epoch 38/101 - loss: 0.8205 - accuracy: 0.6661 - val_loss: 1.1521 - val_accuracy: 0.6172
# 	-!- No improvement: 12/20
# Epoch 39/101 - loss: 0.8140 - accuracy: 0.6683 - val_loss: 1.1632 - val_accuracy: 0.6208
# 	-!- No improvement: 13/20
# Epoch 40/101 - loss: 0.8152 - accuracy: 0.6683 - val_loss: 1.1589 - val_accuracy: 0.6177
# 	-!- No improvement: 14/20
# Epoch 41/101 - loss: 0.8092 - accuracy: 0.6719 - val_loss: 1.1630 - val_accuracy: 0.6208
# 	-!- No improvement: 15/20
# Epoch 42/101 - loss: 0.8108 - accuracy: 0.6694 - val_loss: 1.1683 - val_accuracy: 0.6213
# 	-!- No improvement: 16/20
# Epoch 43/101 - loss: 0.8076 - accuracy: 0.6729 - val_loss: 1.1556 - val_accuracy: 0.6197
# 	-!- No improvement: 17/20
# Epoch 44/101 - loss: 0.8037 - accuracy: 0.6727 - val_loss: 1.1611 - val_accuracy: 0.6169
# 	-!- No improvement: 18/20
# Epoch 45/101 - loss: 0.8044 - accuracy: 0.6710 - val_loss: 1.1640 - val_accuracy: 0.6183
# 	-!- No improvement: 19/20
# Epoch 46/101 - loss: 0.8076 - accuracy: 0.6716 - val_loss: 1.1638 - val_accuracy: 0.6183
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=46
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_13042026_1134_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:07<00:00,  7.21it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 62.86%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.570231  0.553971  0.561983   491.000000
# disgust        0.438776  0.781818  0.562092    55.000000
# fear           0.492424  0.369318  0.422078   528.000000
# happy          0.843387  0.827076  0.835152   879.000000
# sad            0.454545  0.538721  0.493066   594.000000
# surprise       0.724062  0.788462  0.754891   416.000000
# neutral        0.619366  0.592652  0.605714   626.000000
# accuracy       0.628587  0.628587  0.628587     0.628587
# macro avg      0.591827  0.636003  0.604997  3589.000000
# weighted avg   0.630924  0.628587  0.626887  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `inception_13042026_1134_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_7nqtjsxx (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_7nqtjsxx (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_7nqtjsxx (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_7nqtjsxx (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_7nqtjsxx (0.5s)
# wandb: ⣯ uploading artifact cnn_7nqtjsxx (0.5s)
# wandb: ⣟ uploading artifact cnn_7nqtjsxx (0.5s)
# wandb: ⡿ uploading artifact cnn_7nqtjsxx (0.5s)
# wandb: ⢿ uploading artifact cnn_7nqtjsxx (0.5s)
# wandb: ⣻ uploading artifact cnn_7nqtjsxx (1.0s)
# wandb:   ↳ ⣻ inception_13042026_1134_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣽ uploading artifact cnn_7nqtjsxx (1.0s)
# wandb:   ↳ ⣽ inception_13042026_1134_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣾ uploading artifact cnn_7nqtjsxx (1.0s)
# wandb:   ↳ ⣾ inception_13042026_1134_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣷ uploading artifact cnn_7nqtjsxx (1.0s)
# wandb:   ↳ ⣷ inception_13042026_1134_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣯ uploading artifact cnn_7nqtjsxx (1.0s)
# wandb:   ↳ ⣯ inception_13042026_1134_best.pth 25.8MB/25.8MB (0.4s)
# wandb: ⣟ uploading artifact cnn_7nqtjsxx (1.5s)
# wandb: ⡿ uploading artifact cnn_7nqtjsxx (1.5s)
# wandb: ⢿ uploading artifact cnn_7nqtjsxx (1.5s)
# wandb: ⣻ uploading artifact cnn_7nqtjsxx (1.5s)
# wandb: ⣽ uploading artifact cnn_7nqtjsxx (1.5s)
# wandb: ⣾ uploading media/images/Evaluation/Correct_Samples_46_26ff0d8ac974e22...
# wandb: ⣾ uploading media/images/Evaluation/Wrong_Samples_47_b2fc6a352fc9d7ccb...
# wandb: ⣾ uploading output.log 8.3KB/8.3KB (0.1s)
# wandb: ⣾ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣾ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⣾ uploading media/images/Evaluation/Confusion_Matrix_45_193f31c641c9cf...
# wandb: ⣷ uploading media/images/Evaluation/Correct_Samples_46_26ff0d8ac974e22...
# wandb: ⣷ uploading media/images/Evaluation/Wrong_Samples_47_b2fc6a352fc9d7ccb...
# wandb: ⣷ uploading output.log 8.3KB/8.3KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 1.0KB/1.0KB (0.1s)
# wandb: ⣷ uploading config.yaml 3.4KB/3.4KB (0.1s)
# wandb: ⣷ uploading media/images/Evaluation/Confusion_Matrix_45_193f31c641c9cf...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████
# wandb:  Learning_Rate ████████▄▄▄▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:     Train/Loss █▇▆▆▅▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█▇██████████████████
# wandb:       Val/Loss █▇▆▅▄▄▄▄▂▂▃▂▂▂▂▂▃▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 46
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.67157
# wandb:     Train/Loss 0.80758
# wandb:   Val/Accuracy 0.61828
# wandb:       Val/Loss 1.1638
# wandb:
# wandb: 🚀 View run inception_13042026_1134 at: https://wandb.ai/phucga15062005/FER2013/runs/7nqtjsxx
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260413_113416-7nqtjsxx/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
