# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 981, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 981 (delta 174), reused 155 (delta 124), pack-reused 751 (from 2)
# Receiving objects: 100% (981/981), 5.89 MiB | 24.13 MiB/s, done.
# Resolving deltas: 100% (614/614), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config inception --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_111111-c6ija9z3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run inception_10042026_1111
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/c6ija9z3
#
# --> Start training in total 101 epochs with cuda device. Start...
#
# Epoch 1/101 - loss: 2.3641 - accuracy: 0.2653 - val_loss: 1.6941 - val_accuracy: 0.3057
# 	--- Save best at ep 1, val_loss: 1.6941, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 2/101 - loss: 2.1148 - accuracy: 0.3339 - val_loss: 1.5679 - val_accuracy: 0.3887
# 	--- Save best at ep 2, val_loss: 1.5679, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 3/101 - loss: 1.9602 - accuracy: 0.3997 - val_loss: 1.4351 - val_accuracy: 0.4394
# 	--- Save best at ep 3, val_loss: 1.4351, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 4/101 - loss: 1.8465 - accuracy: 0.4455 - val_loss: 1.3645 - val_accuracy: 0.4636
# 	--- Save best at ep 4, val_loss: 1.3645, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 5/101 - loss: 1.7564 - accuracy: 0.4790 - val_loss: 1.3734 - val_accuracy: 0.4857
# 	-!- No improvement: 1/20
# Epoch 6/101 - loss: 1.6886 - accuracy: 0.5062 - val_loss: 1.4564 - val_accuracy: 0.4388
# 	-!- No improvement: 2/20
# Epoch 7/101 - loss: 1.6402 - accuracy: 0.5223 - val_loss: 1.2575 - val_accuracy: 0.5230
# 	--- Save best at ep 7, val_loss: 1.2575, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 8/101 - loss: 1.5995 - accuracy: 0.5358 - val_loss: 1.2200 - val_accuracy: 0.5327
# 	--- Save best at ep 8, val_loss: 1.2200, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 9/101 - loss: 1.5750 - accuracy: 0.5407 - val_loss: 1.1842 - val_accuracy: 0.5514
# 	--- Save best at ep 9, val_loss: 1.1842, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 10/101 - loss: 1.5508 - accuracy: 0.5536 - val_loss: 1.1360 - val_accuracy: 0.5706
# 	--- Save best at ep 10, val_loss: 1.1360, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 11/101 - loss: 1.5284 - accuracy: 0.5625 - val_loss: 1.2570 - val_accuracy: 0.5358
# 	-!- No improvement: 1/20
# Epoch 12/101 - loss: 1.5121 - accuracy: 0.5646 - val_loss: 1.1977 - val_accuracy: 0.5481
# 	-!- No improvement: 2/20
# Epoch 13/101 - loss: 1.4895 - accuracy: 0.5704 - val_loss: 1.1186 - val_accuracy: 0.5823
# 	--- Save best at ep 13, val_loss: 1.1186, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 14/101 - loss: 1.4805 - accuracy: 0.5786 - val_loss: 1.1558 - val_accuracy: 0.5609
# 	-!- No improvement: 1/20
# Epoch 15/101 - loss: 1.4583 - accuracy: 0.5824 - val_loss: 1.1558 - val_accuracy: 0.5612
# 	-!- No improvement: 2/20
# Epoch 16/101 - loss: 1.4490 - accuracy: 0.5876 - val_loss: 1.1311 - val_accuracy: 0.5782
# 	-!- No improvement: 3/20
# Epoch 17/101 - loss: 1.4384 - accuracy: 0.5898 - val_loss: 1.1339 - val_accuracy: 0.5726
# 	-!- No improvement: 4/20
# Epoch 18/101 - loss: 1.3749 - accuracy: 0.6126 - val_loss: 1.0485 - val_accuracy: 0.6010
# 	--- Save best at ep 18, val_loss: 1.0485, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 19/101 - loss: 1.3514 - accuracy: 0.6154 - val_loss: 1.0710 - val_accuracy: 0.6004
# 	-!- No improvement: 1/20
# Epoch 20/101 - loss: 1.3415 - accuracy: 0.6223 - val_loss: 1.0789 - val_accuracy: 0.5996
# 	-!- No improvement: 2/20
# Epoch 21/101 - loss: 1.3322 - accuracy: 0.6226 - val_loss: 1.0664 - val_accuracy: 0.6013
# 	-!- No improvement: 3/20
# Epoch 22/101 - loss: 1.3263 - accuracy: 0.6270 - val_loss: 1.0811 - val_accuracy: 0.5932
# 	-!- No improvement: 4/20
# Epoch 23/101 - loss: 1.2812 - accuracy: 0.6399 - val_loss: 1.0296 - val_accuracy: 0.6227
# 	--- Save best at ep 23, val_loss: 1.0296, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 24/101 - loss: 1.2664 - accuracy: 0.6432 - val_loss: 1.0240 - val_accuracy: 0.6244
# 	--- Save best at ep 24, val_loss: 1.0240, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 25/101 - loss: 1.2605 - accuracy: 0.6436 - val_loss: 1.0245 - val_accuracy: 0.6216
# 	-!- No improvement: 1/20
# Epoch 26/101 - loss: 1.2548 - accuracy: 0.6456 - val_loss: 1.0090 - val_accuracy: 0.6252
# 	--- Save best at ep 26, val_loss: 1.0090, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 27/101 - loss: 1.2402 - accuracy: 0.6552 - val_loss: 1.0155 - val_accuracy: 0.6169
# 	-!- No improvement: 1/20
# Epoch 28/101 - loss: 1.2371 - accuracy: 0.6539 - val_loss: 1.0028 - val_accuracy: 0.6291
# 	--- Save best at ep 28, val_loss: 1.0028, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 29/101 - loss: 1.2289 - accuracy: 0.6553 - val_loss: 1.0035 - val_accuracy: 0.6319
# 	-!- No improvement: 1/20
# Epoch 30/101 - loss: 1.2213 - accuracy: 0.6581 - val_loss: 1.0253 - val_accuracy: 0.6291
# 	-!- No improvement: 2/20
# Epoch 31/101 - loss: 1.2126 - accuracy: 0.6605 - val_loss: 1.0198 - val_accuracy: 0.6186
# 	-!- No improvement: 3/20
# Epoch 32/101 - loss: 1.2093 - accuracy: 0.6606 - val_loss: 1.0060 - val_accuracy: 0.6353
# 	-!- No improvement: 4/20
# Epoch 33/101 - loss: 1.1761 - accuracy: 0.6739 - val_loss: 0.9946 - val_accuracy: 0.6378
# 	--- Save best at ep 33, val_loss: 0.9946, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 34/101 - loss: 1.1637 - accuracy: 0.6785 - val_loss: 1.0010 - val_accuracy: 0.6330
# 	-!- No improvement: 1/20
# Epoch 35/101 - loss: 1.1616 - accuracy: 0.6792 - val_loss: 0.9880 - val_accuracy: 0.6400
# 	--- Save best at ep 35, val_loss: 0.9880, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 36/101 - loss: 1.1609 - accuracy: 0.6789 - val_loss: 1.0010 - val_accuracy: 0.6339
# 	-!- No improvement: 1/20
# Epoch 37/101 - loss: 1.1521 - accuracy: 0.6796 - val_loss: 0.9740 - val_accuracy: 0.6467
# 	--- Save best at ep 37, val_loss: 0.9740, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 38/101 - loss: 1.1543 - accuracy: 0.6818 - val_loss: 0.9933 - val_accuracy: 0.6367
# 	-!- No improvement: 1/20
# Epoch 39/101 - loss: 1.1458 - accuracy: 0.6815 - val_loss: 0.9970 - val_accuracy: 0.6386
# 	-!- No improvement: 2/20
# Epoch 40/101 - loss: 1.1350 - accuracy: 0.6848 - val_loss: 0.9927 - val_accuracy: 0.6381
# 	-!- No improvement: 3/20
# Epoch 41/101 - loss: 1.1389 - accuracy: 0.6885 - val_loss: 0.9764 - val_accuracy: 0.6445
# 	-!- No improvement: 4/20
# Epoch 42/101 - loss: 1.1130 - accuracy: 0.6927 - val_loss: 0.9857 - val_accuracy: 0.6442
# 	-!- No improvement: 5/20
# Epoch 43/101 - loss: 1.1138 - accuracy: 0.6940 - val_loss: 0.9798 - val_accuracy: 0.6475
# 	-!- No improvement: 6/20
# Epoch 44/101 - loss: 1.1096 - accuracy: 0.6988 - val_loss: 0.9854 - val_accuracy: 0.6450
# 	-!- No improvement: 7/20
# Epoch 45/101 - loss: 1.1042 - accuracy: 0.6999 - val_loss: 0.9810 - val_accuracy: 0.6481
# 	-!- No improvement: 8/20
# Epoch 46/101 - loss: 1.0900 - accuracy: 0.7030 - val_loss: 0.9729 - val_accuracy: 0.6520
# 	--- Save best at ep 46, val_loss: 0.9729, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth ---
# Epoch 47/101 - loss: 1.0928 - accuracy: 0.7024 - val_loss: 0.9753 - val_accuracy: 0.6473
# 	-!- No improvement: 1/20
# Epoch 48/101 - loss: 1.0859 - accuracy: 0.7040 - val_loss: 0.9793 - val_accuracy: 0.6481
# 	-!- No improvement: 2/20
# Epoch 49/101 - loss: 1.0846 - accuracy: 0.7052 - val_loss: 0.9857 - val_accuracy: 0.6481
# 	-!- No improvement: 3/20
# Epoch 50/101 - loss: 1.0861 - accuracy: 0.7033 - val_loss: 0.9756 - val_accuracy: 0.6503
# 	-!- No improvement: 4/20
# Epoch 51/101 - loss: 1.0721 - accuracy: 0.7077 - val_loss: 0.9776 - val_accuracy: 0.6506
# 	-!- No improvement: 5/20
# Epoch 52/101 - loss: 1.0757 - accuracy: 0.7048 - val_loss: 0.9811 - val_accuracy: 0.6489
# 	-!- No improvement: 6/20
# Epoch 53/101 - loss: 1.0778 - accuracy: 0.7054 - val_loss: 0.9772 - val_accuracy: 0.6520
# 	-!- No improvement: 7/20
# Epoch 54/101 - loss: 1.0715 - accuracy: 0.7085 - val_loss: 0.9772 - val_accuracy: 0.6514
# 	-!- No improvement: 8/20
# Epoch 55/101 - loss: 1.0646 - accuracy: 0.7092 - val_loss: 0.9772 - val_accuracy: 0.6542
# 	-!- No improvement: 9/20
# Epoch 56/101 - loss: 1.0685 - accuracy: 0.7097 - val_loss: 0.9798 - val_accuracy: 0.6509
# 	-!- No improvement: 10/20
# Epoch 57/101 - loss: 1.0670 - accuracy: 0.7089 - val_loss: 0.9853 - val_accuracy: 0.6498
# 	-!- No improvement: 11/20
# Epoch 58/101 - loss: 1.0628 - accuracy: 0.7124 - val_loss: 0.9814 - val_accuracy: 0.6498
# 	-!- No improvement: 12/20
# Epoch 59/101 - loss: 1.0649 - accuracy: 0.7118 - val_loss: 0.9778 - val_accuracy: 0.6503
# 	-!- No improvement: 13/20
# Epoch 60/101 - loss: 1.0633 - accuracy: 0.7121 - val_loss: 0.9792 - val_accuracy: 0.6509
# 	-!- No improvement: 14/20
# Epoch 61/101 - loss: 1.0661 - accuracy: 0.7091 - val_loss: 0.9743 - val_accuracy: 0.6539
# 	-!- No improvement: 15/20
# Epoch 62/101 - loss: 1.0642 - accuracy: 0.7089 - val_loss: 0.9769 - val_accuracy: 0.6537
# 	-!- No improvement: 16/20
# Epoch 63/101 - loss: 1.0661 - accuracy: 0.7112 - val_loss: 0.9804 - val_accuracy: 0.6500
# 	-!- No improvement: 17/20
# Epoch 64/101 - loss: 1.0637 - accuracy: 0.7112 - val_loss: 0.9756 - val_accuracy: 0.6512
# 	-!- No improvement: 18/20
# Epoch 65/101 - loss: 1.0565 - accuracy: 0.7139 - val_loss: 0.9781 - val_accuracy: 0.6512
# 	-!- No improvement: 19/20
# Epoch 66/101 - loss: 1.0632 - accuracy: 0.7121 - val_loss: 0.9814 - val_accuracy: 0.6509
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=66
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/inception/inception_10042026_1111_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:05<00:00,  9.71it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.18%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.615054  0.582485  0.598326   491.000000
# disgust        0.700000  0.509091  0.589474    55.000000
# fear           0.568915  0.367424  0.446490   528.000000
# happy          0.860087  0.902162  0.880622   879.000000
# sad            0.514961  0.550505  0.532140   594.000000
# surprise       0.748235  0.764423  0.756243   416.000000
# neutral        0.611038  0.742812  0.670512   626.000000
# accuracy       0.671775  0.671775  0.671775     0.671775
# macro avg      0.659756  0.631272  0.639115  3589.000000
# weighted avg   0.667751  0.671775  0.664932  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `inception_10042026_1111_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_c6ija9z3 (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_c6ija9z3 (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_c6ija9z3 (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_c6ija9z3 (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_c6ija9z3 (0.5s)
# wandb: ⣯ uploading artifact cnn_c6ija9z3 (0.5s)
# wandb: ⣟ uploading artifact cnn_c6ija9z3 (0.5s)
# wandb: ⡿ uploading artifact cnn_c6ija9z3 (0.5s)
# wandb: ⢿ uploading artifact cnn_c6ija9z3 (0.5s)
# wandb: ⣻ uploading artifact cnn_c6ija9z3 (1.0s)
# wandb:   ↳ ⣻ inception_10042026_1111_best.pth 27.6MB/27.6MB (0.4s)
# wandb: ⣽ uploading artifact cnn_c6ija9z3 (1.0s)
# wandb:   ↳ ⣽ inception_10042026_1111_best.pth 27.6MB/27.6MB (0.4s)
# wandb: ⣾ uploading artifact cnn_c6ija9z3 (1.0s)
# wandb:   ↳ ⣾ inception_10042026_1111_best.pth 27.6MB/27.6MB (0.4s)
# wandb: ⣷ uploading artifact cnn_c6ija9z3 (1.0s)
# wandb:   ↳ ⣷ inception_10042026_1111_best.pth 27.6MB/27.6MB (0.4s)
# wandb: ⣯ uploading artifact cnn_c6ija9z3 (1.0s)
# wandb:   ↳ ⣯ inception_10042026_1111_best.pth 27.6MB/27.6MB (0.4s)
# wandb: ⣟ uploading artifact cnn_c6ija9z3 (1.5s)
# wandb: ⡿ uploading artifact cnn_c6ija9z3 (1.5s)
# wandb: ⢿ uploading artifact cnn_c6ija9z3 (1.5s)
# wandb: ⣻ uploading artifact cnn_c6ija9z3 (1.5s)
# wandb: ⣽ uploading artifact cnn_c6ija9z3 (1.5s)
# wandb: ⣾ uploading history steps 65-67, summary, console lines 142-164 (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██
# wandb:  Learning_Rate ███████████▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▂▃▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████████
# wandb:     Train/Loss █▇▆▆▅▄▄▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▃▄▄▅▅▆▆▆▇▆▆▇▇▇▇▇▇▇▇▇███████████████████
# wandb:       Val/Loss █▆▆▆▄▃▄▄▃▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 66
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.71208
# wandb:     Train/Loss 1.06319
# wandb:   Val/Accuracy 0.65088
# wandb:       Val/Loss 0.98142
# wandb:
# wandb: 🚀 View run inception_10042026_1111 at: https://wandb.ai/phucga15062005/FER2013/runs/c6ija9z3
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_111111-c6ija9z3/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
