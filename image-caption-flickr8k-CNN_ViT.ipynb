# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 8095

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "image-captioning-flickr8k-iu"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'image-captioning-flickr8k-iu'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 157 (delta 68), reused 121 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 39.27 KiB | 6.54 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# Repo ready: /kaggle/working/image-captioning-flickr8k-iu
#
# Current working dir: /kaggle/working/image-captioning-flickr8k-iu

# %%
# !python -m scripts.train --config transformer --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Image Dir: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/images
# --> Captions File: /kaggle/input/datasets/doduyquynii/flickr8k-toy-model/flickr8k/captions.txt
# Loading captions...
# Filtering valid images...
# Building vocabulary from Train set...
# Building datasets...
# Loader done: Train (30000), Val (5000), Test (5000)
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|███████████████████████████████████████| 20.5M/20.5M [00:00<00:00, 127MB/s]
# --> [Scheduler] StepLR (step_size=5, gamma=0.5)
#
# --> Train on 30000 samples, validate on 5000 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run prrrwdmv (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/image-captioning-flickr8k-iu/wandb/run-20260408_053851-prrrwdmv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run transformer_08042026_0537
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/image-captioning
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/image-captioning/runs/prrrwdmv
#
# --> Start training in total 50 epochs with cuda device. Start...
#
# Epoch 1/50 - loss: 3.4774 - val_loss: 3.0147
# 	--- Save best at ep 1, val_loss: 3.0147, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 2/50 - loss: 2.7456 - val_loss: 2.7919
# 	--- Save best at ep 2, val_loss: 2.7919, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 3/50 - loss: 2.4716 - val_loss: 2.7018
# 	--- Save best at ep 3, val_loss: 2.7018, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 4/50 - loss: 2.2875 - val_loss: 2.6663
# 	--- Save best at ep 4, val_loss: 2.6663, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 5/50 - loss: 2.1391 - val_loss: 2.6654
# 	--- Save best at ep 5, val_loss: 2.6654, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 6/50 - loss: 1.9409 - val_loss: 2.6449
# 	--- Save best at ep 6, val_loss: 2.6449, path: /kaggle/working/image-captioning-flickr8k-iu/outputs/checkpoints/transformer/transformer_08042026_0537_best.pth ---
# Epoch 7/50 - loss: 1.8646 - val_loss: 2.6696
# 	-!- No improvement: 1/10
# Epoch 8/50 - loss: 1.7985 - val_loss: 2.6853
# 	-!- No improvement: 2/10
# Epoch 9/50 - loss: 1.7390 - val_loss: 2.7068
# 	-!- No improvement: 3/10
# Epoch 10/50 - loss: 1.6836 - val_loss: 2.7234
# 	-!- No improvement: 4/10
# Epoch 11/50 - loss: 1.5837 - val_loss: 2.7477
# 	-!- No improvement: 5/10
# Epoch 12/50 - loss: 1.5467 - val_loss: 2.7646
# 	-!- No improvement: 6/10
# Epoch 13/50 - loss: 1.5163 - val_loss: 2.7882
# 	-!- No improvement: 7/10
# Epoch 14/50 - loss: 1.4886 - val_loss: 2.8024
# 	-!- No improvement: 8/10
# Epoch 15/50 - loss: 1.4611 - val_loss: 2.8220
# 	-!- No improvement: 9/10
# Epoch 16/50 - loss: 1.4051 - val_loss: 2.8406
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=16
#
# ===================================================
# Evaluate on Test set
# ===================================================
# --> [Evaluation] Đang đánh giá trên 5000 mẫu (greedy)...
# 100%|█████████████████████████████████████████| 157/157 [02:20<00:00,  1.12it/s]
#    BLEU-1: 0.3262
#    BLEU-2: 0.1634
#    BLEU-3: 0.0988
#    BLEU-4: 0.0653
#
# Ví dụ 1:
#   Gốc: a blond woman in a blue shirt appears to wait for a ride .
#   Dự đoán: a woman in a blue shirt is standing in the street with a <unk> in the background .
# Figure(1000x800)
#
# Ví dụ 2:
#   Gốc: a small dogs ears stick up as it runs in the grass .
#   Dự đoán: a small tan dog runs through the grass .
# Figure(1000x800)
#
# Ví dụ 3:
#   Gốc: three people in the snow put their gear in <unk> .
#   Dự đoán: a group of people are in the snow .
# Figure(1000x800)
#
# Ví dụ 4:
#   Gốc: three children playing in sand at beach
#   Dự đoán: a girl in a pink shirt is playing with a man in the sand .
# Figure(1000x800)
#
# Ví dụ 5:
#   Gốc: two women and a child are sitting by a cart of <unk> in front of a booth at a medieval <unk> .
#   Dự đoán: a girl in a dress dress is sitting on a <unk> .
# Figure(1000x800)
#
# Ví dụ 6:
#   Gốc: a man sleeping with a bag on his lap on public <unk>
#   Dự đoán: a man in black and a black jacket is sitting in a subway station .
# Figure(1000x800)
#
# Ví dụ 7:
#   Gốc: a young girl balances on wooden <unk> at the beach .
#   Dự đoán: a child in a blue shirt and jeans runs along a beach .
# Figure(1000x800)
#
# Ví dụ 8:
#   Gốc: two women sitting in the grass with their bikes behind them .
#   Dự đoán: three boys in white shirts and orange shirts are running in a grassy area .
# Figure(1000x800)
#
# Ví dụ 9:
#   Gốc: a little girl in a flowered <unk> runs through the sand at the beach
#   Dự đoán: a young boy in a swimsuit runs along the beach .
# Figure(1000x800)
#
# Ví dụ 10:
#   Gốc: person hiking up a grassy trail toward a large hill .
#   Dự đoán: a young boy in a blue shirt is walking up a large rock .
# Figure(1000x800)
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `transformer_08042026_0537_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_prrrwdmv (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_prrrwdmv (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_prrrwdmv (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_prrrwdmv (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_prrrwdmv (0.5s)
# wandb:   ↳ ⣷ transformer_08042026_0537_best.pth 1.1MB/178.2MB (0.1s)
# wandb: ⣯ uploading artifact cnn_prrrwdmv (0.5s)
# wandb:   ↳ ⣯ transformer_08042026_0537_best.pth 1.1MB/178.2MB (0.1s)
# wandb: ⣟ uploading artifact cnn_prrrwdmv (0.5s)
# wandb:   ↳ ⣟ transformer_08042026_0537_best.pth 1.1MB/178.2MB (0.1s)
# wandb: ⡿ uploading artifact cnn_prrrwdmv (0.5s)
# wandb:   ↳ ⡿ transformer_08042026_0537_best.pth 1.1MB/178.2MB (0.1s)
# wandb: ⢿ uploading artifact cnn_prrrwdmv (0.5s)
# wandb:   ↳ ⢿ transformer_08042026_0537_best.pth 1.1MB/178.2MB (0.1s)
# wandb: ⣻ uploading artifact cnn_prrrwdmv (1.0s)
# wandb:   ↳ ⣻ transformer_08042026_0537_best.pth 20.0MB/178.2MB (0.6s)
# wandb: ⣽ uploading artifact cnn_prrrwdmv (1.0s)
# wandb:   ↳ ⣽ transformer_08042026_0537_best.pth 20.0MB/178.2MB (0.6s)
# wandb: ⣾ uploading artifact cnn_prrrwdmv (1.0s)
# wandb:   ↳ ⣾ transformer_08042026_0537_best.pth 20.0MB/178.2MB (0.6s)
# wandb: ⣷ uploading artifact cnn_prrrwdmv (1.0s)
# wandb:   ↳ ⣷ transformer_08042026_0537_best.pth 20.0MB/178.2MB (0.6s)
# wandb: ⣯ uploading artifact cnn_prrrwdmv (1.0s)
# wandb:   ↳ ⣯ transformer_08042026_0537_best.pth 20.0MB/178.2MB (0.6s)
# wandb: ⣟ uploading artifact cnn_prrrwdmv (1.5s)
# wandb:   ↳ ⣟ transformer_08042026_0537_best.pth 59.0MB/178.2MB (1.1s)
# wandb: ⡿ uploading artifact cnn_prrrwdmv (1.5s)
# wandb:   ↳ ⡿ transformer_08042026_0537_best.pth 59.0MB/178.2MB (1.1s)
# wandb: ⢿ uploading artifact cnn_prrrwdmv (1.5s)
# wandb:   ↳ ⢿ transformer_08042026_0537_best.pth 59.0MB/178.2MB (1.1s)
# wandb: ⣻ uploading artifact cnn_prrrwdmv (1.5s)
# wandb:   ↳ ⣻ transformer_08042026_0537_best.pth 59.0MB/178.2MB (1.1s)
# wandb: ⣽ uploading artifact cnn_prrrwdmv (1.5s)
# wandb:   ↳ ⣽ transformer_08042026_0537_best.pth 59.0MB/178.2MB (1.1s)
# wandb: ⣾ uploading artifact cnn_prrrwdmv (2.0s)
# wandb:   ↳ ⣾ transformer_08042026_0537_best.pth 99.4MB/178.2MB (1.6s)
# wandb: ⣷ uploading artifact cnn_prrrwdmv (2.0s)
# wandb:   ↳ ⣷ transformer_08042026_0537_best.pth 99.4MB/178.2MB (1.6s)
# wandb: ⣯ uploading artifact cnn_prrrwdmv (2.0s)
# wandb:   ↳ ⣯ transformer_08042026_0537_best.pth 99.4MB/178.2MB (1.6s)
# wandb: ⣟ uploading artifact cnn_prrrwdmv (2.0s)
# wandb:   ↳ ⣟ transformer_08042026_0537_best.pth 99.4MB/178.2MB (1.6s)
# wandb: ⡿ uploading artifact cnn_prrrwdmv (2.0s)
# wandb:   ↳ ⡿ transformer_08042026_0537_best.pth 99.4MB/178.2MB (1.6s)
# wandb: ⢿ uploading artifact cnn_prrrwdmv (2.5s)
# wandb:   ↳ ⢿ transformer_08042026_0537_best.pth 142.6MB/178.2MB (2.1s)
# wandb: ⣻ uploading artifact cnn_prrrwdmv (2.5s)
# wandb:   ↳ ⣻ transformer_08042026_0537_best.pth 142.6MB/178.2MB (2.1s)
# wandb: ⣽ uploading artifact cnn_prrrwdmv (2.5s)
# wandb:   ↳ ⣽ transformer_08042026_0537_best.pth 142.6MB/178.2MB (2.1s)
# wandb: ⣾ uploading artifact cnn_prrrwdmv (2.5s)
# wandb:   ↳ ⣾ transformer_08042026_0537_best.pth 142.6MB/178.2MB (2.1s)
# wandb: ⣷ uploading artifact cnn_prrrwdmv (2.5s)
# wandb:   ↳ ⣷ transformer_08042026_0537_best.pth 142.6MB/178.2MB (2.1s)
# wandb: ⣯ uploading artifact cnn_prrrwdmv (3.0s)
# wandb:   ↳ ⣯ transformer_08042026_0537_best.pth 178.2MB/178.2MB (2.6s)
# wandb: ⣟ uploading artifact cnn_prrrwdmv (3.0s)
# wandb:   ↳ ⣟ transformer_08042026_0537_best.pth 178.2MB/178.2MB (2.6s)
# wandb: ⡿ uploading artifact cnn_prrrwdmv (3.0s)
# wandb:   ↳ ⡿ transformer_08042026_0537_best.pth 178.2MB/178.2MB (2.6s)
# wandb: ⢿ uploading artifact cnn_prrrwdmv (3.0s)
# wandb:   ↳ ⢿ transformer_08042026_0537_best.pth 178.2MB/178.2MB (2.6s)
# wandb: ⣻ uploading artifact cnn_prrrwdmv (3.0s)
# wandb:   ↳ ⣻ transformer_08042026_0537_best.pth 178.2MB/178.2MB (2.6s)
# wandb: ⣽ uploading artifact cnn_prrrwdmv (3.5s)
# wandb: ⣾ uploading artifact cnn_prrrwdmv (3.5s)
# wandb: ⣷ uploading artifact cnn_prrrwdmv (3.5s)
# wandb: ⣯ uploading artifact cnn_prrrwdmv (3.5s)
# wandb: ⣟ uploading artifact cnn_prrrwdmv (3.5s)
# wandb: ⡿ uploading config.yaml 3.6KB/3.6KB (0.2s)
# wandb: ⡿ uploading output.log 4.2KB/4.2KB (0.2s)
# wandb: ⢿ uploading config.yaml 3.6KB/3.6KB (0.2s)
# wandb: ⢿ uploading output.log 4.2KB/4.2KB (0.2s)
# wandb: ⣻ uploading config.yaml 3.6KB/3.6KB (0.2s)
# wandb: ⣻ uploading output.log 4.2KB/4.2KB (0.2s)
# wandb:
# wandb: Run history:
# wandb:         Epoch ▁▁▂▂▃▃▄▄▅▅▆▆▇▇██
# wandb: Learning_Rate █████▄▄▄▄▄▂▂▂▂▂▁
# wandb:    Train/Loss █▆▅▄▃▃▃▂▂▂▂▁▁▁▁▁
# wandb:      Val/Loss █▄▂▁▁▁▁▂▂▂▃▃▄▄▄▅
# wandb:
# wandb: Run summary:
# wandb:         Epoch 16
# wandb: Learning_Rate 1e-05
# wandb:    Train/Loss 1.40515
# wandb:      Val/Loss 2.84061
# wandb:
# wandb: 🚀 View run transformer_08042026_0537 at: https://wandb.ai/phucga15062005/image-captioning/runs/prrrwdmv
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/image-captioning
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260408_053851-prrrwdmv/logs
#
# 		DONE!
#
#
# 		DONE!
