# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 3

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 977, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 977 (delta 171), reused 154 (delta 124), pack-reused 751 (from 2)
# Receiving objects: 100% (977/977), 5.89 MiB | 25.56 MiB/s, done.
# Resolving deltas: 100% (611/611), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_spatial_fusion --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> Using Spatial Attention + Fusion
# --> Using Class Weights to handle imbalance...
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run coyd3xzi (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260410_105307-coyd3xzi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vgg_spatial_10042026_1053
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/coyd3xzi
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# Epoch 1/100 - loss: 2.6881 - accuracy: 0.1816 - val_loss: 1.9090 - val_accuracy: 0.3360
# 	--- Save best at ep 1, val_loss: 1.9090, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 2/100 - loss: 2.4819 - accuracy: 0.3390 - val_loss: 1.7427 - val_accuracy: 0.4299
# 	--- Save best at ep 2, val_loss: 1.7427, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 3/100 - loss: 2.3716 - accuracy: 0.3980 - val_loss: 1.7335 - val_accuracy: 0.4330
# 	--- Save best at ep 3, val_loss: 1.7335, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 4/100 - loss: 2.3181 - accuracy: 0.4363 - val_loss: 1.6763 - val_accuracy: 0.5007
# 	--- Save best at ep 4, val_loss: 1.6763, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 5/100 - loss: 2.2721 - accuracy: 0.4630 - val_loss: 1.6348 - val_accuracy: 0.5339
# 	--- Save best at ep 5, val_loss: 1.6348, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 6/100 - loss: 2.2435 - accuracy: 0.4755 - val_loss: 1.6277 - val_accuracy: 0.5074
# 	--- Save best at ep 6, val_loss: 1.6277, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 7/100 - loss: 2.2067 - accuracy: 0.4896 - val_loss: 1.6241 - val_accuracy: 0.5469
# 	--- Save best at ep 7, val_loss: 1.6241, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 8/100 - loss: 2.1863 - accuracy: 0.5086 - val_loss: 1.6129 - val_accuracy: 0.5600
# 	--- Save best at ep 8, val_loss: 1.6129, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 9/100 - loss: 2.1671 - accuracy: 0.5130 - val_loss: 1.5880 - val_accuracy: 0.5589
# 	--- Save best at ep 9, val_loss: 1.5880, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 10/100 - loss: 2.1515 - accuracy: 0.5227 - val_loss: 1.5627 - val_accuracy: 0.5857
# 	--- Save best at ep 10, val_loss: 1.5627, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 11/100 - loss: 2.1422 - accuracy: 0.5293 - val_loss: 1.5527 - val_accuracy: 0.5684
# 	--- Save best at ep 11, val_loss: 1.5527, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 12/100 - loss: 2.1271 - accuracy: 0.5297 - val_loss: 1.5671 - val_accuracy: 0.6007
# 	-!- No improvement: 1/20
# Epoch 13/100 - loss: 2.1140 - accuracy: 0.5409 - val_loss: 1.5740 - val_accuracy: 0.5773
# 	-!- No improvement: 2/20
# Epoch 14/100 - loss: 2.1001 - accuracy: 0.5492 - val_loss: 1.5352 - val_accuracy: 0.5982
# 	--- Save best at ep 14, val_loss: 1.5352, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 15/100 - loss: 2.0916 - accuracy: 0.5505 - val_loss: 1.5458 - val_accuracy: 0.5974
# 	-!- No improvement: 1/20
# Epoch 16/100 - loss: 2.0827 - accuracy: 0.5563 - val_loss: 1.5354 - val_accuracy: 0.6057
# 	-!- No improvement: 2/20
# Epoch 17/100 - loss: 2.0683 - accuracy: 0.5608 - val_loss: 1.5201 - val_accuracy: 0.5871
# 	--- Save best at ep 17, val_loss: 1.5201, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 18/100 - loss: 2.0606 - accuracy: 0.5673 - val_loss: 1.5393 - val_accuracy: 0.6057
# 	-!- No improvement: 1/20
# Epoch 19/100 - loss: 2.0508 - accuracy: 0.5691 - val_loss: 1.5262 - val_accuracy: 0.6158
# 	-!- No improvement: 2/20
# Epoch 20/100 - loss: 2.0442 - accuracy: 0.5788 - val_loss: 1.5145 - val_accuracy: 0.6211
# 	--- Save best at ep 20, val_loss: 1.5145, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 21/100 - loss: 2.0365 - accuracy: 0.5783 - val_loss: 1.5336 - val_accuracy: 0.6147
# 	-!- No improvement: 1/20
# Epoch 22/100 - loss: 2.0292 - accuracy: 0.5799 - val_loss: 1.5094 - val_accuracy: 0.6110
# 	--- Save best at ep 22, val_loss: 1.5094, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 23/100 - loss: 2.0171 - accuracy: 0.5884 - val_loss: 1.4921 - val_accuracy: 0.6205
# 	--- Save best at ep 23, val_loss: 1.4921, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 24/100 - loss: 2.0110 - accuracy: 0.5925 - val_loss: 1.5228 - val_accuracy: 0.6018
# 	-!- No improvement: 1/20
# Epoch 25/100 - loss: 2.0027 - accuracy: 0.5932 - val_loss: 1.5031 - val_accuracy: 0.6219
# 	-!- No improvement: 2/20
# Epoch 26/100 - loss: 1.9933 - accuracy: 0.5973 - val_loss: 1.5196 - val_accuracy: 0.6144
# 	-!- No improvement: 3/20
# Epoch 27/100 - loss: 1.9850 - accuracy: 0.6009 - val_loss: 1.5209 - val_accuracy: 0.6082
# 	-!- No improvement: 4/20
# Epoch 28/100 - loss: 1.9439 - accuracy: 0.6201 - val_loss: 1.4893 - val_accuracy: 0.6395
# 	--- Save best at ep 28, val_loss: 1.4893, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 29/100 - loss: 1.9204 - accuracy: 0.6312 - val_loss: 1.4789 - val_accuracy: 0.6408
# 	--- Save best at ep 29, val_loss: 1.4789, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 30/100 - loss: 1.9160 - accuracy: 0.6325 - val_loss: 1.4748 - val_accuracy: 0.6447
# 	--- Save best at ep 30, val_loss: 1.4748, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 31/100 - loss: 1.9085 - accuracy: 0.6335 - val_loss: 1.4664 - val_accuracy: 0.6436
# 	--- Save best at ep 31, val_loss: 1.4664, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 32/100 - loss: 1.9057 - accuracy: 0.6359 - val_loss: 1.5035 - val_accuracy: 0.6403
# 	-!- No improvement: 1/20
# Epoch 33/100 - loss: 1.8882 - accuracy: 0.6436 - val_loss: 1.4758 - val_accuracy: 0.6570
# 	-!- No improvement: 2/20
# Epoch 34/100 - loss: 1.8833 - accuracy: 0.6459 - val_loss: 1.4595 - val_accuracy: 0.6498
# 	--- Save best at ep 34, val_loss: 1.4595, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 35/100 - loss: 1.8819 - accuracy: 0.6458 - val_loss: 1.4776 - val_accuracy: 0.6509
# 	-!- No improvement: 1/20
# Epoch 36/100 - loss: 1.8774 - accuracy: 0.6494 - val_loss: 1.4588 - val_accuracy: 0.6559
# 	--- Save best at ep 36, val_loss: 1.4588, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 37/100 - loss: 1.8663 - accuracy: 0.6516 - val_loss: 1.4591 - val_accuracy: 0.6486
# 	-!- No improvement: 1/20
# Epoch 38/100 - loss: 1.8646 - accuracy: 0.6557 - val_loss: 1.4781 - val_accuracy: 0.6517
# 	-!- No improvement: 2/20
# Epoch 39/100 - loss: 1.8603 - accuracy: 0.6548 - val_loss: 1.4680 - val_accuracy: 0.6565
# 	-!- No improvement: 3/20
# Epoch 40/100 - loss: 1.8487 - accuracy: 0.6620 - val_loss: 1.4506 - val_accuracy: 0.6525
# 	--- Save best at ep 40, val_loss: 1.4506, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 41/100 - loss: 1.8409 - accuracy: 0.6669 - val_loss: 1.4643 - val_accuracy: 0.6559
# 	-!- No improvement: 1/20
# Epoch 42/100 - loss: 1.8346 - accuracy: 0.6680 - val_loss: 1.4710 - val_accuracy: 0.6637
# 	-!- No improvement: 2/20
# Epoch 43/100 - loss: 1.8390 - accuracy: 0.6658 - val_loss: 1.4534 - val_accuracy: 0.6656
# 	-!- No improvement: 3/20
# Epoch 44/100 - loss: 1.8266 - accuracy: 0.6702 - val_loss: 1.4714 - val_accuracy: 0.6626
# 	-!- No improvement: 4/20
# Epoch 45/100 - loss: 1.7980 - accuracy: 0.6806 - val_loss: 1.4644 - val_accuracy: 0.6712
# 	-!- No improvement: 5/20
# Epoch 46/100 - loss: 1.7962 - accuracy: 0.6863 - val_loss: 1.4523 - val_accuracy: 0.6718
# 	-!- No improvement: 6/20
# Epoch 47/100 - loss: 1.7762 - accuracy: 0.6928 - val_loss: 1.4499 - val_accuracy: 0.6668
# 	--- Save best at ep 47, val_loss: 1.4499, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 48/100 - loss: 1.7683 - accuracy: 0.6953 - val_loss: 1.4542 - val_accuracy: 0.6690
# 	-!- No improvement: 1/20
# Epoch 49/100 - loss: 1.7663 - accuracy: 0.7000 - val_loss: 1.4554 - val_accuracy: 0.6670
# 	-!- No improvement: 2/20
# Epoch 50/100 - loss: 1.7626 - accuracy: 0.7000 - val_loss: 1.4481 - val_accuracy: 0.6734
# 	--- Save best at ep 50, val_loss: 1.4481, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth ---
# Epoch 51/100 - loss: 1.7519 - accuracy: 0.7026 - val_loss: 1.4630 - val_accuracy: 0.6654
# 	-!- No improvement: 1/20
# Epoch 52/100 - loss: 1.7487 - accuracy: 0.7077 - val_loss: 1.4585 - val_accuracy: 0.6709
# 	-!- No improvement: 2/20
# Epoch 53/100 - loss: 1.7478 - accuracy: 0.7076 - val_loss: 1.4569 - val_accuracy: 0.6682
# 	-!- No improvement: 3/20
# Epoch 54/100 - loss: 1.7399 - accuracy: 0.7086 - val_loss: 1.4724 - val_accuracy: 0.6718
# 	-!- No improvement: 4/20
# Epoch 55/100 - loss: 1.7236 - accuracy: 0.7189 - val_loss: 1.4568 - val_accuracy: 0.6773
# 	-!- No improvement: 5/20
# Epoch 56/100 - loss: 1.7182 - accuracy: 0.7198 - val_loss: 1.4598 - val_accuracy: 0.6740
# 	-!- No improvement: 6/20
# Epoch 57/100 - loss: 1.7176 - accuracy: 0.7186 - val_loss: 1.4495 - val_accuracy: 0.6787
# 	-!- No improvement: 7/20
# Epoch 58/100 - loss: 1.7029 - accuracy: 0.7227 - val_loss: 1.4626 - val_accuracy: 0.6721
# 	-!- No improvement: 8/20
# Epoch 59/100 - loss: 1.6937 - accuracy: 0.7323 - val_loss: 1.4657 - val_accuracy: 0.6793
# 	-!- No improvement: 9/20
# Epoch 60/100 - loss: 1.6917 - accuracy: 0.7309 - val_loss: 1.4694 - val_accuracy: 0.6796
# 	-!- No improvement: 10/20
# Epoch 61/100 - loss: 1.6919 - accuracy: 0.7300 - val_loss: 1.4710 - val_accuracy: 0.6748
# 	-!- No improvement: 11/20
# Epoch 62/100 - loss: 1.6777 - accuracy: 0.7356 - val_loss: 1.4599 - val_accuracy: 0.6821
# 	-!- No improvement: 12/20
# Epoch 63/100 - loss: 1.6831 - accuracy: 0.7334 - val_loss: 1.4562 - val_accuracy: 0.6815
# 	-!- No improvement: 13/20
# Epoch 64/100 - loss: 1.6734 - accuracy: 0.7406 - val_loss: 1.4624 - val_accuracy: 0.6793
# 	-!- No improvement: 14/20
# Epoch 65/100 - loss: 1.6777 - accuracy: 0.7405 - val_loss: 1.4612 - val_accuracy: 0.6785
# 	-!- No improvement: 15/20
# Epoch 66/100 - loss: 1.6726 - accuracy: 0.7399 - val_loss: 1.4627 - val_accuracy: 0.6793
# 	-!- No improvement: 16/20
# Epoch 67/100 - loss: 1.6683 - accuracy: 0.7396 - val_loss: 1.4597 - val_accuracy: 0.6793
# 	-!- No improvement: 17/20
# Epoch 68/100 - loss: 1.6759 - accuracy: 0.7435 - val_loss: 1.4611 - val_accuracy: 0.6804
# 	-!- No improvement: 18/20
# Epoch 69/100 - loss: 1.6702 - accuracy: 0.7396 - val_loss: 1.4599 - val_accuracy: 0.6804
# 	-!- No improvement: 19/20
# Epoch 70/100 - loss: 1.6680 - accuracy: 0.7415 - val_loss: 1.4619 - val_accuracy: 0.6790
# 	-!- No improvement: 20/20
# 	-_- Early stopping at ep=70
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/vgg_spatial/vgg_spatial_10042026_1053_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 47.58it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 69.13%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.618217  0.649695  0.633565   491.000000
# disgust        0.551282  0.781818  0.646617    55.000000
# fear           0.575448  0.426136  0.489663   528.000000
# happy          0.899306  0.883959  0.891566   879.000000
# sad            0.581109  0.476431  0.523589   594.000000
# surprise       0.750000  0.843750  0.794118   416.000000
# neutral        0.615287  0.771565  0.684621   626.000000
# accuracy       0.691279  0.691279  0.691279     0.691279
# macro avg      0.655807  0.690479  0.666248  3589.000000
# weighted avg   0.688364  0.691279  0.685096  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `vgg_spatial_10042026_1053_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_coyd3xzi (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_coyd3xzi (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_coyd3xzi (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_coyd3xzi (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_coyd3xzi (0.5s)
# wandb: ⣯ uploading artifact cnn_coyd3xzi (0.5s)
# wandb: ⣟ uploading artifact cnn_coyd3xzi (0.5s)
# wandb: ⡿ uploading artifact cnn_coyd3xzi (0.5s)
# wandb: ⢿ uploading artifact cnn_coyd3xzi (0.5s)
# wandb: ⣻ uploading artifact cnn_coyd3xzi (1.0s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1053_best.pth 48.9MB/101.1MB (0.5s)
# wandb: ⣽ uploading artifact cnn_coyd3xzi (1.0s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1053_best.pth 48.9MB/101.1MB (0.5s)
# wandb: ⣾ uploading artifact cnn_coyd3xzi (1.0s)
# wandb:   ↳ ⣾ vgg_spatial_10042026_1053_best.pth 48.9MB/101.1MB (0.5s)
# wandb: ⣷ uploading artifact cnn_coyd3xzi (1.0s)
# wandb:   ↳ ⣷ vgg_spatial_10042026_1053_best.pth 48.9MB/101.1MB (0.5s)
# wandb: ⣯ uploading artifact cnn_coyd3xzi (1.0s)
# wandb:   ↳ ⣯ vgg_spatial_10042026_1053_best.pth 48.9MB/101.1MB (0.5s)
# wandb: ⣟ uploading artifact cnn_coyd3xzi (1.5s)
# wandb:   ↳ ⣟ vgg_spatial_10042026_1053_best.pth 87.1MB/101.1MB (1.0s)
# wandb: ⡿ uploading artifact cnn_coyd3xzi (1.5s)
# wandb:   ↳ ⡿ vgg_spatial_10042026_1053_best.pth 87.1MB/101.1MB (1.0s)
# wandb: ⢿ uploading artifact cnn_coyd3xzi (1.5s)
# wandb:   ↳ ⢿ vgg_spatial_10042026_1053_best.pth 87.1MB/101.1MB (1.0s)
# wandb: ⣻ uploading artifact cnn_coyd3xzi (1.5s)
# wandb:   ↳ ⣻ vgg_spatial_10042026_1053_best.pth 87.1MB/101.1MB (1.0s)
# wandb: ⣽ uploading artifact cnn_coyd3xzi (1.5s)
# wandb:   ↳ ⣽ vgg_spatial_10042026_1053_best.pth 87.1MB/101.1MB (1.0s)
# wandb: ⣾ uploading artifact cnn_coyd3xzi (2.0s)
# wandb: ⣷ uploading artifact cnn_coyd3xzi (2.0s)
# wandb: ⣯ uploading artifact cnn_coyd3xzi (2.0s)
# wandb: ⣟ uploading artifact cnn_coyd3xzi (2.0s)
# wandb: ⡿ uploading artifact cnn_coyd3xzi (2.0s)
# wandb: ⢿ uploading artifact cnn_coyd3xzi (2.5s)
# wandb: ⣻ uploading artifact cnn_coyd3xzi (2.5s)
# wandb: ⣽ uploading artifact cnn_coyd3xzi (2.5s)
# wandb: ⣾ uploading artifact cnn_coyd3xzi (2.5s)
# wandb: ⣷ uploading artifact cnn_coyd3xzi (2.5s)
# wandb: ⣯ uploading history steps 68-71, summary, console lines 141-172 (0.1s)
# wandb: ⣟ uploading history steps 68-71, summary, console lines 141-172 (0.1s)
# wandb: ⡿ uploading history steps 68-71, summary, console lines 141-172 (0.1s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███
# wandb:  Learning_Rate ███████████████▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████
# wandb:     Train/Loss █▇▇▇▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▁▃▃▄▅▅▆▆▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇████████████████
# wandb:       Val/Loss █▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 70
# wandb:  Learning_Rate 1e-05
# wandb: Train/Accuracy 0.74151
# wandb:     Train/Loss 1.66802
# wandb:   Val/Accuracy 0.67902
# wandb:       Val/Loss 1.46189
# wandb:
# wandb: 🚀 View run vgg_spatial_10042026_1053 at: https://wandb.ai/phucga15062005/FER2013/runs/coyd3xzi
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260410_105307-coyd3xzi/logs
#
# 		DONE!
