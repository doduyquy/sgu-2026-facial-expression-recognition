# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "doduyquy211@gmail.com"
# !git config --global user.name "doduyquy"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "main"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 183 (delta 98), reused 130 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 209.47 KiB | 9.11 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config simple_cnn --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: doduyquy (doduyquy-sgu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run 26wnw23b (0.3s)
# wandb: ⣾ setting up run 26wnw23b (0.3s)
# wandb: ⣷ setting up run 26wnw23b (0.3s)
# wandb: ⣯ setting up run 26wnw23b (0.3s)
# wandb: ⣟ setting up run 26wnw23b (0.3s)
# wandb: ⡿ setting up run 26wnw23b (0.8s)
# wandb: ⢿ setting up run 26wnw23b (0.8s)
# wandb: ⣻ setting up run 26wnw23b (0.8s)
# wandb: ⣽ setting up run 26wnw23b (0.8s)
# wandb: ⣾ setting up run 26wnw23b (0.8s)
# wandb: ⣷ setting up run 26wnw23b (1.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260331_105200-26wnw23b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run simple_cnn_31032026_1051
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/26wnw23b
#
# --> Start training in total 101 epochs with cuda device. Start...
#
# Epoch 1/101 - loss: 1.7567 - accuracy: 0.2903 - val_loss: 1.5735 - val_accuracy: 0.3931
#
# 	--> Save best at 1 ep, val_loss: 1.5735, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 2/101 - loss: 1.6121 - accuracy: 0.3703 - val_loss: 1.4619 - val_accuracy: 0.4486
#
# 	--> Save best at 2 ep, val_loss: 1.4619, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 3/101 - loss: 1.5134 - accuracy: 0.4114 - val_loss: 1.3947 - val_accuracy: 0.4528
#
# 	--> Save best at 3 ep, val_loss: 1.3947, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 4/101 - loss: 1.4241 - accuracy: 0.4505 - val_loss: 1.3015 - val_accuracy: 0.4971
#
# 	--> Save best at 4 ep, val_loss: 1.3015, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 5/101 - loss: 1.3650 - accuracy: 0.4753 - val_loss: 1.2487 - val_accuracy: 0.5091
#
# 	--> Save best at 5 ep, val_loss: 1.2487, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 6/101 - loss: 1.3135 - accuracy: 0.4970 - val_loss: 1.1986 - val_accuracy: 0.5319
#
# 	--> Save best at 6 ep, val_loss: 1.1986, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 7/101 - loss: 1.2775 - accuracy: 0.5122 - val_loss: 1.2086 - val_accuracy: 0.5472
# -!- No improvement: 1/10
# Epoch 8/101 - loss: 1.2502 - accuracy: 0.5220 - val_loss: 1.1254 - val_accuracy: 0.5662
#
# 	--> Save best at 8 ep, val_loss: 1.1254, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 9/101 - loss: 1.2272 - accuracy: 0.5350 - val_loss: 1.1389 - val_accuracy: 0.5628
# -!- No improvement: 1/10
# Epoch 10/101 - loss: 1.2090 - accuracy: 0.5412 - val_loss: 1.0947 - val_accuracy: 0.5784
#
# 	--> Save best at 10 ep, val_loss: 1.0947, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 11/101 - loss: 1.2028 - accuracy: 0.5485 - val_loss: 1.1106 - val_accuracy: 0.5704
# -!- No improvement: 1/10
# Epoch 12/101 - loss: 1.1838 - accuracy: 0.5492 - val_loss: 1.0770 - val_accuracy: 0.5896
#
# 	--> Save best at 12 ep, val_loss: 1.0770, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 13/101 - loss: 1.1724 - accuracy: 0.5583 - val_loss: 1.0743 - val_accuracy: 0.5907
#
# 	--> Save best at 13 ep, val_loss: 1.0743, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 14/101 - loss: 1.1659 - accuracy: 0.5623 - val_loss: 1.1096 - val_accuracy: 0.5837
# -!- No improvement: 1/10
# Epoch 15/101 - loss: 1.1466 - accuracy: 0.5697 - val_loss: 1.0644 - val_accuracy: 0.5946
#
# 	--> Save best at 15 ep, val_loss: 1.0644, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 16/101 - loss: 1.1417 - accuracy: 0.5669 - val_loss: 1.0555 - val_accuracy: 0.6027
#
# 	--> Save best at 16 ep, val_loss: 1.0555, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 17/101 - loss: 1.1407 - accuracy: 0.5714 - val_loss: 1.0687 - val_accuracy: 0.5907
# -!- No improvement: 1/10
# Epoch 18/101 - loss: 1.1224 - accuracy: 0.5779 - val_loss: 1.0367 - val_accuracy: 0.6035
#
# 	--> Save best at 18 ep, val_loss: 1.0367, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 19/101 - loss: 1.1197 - accuracy: 0.5818 - val_loss: 1.0268 - val_accuracy: 0.6049
#
# 	--> Save best at 19 ep, val_loss: 1.0268, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 20/101 - loss: 1.1144 - accuracy: 0.5808 - val_loss: 1.0479 - val_accuracy: 0.5954
# -!- No improvement: 1/10
# Epoch 21/101 - loss: 1.1045 - accuracy: 0.5859 - val_loss: 1.0201 - val_accuracy: 0.6082
#
# 	--> Save best at 21 ep, val_loss: 1.0201, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 22/101 - loss: 1.1050 - accuracy: 0.5869 - val_loss: 1.0268 - val_accuracy: 0.6127
# -!- No improvement: 1/10
# Epoch 23/101 - loss: 1.0992 - accuracy: 0.5892 - val_loss: 1.0090 - val_accuracy: 0.6194
#
# 	--> Save best at 23 ep, val_loss: 1.0090, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 24/101 - loss: 1.0960 - accuracy: 0.5884 - val_loss: 1.0163 - val_accuracy: 0.6197
# -!- No improvement: 1/10
# Epoch 25/101 - loss: 1.0922 - accuracy: 0.5910 - val_loss: 1.0149 - val_accuracy: 0.6127
# -!- No improvement: 2/10
# Epoch 26/101 - loss: 1.0813 - accuracy: 0.5951 - val_loss: 1.0090 - val_accuracy: 0.6186
#
# 	--> Save best at 26 ep, val_loss: 1.0090, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 27/101 - loss: 1.0868 - accuracy: 0.5952 - val_loss: 1.0143 - val_accuracy: 0.6219
# -!- No improvement: 1/10
# Epoch 28/101 - loss: 1.0465 - accuracy: 0.6063 - val_loss: 0.9859 - val_accuracy: 0.6278
#
# 	--> Save best at 28 ep, val_loss: 0.9859, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 29/101 - loss: 1.0362 - accuracy: 0.6116 - val_loss: 0.9727 - val_accuracy: 0.6314
#
# 	--> Save best at 29 ep, val_loss: 0.9727, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 30/101 - loss: 1.0341 - accuracy: 0.6111 - val_loss: 0.9910 - val_accuracy: 0.6236
# -!- No improvement: 1/10
# Epoch 31/101 - loss: 1.0200 - accuracy: 0.6211 - val_loss: 0.9864 - val_accuracy: 0.6303
# -!- No improvement: 2/10
# Epoch 32/101 - loss: 1.0217 - accuracy: 0.6166 - val_loss: 0.9748 - val_accuracy: 0.6319
# -!- No improvement: 3/10
# Epoch 33/101 - loss: 1.0153 - accuracy: 0.6159 - val_loss: 0.9634 - val_accuracy: 0.6358
#
# 	--> Save best at 33 ep, val_loss: 0.9634, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 34/101 - loss: 1.0118 - accuracy: 0.6230 - val_loss: 0.9759 - val_accuracy: 0.6308
# -!- No improvement: 1/10
# Epoch 35/101 - loss: 1.0013 - accuracy: 0.6231 - val_loss: 0.9801 - val_accuracy: 0.6400
# -!- No improvement: 2/10
# Epoch 36/101 - loss: 1.0060 - accuracy: 0.6230 - val_loss: 0.9843 - val_accuracy: 0.6289
# -!- No improvement: 3/10
# Epoch 37/101 - loss: 1.0052 - accuracy: 0.6239 - val_loss: 0.9530 - val_accuracy: 0.6417
#
# 	--> Save best at 37 ep, val_loss: 0.9530, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 38/101 - loss: 1.0001 - accuracy: 0.6232 - val_loss: 0.9566 - val_accuracy: 0.6361
# -!- No improvement: 1/10
# Epoch 39/101 - loss: 1.0029 - accuracy: 0.6241 - val_loss: 0.9572 - val_accuracy: 0.6383
# -!- No improvement: 2/10
# Epoch 40/101 - loss: 0.9910 - accuracy: 0.6292 - val_loss: 0.9555 - val_accuracy: 0.6406
# -!- No improvement: 3/10
# Epoch 41/101 - loss: 0.9939 - accuracy: 0.6265 - val_loss: 0.9478 - val_accuracy: 0.6428
#
# 	--> Save best at 41 ep, val_loss: 0.9478, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 42/101 - loss: 0.9953 - accuracy: 0.6283 - val_loss: 0.9508 - val_accuracy: 0.6492
# -!- No improvement: 1/10
# Epoch 43/101 - loss: 0.9859 - accuracy: 0.6276 - val_loss: 0.9492 - val_accuracy: 0.6495
# -!- No improvement: 2/10
# Epoch 44/101 - loss: 0.9861 - accuracy: 0.6291 - val_loss: 0.9570 - val_accuracy: 0.6439
# -!- No improvement: 3/10
# Epoch 45/101 - loss: 0.9823 - accuracy: 0.6334 - val_loss: 0.9508 - val_accuracy: 0.6512
# -!- No improvement: 4/10
# Epoch 46/101 - loss: 0.9621 - accuracy: 0.6375 - val_loss: 0.9477 - val_accuracy: 0.6517
#
# 	--> Save best at 46 ep, val_loss: 0.9477, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 47/101 - loss: 0.9590 - accuracy: 0.6411 - val_loss: 0.9358 - val_accuracy: 0.6548
#
# 	--> Save best at 47 ep, val_loss: 0.9358, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 48/101 - loss: 0.9476 - accuracy: 0.6449 - val_loss: 0.9385 - val_accuracy: 0.6520
# -!- No improvement: 1/10
# Epoch 49/101 - loss: 0.9425 - accuracy: 0.6466 - val_loss: 0.9390 - val_accuracy: 0.6559
# -!- No improvement: 2/10
# Epoch 50/101 - loss: 0.9419 - accuracy: 0.6507 - val_loss: 0.9365 - val_accuracy: 0.6514
# -!- No improvement: 3/10
# Epoch 51/101 - loss: 0.9395 - accuracy: 0.6472 - val_loss: 0.9382 - val_accuracy: 0.6539
# -!- No improvement: 4/10
# Epoch 52/101 - loss: 0.9211 - accuracy: 0.6591 - val_loss: 0.9335 - val_accuracy: 0.6606
#
# 	--> Save best at 52 ep, val_loss: 0.9335, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 53/101 - loss: 0.9195 - accuracy: 0.6554 - val_loss: 0.9327 - val_accuracy: 0.6576
#
# 	--> Save best at 53 ep, val_loss: 0.9327, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 54/101 - loss: 0.9191 - accuracy: 0.6538 - val_loss: 0.9355 - val_accuracy: 0.6531
# -!- No improvement: 1/10
# Epoch 55/101 - loss: 0.9220 - accuracy: 0.6541 - val_loss: 0.9206 - val_accuracy: 0.6567
#
# 	--> Save best at 55 ep, val_loss: 0.9206, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
#
# Epoch 56/101 - loss: 0.9189 - accuracy: 0.6564 - val_loss: 0.9289 - val_accuracy: 0.6590
# -!- No improvement: 1/10
# Epoch 57/101 - loss: 0.9112 - accuracy: 0.6612 - val_loss: 0.9243 - val_accuracy: 0.6562
# -!- No improvement: 2/10
# Epoch 58/101 - loss: 0.9160 - accuracy: 0.6567 - val_loss: 0.9279 - val_accuracy: 0.6570
# -!- No improvement: 3/10
# Epoch 59/101 - loss: 0.9060 - accuracy: 0.6597 - val_loss: 0.9324 - val_accuracy: 0.6578
# -!- No improvement: 4/10
# Epoch 60/101 - loss: 0.9076 - accuracy: 0.6606 - val_loss: 0.9221 - val_accuracy: 0.6598
# -!- No improvement: 5/10
# Epoch 61/101 - loss: 0.9014 - accuracy: 0.6603 - val_loss: 0.9250 - val_accuracy: 0.6592
# -!- No improvement: 6/10
# Epoch 62/101 - loss: 0.8949 - accuracy: 0.6647 - val_loss: 0.9251 - val_accuracy: 0.6548
# -!- No improvement: 7/10
# Epoch 63/101 - loss: 0.8914 - accuracy: 0.6673 - val_loss: 0.9252 - val_accuracy: 0.6570
# -!- No improvement: 8/10
# Epoch 64/101 - loss: 0.8904 - accuracy: 0.6671 - val_loss: 0.9306 - val_accuracy: 0.6559
# -!- No improvement: 9/10
# Epoch 65/101 - loss: 0.8895 - accuracy: 0.6646 - val_loss: 0.9216 - val_accuracy: 0.6562
# -!- No improvement: 10/10
# 	-_- Early stopping at ep=64
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/simple_cnn/simple_cnn_31032026_1051_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 46.77it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 67.18%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.595573  0.602851  0.599190   491.000000
# disgust        0.687500  0.400000  0.505747    55.000000
# fear           0.543243  0.380682  0.447661   528.000000
# happy          0.870575  0.895336  0.882782   879.000000
# sad            0.517350  0.552189  0.534202   594.000000
# surprise       0.760664  0.771635  0.766110   416.000000
# neutral        0.624658  0.728435  0.672566   626.000000
# accuracy       0.671775  0.671775  0.671775     0.671775
# macro avg      0.657080  0.618732  0.629751  3589.000000
# weighted avg   0.667898  0.671775  0.666312  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 		DONE!
#
# wandb:
# wandb: 🚀 View run simple_cnn_31032026_1051 at: https://wandb.ai/phucga15062005/FER2013/runs/26wnw23b
# wandb: Find logs at: wandb/run-20260331_105200-26wnw23b/logs

# %% [markdown]
# # The end
# ---
