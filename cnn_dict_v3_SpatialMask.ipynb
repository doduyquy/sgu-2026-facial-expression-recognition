# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2179, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 2179 (delta 158), reused 145 (delta 118), pack-reused 1949 (from 2)
# Receiving objects: 100% (2179/2179), 6.36 MiB | 24.30 MiB/s, done.
# Resolving deltas: 100% (1540/1540), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config cnn_dictionary --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: cnn_dict_v3_SpatialMask_17042026_1140
# --> Facial Region Dictionary: ['forehead', 'eyebrows', 'eyes', 'nose', 'mouth', 'chin']
# --> [CNNDictionary V3] Spatial Prior Mask + soft grounding + visual shortcut
#
# ==================================================
# [Transfer Learning] Loading pretrained backbone...
# ==================================================
# [CNNDictionary] Backbone loaded: 296 weights
# [CNNDictionary] Backbone FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Optimizer] SAM (base=adamw, rho=0.05, adaptive=False)
# --> [Scheduler] ReduceLROnPlateau (factor=0.2, patience=7)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: khoanguyen12062005 (khoanguyen12062005-saigon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run pg4ottwm (0.2s)
# wandb: ⣽ setting up run pg4ottwm (0.2s)
# wandb: ⣾ setting up run pg4ottwm (0.2s)
# wandb: ⣷ setting up run pg4ottwm (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_114054-pg4ottwm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_dict_v3_SpatialMask_17042026_1140
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/pg4ottwm
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# --> Monitor: val_accuracy (max) for checkpoint/early-stop
# --> Early stop metric: val_loss (min)
# Epoch 1/100 - loss: 1.1566 - accuracy: 0.6927 - val_loss: 1.2660 - val_accuracy: 0.6573
# 	--- Save best at ep 1, val_accuracy: 0.6573, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# Epoch 2/100 - loss: 1.1265 - accuracy: 0.7017 - val_loss: 1.2716 - val_accuracy: 0.6590
# 	--- Save best at ep 2, val_accuracy: 0.6590, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# 	-!- No improvement: 1/25
# Epoch 3/100 - loss: 1.1226 - accuracy: 0.7040 - val_loss: 1.2457 - val_accuracy: 0.6545
# Epoch 4/100 - loss: 1.1125 - accuracy: 0.7058 - val_loss: 1.2629 - val_accuracy: 0.6620
# 	--- Save best at ep 4, val_accuracy: 0.6620, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# 	-!- No improvement: 1/25
# Epoch 5/100 - loss: 1.0986 - accuracy: 0.7081 - val_loss: 1.2532 - val_accuracy: 0.6553
# 	-!- No improvement: 2/25
# Epoch 6/100 - loss: 1.0917 - accuracy: 0.7103 - val_loss: 1.2443 - val_accuracy: 0.6562
# Epoch 7/100 - loss: 1.0985 - accuracy: 0.7055 - val_loss: 1.2381 - val_accuracy: 0.6567
# Epoch 8/100 - loss: 1.0891 - accuracy: 0.7087 - val_loss: 1.2566 - val_accuracy: 0.6598
# 	-!- No improvement: 1/25
# Epoch 9/100 - loss: 1.0873 - accuracy: 0.7075 - val_loss: 1.2861 - val_accuracy: 0.6503
# 	-!- No improvement: 2/25
# Epoch 10/100 - loss: 1.0880 - accuracy: 0.7083 - val_loss: 1.2613 - val_accuracy: 0.6651
# 	--- Save best at ep 10, val_accuracy: 0.6651, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# 	-!- No improvement: 3/25
# Epoch 11/100 - loss: 1.0864 - accuracy: 0.7086 - val_loss: 1.2590 - val_accuracy: 0.6604
# 	-!- No improvement: 4/25
# Epoch 12/100 - loss: 1.0832 - accuracy: 0.7099 - val_loss: 1.2558 - val_accuracy: 0.6565
# 	-!- No improvement: 5/25
# [CNNDictionary] All parameters UNFROZEN.
# [CNNDictionary] Param groups: backbone=185 tensors (lr=1e-05), head=38 tensors (lr=0.0002)
# --> [Optimizer] SAM (base=adamw, rho=0.05, adaptive=False)
# [Trainer] Discriminative LR built with config success.
# --> [Scheduler] ReduceLROnPlateau (factor=0.2, patience=7)
# [Trainer] Reset patience + best_score for Phase 2.
# Epoch 13/100 - loss: 1.0701 - accuracy: 0.7137 - val_loss: 1.2285 - val_accuracy: 0.6606
# 	--- Save best at ep 13, val_accuracy: 0.6606, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# Epoch 14/100 - loss: 1.0652 - accuracy: 0.7142 - val_loss: 1.2242 - val_accuracy: 0.6548
# Epoch 15/100 - loss: 1.0630 - accuracy: 0.7134 - val_loss: 1.2188 - val_accuracy: 0.6656
# 	--- Save best at ep 15, val_accuracy: 0.6656, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# Epoch 16/100 - loss: 1.0627 - accuracy: 0.7168 - val_loss: 1.2210 - val_accuracy: 0.6615
# 	-!- No improvement: 1/25
# Epoch 17/100 - loss: 1.0635 - accuracy: 0.7154 - val_loss: 1.2243 - val_accuracy: 0.6609
# 	-!- No improvement: 2/25
# Epoch 18/100 - loss: 1.0511 - accuracy: 0.7204 - val_loss: 1.2217 - val_accuracy: 0.6670
# 	--- Save best at ep 18, val_accuracy: 0.6670, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# 	-!- No improvement: 3/25
# Epoch 19/100 - loss: 1.0488 - accuracy: 0.7167 - val_loss: 1.2267 - val_accuracy: 0.6662
# 	-!- No improvement: 4/25
# Epoch 20/100 - loss: 1.0500 - accuracy: 0.7195 - val_loss: 1.2122 - val_accuracy: 0.6679
# 	--- Save best at ep 20, val_accuracy: 0.6679, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# Epoch 21/100 - loss: 1.0504 - accuracy: 0.7180 - val_loss: 1.2227 - val_accuracy: 0.6665
# 	-!- No improvement: 1/25
# Epoch 22/100 - loss: 1.0474 - accuracy: 0.7194 - val_loss: 1.2207 - val_accuracy: 0.6640
# 	-!- No improvement: 2/25
# Epoch 23/100 - loss: 1.0494 - accuracy: 0.7229 - val_loss: 1.2221 - val_accuracy: 0.6645
# 	-!- No improvement: 3/25
# Epoch 24/100 - loss: 1.0411 - accuracy: 0.7233 - val_loss: 1.2290 - val_accuracy: 0.6604
# 	-!- No improvement: 4/25
# Epoch 25/100 - loss: 1.0388 - accuracy: 0.7238 - val_loss: 1.2173 - val_accuracy: 0.6648
# 	-!- No improvement: 5/25
# Epoch 26/100 - loss: 1.0406 - accuracy: 0.7239 - val_loss: 1.2278 - val_accuracy: 0.6679
# 	-!- No improvement: 6/25
# Epoch 27/100 - loss: 1.0423 - accuracy: 0.7219 - val_loss: 1.2306 - val_accuracy: 0.6662
# 	-!- No improvement: 7/25
# Epoch 28/100 - loss: 1.0345 - accuracy: 0.7242 - val_loss: 1.2197 - val_accuracy: 0.6654
# 	-!- No improvement: 8/25
# Epoch 29/100 - loss: 1.0317 - accuracy: 0.7265 - val_loss: 1.2234 - val_accuracy: 0.6679
# 	-!- No improvement: 9/25
# Epoch 30/100 - loss: 1.0347 - accuracy: 0.7274 - val_loss: 1.2271 - val_accuracy: 0.6679
# 	-!- No improvement: 10/25
# Epoch 31/100 - loss: 1.0357 - accuracy: 0.7267 - val_loss: 1.2206 - val_accuracy: 0.6654
# 	-!- No improvement: 11/25
# Epoch 32/100 - loss: 1.0339 - accuracy: 0.7274 - val_loss: 1.2243 - val_accuracy: 0.6654
# 	-!- No improvement: 12/25
# Epoch 33/100 - loss: 1.0297 - accuracy: 0.7245 - val_loss: 1.2222 - val_accuracy: 0.6656
# 	-!- No improvement: 13/25
# Epoch 34/100 - loss: 1.0300 - accuracy: 0.7257 - val_loss: 1.2257 - val_accuracy: 0.6654
# 	-!- No improvement: 14/25
# Epoch 35/100 - loss: 1.0276 - accuracy: 0.7271 - val_loss: 1.2235 - val_accuracy: 0.6648
# 	-!- No improvement: 15/25
# Epoch 36/100 - loss: 1.0351 - accuracy: 0.7247 - val_loss: 1.2207 - val_accuracy: 0.6668
# 	-!- No improvement: 16/25
# Epoch 37/100 - loss: 1.0332 - accuracy: 0.7259 - val_loss: 1.2224 - val_accuracy: 0.6673
# 	-!- No improvement: 17/25
# Epoch 38/100 - loss: 1.0262 - accuracy: 0.7266 - val_loss: 1.2190 - val_accuracy: 0.6701
# 	--- Save best at ep 38, val_accuracy: 0.6701, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth ---
# 	-!- No improvement: 18/25
# Epoch 39/100 - loss: 1.0326 - accuracy: 0.7252 - val_loss: 1.2260 - val_accuracy: 0.6651
# 	-!- No improvement: 19/25
# Epoch 40/100 - loss: 1.0362 - accuracy: 0.7230 - val_loss: 1.2209 - val_accuracy: 0.6665
# 	-!- No improvement: 20/25
# Epoch 41/100 - loss: 1.0343 - accuracy: 0.7227 - val_loss: 1.2234 - val_accuracy: 0.6659
# 	-!- No improvement: 21/25
# Epoch 42/100 - loss: 1.0310 - accuracy: 0.7250 - val_loss: 1.2182 - val_accuracy: 0.6659
# 	-!- No improvement: 22/25
# Epoch 43/100 - loss: 1.0318 - accuracy: 0.7259 - val_loss: 1.2194 - val_accuracy: 0.6673
# 	-!- No improvement: 23/25
# Epoch 44/100 - loss: 1.0299 - accuracy: 0.7291 - val_loss: 1.2286 - val_accuracy: 0.6659
# 	-!- No improvement: 24/25
# Epoch 45/100 - loss: 1.0332 - accuracy: 0.7269 - val_loss: 1.2318 - val_accuracy: 0.6659
# 	-!- No improvement: 25/25
# 	-_- Early stopping at ep=45
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_cnn_dict_v3_SpatialMask_17042026_1140.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v3_SpatialMask_17042026_1140_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 17.45it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.71%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.627255  0.637475  0.632323   491.000000
# disgust        0.585714  0.745455  0.656000    55.000000
# fear           0.537079  0.452652  0.491264   528.000000
# happy          0.921279  0.852105  0.885343   879.000000
# sad            0.573077  0.501684  0.535009   594.000000
# surprise       0.747826  0.826923  0.785388   416.000000
# neutral        0.616368  0.769968  0.684659   626.000000
# accuracy       0.687099  0.687099  0.687099     0.687099
# macro avg      0.658371  0.683751  0.667141  3589.000000
# weighted avg   0.688473  0.687099  0.684666  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
#
# --> [Attention Heatmap] Generating region attention visualization...
#
# --> Generating attention heatmap for 4 CORRECT samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_correct.png
# --> Generating attention heatmap for 4 WRONG samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_wrong.png
# --> [Attention Heatmap] Done!
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `cnn_dict_v3_SpatialMask_17042026_1140_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣯ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣟ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⡿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⢿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (0...
# wandb: ⣻ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣻ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 42.9MB/86.3MB (0.4s)
# wandb: ⣽ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣽ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 42.9MB/86.3MB (0.4s)
# wandb: ⣾ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣾ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 42.9MB/86.3MB (0.4s)
# wandb: ⣷ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣷ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 42.9MB/86.3MB (0.4s)
# wandb: ⣯ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣯ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 42.9MB/86.3MB (0.4s)
# wandb: ⣟ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣟ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 86.3MB/86.3MB (0.9s)
# wandb: ⡿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⡿ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 86.3MB/86.3MB (0.9s)
# wandb: ⢿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⢿ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 86.3MB/86.3MB (0.9s)
# wandb: ⣻ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣻ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 86.3MB/86.3MB (0.9s)
# wandb: ⣽ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (1...
# wandb:   ↳ ⣽ cnn_dict_v3_SpatialMask_17042026_1140_best.pth 86.3MB/86.3MB (0.9s)
# wandb: ⣾ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣷ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣯ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣟ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⡿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⢿ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣻ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣽ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb: ⣾ uploading artifact cnn_dict_v3_SpatialMask_17042026_1140_pg4ottwm (2...
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ███████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▃▄▄▅▄▄▄▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇████▇█████▇▇███
# wandb:     Train/Loss █▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁
# wandb:   Val/Accuracy ▂▃▁▄▁▂▂▃▆▄▂▄▁▆▄▄▆▇▆▅▆▄▆▇▆▇▇▆▆▆▆▆▇█▆▆▆▆▇▆
# wandb:       Val/Loss ▇█▅▇▆▅▄▆▇▇▆▃▂▂▂▂▃▁▂▂▂▃▂▃▂▂▃▂▂▂▃▂▂▂▃▂▂▂▂▃
# wandb:
# wandb: Run summary:
# wandb:          Epoch 45
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.72695
# wandb:     Train/Loss 1.03317
# wandb:   Val/Accuracy 0.66592
# wandb:       Val/Loss 1.23178
# wandb:
# wandb: 🚀 View run cnn_dict_v3_SpatialMask_17042026_1140 at: https://wandb.ai/phucga15062005/FER2013/runs/pg4ottwm
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 6 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_114054-pg4ottwm/logs
#
# 		DONE!
