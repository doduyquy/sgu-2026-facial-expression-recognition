# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session (trong cái này không có chchỉnh sửa zi cả, chỉ chỉnh sửa trong code rồi púh lênđây chạy thôi@)
# Out:
# 5

# %%
import pandas as pd

train_df = pd.read_csv('/kaggle/input/datasets/doduyquynii/fer13-split/fer13-split/train.csv')

print("Số ảnh train:", len(train_df))
# Out:
# Số ảnh train: 28709

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "phucga150625@gmail.com"
# !git config --global user.name "Luphuc2005"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Phuc"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GH_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 2161, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 2161 (delta 143), reused 136 (delta 114), pack-reused 1949 (from 2)
# Receiving objects: 100% (2161/2161), 6.35 MiB | 19.47 MiB/s, done.
# Resolving deltas: 100% (1525/1525), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config vgg_scratch_48x48x3 --env kaggle
# !python -m scripts.train --config vgg_fusion_48x48x1 --env kaggle
# !python -m scripts.train --config vgg_cbam --env kaggle
# !python -m scripts.train --config cnn_dictionary --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# --> WandB Run Name: cnn_dict_v2_SAM_Agument_17042026_0945
# --> Facial Region Dictionary: ['forehead', 'eyebrows', 'eyes', 'nose', 'mouth', 'chin']
# --> [CNNDictionary V2] Free cross-attention + soft grounding + visual shortcut
#
# ==================================================
# [Transfer Learning] Loading pretrained backbone...
# ==================================================
# [CNNDictionary] Backbone loaded: 296 weights
# [CNNDictionary] Backbone FROZEN.
# ==================================================
#
# --> Using Class Weights to handle imbalance...
# --> [Optimizer] SAM (base=adamw, rho=0.02, adaptive=False)
# --> [Scheduler] ReduceLROnPlateau (factor=0.2, patience=7)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run yvvxw7rj (0.3s)
# wandb: ⣷ setting up run yvvxw7rj (0.3s)
# wandb: ⣯ setting up run yvvxw7rj (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260417_094524-yvvxw7rj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cnn_dict_v2_SAM_Agument_17042026_0945
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/yvvxw7rj
#
# --> Start training in total 100 epochs with cuda device. Start...
#
# --> Monitor: val_accuracy (max) for checkpoint/early-stop
# --> Early stop metric: val_loss (min)
# Epoch 1/100 - loss: 1.3738 - accuracy: 0.6917 - val_loss: 1.4531 - val_accuracy: 0.6570
# 	--- Save best at ep 1, val_accuracy: 0.6570, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# Epoch 2/100 - loss: 1.3448 - accuracy: 0.7003 - val_loss: 1.4525 - val_accuracy: 0.6537
# Epoch 3/100 - loss: 1.3410 - accuracy: 0.7039 - val_loss: 1.4313 - val_accuracy: 0.6534
# Epoch 4/100 - loss: 1.3349 - accuracy: 0.7041 - val_loss: 1.4556 - val_accuracy: 0.6615
# 	--- Save best at ep 4, val_accuracy: 0.6615, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# 	-!- No improvement: 1/25
# Epoch 5/100 - loss: 1.3266 - accuracy: 0.7074 - val_loss: 1.4419 - val_accuracy: 0.6559
# 	-!- No improvement: 2/25
# Epoch 6/100 - loss: 1.3220 - accuracy: 0.7077 - val_loss: 1.4371 - val_accuracy: 0.6559
# 	-!- No improvement: 3/25
# Epoch 7/100 - loss: 1.3228 - accuracy: 0.7076 - val_loss: 1.4352 - val_accuracy: 0.6573
# 	-!- No improvement: 4/25
# Epoch 8/100 - loss: 1.3150 - accuracy: 0.7086 - val_loss: 1.4439 - val_accuracy: 0.6604
# 	-!- No improvement: 5/25
# Epoch 9/100 - loss: 1.3176 - accuracy: 0.7067 - val_loss: 1.4795 - val_accuracy: 0.6467
# 	-!- No improvement: 6/25
# Epoch 10/100 - loss: 1.3128 - accuracy: 0.7067 - val_loss: 1.4521 - val_accuracy: 0.6631
# 	--- Save best at ep 10, val_accuracy: 0.6631, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# 	-!- No improvement: 7/25
# Epoch 11/100 - loss: 1.3129 - accuracy: 0.7065 - val_loss: 1.4525 - val_accuracy: 0.6595
# 	-!- No improvement: 8/25
# Epoch 12/100 - loss: 1.2973 - accuracy: 0.7119 - val_loss: 1.4374 - val_accuracy: 0.6606
# 	-!- No improvement: 9/25
# [CNNDictionary] All parameters UNFROZEN.
# [CNNDictionary] Param groups: backbone=185 tensors (lr=1e-05), head=39 tensors (lr=0.0002)
# --> [Optimizer] SAM (base=adamw, rho=0.02, adaptive=False)
# [Trainer] Discriminative LR built with config success.
# --> [Scheduler] ReduceLROnPlateau (factor=0.2, patience=7)
# [Trainer] Reset patience + best_score for Phase 2.
# Epoch 13/100 - loss: 1.2951 - accuracy: 0.7132 - val_loss: 1.4296 - val_accuracy: 0.6612
# 	--- Save best at ep 13, val_accuracy: 0.6612, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# Epoch 14/100 - loss: 1.2908 - accuracy: 0.7145 - val_loss: 1.4262 - val_accuracy: 0.6581
# Epoch 15/100 - loss: 1.2864 - accuracy: 0.7140 - val_loss: 1.4213 - val_accuracy: 0.6687
# 	--- Save best at ep 15, val_accuracy: 0.6687, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# Epoch 16/100 - loss: 1.2867 - accuracy: 0.7177 - val_loss: 1.4240 - val_accuracy: 0.6654
# 	-!- No improvement: 1/25
# Epoch 17/100 - loss: 1.2899 - accuracy: 0.7168 - val_loss: 1.4274 - val_accuracy: 0.6623
# 	-!- No improvement: 2/25
# Epoch 18/100 - loss: 1.2759 - accuracy: 0.7217 - val_loss: 1.4228 - val_accuracy: 0.6665
# 	-!- No improvement: 3/25
# Epoch 19/100 - loss: 1.2753 - accuracy: 0.7190 - val_loss: 1.4303 - val_accuracy: 0.6684
# 	-!- No improvement: 4/25
# Epoch 20/100 - loss: 1.2772 - accuracy: 0.7212 - val_loss: 1.4183 - val_accuracy: 0.6679
# Epoch 21/100 - loss: 1.2765 - accuracy: 0.7203 - val_loss: 1.4244 - val_accuracy: 0.6654
# 	-!- No improvement: 1/25
# Epoch 22/100 - loss: 1.2736 - accuracy: 0.7209 - val_loss: 1.4246 - val_accuracy: 0.6645
# 	-!- No improvement: 2/25
# Epoch 23/100 - loss: 1.2748 - accuracy: 0.7224 - val_loss: 1.4264 - val_accuracy: 0.6634
# 	-!- No improvement: 3/25
# Epoch 24/100 - loss: 1.2680 - accuracy: 0.7246 - val_loss: 1.4324 - val_accuracy: 0.6631
# 	-!- No improvement: 4/25
# Epoch 25/100 - loss: 1.2673 - accuracy: 0.7250 - val_loss: 1.4196 - val_accuracy: 0.6676
# 	-!- No improvement: 5/25
# Epoch 26/100 - loss: 1.2674 - accuracy: 0.7252 - val_loss: 1.4297 - val_accuracy: 0.6684
# 	-!- No improvement: 6/25
# Epoch 27/100 - loss: 1.2695 - accuracy: 0.7233 - val_loss: 1.4322 - val_accuracy: 0.6679
# 	-!- No improvement: 7/25
# Epoch 28/100 - loss: 1.2619 - accuracy: 0.7264 - val_loss: 1.4211 - val_accuracy: 0.6715
# 	--- Save best at ep 28, val_accuracy: 0.6715, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth ---
# 	-!- No improvement: 8/25
# Epoch 29/100 - loss: 1.2599 - accuracy: 0.7265 - val_loss: 1.4251 - val_accuracy: 0.6698
# 	-!- No improvement: 9/25
# Epoch 30/100 - loss: 1.2612 - accuracy: 0.7272 - val_loss: 1.4296 - val_accuracy: 0.6687
# 	-!- No improvement: 10/25
# Epoch 31/100 - loss: 1.2619 - accuracy: 0.7278 - val_loss: 1.4257 - val_accuracy: 0.6662
# 	-!- No improvement: 11/25
# Epoch 32/100 - loss: 1.2603 - accuracy: 0.7287 - val_loss: 1.4288 - val_accuracy: 0.6704
# 	-!- No improvement: 12/25
# Epoch 33/100 - loss: 1.2591 - accuracy: 0.7255 - val_loss: 1.4261 - val_accuracy: 0.6682
# 	-!- No improvement: 13/25
# Epoch 34/100 - loss: 1.2580 - accuracy: 0.7281 - val_loss: 1.4262 - val_accuracy: 0.6690
# 	-!- No improvement: 14/25
# Epoch 35/100 - loss: 1.2547 - accuracy: 0.7286 - val_loss: 1.4260 - val_accuracy: 0.6640
# 	-!- No improvement: 15/25
# Epoch 36/100 - loss: 1.2623 - accuracy: 0.7242 - val_loss: 1.4239 - val_accuracy: 0.6670
# 	-!- No improvement: 16/25
# Epoch 37/100 - loss: 1.2598 - accuracy: 0.7268 - val_loss: 1.4252 - val_accuracy: 0.6676
# 	-!- No improvement: 17/25
# Epoch 38/100 - loss: 1.2550 - accuracy: 0.7266 - val_loss: 1.4229 - val_accuracy: 0.6698
# 	-!- No improvement: 18/25
# Epoch 39/100 - loss: 1.2592 - accuracy: 0.7264 - val_loss: 1.4284 - val_accuracy: 0.6698
# 	-!- No improvement: 19/25
# Epoch 40/100 - loss: 1.2633 - accuracy: 0.7229 - val_loss: 1.4247 - val_accuracy: 0.6670
# 	-!- No improvement: 20/25
# Epoch 41/100 - loss: 1.2620 - accuracy: 0.7247 - val_loss: 1.4261 - val_accuracy: 0.6682
# 	-!- No improvement: 21/25
# Epoch 42/100 - loss: 1.2580 - accuracy: 0.7272 - val_loss: 1.4217 - val_accuracy: 0.6673
# 	-!- No improvement: 22/25
# Epoch 43/100 - loss: 1.2599 - accuracy: 0.7259 - val_loss: 1.4227 - val_accuracy: 0.6668
# 	-!- No improvement: 23/25
# Epoch 44/100 - loss: 1.2560 - accuracy: 0.7290 - val_loss: 1.4299 - val_accuracy: 0.6659
# 	-!- No improvement: 24/25
# Epoch 45/100 - loss: 1.2606 - accuracy: 0.7263 - val_loss: 1.4325 - val_accuracy: 0.6665
# 	-!- No improvement: 25/25
# 	-_- Early stopping at ep=45
# --> Saved training curves to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/training_curves_cnn_dict_v2_SAM_Agument_17042026_0945.png
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/cnn_dictionary/cnn_dict_v2_SAM_Agument_17042026_0945_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:03<00:00, 17.88it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 68.21%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.618952  0.625255  0.622087   491.000000
# disgust        0.615385  0.727273  0.666667    55.000000
# fear           0.540741  0.414773  0.469453   528.000000
# happy          0.923267  0.848692  0.884410   879.000000
# sad            0.558140  0.525253  0.541197   594.000000
# surprise       0.733753  0.841346  0.783875   416.000000
# neutral        0.608472  0.757188  0.674733   626.000000
# accuracy       0.682084  0.682084  0.682084     0.682084
# macro avg      0.656958  0.677111  0.663203  3589.000000
# weighted avg   0.683336  0.682084  0.679110  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
#
# --> [Attention Heatmap] Generating region attention visualization...
#
# --> Generating attention heatmap for 4 CORRECT samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_correct.png
# --> Generating attention heatmap for 4 WRONG samples...
# --> Saved attention heatmap to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/attention_heatmap_wrong.png
# --> [Attention Heatmap] Done!
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `cnn_dict_v2_SAM_Agument_17042026_0945_best.pth` to cloud successfully!
# wandb: ⢿ uploading media/images/Evaluation/Wrong_Samples_47_afa13396d8fd714f5...
# wandb: ⢿ uploading media/images/Evaluation/Attention_Heatmap_Correct_48_b7bc4...
# wandb: ⢿ uploading media/images/Evaluation/Attention_Heatmap_Wrong_49_2542deb...
# wandb: ⢿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading media/images/Evaluation/Wrong_Samples_47_afa13396d8fd714f5...
# wandb: ⣻ uploading media/images/Evaluation/Attention_Heatmap_Correct_48_b7bc4...
# wandb: ⣻ uploading media/images/Evaluation/Attention_Heatmap_Wrong_49_2542deb...
# wandb: ⣻ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading media/images/Evaluation/Wrong_Samples_47_afa13396d8fd714f5...
# wandb: ⣽ uploading media/images/Evaluation/Attention_Heatmap_Correct_48_b7bc4...
# wandb: ⣽ uploading media/images/Evaluation/Attention_Heatmap_Wrong_49_2542deb...
# wandb: ⣽ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading media/images/Evaluation/Wrong_Samples_47_afa13396d8fd714f5...
# wandb: ⣾ uploading media/images/Evaluation/Attention_Heatmap_Correct_48_b7bc4...
# wandb: ⣾ uploading media/images/Evaluation/Attention_Heatmap_Wrong_49_2542deb...
# wandb: ⣾ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣯ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣟ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⡿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⢿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (0...
# wandb: ⣻ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣻ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 51.0MB/86.3MB (0.5s)
# wandb: ⣽ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣽ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 51.0MB/86.3MB (0.5s)
# wandb: ⣾ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣾ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 51.0MB/86.3MB (0.5s)
# wandb: ⣷ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣷ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 51.0MB/86.3MB (0.5s)
# wandb: ⣯ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣯ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 51.0MB/86.3MB (0.5s)
# wandb: ⣟ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣟ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 86.3MB/86.3MB (1.0s)
# wandb: ⡿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⡿ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 86.3MB/86.3MB (1.0s)
# wandb: ⢿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⢿ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 86.3MB/86.3MB (1.0s)
# wandb: ⣻ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣻ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 86.3MB/86.3MB (1.0s)
# wandb: ⣽ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (1...
# wandb:   ↳ ⣽ cnn_dict_v2_SAM_Agument_17042026_0945_best.pth 86.3MB/86.3MB (1.0s)
# wandb: ⣾ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (2...
# wandb: ⣷ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (2...
# wandb: ⣯ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (2...
# wandb: ⣟ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (2...
# wandb: ⡿ uploading artifact cnn_dict_v2_SAM_Agument_17042026_0945_yvvxw7rj (2...
# wandb: ⢿ uploading output.log 8.8KB/8.8KB (0.0s)
# wandb: ⢿ uploading wandb-summary.json 1.8KB/1.8KB (0.0s)
# wandb: ⢿ uploading config.yaml 4.0KB/4.0KB (0.0s)
# wandb: ⣻ uploading output.log 8.8KB/8.8KB (0.0s)
# wandb: ⣻ uploading wandb-summary.json 1.8KB/1.8KB (0.0s)
# wandb: ⣻ uploading config.yaml 4.0KB/4.0KB (0.0s)
# wandb: ⣽ uploading output.log 8.8KB/8.8KB (0.0s)
# wandb: ⣽ uploading wandb-summary.json 1.8KB/1.8KB (0.0s)
# wandb: ⣽ uploading config.yaml 4.0KB/4.0KB (0.0s)
# wandb: ⣾ uploading output.log 8.8KB/8.8KB (0.0s)
# wandb: ⣾ uploading wandb-summary.json 1.8KB/1.8KB (0.0s)
# wandb: ⣾ uploading config.yaml 4.0KB/4.0KB (0.0s)
# wandb: ⣷ uploading output.log 8.8KB/8.8KB (0.0s)
# wandb: ⣷ uploading wandb-summary.json 1.8KB/1.8KB (0.0s)
# wandb: ⣷ uploading config.yaml 4.0KB/4.0KB (0.0s)
# wandb: ⣯ uploading data (0.4s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:  Learning_Rate ██████████▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▇▆▇▇▇▇▇█████▇█████▇▇█▇█
# wandb:     Train/Loss █▆▆▆▅▅▅▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁
# wandb:   Val/Accuracy ▂▁▁▄▂▂▃▄▅▃▄▄▃▇▆▄▇▇▆▅▅▅▆▇█▇▇▆█▇▇▅▆▇▇▆▇▆▆▆
# wandb:       Val/Loss █▇▃█▅▅▄▆▇▇▅▃▂▂▂▃▃▁▂▂▃▄▁▃▂▂▃▂▃▂▂▂▂▂▃▂▂▂▂▄
# wandb:
# wandb: Run summary:
# wandb:          Epoch 45
# wandb:  Learning_Rate 0.0
# wandb: Train/Accuracy 0.72632
# wandb:     Train/Loss 1.26062
# wandb:   Val/Accuracy 0.66648
# wandb:       Val/Loss 1.43252
# wandb:
# wandb: 🚀 View run cnn_dict_v2_SAM_Agument_17042026_0945 at: https://wandb.ai/phucga15062005/FER2013/runs/yvvxw7rj
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 6 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260417_094524-yvvxw7rj/logs
#
# 		DONE!
