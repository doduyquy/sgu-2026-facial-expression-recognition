# %% [markdown]
# # **FACIAL EXPRESSION RECOGNITION**

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:SpringGreen; font-weight:bold;">Running in Kaggle</span>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        count += 1

print(count)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 3

# %% [markdown]
# # Set up to clone repo and dataset

# %%
# !pip install wandb -q

# ...
from kaggle_secrets import UserSecretsClient
import wandb    

# !git config --global user.email "nhuutri1311@gmail.com"
# !git config --global user.name "Irthn1311"

GITHUB_USERNAME    = "doduyquy"
GITHUB_REPO_NAME   = "sgu-2026-facial-expression-recognition"
GITHUB_REPO_BRANCH = "Tree"

user_secrets = UserSecretsClient()

# Get GITHUB_TOKEN from Secrets
GITHUB_TOKEN = user_secrets.get_secret("GITHUB_TOKEN")

# Get WANDB_API_KEY from Secrets
WANDB_API_KEY = user_secrets.get_secret("WANDB_API_KEY")
os.environ["WANDB_API_KEY"] = WANDB_API_KEY  # <--- TRUYỀN CHO BASH!

# check if secret ok?
if GITHUB_TOKEN and WANDB_API_KEY is not None:
    print("Secret ok")

# ---
# Định dạng URL chuẩn để không bị lỗi 403
# Cách này dùng Token làm password trực tiếp trong URL
REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO_NAME}.git"

WORK_DIR = "/kaggle/working"
REPO_PATH = os.path.join(WORK_DIR, GITHUB_REPO_NAME)

# move current working dir to WORK_DIR
os.chdir(WORK_DIR)
# clone
if not os.path.exists(REPO_PATH):
    print("--- Đang clone repo mới ---")
    # !git clone -b {GITHUB_REPO_BRANCH} {REPO_URL}
else:
    print("--- Repo đã có, đang cập nhật bản mới nhất ---")
    # %cd {GITHUB_REPO_NAME}
    # !git pull origin {GITHUB_REPO_BRANCH}

# ---
os.chdir(f"/kaggle/working/{GITHUB_REPO_NAME}")
print("Repo ready:", os.getcwd())


# ---
CURRENT_WORKING_DIR = os.getcwd()

print()
print("Current working dir:",CURRENT_WORKING_DIR)
# Out:
# Secret ok
# --- Đang clone repo mới ---
# Cloning into 'sgu-2026-facial-expression-recognition'...
# remote: Enumerating objects: 544, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 544 (delta 127), reused 113 (delta 53), pack-reused 329 (from 1)
# Receiving objects: 100% (544/544), 3.54 MiB | 20.61 MiB/s, done.
# Resolving deltas: 100% (315/315), done.
# Repo ready: /kaggle/working/sgu-2026-facial-expression-recognition
#
# Current working dir: /kaggle/working/sgu-2026-facial-expression-recognition

# %% [markdown]
# # Run file

# %%
# /kaggle/input/datasets/doduyquynii/fer13-split
# /kaggle/input/datasets/doduyquynii/fer13-split/train.csv
# !python -m scripts.train --config efficientnet --env kaggle
# Out:
# 		--> In main <--
# --- Use device: cuda
# [OK] Seed set to 42
# emotion
# 0    3995
# 1     436
# 2    4097
# 3    7215
# 4    4830
# 5    3171
# 6    4965
# Name: count, dtype: int64
# tensor([0.0686, 0.6283, 0.0669, 0.0380, 0.0567, 0.0864, 0.0552],
#        device='cuda:0')
# --> [Scheduler] ReduceLROnPlateau (factor=0.5, patience=3)
#
# --> Train on 28709 samples, validate on 3589 samples
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: irthn1311 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/sgu-2026-facial-expression-recognition/wandb/run-20260404_151904-ebuebtwu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run efficientnet_fer2013_04042026_1518
# wandb: ⭐️ View project at https://wandb.ai/phucga15062005/FER2013
# wandb: 🚀 View run at https://wandb.ai/phucga15062005/FER2013/runs/ebuebtwu
#
# --> Start training in total 50 epochs with cuda device. Start...
#
# Epoch 1/50 - loss: 1.8595 - accuracy: 0.2402 - val_loss: 1.7508 - val_accuracy: 0.3399
# 	--- Save best at ep 1, val_loss: 1.7508, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 2/50 - loss: 1.6429 - accuracy: 0.3767 - val_loss: 1.5027 - val_accuracy: 0.4185
# 	--- Save best at ep 2, val_loss: 1.5027, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 3/50 - loss: 1.5116 - accuracy: 0.4257 - val_loss: 1.6137 - val_accuracy: 0.3951
# 	-!- No improvement: 1/10
# Epoch 4/50 - loss: 1.4285 - accuracy: 0.4568 - val_loss: 1.3707 - val_accuracy: 0.4862
# 	--- Save best at ep 4, val_loss: 1.3707, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 5/50 - loss: 1.3736 - accuracy: 0.4791 - val_loss: 1.3418 - val_accuracy: 0.5152
# 	--- Save best at ep 5, val_loss: 1.3418, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 6/50 - loss: 1.3319 - accuracy: 0.4987 - val_loss: 1.2710 - val_accuracy: 0.5208
# 	--- Save best at ep 6, val_loss: 1.2710, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 7/50 - loss: 1.2975 - accuracy: 0.5105 - val_loss: 1.2799 - val_accuracy: 0.5339
# 	-!- No improvement: 1/10
# Epoch 8/50 - loss: 1.2589 - accuracy: 0.5224 - val_loss: 1.2240 - val_accuracy: 0.5511
# 	--- Save best at ep 8, val_loss: 1.2240, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 9/50 - loss: 1.2536 - accuracy: 0.5236 - val_loss: 1.2333 - val_accuracy: 0.5536
# 	-!- No improvement: 1/10
# Epoch 10/50 - loss: 1.2077 - accuracy: 0.5381 - val_loss: 1.2106 - val_accuracy: 0.5536
# 	--- Save best at ep 10, val_loss: 1.2106, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 11/50 - loss: 1.2056 - accuracy: 0.5424 - val_loss: 1.2029 - val_accuracy: 0.5656
# 	--- Save best at ep 11, val_loss: 1.2029, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 12/50 - loss: 1.1871 - accuracy: 0.5502 - val_loss: 1.2187 - val_accuracy: 0.5639
# 	-!- No improvement: 1/10
# Epoch 13/50 - loss: 1.1678 - accuracy: 0.5557 - val_loss: 1.1831 - val_accuracy: 0.5573
# 	--- Save best at ep 13, val_loss: 1.1831, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 14/50 - loss: 1.1591 - accuracy: 0.5549 - val_loss: 1.1409 - val_accuracy: 0.5706
# 	--- Save best at ep 14, val_loss: 1.1409, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 15/50 - loss: 1.1424 - accuracy: 0.5624 - val_loss: 1.1719 - val_accuracy: 0.5681
# 	-!- No improvement: 1/10
# Epoch 16/50 - loss: 1.1288 - accuracy: 0.5677 - val_loss: 1.1326 - val_accuracy: 0.5745
# 	--- Save best at ep 16, val_loss: 1.1326, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 17/50 - loss: 1.1268 - accuracy: 0.5682 - val_loss: 1.2336 - val_accuracy: 0.5726
# 	-!- No improvement: 1/10
# Epoch 18/50 - loss: 1.1055 - accuracy: 0.5729 - val_loss: 1.1718 - val_accuracy: 0.5743
# 	-!- No improvement: 2/10
# Epoch 19/50 - loss: 1.1012 - accuracy: 0.5741 - val_loss: 1.1810 - val_accuracy: 0.5893
# 	-!- No improvement: 3/10
# Epoch 20/50 - loss: 1.0823 - accuracy: 0.5879 - val_loss: 1.1219 - val_accuracy: 0.5935
# 	--- Save best at ep 20, val_loss: 1.1219, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 21/50 - loss: 1.0812 - accuracy: 0.5817 - val_loss: 1.1006 - val_accuracy: 0.5918
# 	--- Save best at ep 21, val_loss: 1.1006, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 22/50 - loss: 1.0764 - accuracy: 0.5864 - val_loss: 1.1103 - val_accuracy: 0.5901
# 	-!- No improvement: 1/10
# Epoch 23/50 - loss: 1.0648 - accuracy: 0.5872 - val_loss: 1.1031 - val_accuracy: 0.5974
# 	-!- No improvement: 2/10
# Epoch 24/50 - loss: 1.0779 - accuracy: 0.5859 - val_loss: 1.2281 - val_accuracy: 0.5963
# 	-!- No improvement: 3/10
# Epoch 25/50 - loss: 1.0492 - accuracy: 0.5926 - val_loss: 1.2274 - val_accuracy: 0.5982
# 	-!- No improvement: 4/10
# Epoch 26/50 - loss: 1.0046 - accuracy: 0.6097 - val_loss: 1.0810 - val_accuracy: 0.6186
# 	--- Save best at ep 26, val_loss: 1.0810, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 27/50 - loss: 0.9778 - accuracy: 0.6165 - val_loss: 1.0899 - val_accuracy: 0.6208
# 	-!- No improvement: 1/10
# Epoch 28/50 - loss: 0.9697 - accuracy: 0.6186 - val_loss: 1.0877 - val_accuracy: 0.6225
# 	-!- No improvement: 2/10
# Epoch 29/50 - loss: 0.9567 - accuracy: 0.6218 - val_loss: 1.1127 - val_accuracy: 0.6205
# 	-!- No improvement: 3/10
# Epoch 30/50 - loss: 0.9612 - accuracy: 0.6235 - val_loss: 1.1240 - val_accuracy: 0.6255
# 	-!- No improvement: 4/10
# Epoch 31/50 - loss: 0.9283 - accuracy: 0.6321 - val_loss: 1.0933 - val_accuracy: 0.6333
# 	-!- No improvement: 5/10
# Epoch 32/50 - loss: 0.9097 - accuracy: 0.6387 - val_loss: 1.0903 - val_accuracy: 0.6291
# 	-!- No improvement: 6/10
# Epoch 33/50 - loss: 0.9195 - accuracy: 0.6338 - val_loss: 1.0513 - val_accuracy: 0.6255
# 	--- Save best at ep 33, val_loss: 1.0513, path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth ---
# Epoch 34/50 - loss: 0.9103 - accuracy: 0.6395 - val_loss: 1.0860 - val_accuracy: 0.6308
# 	-!- No improvement: 1/10
# Epoch 35/50 - loss: 0.9070 - accuracy: 0.6389 - val_loss: 1.0637 - val_accuracy: 0.6280
# 	-!- No improvement: 2/10
# Epoch 36/50 - loss: 0.8887 - accuracy: 0.6435 - val_loss: 1.0912 - val_accuracy: 0.6294
# 	-!- No improvement: 3/10
# Epoch 37/50 - loss: 0.8974 - accuracy: 0.6435 - val_loss: 1.1051 - val_accuracy: 0.6275
# 	-!- No improvement: 4/10
# Epoch 38/50 - loss: 0.8840 - accuracy: 0.6486 - val_loss: 1.0783 - val_accuracy: 0.6333
# 	-!- No improvement: 5/10
# Epoch 39/50 - loss: 0.8668 - accuracy: 0.6536 - val_loss: 1.0828 - val_accuracy: 0.6428
# 	-!- No improvement: 6/10
# Epoch 40/50 - loss: 0.8644 - accuracy: 0.6552 - val_loss: 1.0905 - val_accuracy: 0.6347
# 	-!- No improvement: 7/10
# Epoch 41/50 - loss: 0.8667 - accuracy: 0.6543 - val_loss: 1.0954 - val_accuracy: 0.6375
# 	-!- No improvement: 8/10
# Epoch 42/50 - loss: 0.8504 - accuracy: 0.6603 - val_loss: 1.0692 - val_accuracy: 0.6342
# 	-!- No improvement: 9/10
# Epoch 43/50 - loss: 0.8555 - accuracy: 0.6581 - val_loss: 1.0918 - val_accuracy: 0.6361
# 	-!- No improvement: 10/10
# 	-_- Early stopping at ep=43
#
# ===================================================
# Evaluate in test set
# ===================================================
# --> Loading ckpt from /kaggle/working/sgu-2026-facial-expression-recognition/outputs/checkpoints/efficientnet_fer2013/efficientnet_fer2013_04042026_1518_best.pth
# Evaluatoin save path: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
# Evaluate test set...: 100%|█████████████████████| 57/57 [00:01<00:00, 44.64it/s]
#
# Pushing to WandB & Dashboard...
# Compute metrics and confusion matrix...
# --> Accuracy: 64.17%
# --> Report:
#                precision    recall  f1-score      support
# angry          0.546992  0.592668  0.568915   491.000000
# disgust        0.432692  0.818182  0.566038    55.000000
# fear           0.513812  0.352273  0.417978   528.000000
# happy          0.887393  0.824801  0.854953   879.000000
# sad            0.529058  0.444444  0.483074   594.000000
# surprise       0.677866  0.824519  0.744035   416.000000
# neutral        0.583875  0.717252  0.643728   626.000000
# accuracy       0.641683  0.641683  0.641683     0.641683
# macro avg      0.595956  0.653449  0.611246  3589.000000
# weighted avg   0.642363  0.641683  0.635860  3589.000000
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/correct_preds.png
# --> Saved prediction grid to /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures/wrong_preds.png
# Done! Save file at: /kaggle/working/sgu-2026-facial-expression-recognition/outputs/figures
#
# 	--> Uploading best ckpt to WandB, please wait...
# 	--> [WandB] Send File `efficientnet_fer2013_04042026_1518_best.pth` to cloud successfully!
# wandb: ⢿ uploading artifact cnn_ebuebtwu (0.0s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact cnn_ebuebtwu (0.0s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact cnn_ebuebtwu (0.0s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact cnn_ebuebtwu (0.0s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading artifact cnn_ebuebtwu (0.5s)
# wandb:   ↳ ⣷ efficientnet_fer2013_04042026_1518_best.pth 3.0MB/4.5MB (0.0s)
# wandb: ⣯ uploading artifact cnn_ebuebtwu (0.5s)
# wandb:   ↳ ⣯ efficientnet_fer2013_04042026_1518_best.pth 3.0MB/4.5MB (0.0s)
# wandb: ⣟ uploading artifact cnn_ebuebtwu (0.5s)
# wandb:   ↳ ⣟ efficientnet_fer2013_04042026_1518_best.pth 3.0MB/4.5MB (0.0s)
# wandb: ⡿ uploading artifact cnn_ebuebtwu (0.5s)
# wandb:   ↳ ⡿ efficientnet_fer2013_04042026_1518_best.pth 3.0MB/4.5MB (0.0s)
# wandb: ⢿ uploading artifact cnn_ebuebtwu (0.5s)
# wandb:   ↳ ⢿ efficientnet_fer2013_04042026_1518_best.pth 3.0MB/4.5MB (0.0s)
# wandb: ⣻ uploading artifact cnn_ebuebtwu (1.0s)
# wandb: ⣽ uploading artifact cnn_ebuebtwu (1.0s)
# wandb: ⣾ uploading artifact cnn_ebuebtwu (1.0s)
# wandb: ⣷ uploading artifact cnn_ebuebtwu (1.0s)
# wandb: ⣯ uploading artifact cnn_ebuebtwu (1.0s)
# wandb:
# wandb: Run history:
# wandb:          Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██
# wandb:  Learning_Rate ████████████████████████▄▄▄▄▂▂▂▂▂▂▂▁▁▁▁▁
# wandb: Train/Accuracy ▁▃▄▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇████████████
# wandb:     Train/Loss █▆▆▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:   Val/Accuracy ▁▃▂▄▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████
# wandb:       Val/Loss █▆▇▄▄▃▃▃▃▃▃▃▂▂▂▃▂▂▂▁▂▂▃▃▁▁▂▂▁▁▁▁▁▁▂▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:          Epoch 43
# wandb:  Learning_Rate 6e-05
# wandb: Train/Accuracy 0.65809
# wandb:     Train/Loss 0.85552
# wandb:   Val/Accuracy 0.63611
# wandb:       Val/Loss 1.09181
# wandb:
# wandb: 🚀 View run efficientnet_fer2013_04042026_1518 at: https://wandb.ai/phucga15062005/FER2013/runs/ebuebtwu
# wandb: ⭐️ View project at: https://wandb.ai/phucga15062005/FER2013
# wandb: Synced 5 W&B file(s), 3 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260404_151904-ebuebtwu/logs
#
# 		DONE!

# %% [markdown]
# # The end
# ---
